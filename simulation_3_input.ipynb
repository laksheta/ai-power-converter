# %% [markdown]
# # Spesifikasi

# %% [markdown]
# - V<sub>in</sub> = 48V
# - V<sub>out</sub> = 12V
# - P<sub>o</sub> = 100W
# - &#916;V<sub>o</sub> &#8804; 1%
# - &#916;I<sub>L</sub> &#8804; 10%
# - f<sub>sw</sub> = 20e3
# - Mosfet: IRFB4310PbF, Infineon

# %% [markdown]
# # Plecs

# %%
import xmlrpc.client as xml
import os
import numpy as np
import itertools
import csv

# %%
model = 'buck'
file_type = '.plecs'
V_in = 48
V_out = 12
f_sw = 20e3

# %%
plecs = xml.Server("http://localhost:1080/RPC2").plecs

# %%
# plecs.load(r"D:\Krishna\ai-power-converter\buck.plecs")
plecs.load(r"E:\ai-power-converter\buck.plecs")
# Out:
# 0

# %%
plecs.get(model+'/L1')
# Out:
# {'CommentStatus': 'Active',
#  'L': '0.002',
#  'Name': 'L1',
#  'Type': 'Inductor',
#  'i_init': '0'}

# %%
plecs.get(model+'/C')
# Out:
# {'C': '0.0002',
#  'CommentStatus': 'Active',
#  'Name': 'C',
#  'Type': 'Capacitor',
#  'v_init': '0'}

# %%
plecs.get(model+'/Symmetrical PWM1')
# Out:
# {'CommentStatus': 'Active',
#  'Name': 'Symmetrical PWM1',
#  'Type': 'Subsystem',
#  'carrier_limits': '[0 1]',
#  'carrier_phaseshift': '0',
#  'fc': '200000',
#  'output_values': '[-1 1]',
#  'sampling': 'Natural (carrier starts at center)'}

# %%
plecs.get(model+'/RL')
# Out:
# {'CommentStatus': 'Active', 'Name': 'RL', 'R': '0.443394', 'Type': 'Resistor'}

# %%
RL = plecs.get(model+'/RL', 'R')

# %%
plecs.get(model+'/ESR')
# Out:
# {'CommentStatus': 'Active',
#  'Name': 'ESR',
#  'R': '0.0005570423008216338',
#  'Type': 'Resistor'}

# %%
plecs.get(model+'/ESL')
# Out:
# {'CommentStatus': 'Active',
#  'L': '2.1945e-07',
#  'Name': 'ESL',
#  'Type': 'Inductor',
#  'i_init': '0'}

# %%
plecs.get(model+'/Deadtime')
# Out:
# {'CommentStatus': 'Active',
#  'Configuration': 'on',
#  'Name': 'Deadtime',
#  'Type': 'ConfigurableSubsystem',
#  'td': '1.78e-07'}

# %% [markdown]
# # Average Current

# %%
V_in = 48
V_out = 12
R_on = 5.6
t_rise = 110e-9
t_fall = 78e-9
diode_voltage = 0.5

L_range = (30e-6, 2000e-6)  # Range for L
C_range = (30e-6, 200e-6)   # Range for C
# t_dt_range = (0.178e-6, 1e-6) # Range for dead time
fsw_range = (20e3, 200e3)    # Range for fsw
num_values = 3           # Number of values for each parameter

# Borders for R_L
border_values = [
    (144e-6, 0.079576),
    (509e-6, 0.179228),
    (1003e-6, 0.253239),
    (2519e-6, 0.443394)
]

# Constants for ESL calculation
K_esl = 4.389e-11  # Adjust as needed
tan_delta = 0.14

# Create arrays of discrete L and C values within the specified ranges with increments of 1e-6
L_values = np.linspace(L_range[0], L_range[1], num=num_values)
C_values = np.linspace(C_range[0], C_range[1], num=num_values)
# t_dt_values = np.linspace(t_dt_range[0], t_dt_range[1], num=num_values)


# Round the values to the desired number of decimal places
L_values = np.around(L_values, decimals=6)
C_values = np.around(C_values, decimals=6)
# t_dt_values = np.around(t_dt_values, decimals=9)

fsw_values = np.linspace(fsw_range[0], fsw_range[1], num=num_values, dtype=int)

# Initialize arrays to store results
average_currents = []
delta_currents = []
delta_currents_percentage = []

# Open a CSV file for writing
csv_file_path = 'average_current_3_3.csv'

# Define the header for the CSV file
csv_header = ['No','L', 'C','fsw','average_current']

# Initialize a list to store the data for each simulation
csv_data = []

# Print the chosen values
print("Chosen L values:", L_values)
print("Chosen C values:", C_values)
# print("Chosen dead time values:", t_dt_values)
print("Chosen fsw values:", fsw_values)

# Generate all combinations of L, C, and fsw
combinations = list(itertools.product(L_values, C_values, fsw_values))
print(combinations)
# Display the chosen values and simulate
print("\nChosen values and simulation results:")
# Out:
# Chosen L values: [3.000e-05 1.015e-03 2.000e-03]
# Chosen C values: [3.00e-05 1.15e-04 2.00e-04]
# Chosen fsw values: [ 20000 110000 200000]
# [(3e-05, 3e-05, 20000), (3e-05, 3e-05, 110000), (3e-05, 3e-05, 200000), (3e-05, 0.000115, 20000), (3e-05, 0.000115, 110000), (3e-05, 0.000115, 200000), (3e-05, 0.0002, 20000), (3e-05, 0.0002, 110000), (3e-05, 0.0002, 200000), (0.001015, 3e-05, 20000), (0.001015, 3e-05, 110000), (0.001015, 3e-05, 200000), (0.001015, 0.000115, 20000), (0.001015, 0.000115, 110000), (0.001015, 0.000115, 200000), (0.001015, 0.0002, 20000), (0.001015, 0.0002, 110000), (0.001015, 0.0002, 200000), (0.002, 3e-05, 20000), (0.002, 3e-05, 110000), (0.002, 3e-05, 200000), (0.002, 0.000115, 20000), (0.002, 0.000115, 110000), (0.002, 0.000115, 200000), (0.002, 0.0002, 20000), (0.002, 0.0002, 110000), (0.002, 0.0002, 200000)]
#
# Chosen values and simulation results:

# %% [markdown]
# # Functions

# %% [markdown]
# ## Write to CSV

# %%
def write_to_csv(file_path, header, data):
    with open(file_path, 'w', newline='') as csv_file:
        csv_writer = csv.writer(csv_file)
        csv_writer.writerow(header)
        csv_writer.writerows(data)

# %% [markdown]
# ## Ripples

# %% [markdown]
# ### Current
# - Average
# - &Delta;I<sub>L</sub>%

# %%
def calculate_current(times, current, start_time, end_time):
    # Convert 'times' to a NumPy array
    times = np.array(times)

    # Find the indices corresponding to the time range
    start_index = np.argmax(times >= start_time)
    end_index = np.argmax(times >= end_time)

    # Extract the current values in the specified time range
    current_range = current[start_index:end_index]

    # Calculate the average current value
    average_current = np.mean(current_range)

    # Calculate the difference between the highest and lowest current values
    delta_current = np.max(current_range) - np.min(current_range)

    # print(np.max(current_range))
    # print(np.min(current_range))
    delta_current_percentage = delta_current/average_current *100

    return average_current, delta_current, delta_current_percentage

# %% [markdown]
# ### &Delta;V<sub>O</sub>%

# %%
def calculate_voltage(times, voltage, start_time, end_time):
    # Convert 'times' to a NumPy array
    times = np.array(times)

    # Find the indices corresponding to the time range
    start_index = np.argmax(times >= start_time)
    end_index = np.argmax(times >= end_time)

    # Extract the voltage values in the specified time range
    voltage_range = voltage[start_index:end_index]

    # Calculate the average voltage value
    average_voltage = np.mean(voltage_range)

    # Calculate the difference between the highest and lowest voltage values
    delta_voltage = np.max(voltage_range) - np.min(voltage_range)

    print('Voltage:')
    print("\nmax:", np.max(voltage_range))
    print("\nmin:", np.min(voltage_range))
    print("\ndelta:",delta_voltage)
    print("\naverage:",average_voltage)

    delta_voltage_percentage = delta_voltage/average_voltage * 100

    return average_voltage, delta_voltage, delta_voltage_percentage

# %% [markdown]
# ## Switching Losses
# - Conduction Loss
#     - R<sub>DS(on)</sub> = R<sub>ON-H</sub> = R<sub>ON-L</sub> = 5.6k&Omega;
#     - High Side
#         - P<sub>ON-H</sub> = I<sub>OUT</sub> / 2 &times; R<sub>ON-H</sub> &times; V<sub>OUT</sub> / V<sub>IN</sub> [W]
#     - Low Side
#         - P<sub>ON-L</sub> = I<sub>OUT</sub> / 2 &times; R<sub>ON-L</sub> &times; (1 - V<sub>OUT</sub> / V<sub>IN</sub>) [W]
# - Switching Losses
#     - t<sub>rise</sub> = 110 ns
#     - t<sub>fall</sub> = 78 ns
#     - High Side
#         - P<sub>SW-H</sub> = 1/2 &times; V<sub>IN</sub> &times; I<sub>OUT</sub> &times; (t<sub>rise-H</sub> + t<sub>fall-H</sub>) &times; f<sub>SW</sub>
#     - Low Side
#         - P<sub>SW-L</sub> = 1/2 &times; V<sub>D</sub> &times; I<sub>OUT</sub> &times; (t<sub>rise-L</sub> + t<sub>fall-L</sub>) &times; f<sub>SW</sub>
#
#
#
# <strong>Switching Losses<strong> = P<sub>ON-H</sub> + P<sub>ON-L</sub> + P<sub>SW-H</sub> + P<sub>SW-L</sub>

# %%
def calculate_switching_losses(average_current, V_out, V_in, R_on, t_rise, t_fall, f_sw):
    # Calculate power losses during ON state (High and Low)
    P_ON_H = average_current / 2 * R_on * V_out / V_in
    P_ON_L = average_current / 2 * R_on * V_out / V_in

    # Calculate power losses during switching (High and Low)
    P_SW_H = 0.5 * V_in * average_current * (t_rise + t_fall) * f_sw
    P_SW_L = 0.5 * V_in * average_current * (t_rise + t_fall) * f_sw

    # High Side
    Pl_s1 = P_ON_H + P_SW_H

    #Low Side
    Pl_s2 = P_ON_L + P_SW_L

    return Pl_s1, Pl_s2

# %% [markdown]
# ## Capacitor Loss
# - P<sub>CAP(ESR)</sub> = I<sub>CAP(RMS)</sub><sup>2</sup>  &#x00D7; ESR [W]
# - ESR = tan(&#x03B4;) / 2&pi;f<sub>SW</sub>C)
#     - Dengan 25 V Nippon KZE series: tan &#x03B4; = 0.14
# - ESL = 1 / (4π² SRF² C)
#     - Assume SRF = 100kHz
# - Input Capacitor
#     - I<sub>CIN(RMS)</sub> = I<sub>OUT</sub> &times; &radic;(V<sub>IN</sub> - V<sub>OUT</sub>) &times; V<sub>OUT</sub> / V<sub>IN</sub> [A]
# - Output Capacitor
#     - I<sub>COUT(RMS)</sub> = &Delta;I<sub>L</sub> / (2&radic;3) [A]
#     - &Delta;I<sub>L</sub> = (V<sub>IN</sub> - V<sub>OUT</sub>) / (f<sub>SW</sub> &times; L) &times; V<sub>OUT</sub> / V<sub>IN</sub> [A]
#
# <strong>Capacitor Losses<strong> = P<sub>cap_in</sub> + P<sub>cap_out</sub>

# %%
def calculate_capacitor_losses(average_current, V_in, V_out, f_sw, L, ESR):
    I_cin = average_current * np.sqrt(V_in - V_out) * V_out / V_in
    I_L = ((V_in - V_out) / (f_sw * L)) * (V_out / V_in)

    I_cout = I_L / (2 * np.sqrt(3))
    P_cap_in = I_cin**2 * ESR
    P_cap_out = I_cout**2 * ESR

    Pl_C = P_cap_in + P_cap_out

    return Pl_C

# %% [markdown]
# ## Inductor Loss
# - Inductor Copper Loss
#     - P<sub>Copper, L</sub> = I<sub>RMS</sub><sup>2</sup> &middot; R<sub>L</sub>
# <br>
#     - I<sub>RMS</sub> = &radic;(I<sub>AVG</sub><sup>2</sup> + <sup>1</sup>&frasl;<sub>12</sub> &Delta;I<sub>L</sub><sup>2</sup>)

# %%
def calculate_inductor_copper_loss(average_current, delta_current, R_L):
    I_rms = np.sqrt(average_current**2 + 1/12 * delta_current**2)
    Pl_L_Cu = I_rms**2 * R_L

    return Pl_L_Cu

# %% [markdown]
# ## Dead time losses

# %% [markdown]
# - t<sub>d(on)</sub> = 26 nS
# - t<sub>d(off)</sub> = 68 nS
# - t<sub>r</sub> = 110 nS
# - t<sub>f</sub> = 78 nS
# - Safety factor = 20%
# - V<sub>D</sub> = 0.5V
#
# <strong>t<sub>dt</sub><strong> = (t<sub>r</sub> + t<sub>d(off)</sub>) = 178 nS
#
# <strong>t<sub>dt</sub><strong> = t<sub>Dr</sub> = t<sub>Df</sub>
#
# <strong>P<sub>D</sub></strong> = V<sub>D</sub> × I<sub>out</sub> × (t<sub>Dr</sub> + t<sub>Df</sub>) × f<sub>sw</sub>

# %%
def calculate_dead_time_loss(average_current, f_sw, t_dt):
    P_D = diode_voltage * average_current * 2 * t_dt * f_sw

    return P_D

# %% [markdown]
# # Single

# %%
val_test =[3e-05,3e-05,20000]

L = val_test[0]
C = val_test[1]
fsw = val_test[2]
# t_dt = 1e-6

R_L = next((rl for border, rl in border_values if L <= border), 0.0)

# Calculate ESR and ESL based on the updated C
ESR = tan_delta / (2 * np.pi * fsw * C)
ESL = K_esl / C

# Set Plecs parameters and simulate
plecs.set(model+'/L1', 'L', str(L))
plecs.set(model+'/C', 'C', str(C))
plecs.set(model+'/Symmetrical PWM1', 'fc', str(fsw))
plecs.set(model+'/RL', 'R', str(R_L))
plecs.set(model+'/ESR', 'R', str(ESR))
plecs.set(model+'/ESL', 'L', str(ESL))
# plecs.set(model+'/Deadtime', 'td', str(t_dt))

times = plecs.simulate(model)['Time']
current = plecs.simulate(model)['Values'][0]
voltage = plecs.simulate(model)['Values'][1]

# Calculate average and delta current using the function
average_current, delta_current, delta_current_percentage = calculate_current(times, current, start_time=0.004, end_time=0.005)
# average_voltage, delta_voltage, delta_voltage_percentage = calculate_voltage(times, voltage, start_time=0.004, end_time=0.005)
# Pl_s1, Pl_s2 = calculate_switching_losses(average_current, V_out, V_in, R_on, t_rise, t_fall, fsw)
# Pl_C = calculate_capacitor_losses(average_current, V_in, V_out, fsw, L, ESR)
# Pl_L_Cu = calculate_inductor_copper_loss(average_current, delta_current, R_L)
# P_D = calculate_dead_time_loss(average_current, fsw, t_dt)


print(f"Average Current between 0.004 and 0.005 seconds: {average_current} A")
print(f"Difference between highest and lowest current values between 0.004 and 0.005 seconds: {delta_current} A")
print(f"Difference between highest and lowest current values between 0.004 and 0.005 seconds: {delta_current_percentage} %")
# print(f"Difference between highest and lowest voltage values between 0.004 and 0.005 seconds: {delta_voltage} V")
# print(f"Difference between highest and lowest voltage values between 0.004 and 0.005 seconds: {delta_voltage_percentage} %")
# print(f"High Side Switching Losses: {Pl_s1} W")
# print(f"Low Side Switching  Losses: {Pl_s2} W")
# print(f"Capacitor Losses: {Pl_C} W")
# print(f"Inductor Copper Losses: {Pl_L_Cu} W")
# print(f"Dead time Losses: {P_D} W")
# print(f"Total Losses: {Pl_s1 + Pl_s2 + Pl_C + Pl_L_Cu + P_D} W")
# Out:
# Average Current between 0.004 and 0.005 seconds: 3.2556026550071735 A
# Difference between highest and lowest current values between 0.004 and 0.005 seconds: 14.944351228442894 A
# Difference between highest and lowest current values between 0.004 and 0.005 seconds: 459.0348642657058 %

# %% [markdown]
# # Loop

# %%
# Loop through the combinations and simulate
csv_data = []
for simulation_num, (L, C, fsw) in enumerate(combinations, start=1):
    # Rules for picking R_L based on L
    R_L = next((rl for border, rl in border_values if L <= border), 0.0)

    # Calculate ESR and ESL based on the updated C
    ESR = tan_delta / (2 * np.pi * fsw * C)
    ESL = K_esl / C

    # Set Plecs parameters and simulate
    plecs.set(model+'/L1', 'L', str(L))
    plecs.set(model+'/C', 'C', str(C))
    plecs.set(model+'/Symmetrical PWM1', 'fc', str(fsw))
    plecs.set(model+'/RL', 'R', str(R_L))
    plecs.set(model+'/ESR', 'R', str(ESR))
    plecs.set(model+'/ESL', 'L', str(ESL))
    # plecs.set(model+'/Deadtime', 'td', str(t_dt))

    times = plecs.simulate(model)['Time']
    current = plecs.simulate(model)['Values'][0]
    voltage = plecs.simulate(model)['Values'][1]

    # Calculate average and delta current using the function
    average_current, delta_current, delta_current_percentage = calculate_current(times, current, start_time=0.004, end_time=0.005)
    # average_voltage, delta_voltage, delta_voltage_percentage = calculate_voltage(times, voltage, start_time=0.004, end_time=0.005)
    # Pl_s1, Pl_s2 = calculate_switching_losses(average_current, V_out, V_in, R_on, t_rise, t_fall, fsw)
    # Pl_C = calculate_capacitor_losses(average_current, V_in, V_out, fsw, L, ESR)
    # Pl_L_Cu = calculate_inductor_copper_loss(average_current, delta_current, R_L)
    # P_D = calculate_dead_time_loss(average_current, fsw, t_dt)

    # Append the data for this simulation to the list
    csv_data.append([simulation_num,L, C, fsw, average_current])

    print(f'\nSimulation {simulation_num} for L={L:.6f}, C={C:.6f}, fsw={fsw:.2f}, RL={R_L:.6f}, ESR={ESR:.6f}, ESL={ESL:.6e}')
    print(f"\nSimulation {simulation_num} results:")
    print(f"Average Current between 0.004 and 0.005 seconds: {average_current} A")
    # print(f"Difference between highest and lowest current values between 0.004 and 0.005 seconds: {delta_current} A")
    # print(f"Difference between highest and lowest current values between 0.004 and 0.005 seconds: {delta_current_percentage} %")
    # print(f"Difference between highest and lowest voltage values between 0.004 and 0.005 seconds: {delta_voltage} A")
    # print(f"Difference between highest and lowest voltage values between 0.004 and 0.005 seconds: {delta_voltage_percentage} %")
    # print(f"High Side Switching Losses: {Pl_s1} W")
    # print(f"Low Side Switching  Losses: {Pl_s2} W")
    # print(f"Capacitor Losses: {Pl_C} W")
    # print(f"Inductor Copper Losses: {Pl_L_Cu} W")
    # # print(f"Dead time Losses: {P_D} W")
    # print(f"Total Losses: {Pl_s1 + Pl_s2 + Pl_C + Pl_L_Cu} W")
# Out:
# Simulation 1 for L=0.000030, C=0.000030, fsw=20000.00, RL=0.079576, ESR=0.037136, ESL=1.463000e-06
#
# Simulation 1 results:
# Average Current between 0.004 and 0.005 seconds: 2.369076212400351 A
#
# Simulation 2 for L=0.000030, C=0.000030, fsw=110000.00, RL=0.079576, ESR=0.006752, ESL=1.463000e-06
#
# Simulation 2 results:
# Average Current between 0.004 and 0.005 seconds: 2.2609969793405247 A
#
# Simulation 3 for L=0.000030, C=0.000030, fsw=200000.00, RL=0.079576, ESR=0.003714, ESL=1.463000e-06
#
# Simulation 3 results:
# Average Current between 0.004 and 0.005 seconds: 2.082148933928239 A
#
# Simulation 4 for L=0.000030, C=0.000115, fsw=20000.00, RL=0.079576, ESR=0.009688, ESL=3.816522e-07
#
# Simulation 4 results:
# Average Current between 0.004 and 0.005 seconds: 2.1876638438148737 A
#
# Simulation 5 for L=0.000030, C=0.000115, fsw=110000.00, RL=0.079576, ESR=0.001761, ESL=3.816522e-07
#
# Simulation 5 results:
# Average Current between 0.004 and 0.005 seconds: 2.0157392163492425 A
#
# Simulation 6 for L=0.000030, C=0.000115, fsw=200000.00, RL=0.079576, ESR=0.000969, ESL=3.816522e-07
#
# Simulation 6 results:
# Average Current between 0.004 and 0.005 seconds: 2.029221401111471 A
#
# Simulation 7 for L=0.000030, C=0.000200, fsw=20000.00, RL=0.079576, ESR=0.005570, ESL=2.194500e-07
#
# Simulation 7 results:
# Average Current between 0.004 and 0.005 seconds: 2.261653529927751 A
#
# Simulation 8 for L=0.000030, C=0.000200, fsw=110000.00, RL=0.079576, ESR=0.001013, ESL=2.194500e-07
#
# Simulation 8 results:
# Average Current between 0.004 and 0.005 seconds: 2.344765088274239 A
#
# Simulation 9 for L=0.000030, C=0.000200, fsw=200000.00, RL=0.079576, ESR=0.000557, ESL=2.194500e-07
#
# Simulation 9 results:
# Average Current between 0.004 and 0.005 seconds: 2.0230530003312395 A
#
# Simulation 10 for L=0.001015, C=0.000030, fsw=20000.00, RL=0.443394, ESR=0.037136, ESL=1.463000e-06
#
# Simulation 10 results:
# Average Current between 0.004 and 0.005 seconds: 2.1716330608640995 A
#
# Simulation 11 for L=0.001015, C=0.000030, fsw=110000.00, RL=0.443394, ESR=0.006752, ESL=1.463000e-06
#
# Simulation 11 results:
# Average Current between 0.004 and 0.005 seconds: 2.034107401270399 A
#
# Simulation 12 for L=0.001015, C=0.000030, fsw=200000.00, RL=0.443394, ESR=0.003714, ESL=1.463000e-06
#
# Simulation 12 results:
# Average Current between 0.004 and 0.005 seconds: 1.8917855164546449 A
#
# Simulation 13 for L=0.001015, C=0.000115, fsw=20000.00, RL=0.443394, ESR=0.009688, ESL=3.816522e-07
#
# Simulation 13 results:
# Average Current between 0.004 and 0.005 seconds: 2.1549646631956985 A
#
# Simulation 14 for L=0.001015, C=0.000115, fsw=110000.00, RL=0.443394, ESR=0.001761, ESL=3.816522e-07
#
# Simulation 14 results:
# Average Current between 0.004 and 0.005 seconds: 2.02085774167209 A
#
# Simulation 15 for L=0.001015, C=0.000115, fsw=200000.00, RL=0.443394, ESR=0.000969, ESL=3.816522e-07
#
# Simulation 15 results:
# Average Current between 0.004 and 0.005 seconds: 1.879796956460778 A
#
# Simulation 16 for L=0.001015, C=0.000200, fsw=20000.00, RL=0.443394, ESR=0.005570, ESL=2.194500e-07
#
# Simulation 16 results:
# Average Current between 0.004 and 0.005 seconds: 2.185193585076375 A
#
# Simulation 17 for L=0.001015, C=0.000200, fsw=110000.00, RL=0.443394, ESR=0.001013, ESL=2.194500e-07
#
# Simulation 17 results:
# Average Current between 0.004 and 0.005 seconds: 2.0463029073252876 A
#
# Simulation 18 for L=0.001015, C=0.000200, fsw=200000.00, RL=0.443394, ESR=0.000557, ESL=2.194500e-07
#
# Simulation 18 results:
# Average Current between 0.004 and 0.005 seconds: 1.9048661592395737 A
#
# Simulation 19 for L=0.002000, C=0.000030, fsw=20000.00, RL=0.443394, ESR=0.037136, ESL=1.463000e-06
#
# Simulation 19 results:
# Average Current between 0.004 and 0.005 seconds: 2.1723967709809586 A
#
# Simulation 20 for L=0.002000, C=0.000030, fsw=110000.00, RL=0.443394, ESR=0.006752, ESL=1.463000e-06
#
# Simulation 20 results:
# Average Current between 0.004 and 0.005 seconds: 2.033157460553975 A
#
# Simulation 21 for L=0.002000, C=0.000030, fsw=200000.00, RL=0.443394, ESR=0.003714, ESL=1.463000e-06
#
# Simulation 21 results:
# Average Current between 0.004 and 0.005 seconds: 1.8911774822737262 A
#
# Simulation 22 for L=0.002000, C=0.000115, fsw=20000.00, RL=0.443394, ESR=0.009688, ESL=3.816522e-07
#
# Simulation 22 results:
# Average Current between 0.004 and 0.005 seconds: 2.201975133461274 A
#
# Simulation 23 for L=0.002000, C=0.000115, fsw=110000.00, RL=0.443394, ESR=0.001761, ESL=3.816522e-07
#
# Simulation 23 results:
# Average Current between 0.004 and 0.005 seconds: 2.0613144621790935 A
#
# Simulation 24 for L=0.002000, C=0.000115, fsw=200000.00, RL=0.443394, ESR=0.000969, ESL=3.816522e-07
#
# Simulation 24 results:
# Average Current between 0.004 and 0.005 seconds: 1.9179814421905244 A
#
# Simulation 25 for L=0.002000, C=0.000200, fsw=20000.00, RL=0.443394, ESR=0.005570, ESL=2.194500e-07
#
# Simulation 25 results:
# Average Current between 0.004 and 0.005 seconds: 2.1499884472629462 A
#
# Simulation 26 for L=0.002000, C=0.000200, fsw=110000.00, RL=0.443394, ESR=0.001013, ESL=2.194500e-07
#
# Simulation 26 results:
# Average Current between 0.004 and 0.005 seconds: 2.0117224594473 A
#
# Simulation 27 for L=0.002000, C=0.000200, fsw=200000.00, RL=0.443394, ESR=0.000557, ESL=2.194500e-07
#
# Simulation 27 results:
# Average Current between 0.004 and 0.005 seconds: 1.8720934556521582 A

# %%
# Use the function to write data to the CSV file
write_to_csv(csv_file_path, csv_header, csv_data)

# %% [markdown]
# # All

# %%
V_in = 48
V_out = 12
R_on = 5.6
t_rise = 110e-9
t_fall = 78e-9
diode_voltage = 0.5

L_range = (30e-6, 2000e-6)  # Range for L
C_range = (30e-6, 200e-6)   # Range for C
# t_dt_range = (0.178e-6, 1e-6) # Range for dead time
fsw_range = (20e3, 200e3)    # Range for fsw
num_values = 3           # Number of values for each parameter

# Borders for R_L
border_values = [
    (144e-6, 0.079576),
    (509e-6, 0.179228),
    (1003e-6, 0.253239),
    (2519e-6, 0.443394)
]

# Constants for ESL calculation
K_esl = 4.389e-11  # Adjust as needed
tan_delta = 0.14

# Create arrays of discrete L and C values within the specified ranges with increments of 1e-6
L_values = np.linspace(L_range[0], L_range[1], num=num_values)
C_values = np.linspace(C_range[0], C_range[1], num=num_values)
# t_dt_values = np.linspace(t_dt_range[0], t_dt_range[1], num=num_values)


# Round the values to the desired number of decimal places
L_values = np.around(L_values, decimals=6)
C_values = np.around(C_values, decimals=6)
# t_dt_values = np.around(t_dt_values, decimals=9)

fsw_values = np.linspace(fsw_range[0], fsw_range[1], num=num_values, dtype=int)

# Initialize arrays to store results
average_currents = []
delta_currents = []
delta_currents_percentage = []

# Open a CSV file for writing
csv_file_path = 'all_3_3.csv'

# Define the header for the CSV file
csv_header = ['No','L', 'C', 'delta_current', 'delta_voltage', 'Pl_s1', 'Pl_s2' 'Pl_C', 'Pl_L_Cu']

# Initialize a list to store the data for each simulation
csv_data = []

# Print the chosen values
print("Chosen L values:", L_values)
print("Chosen C values:", C_values)
# print("Chosen dead time values:", t_dt_values)
print("Chosen fsw values:", fsw_values)

# Generate all combinations of L, C, and fsw
combinations = list(itertools.product(L_values, C_values, fsw_values))
print(combinations)
# Display the chosen values and simulate
print("\nChosen values and simulation results:")
# Out:
# Chosen L values: [3.000e-05 1.015e-03 2.000e-03]
# Chosen C values: [3.00e-05 1.15e-04 2.00e-04]
# Chosen fsw values: [ 20000 110000 200000]
# [(3e-05, 3e-05, 20000), (3e-05, 3e-05, 110000), (3e-05, 3e-05, 200000), (3e-05, 0.000115, 20000), (3e-05, 0.000115, 110000), (3e-05, 0.000115, 200000), (3e-05, 0.0002, 20000), (3e-05, 0.0002, 110000), (3e-05, 0.0002, 200000), (0.001015, 3e-05, 20000), (0.001015, 3e-05, 110000), (0.001015, 3e-05, 200000), (0.001015, 0.000115, 20000), (0.001015, 0.000115, 110000), (0.001015, 0.000115, 200000), (0.001015, 0.0002, 20000), (0.001015, 0.0002, 110000), (0.001015, 0.0002, 200000), (0.002, 3e-05, 20000), (0.002, 3e-05, 110000), (0.002, 3e-05, 200000), (0.002, 0.000115, 20000), (0.002, 0.000115, 110000), (0.002, 0.000115, 200000), (0.002, 0.0002, 20000), (0.002, 0.0002, 110000), (0.002, 0.0002, 200000)]
#
# Chosen values and simulation results:

# %%
# Loop through the combinations and simulate
csv_data = []
for simulation_num, (L, C, fsw) in enumerate(combinations, start=1):
    # Rules for picking R_L based on L
    R_L = next((rl for border, rl in border_values if L <= border), 0.0)

    # Calculate ESR and ESL based on the updated C
    ESR = tan_delta / (2 * np.pi * fsw * C)
    ESL = K_esl / C

    # Set Plecs parameters and simulate
    plecs.set(model+'/L1', 'L', str(L))
    plecs.set(model+'/C', 'C', str(C))
    plecs.set(model+'/Symmetrical PWM1', 'fc', str(fsw))
    plecs.set(model+'/RL', 'R', str(R_L))
    plecs.set(model+'/ESR', 'R', str(ESR))
    plecs.set(model+'/ESL', 'L', str(ESL))
    # plecs.set(model+'/Deadtime', 'td', str(t_dt))

    times = plecs.simulate(model)['Time']
    current = plecs.simulate(model)['Values'][0]
    voltage = plecs.simulate(model)['Values'][1]

    # Calculate average and delta current using the function
    average_current, delta_current, delta_current_percentage = calculate_current(times, current, start_time=0.004, end_time=0.005)
    average_voltage, delta_voltage, delta_voltage_percentage = calculate_voltage(times, voltage, start_time=0.004, end_time=0.005)
    Pl_s1, Pl_s2 = calculate_switching_losses(average_current, V_out, V_in, R_on, t_rise, t_fall, fsw)
    Pl_C = calculate_capacitor_losses(average_current, V_in, V_out, fsw, L, ESR)
    Pl_L_Cu = calculate_inductor_copper_loss(average_current, delta_current, R_L)
    # P_D = calculate_dead_time_loss(average_current, fsw, t_dt)

    # Append the data for this simulation to the list
    csv_data.append([simulation_num,L, C, fsw, delta_current_percentage, delta_voltage_percentage, Pl_s1, Pl_s2, Pl_C, Pl_L_Cu])

    print(f'\nSimulation {simulation_num} for L={L:.6f}, C={C:.6f}, fsw={fsw:.2f}, RL={R_L:.6f}, ESR={ESR:.6f}, ESL={ESL:.6e}')
    print(f"\nSimulation {simulation_num} results:")
    print(f"Average Current between 0.004 and 0.005 seconds: {average_current} A")
    print(f"Difference between highest and lowest current values between 0.004 and 0.005 seconds: {delta_current} A")
    print(f"Difference between highest and lowest current values between 0.004 and 0.005 seconds: {delta_current_percentage} %")
    print(f"Difference between highest and lowest voltage values between 0.004 and 0.005 seconds: {delta_voltage} A")
    print(f"Difference between highest and lowest voltage values between 0.004 and 0.005 seconds: {delta_voltage_percentage} %")
    print(f"High Side Switching Losses: {Pl_s1} W")
    print(f"Low Side Switching  Losses: {Pl_s2} W")
    print(f"Capacitor Losses: {Pl_C} W")
    print(f"Inductor Copper Losses: {Pl_L_Cu} W")
    # print(f"Dead time Losses: {P_D} W")
    print(f"Total Losses: {Pl_s1 + Pl_s2 + Pl_C + Pl_L_Cu} W")
# Out:
# Voltage:
#
# max: 12.679319769676034
#
# min: 10.055395242914386
#
# delta: 2.6239245267616482
#
# average: 11.754836343978347
#
# Simulation 1 for L=0.000030, C=0.000030, fsw=20000.00, RL=0.079576, ESR=0.037136, ESL=1.463000e-06
#
# Simulation 1 results:
# Average Current between 0.004 and 0.005 seconds: 2.369076212400351 A
# Difference between highest and lowest current values between 0.004 and 0.005 seconds: 14.942629474599412 A
# Difference between highest and lowest current values between 0.004 and 0.005 seconds: 630.7365460167921 %
# Difference between highest and lowest voltage values between 0.004 and 0.005 seconds: 2.6239245267616482 A
# Difference between highest and lowest voltage values between 0.004 and 0.005 seconds: 22.322084714567776 %
# High Side Switching Losses: 1.8721387860872531 W
# Low Side Switching  Losses: 1.8721387860872531 W
# Capacitor Losses: 1.1652647096399509 W
# Inductor Copper Losses: 1.927280592538472 W
# Total Losses: 6.836822874352929 W
# Voltage:
#
# max: 12.55893532660962
#
# min: 10.357033046983464
#
# delta: 2.2019022796261556
#
# average: 11.15223587448624
#
# Simulation 2 for L=0.000030, C=0.000030, fsw=110000.00, RL=0.079576, ESR=0.006752, ESL=1.463000e-06
#
# Simulation 2 results:
# Average Current between 0.004 and 0.005 seconds: 2.2609969793405247 A
# Difference between highest and lowest current values between 0.004 and 0.005 seconds: 2.482897398066994 A
# Difference between highest and lowest current values between 0.004 and 0.005 seconds: 109.81427311730386 %
# Difference between highest and lowest voltage values between 0.004 and 0.005 seconds: 2.2019022796261556 A
# Difference between highest and lowest voltage values between 0.004 and 0.005 seconds: 19.744043296856763 %
# High Side Switching Losses: 2.704875906324656 W
# Low Side Switching  Losses: 2.704875906324656 W
# Capacitor Losses: 0.08184859675465744 W
# Inductor Copper Losses: 0.44768176145477867 W
# Total Losses: 5.939282170858748 W
# Voltage:
#
# max: 11.821327769265837
#
# min: 9.650546358280302
#
# delta: 2.1707814109855352
#
# average: 10.353253852105773
#
# Simulation 3 for L=0.000030, C=0.000030, fsw=200000.00, RL=0.079576, ESR=0.003714, ESL=1.463000e-06
#
# Simulation 3 results:
# Average Current between 0.004 and 0.005 seconds: 2.082148933928239 A
# Difference between highest and lowest current values between 0.004 and 0.005 seconds: 1.3053968333079462 A
# Difference between highest and lowest current values between 0.004 and 0.005 seconds: 62.69469066485792 %
# Difference between highest and lowest voltage values between 0.004 and 0.005 seconds: 2.1707814109855352 A
# Difference between highest and lowest voltage values between 0.004 and 0.005 seconds: 20.967141750745487 %
# High Side Switching Losses: 3.3364354517266097 W
# Low Side Switching  Losses: 3.3364354517266097 W
# Capacitor Losses: 0.03692085435479595 W
# Inductor Copper Losses: 0.3562895445089342 W
# Total Losses: 7.06608130231695 W
# Voltage:
#
# max: 12.061498113071139
#
# min: 11.32682892975986
#
# delta: 0.7346691833112793
#
# average: 11.788041919427142
#
# Simulation 4 for L=0.000030, C=0.000115, fsw=20000.00, RL=0.079576, ESR=0.009688, ESL=3.816522e-07
#
# Simulation 4 results:
# Average Current between 0.004 and 0.005 seconds: 2.1876638438148737 A
# Difference between highest and lowest current values between 0.004 and 0.005 seconds: 14.97949207477986 A
# Difference between highest and lowest current values between 0.004 and 0.005 seconds: 684.7254946015128 %
# Difference between highest and lowest voltage values between 0.004 and 0.005 seconds: 0.7346691833112793 A
# Difference between highest and lowest voltage values between 0.004 and 0.005 seconds: 6.232325846250313 %
# High Side Switching Losses: 1.7287794759362656 W
# Low Side Switching  Losses: 1.7287794759362656 W
# Capacitor Losses: 0.28596337563821594 W
# Inductor Copper Losses: 1.8688135796208314 W
# Total Losses: 5.612335907131579 W
# Voltage:
#
# max: 11.341552306157443
#
# min: 10.732669093114243
#
# delta: 0.6088832130431996
#
# average: 11.018300867689272
#
# Simulation 5 for L=0.000030, C=0.000115, fsw=110000.00, RL=0.079576, ESR=0.001761, ESL=3.816522e-07
#
# Simulation 5 results:
# Average Current between 0.004 and 0.005 seconds: 2.0157392163492425 A
# Difference between highest and lowest current values between 0.004 and 0.005 seconds: 2.5502856780856265 A
# Difference between highest and lowest current values between 0.004 and 0.005 seconds: 126.51863184487301 %
# Difference between highest and lowest voltage values between 0.004 and 0.005 seconds: 0.6088832130431996 A
# Difference between highest and lowest voltage values between 0.004 and 0.005 seconds: 5.526108066523445 %
# High Side Switching Losses: 2.4114691393029255 W
# Low Side Switching  Losses: 2.4114691393029255 W
# Capacitor Losses: 0.0171948522584426 W
# Inductor Copper Losses: 0.3664634754377259 W
# Total Losses: 5.2065966063020195 W
# Voltage:
#
# max: 10.60701924766944
#
# min: 9.99651606389381
#
# delta: 0.610503183775629
#
# average: 10.177720861271984
#
# Simulation 6 for L=0.000030, C=0.000115, fsw=200000.00, RL=0.079576, ESR=0.000969, ESL=3.816522e-07
#
# Simulation 6 results:
# Average Current between 0.004 and 0.005 seconds: 2.029221401111471 A
# Difference between highest and lowest current values between 0.004 and 0.005 seconds: 1.3328967581224052 A
# Difference between highest and lowest current values between 0.004 and 0.005 seconds: 65.6851321098986 %
# Difference between highest and lowest voltage values between 0.004 and 0.005 seconds: 0.610503183775629 A
# Difference between highest and lowest voltage values between 0.004 and 0.005 seconds: 5.998427271656672 %
# High Side Switching Losses: 3.251624373141021 W
# Low Side Switching  Losses: 3.251624373141021 W
# Capacitor Losses: 0.009157207594159483 W
# Inductor Copper Losses: 0.3394545561314978 W
# Total Losses: 6.8518605100076995 W
# Voltage:
#
# max: 11.961382988370858
#
# min: 11.528882031255677
#
# delta: 0.432500957115181
#
# average: 11.78844334086406
#
# Simulation 7 for L=0.000030, C=0.000200, fsw=20000.00, RL=0.079576, ESR=0.005570, ESL=2.194500e-07
#
# Simulation 7 results:
# Average Current between 0.004 and 0.005 seconds: 2.261653529927751 A
# Difference between highest and lowest current values between 0.004 and 0.005 seconds: 15.004018450657702 A
# Difference between highest and lowest current values between 0.004 and 0.005 seconds: 663.4092380691488 %
# Difference between highest and lowest voltage values between 0.004 and 0.005 seconds: 0.432500957115181 A
# Difference between highest and lowest voltage values between 0.004 and 0.005 seconds: 3.6688555444461244 %
# High Side Switching Losses: 1.7872490854901062 W
# Low Side Switching  Losses: 1.7872490854901062 W
# Capacitor Losses: 0.16855499838319654 W
# Inductor Copper Losses: 1.8998868802947058 W
# Total Losses: 5.642940049658114 W
# Voltage:
#
# max: 11.172303452724792
#
# min: 10.800089846970538
#
# delta: 0.3722136057542542
#
# average: 10.922011280191002
#
# Simulation 8 for L=0.000030, C=0.000200, fsw=110000.00, RL=0.079576, ESR=0.001013, ESL=2.194500e-07
#
# Simulation 8 results:
# Average Current between 0.004 and 0.005 seconds: 2.344765088274239 A
# Difference between highest and lowest current values between 0.004 and 0.005 seconds: 2.565987149872634 A
# Difference between highest and lowest current values between 0.004 and 0.005 seconds: 109.4347217426892 %
# Difference between highest and lowest voltage values between 0.004 and 0.005 seconds: 0.3722136057542542 A
# Difference between highest and lowest voltage values between 0.004 and 0.005 seconds: 3.4079218214078333 %
# High Side Switching Losses: 2.8050893704042377 W
# Low Side Switching  Losses: 2.8050893704042377 W
# Capacitor Losses: 0.013156490596712929 W
# Inductor Copper Losses: 0.48116536815469896 W
# Total Losses: 6.104500599559887 W
# Voltage:
#
# max: 10.408381817924285
#
# min: 10.046022396296438
#
# delta: 0.36235942162784696
#
# average: 10.138946573664573
#
# Simulation 9 for L=0.000030, C=0.000200, fsw=200000.00, RL=0.079576, ESR=0.000557, ESL=2.194500e-07
#
# Simulation 9 results:
# Average Current between 0.004 and 0.005 seconds: 2.0230530003312395 A
# Difference between highest and lowest current values between 0.004 and 0.005 seconds: 1.3426385325097179 A
# Difference between highest and lowest current values between 0.004 and 0.005 seconds: 66.36694798850472 %
# Difference between highest and lowest voltage values between 0.004 and 0.005 seconds: 0.36235942162784696 A
# Difference between highest and lowest voltage values between 0.004 and 0.005 seconds: 3.573935605589028 %
# High Side Switching Losses: 3.2417401277307776 W
# Low Side Switching  Losses: 3.2417401277307776 W
# Capacitor Losses: 0.005234065684700842 W
# Inductor Copper Losses: 0.3376383123815753 W
# Total Losses: 6.826352633527831 W
# Voltage:
#
# max: 10.8923267076726
#
# min: 10.812539817936159
#
# delta: 0.07978688973644132
#
# average: 10.863681827937555
#
# Simulation 10 for L=0.001015, C=0.000030, fsw=20000.00, RL=0.443394, ESR=0.037136, ESL=1.463000e-06
#
# Simulation 10 results:
# Average Current between 0.004 and 0.005 seconds: 2.1716330608640995 A
# Difference between highest and lowest current values between 0.004 and 0.005 seconds: 0.4390526806223476 A
# Difference between highest and lowest current values between 0.004 and 0.005 seconds: 20.217627394549208 %
# Difference between highest and lowest voltage values between 0.004 and 0.005 seconds: 0.07978688973644132 A
# Difference between highest and lowest voltage values between 0.004 and 0.005 seconds: 0.734436915588393 %
# High Side Switching Losses: 1.7161113100172458 W
# Low Side Switching  Losses: 1.7161113100172458 W
# Capacitor Losses: 0.3946591877684631 W
# Inductor Copper Losses: 2.0981643907682686 W
# Total Losses: 5.9250461985712235 W
# Voltage:
#
# max: 10.210982837006767
#
# min: 10.142774165571327
#
# delta: 0.06820867143544085
#
# average: 10.1662932754562
#
# Simulation 11 for L=0.001015, C=0.000030, fsw=110000.00, RL=0.443394, ESR=0.006752, ESL=1.463000e-06
#
# Simulation 11 results:
# Average Current between 0.004 and 0.005 seconds: 2.034107401270399 A
# Difference between highest and lowest current values between 0.004 and 0.005 seconds: 0.07614962685379689 A
# Difference between highest and lowest current values between 0.004 and 0.005 seconds: 3.743638453222173 %
# Difference between highest and lowest voltage values between 0.004 and 0.005 seconds: 0.06820867143544085 A
# Difference between highest and lowest voltage values between 0.004 and 0.005 seconds: 0.6709296061732989 %
# High Side Switching Losses: 2.4334433662878032 W
# Low Side Switching  Losses: 2.4334433662878032 W
# Capacitor Losses: 0.06286222739267668 W
# Inductor Copper Losses: 1.8347981366196005 W
# Total Losses: 6.764547096587884 W
# Voltage:
#
# max: 9.505026981084274
#
# min: 9.438052304580912
#
# delta: 0.06697467650336186
#
# average: 9.460517829679171
#
# Simulation 12 for L=0.001015, C=0.000030, fsw=200000.00, RL=0.443394, ESR=0.003714, ESL=1.463000e-06
#
# Simulation 12 results:
# Average Current between 0.004 and 0.005 seconds: 1.8917855164546449 A
# Difference between highest and lowest current values between 0.004 and 0.005 seconds: 0.03979009600630712 A
# Difference between highest and lowest current values between 0.004 and 0.005 seconds: 2.1033090516982544 %
# Difference between highest and lowest voltage values between 0.004 and 0.005 seconds: 0.06697467650336186 A
# Difference between highest and lowest voltage values between 0.004 and 0.005 seconds: 0.7079388011219797 %
# High Side Switching Losses: 3.031397111566923 W
# Low Side Switching  Losses: 3.031397111566923 W
# Capacitor Losses: 0.02990419125152698 W
# Inductor Copper Losses: 1.586900199260172 W
# Total Losses: 7.6795986136455445 W
# Voltage:
#
# max: 10.858638228669705
#
# min: 10.762574743189148
#
# delta: 0.09606348548055621
#
# average: 10.803766143100795
#
# Simulation 13 for L=0.001015, C=0.000115, fsw=20000.00, RL=0.443394, ESR=0.009688, ESL=3.816522e-07
#
# Simulation 13 results:
# Average Current between 0.004 and 0.005 seconds: 2.1549646631956985 A
# Difference between highest and lowest current values between 0.004 and 0.005 seconds: 0.5023860724977642 A
# Difference between highest and lowest current values between 0.004 and 0.005 seconds: 23.31296104655156 %
# Difference between highest and lowest voltage values between 0.004 and 0.005 seconds: 0.09606348548055621 A
# Difference between highest and lowest voltage values between 0.004 and 0.005 seconds: 0.8891666499269946 %
# High Side Switching Losses: 1.7029392754437684 W
# Low Side Switching  Losses: 1.7029392754437684 W
# Capacitor Losses: 0.10138260446310082 W
# Inductor Copper Losses: 2.068391041328159 W
# Total Losses: 5.5756521966787975 W
# Voltage:
#
# max: 10.164704006568263
#
# min: 10.06969856703243
#
# delta: 0.09500543953583218
#
# average: 10.103192056497312
#
# Simulation 14 for L=0.001015, C=0.000115, fsw=110000.00, RL=0.443394, ESR=0.001761, ESL=3.816522e-07
#
# Simulation 14 results:
# Average Current between 0.004 and 0.005 seconds: 2.02085774167209 A
# Difference between highest and lowest current values between 0.004 and 0.005 seconds: 0.13675492095507713 A
# Difference between highest and lowest current values between 0.004 and 0.005 seconds: 6.767172084162833 %
# Difference between highest and lowest voltage values between 0.004 and 0.005 seconds: 0.09500543953583218 A
# Difference between highest and lowest voltage values between 0.004 and 0.005 seconds: 0.9403507228661923 %
# High Side Switching Losses: 2.4175925335171544 W
# Low Side Switching  Losses: 2.4175925335171544 W
# Capacitor Losses: 0.016185914305466776 W
# Inductor Copper Losses: 1.8114527127230606 W
# Total Losses: 6.662823694062837 W
# Voltage:
#
# max: 9.459426139604753
#
# min: 9.370105170245774
#
# delta: 0.0893209693589796
#
# average: 9.401294822351627
#
# Simulation 15 for L=0.001015, C=0.000115, fsw=200000.00, RL=0.443394, ESR=0.000969, ESL=3.816522e-07
#
# Simulation 15 results:
# Average Current between 0.004 and 0.005 seconds: 1.879796956460778 A
# Difference between highest and lowest current values between 0.004 and 0.005 seconds: 0.096275822940868 A
# Difference between highest and lowest current values between 0.004 and 0.005 seconds: 5.121607555005998 %
# Difference between highest and lowest voltage values between 0.004 and 0.005 seconds: 0.0893209693589796 A
# Difference between highest and lowest voltage values between 0.004 and 0.005 seconds: 0.9500922058801786 %
# High Side Switching Losses: 3.0121866430327504 W
# Low Side Switching  Losses: 3.0121866430327504 W
# Capacitor Losses: 0.007702535007483892 W
# Inductor Copper Losses: 1.5671357516952775 W
# Total Losses: 7.599211572768262 W
# Voltage:
#
# max: 11.365966663357963
#
# min: 10.953999109039998
#
# delta: 0.4119675543179646
#
# average: 11.23507296901773
#
# Simulation 16 for L=0.001015, C=0.000200, fsw=20000.00, RL=0.443394, ESR=0.005570, ESL=2.194500e-07
#
# Simulation 16 results:
# Average Current between 0.004 and 0.005 seconds: 2.185193585076375 A
# Difference between highest and lowest current values between 0.004 and 0.005 seconds: 0.7970305310816679 A
# Difference between highest and lowest current values between 0.004 and 0.005 seconds: 36.47413833378111 %
# Difference between highest and lowest voltage values between 0.004 and 0.005 seconds: 0.4119675543179646 A
# Difference between highest and lowest voltage values between 0.004 and 0.005 seconds: 3.666799098270409 %
# High Side Switching Losses: 1.7268273786707544 W
# Low Side Switching  Losses: 1.7268273786707544 W
# Capacitor Losses: 0.05993936518955545 W
# Inductor Copper Losses: 2.1407102860468044 W
# Total Losses: 5.654304408577868 W
# Voltage:
#
# max: 10.637287120339012
#
# min: 10.244252662393434
#
# delta: 0.39303445794557845
#
# average: 10.51191253006453
#
# Simulation 17 for L=0.001015, C=0.000200, fsw=110000.00, RL=0.443394, ESR=0.001013, ESL=2.194500e-07
#
# Simulation 17 results:
# Average Current between 0.004 and 0.005 seconds: 2.0463029073252876 A
# Difference between highest and lowest current values between 0.004 and 0.005 seconds: 0.4259893569296205 A
# Difference between highest and lowest current values between 0.004 and 0.005 seconds: 20.81751217792233 %
# Difference between highest and lowest voltage values between 0.004 and 0.005 seconds: 0.39303445794557845 A
# Difference between highest and lowest voltage values between 0.004 and 0.005 seconds: 3.738943382771524 %
# High Side Switching Losses: 2.4480330940913877 W
# Low Side Switching  Losses: 2.4480330940913877 W
# Capacitor Losses: 0.009542733746552684 W
# Inductor Copper Losses: 1.8633534562317147 W
# Total Losses: 6.768962378161043 W
# Voltage:
#
# max: 9.897962325582332
#
# min: 9.532365974818553
#
# delta: 0.36559635076377894
#
# average: 9.781861668423344
#
# Simulation 18 for L=0.001015, C=0.000200, fsw=200000.00, RL=0.443394, ESR=0.000557, ESL=2.194500e-07
#
# Simulation 18 results:
# Average Current between 0.004 and 0.005 seconds: 1.9048661592395737 A
# Difference between highest and lowest current values between 0.004 and 0.005 seconds: 0.36665171448322664 A
# Difference between highest and lowest current values between 0.004 and 0.005 seconds: 19.248161489182774 %
# Difference between highest and lowest voltage values between 0.004 and 0.005 seconds: 0.36559635076377894 A
# Difference between highest and lowest voltage values between 0.004 and 0.005 seconds: 3.737492546474605 %
# High Side Switching Losses: 3.052357533565493 W
# Low Side Switching  Losses: 3.052357533565493 W
# Capacitor Losses: 0.004547873123492862 W
# Inductor Copper Losses: 1.6138290672876945 W
# Total Losses: 7.723092007542173 W
# Voltage:
#
# max: 10.878943414423826
#
# min: 10.838494178824238
#
# delta: 0.04044923559958846
#
# average: 10.864759801373504
#
# Simulation 19 for L=0.002000, C=0.000030, fsw=20000.00, RL=0.443394, ESR=0.037136, ESL=1.463000e-06
#
# Simulation 19 results:
# Average Current between 0.004 and 0.005 seconds: 2.1723967709809586 A
# Difference between highest and lowest current values between 0.004 and 0.005 seconds: 0.22283603482142533 A
# Difference between highest and lowest current values between 0.004 and 0.005 seconds: 10.257612135963653 %
# Difference between highest and lowest voltage values between 0.004 and 0.005 seconds: 0.04044923559958846 A
# Difference between highest and lowest voltage values between 0.004 and 0.005 seconds: 0.37229755962460337 %
# High Side Switching Losses: 1.7167148242999926 W
# Low Side Switching  Losses: 1.7167148242999926 W
# Capacitor Losses: 0.3944847736252858 W
# Inductor Copper Losses: 2.09434749250617 W
# Total Losses: 5.9222619147314415 W
# Voltage:
#
# max: 10.185537177643472
#
# min: 10.150905001479705
#
# delta: 0.03463217616376646
#
# average: 10.163058815452715
#
# Simulation 20 for L=0.002000, C=0.000030, fsw=110000.00, RL=0.443394, ESR=0.006752, ESL=1.463000e-06
#
# Simulation 20 results:
# Average Current between 0.004 and 0.005 seconds: 2.033157460553975 A
# Difference between highest and lowest current values between 0.004 and 0.005 seconds: 0.03866913739231226 A
# Difference between highest and lowest current values between 0.004 and 0.005 seconds: 1.9019253620315302 %
# Difference between highest and lowest voltage values between 0.004 and 0.005 seconds: 0.03463217616376646 A
# Difference between highest and lowest voltage values between 0.004 and 0.005 seconds: 0.3407652832935393 %
# High Side Switching Losses: 2.4323069332099316 W
# Low Side Switching  Losses: 2.4323069332099316 W
# Capacitor Losses: 0.06280081595587439 W
# Inductor Copper Losses: 1.8329260019133382 W
# Total Losses: 6.760340684289076 W
# Voltage:
#
# max: 9.479404801036557
#
# min: 9.445377598226957
#
# delta: 0.034027202809600254
#
# average: 9.456803832100476
#
# Simulation 21 for L=0.002000, C=0.000030, fsw=200000.00, RL=0.443394, ESR=0.003714, ESL=1.463000e-06
#
# Simulation 21 results:
# Average Current between 0.004 and 0.005 seconds: 1.8911774822737262 A
# Difference between highest and lowest current values between 0.004 and 0.005 seconds: 0.020204224514633662 A
# Difference between highest and lowest current values between 0.004 and 0.005 seconds: 1.068341004692088 %
# Difference between highest and lowest voltage values between 0.004 and 0.005 seconds: 0.034027202809600254 A
# Difference between highest and lowest voltage values between 0.004 and 0.005 seconds: 0.35981715824639643 %
# High Side Switching Losses: 3.0304227975954188 W
# Low Side Switching  Losses: 3.0304227975954188 W
# Capacitor Losses: 0.02988452024597286 W
# Inductor Copper Losses: 1.5858369001454131 W
# Total Losses: 7.676567015582223 W
# Voltage:
#
# max: 10.961739233079166
#
# min: 10.739848631253839
#
# delta: 0.2218906018253275
#
# average: 10.896666519794044
#
# Simulation 22 for L=0.002000, C=0.000115, fsw=20000.00, RL=0.443394, ESR=0.009688, ESL=3.816522e-07
#
# Simulation 22 results:
# Average Current between 0.004 and 0.005 seconds: 2.201975133461274 A
# Difference between highest and lowest current values between 0.004 and 0.005 seconds: 0.25043143682832447 A
# Difference between highest and lowest current values between 0.004 and 0.005 seconds: 11.37303655353603 %
# Difference between highest and lowest voltage values between 0.004 and 0.005 seconds: 0.2218906018253275 A
# Difference between highest and lowest voltage values between 0.004 and 0.005 seconds: 2.036316348878422 %
# High Side Switching Losses: 1.7400888294664372 W
# Low Side Switching  Losses: 1.7400888294664372 W
# Capacitor Losses: 0.10572935431708998 W
# Inductor Copper Losses: 2.1521993652967977 W
# Total Losses: 5.738106378546762 W
# Voltage:
#
# max: 10.253733959997922
#
# min: 10.039362262301673
#
# delta: 0.21437169769624909
#
# average: 10.190348819090653
#
# Simulation 23 for L=0.002000, C=0.000115, fsw=110000.00, RL=0.443394, ESR=0.001761, ESL=3.816522e-07
#
# Simulation 23 results:
# Average Current between 0.004 and 0.005 seconds: 2.0613144621790935 A
# Difference between highest and lowest current values between 0.004 and 0.005 seconds: 0.06601219455391316 A
# Difference between highest and lowest current values between 0.004 and 0.005 seconds: 3.202432028936001 %
# Difference between highest and lowest voltage values between 0.004 and 0.005 seconds: 0.21437169769624909 A
# Difference between highest and lowest voltage values between 0.004 and 0.005 seconds: 2.1036737947050845 %
# High Side Switching Losses: 2.4659917173940933 W
# Low Side Switching  Losses: 2.4659917173940933 W
# Capacitor Losses: 0.016839725030868172 W
# Inductor Copper Losses: 1.8841497935363183 W
# Total Losses: 6.832972953355373 W
# Voltage:
#
# max: 9.541447048284514
#
# min: 9.34107190806357
#
# delta: 0.2003751402209435
#
# average: 9.482095828828477
#
# Simulation 24 for L=0.002000, C=0.000115, fsw=200000.00, RL=0.443394, ESR=0.000969, ESL=3.816522e-07
#
# Simulation 24 results:
# Average Current between 0.004 and 0.005 seconds: 1.9179814421905244 A
# Difference between highest and lowest current values between 0.004 and 0.005 seconds: 0.04578195808424068 A
# Difference between highest and lowest current values between 0.004 and 0.005 seconds: 2.3869864993038283 %
# Difference between highest and lowest voltage values between 0.004 and 0.005 seconds: 0.2003751402209435 A
# Difference between highest and lowest voltage values between 0.004 and 0.005 seconds: 2.113194633740588 %
# High Side Switching Losses: 3.073373462966096 W
# Low Side Switching  Losses: 3.073373462966096 W
# Capacitor Losses: 0.008018513495963659 W
# Inductor Copper Losses: 1.6311700308813133 W
# Total Losses: 7.785935470309469 W
# Voltage:
#
# max: 10.574710863968676
#
# min: 9.97820180662124
#
# delta: 0.5965090573474363
#
# average: 10.187253721170302
#
# Simulation 25 for L=0.002000, C=0.000200, fsw=20000.00, RL=0.443394, ESR=0.005570, ESL=2.194500e-07
#
# Simulation 25 results:
# Average Current between 0.004 and 0.005 seconds: 2.1499884472629462 A
# Difference between highest and lowest current values between 0.004 and 0.005 seconds: 0.5559680589223628 A
# Difference between highest and lowest current values between 0.004 and 0.005 seconds: 25.8591184352707 %
# Difference between highest and lowest voltage values between 0.004 and 0.005 seconds: 0.5965090573474363 A
# Difference between highest and lowest voltage values between 0.004 and 0.005 seconds: 5.855445183502408 %
# High Side Switching Losses: 1.6990068705650705 W
# Low Side Switching  Losses: 1.6990068705650705 W
# Capacitor Losses: 0.057958758402176305 W
# Inductor Copper Losses: 2.0609878469573983 W
# Total Losses: 5.516960346489716 W
# Voltage:
#
# max: 9.881247017347361
#
# min: 9.328358470120845
#
# delta: 0.5528885472265159
#
# average: 9.52378057623878
#
# Simulation 26 for L=0.002000, C=0.000200, fsw=110000.00, RL=0.443394, ESR=0.001013, ESL=2.194500e-07
#
# Simulation 26 results:
# Average Current between 0.004 and 0.005 seconds: 2.0117224594473 A
# Difference between highest and lowest current values between 0.004 and 0.005 seconds: 0.3595390225946613 A
# Difference between highest and lowest current values between 0.004 and 0.005 seconds: 17.872198071171354 %
# Difference between highest and lowest voltage values between 0.004 and 0.005 seconds: 0.5528885472265159 A
# Difference between highest and lowest voltage values between 0.004 and 0.005 seconds: 5.8053473912023685 %
# High Side Switching Losses: 2.406663812685994 W
# Low Side Switching  Losses: 2.406663812685994 W
# Capacitor Losses: 0.009222545047028914 W
# Inductor Copper Losses: 1.7992040015660493 W
# Total Losses: 6.621754171985066 W
# Voltage:
#
# max: 9.195997391781708
#
# min: 8.679496030375162
#
# delta: 0.5165013614065455
#
# average: 8.86077542529953
#
# Simulation 27 for L=0.002000, C=0.000200, fsw=200000.00, RL=0.443394, ESR=0.000557, ESL=2.194500e-07
#
# Simulation 27 results:
# Average Current between 0.004 and 0.005 seconds: 1.8720934556521582 A
# Difference between highest and lowest current values between 0.004 and 0.005 seconds: 0.3196287265139668 A
# Difference between highest and lowest current values between 0.004 and 0.005 seconds: 17.0733317585698 %
# Difference between highest and lowest voltage values between 0.004 and 0.005 seconds: 0.5165013614065455 A
# Difference between highest and lowest voltage values between 0.004 and 0.005 seconds: 5.829076312348653 %
# High Side Switching Losses: 2.999842553337018 W
# Low Side Switching  Losses: 2.999842553337018 W
# Capacitor Losses: 0.0043926648383170635 W
# Inductor Copper Losses: 1.557752839962083 W
# Total Losses: 7.561830611474436 W

# %%
# Use the function to write data to the CSV file
write_to_csv(csv_file_path, csv_header, csv_data)

# %% [markdown]
# # Spesifikasi

# %% [markdown]
# - V<sub>in</sub> = 48V
# - V<sub>out</sub> = 12V
# - P<sub>o</sub> = 100W
# - &#916;V<sub>o</sub> &#8804; 1%
# - &#916;I<sub>L</sub> &#8804; 10%
# - f<sub>sw</sub> = 20e3
# - Mosfet: IRFB4310PbF, Infineon

# %% [markdown]
# # Plecs

# %%
import xmlrpc.client as xml
import os
import numpy as np
import itertools
import csv

# %%
model = 'buck'
file_type = '.plecs'
V_in = 48
V_out = 12
f_sw = 20e3

# %%
plecs = xml.Server("http://localhost:1080/RPC2").plecs

# %%
# plecs.load(r"D:\Krishna\ai-power-converter\buck.plecs")
plecs.load(r"E:\ai-power-converter\buck.plecs")
# Out:
# 0

# %%
plecs.get(model+'/L1')
# Out:
# {'CommentStatus': 'Active',
#  'L': '0.002',
#  'Name': 'L1',
#  'Type': 'Inductor',
#  'i_init': '0'}

# %%
plecs.get(model+'/C')
# Out:
# {'C': '0.0002',
#  'CommentStatus': 'Active',
#  'Name': 'C',
#  'Type': 'Capacitor',
#  'v_init': '0'}

# %%
plecs.get(model+'/Symmetrical PWM1')
# Out:
# {'CommentStatus': 'Active',
#  'Name': 'Symmetrical PWM1',
#  'Type': 'Subsystem',
#  'carrier_limits': '[0 1]',
#  'carrier_phaseshift': '0',
#  'fc': '200000',
#  'output_values': '[-1 1]',
#  'sampling': 'Natural (carrier starts at center)'}

# %%
plecs.get(model+'/RL')
# Out:
# {'CommentStatus': 'Active', 'Name': 'RL', 'R': '0.443394', 'Type': 'Resistor'}

# %%
RL = plecs.get(model+'/RL', 'R')

# %%
plecs.get(model+'/ESR')
# Out:
# {'CommentStatus': 'Active',
#  'Name': 'ESR',
#  'R': '0.0005570423008216338',
#  'Type': 'Resistor'}

# %%
plecs.get(model+'/ESL')
# Out:
# {'CommentStatus': 'Active',
#  'L': '2.1945e-07',
#  'Name': 'ESL',
#  'Type': 'Inductor',
#  'i_init': '0'}

# %%
plecs.get(model+'/Deadtime')
# Out:
# {'CommentStatus': 'Active',
#  'Configuration': 'on',
#  'Name': 'Deadtime',
#  'Type': 'ConfigurableSubsystem',
#  'td': '0'}

# %% [markdown]
# # Average Current

# %%
V_in = 48
V_out = 12
R_on = 5.6
t_rise = 110e-9
t_fall = 78e-9
diode_voltage = 0.5

L_range = (30e-6, 2000e-6)  # Range for L
C_range = (30e-6, 200e-6)   # Range for C
# t_dt_range = (0.178e-6, 1e-6) # Range for dead time
fsw_range = (20e3, 200e3)    # Range for fsw
num_values = 3           # Number of values for each parameter

# Borders for R_L
border_values = [
    (144e-6, 0.079576),
    (509e-6, 0.179228),
    (1003e-6, 0.253239),
    (2519e-6, 0.443394)
]

# Constants for ESL calculation
K_esl = 4.389e-11  # Adjust as needed
tan_delta = 0.14

# Create arrays of discrete L and C values within the specified ranges with increments of 1e-6
L_values = np.linspace(L_range[0], L_range[1], num=num_values)
C_values = np.linspace(C_range[0], C_range[1], num=num_values)
# t_dt_values = np.linspace(t_dt_range[0], t_dt_range[1], num=num_values)


# Round the values to the desired number of decimal places
L_values = np.around(L_values, decimals=6)
C_values = np.around(C_values, decimals=6)
# t_dt_values = np.around(t_dt_values, decimals=9)

fsw_values = np.linspace(fsw_range[0], fsw_range[1], num=num_values, dtype=int)

# Initialize arrays to store results
average_currents = []
delta_currents = []
delta_currents_percentage = []

# Open a CSV file for writing
csv_file_path = 'average_current_3.csv'

# Define the header for the CSV file
csv_header = ['No','L', 'C','fsw','average_current']

# Initialize a list to store the data for each simulation
csv_data = []

# Print the chosen values
print("Chosen L values:", L_values)
print("Chosen C values:", C_values)
# print("Chosen dead time values:", t_dt_values)
print("Chosen fsw values:", fsw_values)

# Generate all combinations of L, C, and fsw
combinations = list(itertools.product(L_values, C_values, fsw_values))
print(combinations)
# Display the chosen values and simulate
print("\nChosen values and simulation results:")
# Out:
# Chosen L values: [3.000e-05 1.015e-03 2.000e-03]
# Chosen C values: [3.00e-05 1.15e-04 2.00e-04]
# Chosen fsw values: [ 20000 110000 200000]
# [(3e-05, 3e-05, 20000), (3e-05, 3e-05, 110000), (3e-05, 3e-05, 200000), (3e-05, 0.000115, 20000), (3e-05, 0.000115, 110000), (3e-05, 0.000115, 200000), (3e-05, 0.0002, 20000), (3e-05, 0.0002, 110000), (3e-05, 0.0002, 200000), (0.001015, 3e-05, 20000), (0.001015, 3e-05, 110000), (0.001015, 3e-05, 200000), (0.001015, 0.000115, 20000), (0.001015, 0.000115, 110000), (0.001015, 0.000115, 200000), (0.001015, 0.0002, 20000), (0.001015, 0.0002, 110000), (0.001015, 0.0002, 200000), (0.002, 3e-05, 20000), (0.002, 3e-05, 110000), (0.002, 3e-05, 200000), (0.002, 0.000115, 20000), (0.002, 0.000115, 110000), (0.002, 0.000115, 200000), (0.002, 0.0002, 20000), (0.002, 0.0002, 110000), (0.002, 0.0002, 200000)]
#
# Chosen values and simulation results:

# %% [markdown]
# # Functions

# %% [markdown]
# ## Write to CSV

# %%
def write_to_csv(file_path, header, data):
    with open(file_path, 'w', newline='') as csv_file:
        csv_writer = csv.writer(csv_file)
        csv_writer.writerow(header)
        csv_writer.writerows(data)

# %% [markdown]
# ## Ripples

# %% [markdown]
# ### Current
# - Average
# - &Delta;I<sub>L</sub>%

# %%
def calculate_current(times, current, start_time, end_time):
    # Convert 'times' to a NumPy array
    times = np.array(times)

    # Find the indices corresponding to the time range
    start_index = np.argmax(times >= start_time)
    end_index = np.argmax(times >= end_time)

    # Extract the current values in the specified time range
    current_range = current[start_index:end_index]

    # Calculate the average current value
    average_current = np.mean(current_range)

    # Calculate the difference between the highest and lowest current values
    delta_current = np.max(current_range) - np.min(current_range)

    # print(np.max(current_range))
    # print(np.min(current_range))
    delta_current_percentage = delta_current/average_current *100

    return average_current, delta_current, delta_current_percentage

# %% [markdown]
# ### &Delta;V<sub>O</sub>%

# %%
def calculate_voltage(times, voltage, start_time, end_time):
    # Convert 'times' to a NumPy array
    times = np.array(times)

    # Find the indices corresponding to the time range
    start_index = np.argmax(times >= start_time)
    end_index = np.argmax(times >= end_time)

    # Extract the voltage values in the specified time range
    voltage_range = voltage[start_index:end_index]

    # Calculate the average voltage value
    average_voltage = np.mean(voltage_range)

    # Calculate the difference between the highest and lowest voltage values
    delta_voltage = np.max(voltage_range) - np.min(voltage_range)

    print('Voltage:')
    print("\nmax:", np.max(voltage_range))
    print("\nmin:", np.min(voltage_range))
    print("\ndelta:",delta_voltage)
    print("\naverage:",average_voltage)

    delta_voltage_percentage = delta_voltage/average_voltage * 100

    return average_voltage, delta_voltage, delta_voltage_percentage

# %% [markdown]
# ## Switching Losses
# - Conduction Loss
#     - R<sub>DS(on)</sub> = R<sub>ON-H</sub> = R<sub>ON-L</sub> = 5.6k&Omega;
#     - High Side
#         - P<sub>ON-H</sub> = I<sub>OUT</sub> / 2 &times; R<sub>ON-H</sub> &times; V<sub>OUT</sub> / V<sub>IN</sub> [W]
#     - Low Side
#         - P<sub>ON-L</sub> = I<sub>OUT</sub> / 2 &times; R<sub>ON-L</sub> &times; (1 - V<sub>OUT</sub> / V<sub>IN</sub>) [W]
# - Switching Losses
#     - t<sub>rise</sub> = 110 ns
#     - t<sub>fall</sub> = 78 ns
#     - High Side
#         - P<sub>SW-H</sub> = 1/2 &times; V<sub>IN</sub> &times; I<sub>OUT</sub> &times; (t<sub>rise-H</sub> + t<sub>fall-H</sub>) &times; f<sub>SW</sub>
#     - Low Side
#         - P<sub>SW-L</sub> = 1/2 &times; V<sub>D</sub> &times; I<sub>OUT</sub> &times; (t<sub>rise-L</sub> + t<sub>fall-L</sub>) &times; f<sub>SW</sub>
#
#
#
# <strong>Switching Losses<strong> = P<sub>ON-H</sub> + P<sub>ON-L</sub> + P<sub>SW-H</sub> + P<sub>SW-L</sub>

# %%
def calculate_switching_losses(average_current, V_out, V_in, R_on, t_rise, t_fall, f_sw):
    # Calculate power losses during ON state (High and Low)
    P_ON_H = average_current / 2 * R_on * V_out / V_in
    P_ON_L = average_current / 2 * R_on * V_out / V_in

    # Calculate power losses during switching (High and Low)
    P_SW_H = 0.5 * V_in * average_current * (t_rise + t_fall) * f_sw
    P_SW_L = 0.5 * V_in * average_current * (t_rise + t_fall) * f_sw

    # High Side
    Pl_s1 = P_ON_H + P_SW_H

    #Low Side
    Pl_s2 = P_ON_L + P_SW_L

    return Pl_s1, Pl_s2

# %% [markdown]
# ## Capacitor Loss
# - P<sub>CAP(ESR)</sub> = I<sub>CAP(RMS)</sub><sup>2</sup>  &#x00D7; ESR [W]
# - ESR = tan(&#x03B4;) / 2&pi;f<sub>SW</sub>C)
#     - Dengan 25 V Nippon KZE series: tan &#x03B4; = 0.14
# - ESL = 1 / (4π² SRF² C)
#     - Assume SRF = 100kHz
# - Input Capacitor
#     - I<sub>CIN(RMS)</sub> = I<sub>OUT</sub> &times; &radic;(V<sub>IN</sub> - V<sub>OUT</sub>) &times; V<sub>OUT</sub> / V<sub>IN</sub> [A]
# - Output Capacitor
#     - I<sub>COUT(RMS)</sub> = &Delta;I<sub>L</sub> / (2&radic;3) [A]
#     - &Delta;I<sub>L</sub> = (V<sub>IN</sub> - V<sub>OUT</sub>) / (f<sub>SW</sub> &times; L) &times; V<sub>OUT</sub> / V<sub>IN</sub> [A]
#
# <strong>Capacitor Losses<strong> = P<sub>cap_in</sub> + P<sub>cap_out</sub>

# %%
def calculate_capacitor_losses(average_current, V_in, V_out, f_sw, L, ESR):
    I_cin = average_current * np.sqrt(V_in - V_out) * V_out / V_in
    I_L = ((V_in - V_out) / (f_sw * L)) * (V_out / V_in)

    I_cout = I_L / (2 * np.sqrt(3))
    P_cap_in = I_cin**2 * ESR
    P_cap_out = I_cout**2 * ESR

    Pl_C = P_cap_in + P_cap_out

    return Pl_C

# %% [markdown]
# ## Inductor Loss
# - Inductor Copper Loss
#     - P<sub>Copper, L</sub> = I<sub>RMS</sub><sup>2</sup> &middot; R<sub>L</sub>
# <br>
#     - I<sub>RMS</sub> = &radic;(I<sub>AVG</sub><sup>2</sup> + <sup>1</sup>&frasl;<sub>12</sub> &Delta;I<sub>L</sub><sup>2</sup>)

# %%
def calculate_inductor_copper_loss(average_current, delta_current, R_L):
    I_rms = np.sqrt(average_current**2 + 1/12 * delta_current**2)
    Pl_L_Cu = I_rms**2 * R_L

    return Pl_L_Cu

# %% [markdown]
# ## Dead time losses

# %% [markdown]
# - t<sub>d(on)</sub> = 26 nS
# - t<sub>d(off)</sub> = 68 nS
# - t<sub>r</sub> = 110 nS
# - t<sub>f</sub> = 78 nS
# - Safety factor = 20%
# - V<sub>D</sub> = 0.5V
#
# <strong>t<sub>dt</sub><strong> = (t<sub>r</sub> + t<sub>d(off)</sub>) = 178 nS
#
# <strong>t<sub>dt</sub><strong> = t<sub>Dr</sub> = t<sub>Df</sub>
#
# <strong>P<sub>D</sub></strong> = V<sub>D</sub> × I<sub>out</sub> × (t<sub>Dr</sub> + t<sub>Df</sub>) × f<sub>sw</sub>

# %%
def calculate_dead_time_loss(average_current, f_sw, t_dt):
    P_D = diode_voltage * average_current * 2 * t_dt * f_sw

    return P_D

# %% [markdown]
# # Single

# %%
val_test =[3e-05,3e-05,20000]

L = val_test[0]
C = val_test[1]
fsw = val_test[2]
# t_dt = 1e-6

R_L = next((rl for border, rl in border_values if L <= border), 0.0)

# Calculate ESR and ESL based on the updated C
ESR = tan_delta / (2 * np.pi * fsw * C)
ESL = K_esl / C

# Set Plecs parameters and simulate
plecs.set(model+'/L1', 'L', str(L))
plecs.set(model+'/C', 'C', str(C))
plecs.set(model+'/Symmetrical PWM1', 'fc', str(fsw))
plecs.set(model+'/RL', 'R', str(R_L))
plecs.set(model+'/ESR', 'R', str(ESR))
plecs.set(model+'/ESL', 'L', str(ESL))
# plecs.set(model+'/Deadtime', 'td', str(t_dt))

times = plecs.simulate(model)['Time']
current = plecs.simulate(model)['Values'][0]
voltage = plecs.simulate(model)['Values'][1]

# Calculate average and delta current using the function
average_current, delta_current, delta_current_percentage = calculate_current(times, current, start_time=0.004, end_time=0.005)
# average_voltage, delta_voltage, delta_voltage_percentage = calculate_voltage(times, voltage, start_time=0.004, end_time=0.005)
# Pl_s1, Pl_s2 = calculate_switching_losses(average_current, V_out, V_in, R_on, t_rise, t_fall, fsw)
# Pl_C = calculate_capacitor_losses(average_current, V_in, V_out, fsw, L, ESR)
# Pl_L_Cu = calculate_inductor_copper_loss(average_current, delta_current, R_L)
# P_D = calculate_dead_time_loss(average_current, fsw, t_dt)


print(f"Average Current between 0.004 and 0.005 seconds: {average_current} A")
print(f"Difference between highest and lowest current values between 0.004 and 0.005 seconds: {delta_current} A")
print(f"Difference between highest and lowest current values between 0.004 and 0.005 seconds: {delta_current_percentage} %")
# print(f"Difference between highest and lowest voltage values between 0.004 and 0.005 seconds: {delta_voltage} V")
# print(f"Difference between highest and lowest voltage values between 0.004 and 0.005 seconds: {delta_voltage_percentage} %")
# print(f"High Side Switching Losses: {Pl_s1} W")
# print(f"Low Side Switching  Losses: {Pl_s2} W")
# print(f"Capacitor Losses: {Pl_C} W")
# print(f"Inductor Copper Losses: {Pl_L_Cu} W")
# print(f"Dead time Losses: {P_D} W")
# print(f"Total Losses: {Pl_s1 + Pl_s2 + Pl_C + Pl_L_Cu + P_D} W")
# Out:
# Average Current between 0.004 and 0.005 seconds: 3.2556026550071735 A
# Difference between highest and lowest current values between 0.004 and 0.005 seconds: 14.944351228442894 A
# Difference between highest and lowest current values between 0.004 and 0.005 seconds: 459.0348642657058 %

# %% [markdown]
# # Loop

# %%
# Loop through the combinations and simulate
csv_data = []
for simulation_num, (L, C, fsw) in enumerate(combinations, start=1):
    # Rules for picking R_L based on L
    R_L = next((rl for border, rl in border_values if L <= border), 0.0)

    # Calculate ESR and ESL based on the updated C
    ESR = tan_delta / (2 * np.pi * fsw * C)
    ESL = K_esl / C

    # Set Plecs parameters and simulate
    plecs.set(model+'/L1', 'L', str(L))
    plecs.set(model+'/C', 'C', str(C))
    plecs.set(model+'/Symmetrical PWM1', 'fc', str(fsw))
    plecs.set(model+'/RL', 'R', str(R_L))
    plecs.set(model+'/ESR', 'R', str(ESR))
    plecs.set(model+'/ESL', 'L', str(ESL))
    # plecs.set(model+'/Deadtime', 'td', str(t_dt))

    times = plecs.simulate(model)['Time']
    current = plecs.simulate(model)['Values'][0]
    voltage = plecs.simulate(model)['Values'][1]

    # Calculate average and delta current using the function
    average_current, delta_current, delta_current_percentage = calculate_current(times, current, start_time=0.004, end_time=0.005)
    # average_voltage, delta_voltage, delta_voltage_percentage = calculate_voltage(times, voltage, start_time=0.004, end_time=0.005)
    # Pl_s1, Pl_s2 = calculate_switching_losses(average_current, V_out, V_in, R_on, t_rise, t_fall, fsw)
    # Pl_C = calculate_capacitor_losses(average_current, V_in, V_out, fsw, L, ESR)
    # Pl_L_Cu = calculate_inductor_copper_loss(average_current, delta_current, R_L)
    # P_D = calculate_dead_time_loss(average_current, fsw, t_dt)

    # Append the data for this simulation to the list
    csv_data.append([simulation_num,L, C, fsw, average_current])

    print(f'\nSimulation {simulation_num} for L={L:.6f}, C={C:.6f}, fsw={fsw:.2f}, RL={R_L:.6f}, ESR={ESR:.6f}, ESL={ESL:.6e}')
    print(f"\nSimulation {simulation_num} results:")
    print(f"Average Current between 0.004 and 0.005 seconds: {average_current} A")
    # print(f"Difference between highest and lowest current values between 0.004 and 0.005 seconds: {delta_current} A")
    # print(f"Difference between highest and lowest current values between 0.004 and 0.005 seconds: {delta_current_percentage} %")
    # print(f"Difference between highest and lowest voltage values between 0.004 and 0.005 seconds: {delta_voltage} A")
    # print(f"Difference between highest and lowest voltage values between 0.004 and 0.005 seconds: {delta_voltage_percentage} %")
    # print(f"High Side Switching Losses: {Pl_s1} W")
    # print(f"Low Side Switching  Losses: {Pl_s2} W")
    # print(f"Capacitor Losses: {Pl_C} W")
    # print(f"Inductor Copper Losses: {Pl_L_Cu} W")
    # # print(f"Dead time Losses: {P_D} W")
    # print(f"Total Losses: {Pl_s1 + Pl_s2 + Pl_C + Pl_L_Cu} W")
# Out:
# Simulation 1 for L=0.000030, C=0.000030, fsw=20000.00, RL=0.079576, ESR=0.037136, ESL=1.463000e-06
#
# Simulation 1 results:
# Average Current between 0.004 and 0.005 seconds: 3.2556026550071735 A
#
# Simulation 2 for L=0.000030, C=0.000030, fsw=110000.00, RL=0.079576, ESR=0.006752, ESL=1.463000e-06
#
# Simulation 2 results:
# Average Current between 0.004 and 0.005 seconds: 2.488782891491957 A
#
# Simulation 3 for L=0.000030, C=0.000030, fsw=200000.00, RL=0.079576, ESR=0.003714, ESL=1.463000e-06
#
# Simulation 3 results:
# Average Current between 0.004 and 0.005 seconds: 2.4480963015005166 A
#
# Simulation 4 for L=0.000030, C=0.000115, fsw=20000.00, RL=0.079576, ESR=0.009688, ESL=3.816522e-07
#
# Simulation 4 results:
# Average Current between 0.004 and 0.005 seconds: 2.015067529180449 A
#
# Simulation 5 for L=0.000030, C=0.000115, fsw=110000.00, RL=0.079576, ESR=0.001761, ESL=3.816522e-07
#
# Simulation 5 results:
# Average Current between 0.004 and 0.005 seconds: 2.537691919689737 A
#
# Simulation 6 for L=0.000030, C=0.000115, fsw=200000.00, RL=0.079576, ESR=0.000969, ESL=3.816522e-07
#
# Simulation 6 results:
# Average Current between 0.004 and 0.005 seconds: 2.3669550373033585 A
#
# Simulation 7 for L=0.000030, C=0.000200, fsw=20000.00, RL=0.079576, ESR=0.005570, ESL=2.194500e-07
#
# Simulation 7 results:
# Average Current between 0.004 and 0.005 seconds: 2.259277826903446 A
#
# Simulation 8 for L=0.000030, C=0.000200, fsw=110000.00, RL=0.079576, ESR=0.001013, ESL=2.194500e-07
#
# Simulation 8 results:
# Average Current between 0.004 and 0.005 seconds: 2.3060172766352514 A
#
# Simulation 9 for L=0.000030, C=0.000200, fsw=200000.00, RL=0.079576, ESR=0.000557, ESL=2.194500e-07
#
# Simulation 9 results:
# Average Current between 0.004 and 0.005 seconds: 2.4145527294792837 A
#
# Simulation 10 for L=0.001015, C=0.000030, fsw=20000.00, RL=0.443394, ESR=0.037136, ESL=1.463000e-06
#
# Simulation 10 results:
# Average Current between 0.004 and 0.005 seconds: 2.2056078149267755 A
#
# Simulation 11 for L=0.001015, C=0.000030, fsw=110000.00, RL=0.443394, ESR=0.006752, ESL=1.463000e-06
#
# Simulation 11 results:
# Average Current between 0.004 and 0.005 seconds: 2.2077439758592026 A
#
# Simulation 12 for L=0.001015, C=0.000030, fsw=200000.00, RL=0.443394, ESR=0.003714, ESL=1.463000e-06
#
# Simulation 12 results:
# Average Current between 0.004 and 0.005 seconds: 2.207317934931173 A
#
# Simulation 13 for L=0.001015, C=0.000115, fsw=20000.00, RL=0.443394, ESR=0.009688, ESL=3.816522e-07
#
# Simulation 13 results:
# Average Current between 0.004 and 0.005 seconds: 2.1892102685401005 A
#
# Simulation 14 for L=0.001015, C=0.000115, fsw=110000.00, RL=0.443394, ESR=0.001761, ESL=3.816522e-07
#
# Simulation 14 results:
# Average Current between 0.004 and 0.005 seconds: 2.1925165572923 A
#
# Simulation 15 for L=0.001015, C=0.000115, fsw=200000.00, RL=0.443394, ESR=0.000969, ESL=3.816522e-07
#
# Simulation 15 results:
# Average Current between 0.004 and 0.005 seconds: 2.191757506122896 A
#
# Simulation 16 for L=0.001015, C=0.000200, fsw=20000.00, RL=0.443394, ESR=0.005570, ESL=2.194500e-07
#
# Simulation 16 results:
# Average Current between 0.004 and 0.005 seconds: 2.210189218564623 A
#
# Simulation 17 for L=0.001015, C=0.000200, fsw=110000.00, RL=0.443394, ESR=0.001013, ESL=2.194500e-07
#
# Simulation 17 results:
# Average Current between 0.004 and 0.005 seconds: 2.2206118616308337 A
#
# Simulation 18 for L=0.001015, C=0.000200, fsw=200000.00, RL=0.443394, ESR=0.000557, ESL=2.194500e-07
#
# Simulation 18 results:
# Average Current between 0.004 and 0.005 seconds: 2.221380712724526 A
#
# Simulation 19 for L=0.002000, C=0.000030, fsw=20000.00, RL=0.443394, ESR=0.037136, ESL=1.463000e-06
#
# Simulation 19 results:
# Average Current between 0.004 and 0.005 seconds: 2.2077869921943662 A
#
# Simulation 20 for L=0.002000, C=0.000030, fsw=110000.00, RL=0.443394, ESR=0.006752, ESL=1.463000e-06
#
# Simulation 20 results:
# Average Current between 0.004 and 0.005 seconds: 2.2062050463326557 A
#
# Simulation 21 for L=0.002000, C=0.000030, fsw=200000.00, RL=0.443394, ESR=0.003714, ESL=1.463000e-06
#
# Simulation 21 results:
# Average Current between 0.004 and 0.005 seconds: 2.2057074895283653 A
#
# Simulation 22 for L=0.002000, C=0.000115, fsw=20000.00, RL=0.443394, ESR=0.009688, ESL=3.816522e-07
#
# Simulation 22 results:
# Average Current between 0.004 and 0.005 seconds: 2.2334948031557067 A
#
# Simulation 23 for L=0.002000, C=0.000115, fsw=110000.00, RL=0.443394, ESR=0.001761, ESL=3.816522e-07
#
# Simulation 23 results:
# Average Current between 0.004 and 0.005 seconds: 2.2366608251040994 A
#
# Simulation 24 for L=0.002000, C=0.000115, fsw=200000.00, RL=0.443394, ESR=0.000969, ESL=3.816522e-07
#
# Simulation 24 results:
# Average Current between 0.004 and 0.005 seconds: 2.236535602931743 A
#
# Simulation 25 for L=0.002000, C=0.000200, fsw=20000.00, RL=0.443394, ESR=0.005570, ESL=2.194500e-07
#
# Simulation 25 results:
# Average Current between 0.004 and 0.005 seconds: 2.179446821143291 A
#
# Simulation 26 for L=0.002000, C=0.000200, fsw=110000.00, RL=0.443394, ESR=0.001013, ESL=2.194500e-07
#
# Simulation 26 results:
# Average Current between 0.004 and 0.005 seconds: 2.1826707660230236 A
#
# Simulation 27 for L=0.002000, C=0.000200, fsw=200000.00, RL=0.443394, ESR=0.000557, ESL=2.194500e-07
#
# Simulation 27 results:
# Average Current between 0.004 and 0.005 seconds: 2.1830247327071093 A

# %%
# Use the function to write data to the CSV file
write_to_csv(csv_file_path, csv_header, csv_data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 2
#       1 # Use the function to write data to the CSV file
# ----> 2 write_to_csv(csv_file_path, csv_header, csv_data)
#
# NameError: name 'csv_file_path' is not defined

# %% [markdown]
# # All

# %%
V_in = 48
V_out = 12
R_on = 5.6
t_rise = 110e-9
t_fall = 78e-9
diode_voltage = 0.5

L_range = (30e-6, 2000e-6)  # Range for L
C_range = (30e-6, 200e-6)   # Range for C
# t_dt_range = (0.178e-6, 1e-6) # Range for dead time
fsw_range = (20e3, 200e3)    # Range for fsw
num_values = 3           # Number of values for each parameter

# Borders for R_L
border_values = [
    (144e-6, 0.079576),
    (509e-6, 0.179228),
    (1003e-6, 0.253239),
    (2519e-6, 0.443394)
]

# Constants for ESL calculation
K_esl = 4.389e-11  # Adjust as needed
tan_delta = 0.14

# Create arrays of discrete L and C values within the specified ranges with increments of 1e-6
L_values = np.linspace(L_range[0], L_range[1], num=num_values)
C_values = np.linspace(C_range[0], C_range[1], num=num_values)
# t_dt_values = np.linspace(t_dt_range[0], t_dt_range[1], num=num_values)


# Round the values to the desired number of decimal places
L_values = np.around(L_values, decimals=6)
C_values = np.around(C_values, decimals=6)
# t_dt_values = np.around(t_dt_values, decimals=9)

fsw_values = np.linspace(fsw_range[0], fsw_range[1], num=num_values, dtype=int)

# Initialize arrays to store results
average_currents = []
delta_currents = []
delta_currents_percentage = []

# Open a CSV file for writing
csv_file_path = 'all_3.csv'

# Define the header for the CSV file
csv_header = ['No','L', 'C', 'delta_current', 'delta_voltage', 'Pl_s1', 'Pl_s2' 'Pl_C', 'Pl_L_Cu']

# Initialize a list to store the data for each simulation
csv_data = []

# Print the chosen values
print("Chosen L values:", L_values)
print("Chosen C values:", C_values)
# print("Chosen dead time values:", t_dt_values)
print("Chosen fsw values:", fsw_values)

# Generate all combinations of L, C, and fsw
combinations = list(itertools.product(L_values, C_values, fsw_values))
print(combinations)
# Display the chosen values and simulate
print("\nChosen values and simulation results:")
# Out:
# Chosen L values: [3.000e-05 1.015e-03 2.000e-03]
# Chosen C values: [3.00e-05 1.15e-04 2.00e-04]
# Chosen fsw values: [ 20000 110000 200000]
# [(3e-05, 3e-05, 20000), (3e-05, 3e-05, 110000), (3e-05, 3e-05, 200000), (3e-05, 0.000115, 20000), (3e-05, 0.000115, 110000), (3e-05, 0.000115, 200000), (3e-05, 0.0002, 20000), (3e-05, 0.0002, 110000), (3e-05, 0.0002, 200000), (0.001015, 3e-05, 20000), (0.001015, 3e-05, 110000), (0.001015, 3e-05, 200000), (0.001015, 0.000115, 20000), (0.001015, 0.000115, 110000), (0.001015, 0.000115, 200000), (0.001015, 0.0002, 20000), (0.001015, 0.0002, 110000), (0.001015, 0.0002, 200000), (0.002, 3e-05, 20000), (0.002, 3e-05, 110000), (0.002, 3e-05, 200000), (0.002, 0.000115, 20000), (0.002, 0.000115, 110000), (0.002, 0.000115, 200000), (0.002, 0.0002, 20000), (0.002, 0.0002, 110000), (0.002, 0.0002, 200000)]
#
# Chosen values and simulation results:

# %%
# Loop through the combinations and simulate
csv_data = []
for simulation_num, (L, C, fsw) in enumerate(combinations, start=1):
    # Rules for picking R_L based on L
    R_L = next((rl for border, rl in border_values if L <= border), 0.0)

    # Calculate ESR and ESL based on the updated C
    ESR = tan_delta / (2 * np.pi * fsw * C)
    ESL = K_esl / C

    # Set Plecs parameters and simulate
    plecs.set(model+'/L1', 'L', str(L))
    plecs.set(model+'/C', 'C', str(C))
    plecs.set(model+'/Symmetrical PWM1', 'fc', str(fsw))
    plecs.set(model+'/RL', 'R', str(R_L))
    plecs.set(model+'/ESR', 'R', str(ESR))
    plecs.set(model+'/ESL', 'L', str(ESL))
    # plecs.set(model+'/Deadtime', 'td', str(t_dt))

    times = plecs.simulate(model)['Time']
    current = plecs.simulate(model)['Values'][0]
    voltage = plecs.simulate(model)['Values'][1]

    # Calculate average and delta current using the function
    average_current, delta_current, delta_current_percentage = calculate_current(times, current, start_time=0.004, end_time=0.005)
    average_voltage, delta_voltage, delta_voltage_percentage = calculate_voltage(times, voltage, start_time=0.004, end_time=0.005)
    Pl_s1, Pl_s2 = calculate_switching_losses(average_current, V_out, V_in, R_on, t_rise, t_fall, fsw)
    Pl_C = calculate_capacitor_losses(average_current, V_in, V_out, fsw, L, ESR)
    Pl_L_Cu = calculate_inductor_copper_loss(average_current, delta_current, R_L)
    # P_D = calculate_dead_time_loss(average_current, fsw, t_dt)

    # Append the data for this simulation to the list
    csv_data.append([simulation_num,L, C, fsw, delta_current_percentage, delta_voltage_percentage, Pl_s1, Pl_s2, Pl_C, Pl_L_Cu])

    print(f'\nSimulation {simulation_num} for L={L:.6f}, C={C:.6f}, fsw={fsw:.2f}, RL={R_L:.6f}, ESR={ESR:.6f}, ESL={ESL:.6e}')
    print(f"\nSimulation {simulation_num} results:")
    print(f"Average Current between 0.004 and 0.005 seconds: {average_current} A")
    print(f"Difference between highest and lowest current values between 0.004 and 0.005 seconds: {delta_current} A")
    print(f"Difference between highest and lowest current values between 0.004 and 0.005 seconds: {delta_current_percentage} %")
    print(f"Difference between highest and lowest voltage values between 0.004 and 0.005 seconds: {delta_voltage} A")
    print(f"Difference between highest and lowest voltage values between 0.004 and 0.005 seconds: {delta_voltage_percentage} %")
    print(f"High Side Switching Losses: {Pl_s1} W")
    print(f"Low Side Switching  Losses: {Pl_s2} W")
    print(f"Capacitor Losses: {Pl_C} W")
    print(f"Inductor Copper Losses: {Pl_L_Cu} W")
    # print(f"Dead time Losses: {P_D} W")
    print(f"Total Losses: {Pl_s1 + Pl_s2 + Pl_C + Pl_L_Cu} W")
# Out:
# Voltage:
#
# max: 12.675008038889622
#
# min: 10.055806220980628
#
# delta: 2.619201817908994
#
# average: 11.548067497351191
#
# Simulation 1 for L=0.000030, C=0.000030, fsw=20000.00, RL=0.079576, ESR=0.037136, ESL=1.463000e-06
#
# Simulation 1 results:
# Average Current between 0.004 and 0.005 seconds: 3.2556026550071735 A
# Difference between highest and lowest current values between 0.004 and 0.005 seconds: 14.944351228442894 A
# Difference between highest and lowest current values between 0.004 and 0.005 seconds: 459.0348642657058 %
# Difference between highest and lowest voltage values between 0.004 and 0.005 seconds: 2.619201817908994 A
# Difference between highest and lowest voltage values between 0.004 and 0.005 seconds: 22.680866894047572 %
# High Side Switching Losses: 2.5727074420928684 W
# Low Side Switching  Losses: 2.5727074420928684 W
# Capacitor Losses: 1.5819122871435367 W
# Inductor Copper Losses: 2.3244217067618997 W
# Total Losses: 9.051748878091173 W
# Voltage:
#
# max: 13.440169149181216
#
# min: 11.241186258736214
#
# delta: 2.198982890445002
#
# average: 12.12019050934885
#
# Simulation 2 for L=0.000030, C=0.000030, fsw=110000.00, RL=0.079576, ESR=0.006752, ESL=1.463000e-06
#
# Simulation 2 results:
# Average Current between 0.004 and 0.005 seconds: 2.488782891491957 A
# Difference between highest and lowest current values between 0.004 and 0.005 seconds: 2.624332881846885 A
# Difference between highest and lowest current values between 0.004 and 0.005 seconds: 105.44643692377961 %
# Difference between highest and lowest voltage values between 0.004 and 0.005 seconds: 2.198982890445002 A
# Difference between highest and lowest voltage values between 0.004 and 0.005 seconds: 18.14313800388556 %
# High Side Switching Losses: 2.977380748749658 W
# Low Side Switching  Losses: 2.977380748749658 W
# Capacitor Losses: 0.09828538987610164 W
# Inductor Copper Losses: 0.5385677582158195 W
# Total Losses: 6.591614645591237 W
# Voltage:
#
# max: 13.445362653254902
#
# min: 11.2541600777645
#
# delta: 2.1912025754904025
#
# average: 12.059002398328614
#
# Simulation 3 for L=0.000030, C=0.000030, fsw=200000.00, RL=0.079576, ESR=0.003714, ESL=1.463000e-06
#
# Simulation 3 results:
# Average Current between 0.004 and 0.005 seconds: 2.4480963015005166 A
# Difference between highest and lowest current values between 0.004 and 0.005 seconds: 1.4511352153038453 A
# Difference between highest and lowest current values between 0.004 and 0.005 seconds: 59.27606746574463 %
# Difference between highest and lowest voltage values between 0.004 and 0.005 seconds: 2.1912025754904025 A
# Difference between highest and lowest voltage values between 0.004 and 0.005 seconds: 18.170678660733202 %
# High Side Switching Losses: 3.9228295135244275 W
# Low Side Switching  Losses: 3.9228295135244275 W
# Capacitor Losses: 0.05077308693411397 W
# Inductor Copper Losses: 0.4908771517544086 W
# Total Losses: 8.387309265737377 W
# Voltage:
#
# max: 12.061593017168697
#
# min: 11.326642890762908
#
# delta: 0.7349501264057885
#
# average: 11.848380834720686
#
# Simulation 4 for L=0.000030, C=0.000115, fsw=20000.00, RL=0.079576, ESR=0.009688, ESL=3.816522e-07
#
# Simulation 4 results:
# Average Current between 0.004 and 0.005 seconds: 2.015067529180449 A
# Difference between highest and lowest current values between 0.004 and 0.005 seconds: 14.97969312750441 A
# Difference between highest and lowest current values between 0.004 and 0.005 seconds: 743.3841750006673 %
# Difference between highest and lowest voltage values between 0.004 and 0.005 seconds: 0.7349501264057885 A
# Difference between highest and lowest voltage values between 0.004 and 0.005 seconds: 6.20295833378413 %
# High Side Switching Losses: 1.5923869642595578 W
# Low Side Switching  Losses: 1.5923869642595578 W
# Capacitor Losses: 0.27015213313744646 W
# Inductor Copper Losses: 1.811131006324687 W
# Total Losses: 5.266057067981249 W
# Voltage:
#
# max: 12.25576610202548
#
# min: 11.65166694612025
#
# delta: 0.6040991559052298
#
# average: 11.91670448774244
#
# Simulation 5 for L=0.000030, C=0.000115, fsw=110000.00, RL=0.079576, ESR=0.001761, ESL=3.816522e-07
#
# Simulation 5 results:
# Average Current between 0.004 and 0.005 seconds: 2.537691919689737 A
# Difference between highest and lowest current values between 0.004 and 0.005 seconds: 2.7016359879625806 A
# Difference between highest and lowest current values between 0.004 and 0.005 seconds: 106.46036136226054 %
# Difference between highest and lowest voltage values between 0.004 and 0.005 seconds: 0.6040991559052298 A
# Difference between highest and lowest voltage values between 0.004 and 0.005 seconds: 5.069347456980309 %
# High Side Switching Losses: 3.035891597363226 W
# Low Side Switching  Losses: 3.035891597363226 W
# Capacitor Losses: 0.026613966927726447 W
# Inductor Copper Losses: 0.5608609342709066 W
# Total Losses: 6.659258095925085 W
# Voltage:
#
# max: 12.264068737181114
#
# min: 11.650601956086662
#
# delta: 0.6134667810944521
#
# average: 11.842870189572531
#
# Simulation 6 for L=0.000030, C=0.000115, fsw=200000.00, RL=0.079576, ESR=0.000969, ESL=3.816522e-07
#
# Simulation 6 results:
# Average Current between 0.004 and 0.005 seconds: 2.3669550373033585 A
# Difference between highest and lowest current values between 0.004 and 0.005 seconds: 1.4892993264977428 A
# Difference between highest and lowest current values between 0.004 and 0.005 seconds: 62.920473901121596 %
# Difference between highest and lowest voltage values between 0.004 and 0.005 seconds: 0.6134667810944521 A
# Difference between highest and lowest voltage values between 0.004 and 0.005 seconds: 5.180051552322175 %
# High Side Switching Losses: 3.792808751774901 W
# Low Side Switching  Losses: 3.792808751774901 W
# Capacitor Losses: 0.012393533722924075 W
# Inductor Copper Losses: 0.46053102212052577 W
# Total Losses: 8.058542059393252 W
# Voltage:
#
# max: 11.961778928758996
#
# min: 11.52811595719546
#
# delta: 0.4336629715635354
#
# average: 11.826869689735616
#
# Simulation 7 for L=0.000030, C=0.000200, fsw=20000.00, RL=0.079576, ESR=0.005570, ESL=2.194500e-07
#
# Simulation 7 results:
# Average Current between 0.004 and 0.005 seconds: 2.259277826903446 A
# Difference between highest and lowest current values between 0.004 and 0.005 seconds: 15.007081334424608 A
# Difference between highest and lowest current values between 0.004 and 0.005 seconds: 664.2424032901359 %
# Difference between highest and lowest voltage values between 0.004 and 0.005 seconds: 0.4336629715635354 A
# Difference between highest and lowest voltage values between 0.004 and 0.005 seconds: 3.6667603765001804 %
# High Side Switching Losses: 1.785371709932179 W
# Low Side Switching  Losses: 1.785371709932179 W
# Capacitor Losses: 0.16842038421943312 W
# Inductor Copper Losses: 1.8996417585407825 W
# Total Losses: 5.638805562624574 W
# Voltage:
#
# max: 12.114666906290156
#
# min: 11.617681802803293
#
# delta: 0.4969851034868622
#
# average: 11.885836233519305
#
# Simulation 8 for L=0.000030, C=0.000200, fsw=110000.00, RL=0.079576, ESR=0.001013, ESL=2.194500e-07
#
# Simulation 8 results:
# Average Current between 0.004 and 0.005 seconds: 2.3060172766352514 A
# Difference between highest and lowest current values between 0.004 and 0.005 seconds: 2.7400475373690574 A
# Difference between highest and lowest current values between 0.004 and 0.005 seconds: 118.82163959183805 %
# Difference between highest and lowest voltage values between 0.004 and 0.005 seconds: 0.4969851034868622 A
# Difference between highest and lowest voltage values between 0.004 and 0.005 seconds: 4.181322152877322 %
# High Side Switching Losses: 2.7587345883842835 W
# Low Side Switching  Losses: 2.7587345883842835 W
# Capacitor Losses: 0.012745831732651291 W
# Inductor Copper Losses: 0.47294966860520754 W
# Total Losses: 6.003164677106426 W
# Voltage:
#
# max: 12.103043000449853
#
# min: 11.636215853487315
#
# delta: 0.46682714696253846
#
# average: 11.867284329832962
#
# Simulation 9 for L=0.000030, C=0.000200, fsw=200000.00, RL=0.079576, ESR=0.000557, ESL=2.194500e-07
#
# Simulation 9 results:
# Average Current between 0.004 and 0.005 seconds: 2.4145527294792837 A
# Difference between highest and lowest current values between 0.004 and 0.005 seconds: 1.52246913350394 A
# Difference between highest and lowest current values between 0.004 and 0.005 seconds: 63.0538780502123 %
# Difference between highest and lowest voltage values between 0.004 and 0.005 seconds: 0.46682714696253846 A
# Difference between highest and lowest voltage values between 0.004 and 0.005 seconds: 3.9337318799128265 %
# High Side Switching Losses: 3.869079293717604 W
# Low Side Switching  Losses: 3.869079293717604 W
# Capacitor Losses: 0.007411529133773229 W
# Inductor Copper Losses: 0.47930409201416607 W
# Total Losses: 8.224874208583149 W
# Voltage:
#
# max: 11.049489471089085
#
# min: 10.969211920579633
#
# delta: 0.08027755050945196
#
# average: 11.021377335369975
#
# Simulation 10 for L=0.001015, C=0.000030, fsw=20000.00, RL=0.443394, ESR=0.037136, ESL=1.463000e-06
#
# Simulation 10 results:
# Average Current between 0.004 and 0.005 seconds: 2.2056078149267755 A
# Difference between highest and lowest current values between 0.004 and 0.005 seconds: 0.4432962015223336 A
# Difference between highest and lowest current values between 0.004 and 0.005 seconds: 20.098595884647366 %
# Difference between highest and lowest voltage values between 0.004 and 0.005 seconds: 0.08027755050945196 A
# Difference between highest and lowest voltage values between 0.004 and 0.005 seconds: 0.7283803835644389 %
# High Side Switching Losses: 1.742959519667735 W
# Low Side Switching  Losses: 1.742959519667735 W
# Capacitor Losses: 0.407085326637952 W
# Inductor Copper Losses: 2.1642423807278113 W
# Total Losses: 6.057246746701233 W
# Voltage:
#
# max: 11.07290884058718
#
# min: 11.004822101938714
#
# delta: 0.06808673864846604
#
# average: 11.030750035784365
#
# Simulation 11 for L=0.001015, C=0.000030, fsw=110000.00, RL=0.443394, ESR=0.006752, ESL=1.463000e-06
#
# Simulation 11 results:
# Average Current between 0.004 and 0.005 seconds: 2.2077439758592026 A
# Difference between highest and lowest current values between 0.004 and 0.005 seconds: 0.08051745539589161 A
# Difference between highest and lowest current values between 0.004 and 0.005 seconds: 3.6470467715603707 %
# Difference between highest and lowest voltage values between 0.004 and 0.005 seconds: 0.06808673864846604 A
# Difference between highest and lowest voltage values between 0.004 and 0.005 seconds: 0.6172448693659894 %
# High Side Switching Losses: 2.641168273199881 W
# Low Side Switching  Losses: 2.641168273199881 W
# Capacitor Losses: 0.07405179754021814 W
# Inductor Copper Losses: 2.161401078516477 W
# Total Losses: 7.517789422456456 W
# Voltage:
#
# max: 11.072974558779901
#
# min: 11.005261756601389
#
# delta: 0.06771280217851228
#
# average: 11.029457580691783
#
# Simulation 12 for L=0.001015, C=0.000030, fsw=200000.00, RL=0.443394, ESR=0.003714, ESL=1.463000e-06
#
# Simulation 12 results:
# Average Current between 0.004 and 0.005 seconds: 2.207317934931173 A
# Difference between highest and lowest current values between 0.004 and 0.005 seconds: 0.044292674454045944 A
# Difference between highest and lowest current values between 0.004 and 0.005 seconds: 2.006628666994773 %
# Difference between highest and lowest voltage values between 0.004 and 0.005 seconds: 0.06771280217851228 A
# Difference between highest and lowest voltage values between 0.004 and 0.005 seconds: 0.6139268561769584 %
# High Side Switching Losses: 3.5370062589337117 W
# Low Side Switching  Losses: 3.5370062589337117 W
# Capacitor Losses: 0.04071136914368219 W
# Inductor Copper Losses: 2.1603999988958487 W
# Total Losses: 9.275123885906954 W
# Voltage:
#
# max: 11.015351909190164
#
# min: 10.918206081633562
#
# delta: 0.09714582755660217
#
# average: 10.962964109040184
#
# Simulation 13 for L=0.001015, C=0.000115, fsw=20000.00, RL=0.443394, ESR=0.009688, ESL=3.816522e-07
#
# Simulation 13 results:
# Average Current between 0.004 and 0.005 seconds: 2.1892102685401005 A
# Difference between highest and lowest current values between 0.004 and 0.005 seconds: 0.5075442570321378 A
# Difference between highest and lowest current values between 0.004 and 0.005 seconds: 23.18389714892939 %
# Difference between highest and lowest voltage values between 0.004 and 0.005 seconds: 0.09714582755660217 A
# Difference between highest and lowest voltage values between 0.004 and 0.005 seconds: 0.8861273884541374 %
# High Side Switching Losses: 1.7300015226111292 W
# Low Side Switching  Losses: 1.7300015226111292 W
# Capacitor Losses: 0.1046253659171015 W
# Inductor Copper Losses: 2.1345467640739066 W
# Total Losses: 5.699175175213266 W
# Voltage:
#
# max: 11.028362073129914
#
# min: 10.92194689814145
#
# delta: 0.10641517498846476
#
# average: 10.963427696036538
#
# Simulation 14 for L=0.001015, C=0.000115, fsw=110000.00, RL=0.443394, ESR=0.001761, ESL=3.816522e-07
#
# Simulation 14 results:
# Average Current between 0.004 and 0.005 seconds: 2.1925165572923 A
# Difference between highest and lowest current values between 0.004 and 0.005 seconds: 0.14627522705418006 A
# Difference between highest and lowest current values between 0.004 and 0.005 seconds: 6.671567727398423 %
# Difference between highest and lowest voltage values between 0.004 and 0.005 seconds: 0.10641517498846476 A
# Difference between highest and lowest voltage values between 0.004 and 0.005 seconds: 0.9706378145489627 %
# High Side Switching Losses: 2.622951407819924 W
# Low Side Switching  Losses: 2.622951407819924 W
# Capacitor Losses: 0.01905231112608461 W
# Inductor Copper Losses: 2.132242678926384 W
# Total Losses: 7.397197805692317 W
# Voltage:
#
# max: 11.027231586901634
#
# min: 10.92564976858618
#
# delta: 0.10158181831545399
#
# average: 10.961903813320239
#
# Simulation 15 for L=0.001015, C=0.000115, fsw=200000.00, RL=0.443394, ESR=0.000969, ESL=3.816522e-07
#
# Simulation 15 results:
# Average Current between 0.004 and 0.005 seconds: 2.191757506122896 A
# Difference between highest and lowest current values between 0.004 and 0.005 seconds: 0.11016119818679115 A
# Difference between highest and lowest current values between 0.004 and 0.005 seconds: 5.026158134695318 %
# Difference between highest and lowest voltage values between 0.004 and 0.005 seconds: 0.10158181831545399 A
# Difference between highest and lowest voltage values between 0.004 and 0.005 seconds: 0.926680438410871 %
# High Side Switching Losses: 3.5120722278113283 W
# Low Side Switching  Losses: 3.5120722278113283 W
# Capacitor Losses: 0.010471151328521867 W
# Inductor Copper Losses: 2.130424925634124 W
# Total Losses: 9.165040532585303 W
# Voltage:
#
# max: 11.530089146396467
#
# min: 11.111129113743464
#
# delta: 0.4189600326530023
#
# average: 11.397938979424238
#
# Simulation 16 for L=0.001015, C=0.000200, fsw=20000.00, RL=0.443394, ESR=0.005570, ESL=2.194500e-07
#
# Simulation 16 results:
# Average Current between 0.004 and 0.005 seconds: 2.210189218564623 A
# Difference between highest and lowest current values between 0.004 and 0.005 seconds: 0.806389629597615 A
# Difference between highest and lowest current values between 0.004 and 0.005 seconds: 36.485094707018504 %
# Difference between highest and lowest voltage values between 0.004 and 0.005 seconds: 0.4189600326530023 A
# Difference between highest and lowest voltage values between 0.004 and 0.005 seconds: 3.675752549731284 %
# High Side Switching Losses: 1.7465799280785077 W
# Low Side Switching  Losses: 1.7465799280785077 W
# Capacitor Losses: 0.06131635760073612 W
# Inductor Copper Losses: 2.189978420439003 W
# Total Losses: 5.744454634196755 W
# Voltage:
#
# max: 11.540493528614004
#
# min: 11.114490198097348
#
# delta: 0.4260033305166555
#
# average: 11.40448832218596
#
# Simulation 17 for L=0.001015, C=0.000200, fsw=110000.00, RL=0.443394, ESR=0.001013, ESL=2.194500e-07
#
# Simulation 17 results:
# Average Current between 0.004 and 0.005 seconds: 2.2206118616308337 A
# Difference between highest and lowest current values between 0.004 and 0.005 seconds: 0.4600358495635124 A
# Difference between highest and lowest current values between 0.004 and 0.005 seconds: 20.716625787347578 %
# Difference between highest and lowest voltage values between 0.004 and 0.005 seconds: 0.4260033305166555 A
# Difference between highest and lowest voltage values between 0.004 and 0.005 seconds: 3.735400646497406 %
# High Side Switching Losses: 2.656562382306199 W
# Low Side Switching  Losses: 2.656562382306199 W
# Capacitor Losses: 0.01123762434282176 W
# Inductor Copper Losses: 2.1942474417417164 W
# Total Losses: 7.518609830696935 W
# Voltage:
#
# max: 11.540315797996954
#
# min: 11.113907576346923
#
# delta: 0.42640822165003023
#
# average: 11.405008311658007
#
# Simulation 18 for L=0.001015, C=0.000200, fsw=200000.00, RL=0.443394, ESR=0.000557, ESL=2.194500e-07
#
# Simulation 18 results:
# Average Current between 0.004 and 0.005 seconds: 2.221380712724526 A
# Difference between highest and lowest current values between 0.004 and 0.005 seconds: 0.42538050037469155 A
# Difference between highest and lowest current values between 0.004 and 0.005 seconds: 19.149373987899708 %
# Difference between highest and lowest voltage values between 0.004 and 0.005 seconds: 0.42640822165003023 A
# Difference between highest and lowest voltage values between 0.004 and 0.005 seconds: 3.738780455023106 %
# High Side Switching Losses: 3.55954045406978 W
# Low Side Switching  Losses: 3.55954045406978 W
# Capacitor Losses: 0.00618476346475877 W
# Inductor Copper Losses: 2.194627960898578 W
# Total Losses: 9.319893632502897 W
# Voltage:
#
# max: 11.036257691711224
#
# min: 10.995375555954462
#
# delta: 0.04088213575676214
#
# average: 11.021200225506913
#
# Simulation 19 for L=0.002000, C=0.000030, fsw=20000.00, RL=0.443394, ESR=0.037136, ESL=1.463000e-06
#
# Simulation 19 results:
# Average Current between 0.004 and 0.005 seconds: 2.2077869921943662 A
# Difference between highest and lowest current values between 0.004 and 0.005 seconds: 0.22498826109326675 A
# Difference between highest and lowest current values between 0.004 and 0.005 seconds: 10.190668841184092 %
# Difference between highest and lowest voltage values between 0.004 and 0.005 seconds: 0.04088213575676214 A
# Difference between highest and lowest voltage values between 0.004 and 0.005 seconds: 0.3709408677844957 %
# High Side Switching Losses: 1.7446815927116759 W
# Low Side Switching  Losses: 1.7446815927116759 W
# Capacitor Losses: 0.40743731664234983 W
# Inductor Copper Losses: 2.163116124163178 W
# Total Losses: 6.05991662622888 W
# Voltage:
#
# max: 11.048140474081604
#
# min: 11.013624972026685
#
# delta: 0.03451550205491927
#
# average: 11.026769205908783
#
# Simulation 20 for L=0.002000, C=0.000030, fsw=110000.00, RL=0.443394, ESR=0.006752, ESL=1.463000e-06
#
# Simulation 20 results:
# Average Current between 0.004 and 0.005 seconds: 2.2062050463326557 A
# Difference between highest and lowest current values between 0.004 and 0.005 seconds: 0.04088741620077574 A
# Difference between highest and lowest current values between 0.004 and 0.005 seconds: 1.8532917540344824 %
# Difference between highest and lowest voltage values between 0.004 and 0.005 seconds: 0.03451550205491927 A
# Difference between highest and lowest voltage values between 0.004 and 0.005 seconds: 0.3130155479850241 %
# High Side Switching Losses: 2.6393272210286827 W
# Low Side Switching  Losses: 2.6393272210286827 W
# Capacitor Losses: 0.07394588709345443 W
# Inductor Copper Losses: 2.1582114366665563 W
# Total Losses: 7.510811765817376 W
# Voltage:
#
# max: 11.048176012118773
#
# min: 11.013774646401716
#
# delta: 0.03440136571705743
#
# average: 11.025653038372514
#
# Simulation 21 for L=0.002000, C=0.000030, fsw=200000.00, RL=0.443394, ESR=0.003714, ESL=1.463000e-06
#
# Simulation 21 results:
# Average Current between 0.004 and 0.005 seconds: 2.2057074895283653 A
# Difference between highest and lowest current values between 0.004 and 0.005 seconds: 0.02249104753892084 A
# Difference between highest and lowest current values between 0.004 and 0.005 seconds: 1.0196749861755232 %
# Difference between highest and lowest voltage values between 0.004 and 0.005 seconds: 0.03440136571705743 A
# Difference between highest and lowest voltage values between 0.004 and 0.005 seconds: 0.31201204679061245 %
# High Side Switching Losses: 3.5344256812202524 W
# Low Side Switching  Losses: 3.5344256812202524 W
# Capacitor Losses: 0.04065153456076155 W
# Inductor Copper Losses: 2.1571950276475564 W
# Total Losses: 9.266697924648822 W
# Voltage:
#
# max: 11.120029233537698
#
# min: 10.895027878622331
#
# delta: 0.2250013549153671
#
# average: 11.056302356330496
#
# Simulation 22 for L=0.002000, C=0.000115, fsw=20000.00, RL=0.443394, ESR=0.009688, ESL=3.816522e-07
#
# Simulation 22 results:
# Average Current between 0.004 and 0.005 seconds: 2.2334948031557067 A
# Difference between highest and lowest current values between 0.004 and 0.005 seconds: 0.2529772883316026 A
# Difference between highest and lowest current values between 0.004 and 0.005 seconds: 11.326522361913302 %
# Difference between highest and lowest voltage values between 0.004 and 0.005 seconds: 0.2250013549153671 A
# Difference between highest and lowest voltage values between 0.004 and 0.005 seconds: 2.0350506676089437 %
# High Side Switching Losses: 1.7649969332457658 W
# Low Side Switching  Losses: 1.7649969332457658 W
# Capacitor Losses: 0.10877671701469517 W
# Inductor Copper Losses: 2.2142352173826616 W
# Total Losses: 5.853005800888889 W
# Voltage:
#
# max: 11.124887234825865
#
# min: 10.892495988725745
#
# delta: 0.23239124610011963
#
# average: 11.057664759332315
#
# Simulation 23 for L=0.002000, C=0.000115, fsw=110000.00, RL=0.443394, ESR=0.001761, ESL=3.816522e-07
#
# Simulation 23 results:
# Average Current between 0.004 and 0.005 seconds: 2.2366608251040994 A
# Difference between highest and lowest current values between 0.004 and 0.005 seconds: 0.07054955409168118 A
# Difference between highest and lowest current values between 0.004 and 0.005 seconds: 3.1542356936661435 %
# Difference between highest and lowest voltage values between 0.004 and 0.005 seconds: 0.23239124610011963 A
# Difference between highest and lowest voltage values between 0.004 and 0.005 seconds: 2.101630417977619 %
# High Side Switching Losses: 2.675762078288536 W
# Low Side Switching  Losses: 2.675762078288536 W
# Capacitor Losses: 0.019826488535490124 W
# Inductor Copper Losses: 2.2183296306867177 W
# Total Losses: 7.58968027579928 W
# Voltage:
#
# max: 11.12442877940856
#
# min: 10.891671211338439
#
# delta: 0.23275756807012193
#
# average: 11.057359892654905
#
# Simulation 24 for L=0.002000, C=0.000115, fsw=200000.00, RL=0.443394, ESR=0.000969, ESL=3.816522e-07
#
# Simulation 24 results:
# Average Current between 0.004 and 0.005 seconds: 2.236535602931743 A
# Difference between highest and lowest current values between 0.004 and 0.005 seconds: 0.05231166600229464 A
# Difference between highest and lowest current values between 0.004 and 0.005 seconds: 2.3389596809334203 %
# Difference between highest and lowest voltage values between 0.004 and 0.005 seconds: 0.23275756807012193 A
# Difference between highest and lowest voltage values between 0.004 and 0.005 seconds: 2.1050012871945705 %
# High Side Switching Losses: 3.583824650137825 W
# Low Side Switching  Losses: 3.583824650137825 W
# Capacitor Losses: 0.01090325349546093 W
# Inductor Copper Losses: 2.217998472652572 W
# Total Losses: 9.396551026423683 W
# Voltage:
#
# max: 10.72843241741595
#
# min: 10.122387766982314
#
# delta: 0.6060446504336365
#
# average: 10.335934900838392
#
# Simulation 25 for L=0.002000, C=0.000200, fsw=20000.00, RL=0.443394, ESR=0.005570, ESL=2.194500e-07
#
# Simulation 25 results:
# Average Current between 0.004 and 0.005 seconds: 2.179446821143291 A
# Difference between highest and lowest current values between 0.004 and 0.005 seconds: 0.5629873617854202 A
# Difference between highest and lowest current values between 0.004 and 0.005 seconds: 25.831663169009516 %
# Difference between highest and lowest voltage values between 0.004 and 0.005 seconds: 0.6060446504336365 A
# Difference between highest and lowest voltage values between 0.004 and 0.005 seconds: 5.863472015332427 %
# High Side Switching Losses: 1.7222860559402742 W
# Low Side Switching  Losses: 1.7222860559402742 W
# Capacitor Losses: 0.059557251313277645 W
# Inductor Copper Losses: 2.1178276973674297 W
# Total Losses: 5.621957060561256 W
# Voltage:
#
# max: 10.720549594361866
#
# min: 10.119492642630943
#
# delta: 0.6010569517309232
#
# average: 10.332661831863389
#
# Simulation 26 for L=0.002000, C=0.000200, fsw=110000.00, RL=0.443394, ESR=0.001013, ESL=2.194500e-07
#
# Simulation 26 results:
# Average Current between 0.004 and 0.005 seconds: 2.1826707660230236 A
# Difference between highest and lowest current values between 0.004 and 0.005 seconds: 0.38907830135322974 A
# Difference between highest and lowest current values between 0.004 and 0.005 seconds: 17.825789734754967 %
# Difference between highest and lowest voltage values between 0.004 and 0.005 seconds: 0.6010569517309232 A
# Difference between highest and lowest voltage values between 0.004 and 0.005 seconds: 5.817058193827764 %
# High Side Switching Losses: 2.6111726908086634 W
# Low Side Switching  Losses: 2.6111726908086634 W
# Capacitor Losses: 0.010856507042019726 W
# Inductor Copper Losses: 2.1179454138547458 W
# Total Losses: 7.351147302514092 W
# Voltage:
#
# max: 10.722156299264833
#
# min: 10.119222568295378
#
# delta: 0.6029337309694558
#
# average: 10.332267181083623
#
# Simulation 27 for L=0.002000, C=0.000200, fsw=200000.00, RL=0.443394, ESR=0.000557, ESL=2.194500e-07
#
# Simulation 27 results:
# Average Current between 0.004 and 0.005 seconds: 2.1830247327071093 A
# Difference between highest and lowest current values between 0.004 and 0.005 seconds: 0.3716887031785807 A
# Difference between highest and lowest current values between 0.004 and 0.005 seconds: 17.02631663351151 %
# Difference between highest and lowest voltage values between 0.004 and 0.005 seconds: 0.6029337309694558 A
# Difference between highest and lowest voltage values between 0.004 and 0.005 seconds: 5.835444635745681 %
# High Side Switching Losses: 3.498078831689872 W
# Low Side Switching  Losses: 3.498078831689872 W
# Capacitor Losses: 0.005972961494435445 W
# Inductor Copper Losses: 2.1181417744569533 W
# Total Losses: 9.120272399331132 W

# %%
# Use the function to write data to the CSV file
write_to_csv(csv_file_path, csv_header, csv_data)

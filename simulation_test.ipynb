# %% [markdown]
# # Spesifikasi

# %% [markdown]
# - V<sub>in</sub> = 48V
# - V<sub>out</sub> = 12V
# - P<sub>o</sub> = 100W
# - &#916;V<sub>o</sub> &#8804; 1%
# - &#916;I<sub>L</sub> &#8804; 10%
# - f<sub>sw</sub> = 20e3
# - Mosfet: IRFB4310PbF, Infineon

# %% [markdown]
# # Plecs

# %%
import xmlrpc.client as xml
import os
import numpy as np
import itertools
import csv

# %%
model = 'buck'
file_type = '.plecs'
V_in = 48
V_out = 12
f_sw = 20e3

# %%
plecs = xml.Server("http://localhost:1080/RPC2").plecs

# %%
# plecs.load(r"D:\Krishna\ai-power-converter\buck.plecs")
plecs.load(r"E:\ai-power-converter\buck.plecs")
# Out:
# 0

# %%
plecs.get(model+'/L1')
# Out:
# {'CommentStatus': 'Active',
#  'L': '0.001256',
#  'Name': 'L1',
#  'Type': 'Inductor',
#  'i_init': '0'}

# %%
plecs.get(model+'/C')
# Out:
# {'C': '8.1e-05',
#  'CommentStatus': 'Active',
#  'Name': 'C',
#  'Type': 'Capacitor',
#  'v_init': '0'}

# %%
plecs.get(model+'/Symmetrical PWM1')
# Out:
# {'CommentStatus': 'Active',
#  'Name': 'Symmetrical PWM1',
#  'Type': 'Subsystem',
#  'carrier_limits': '[0 1]',
#  'carrier_phaseshift': '0',
#  'fc': '176495.0',
#  'output_values': '[-1 1]',
#  'sampling': 'Natural (carrier starts at center)'}

# %%
plecs.get(model+'/RL')
# Out:
# {'CommentStatus': 'Active', 'Name': 'RL', 'R': '0.443394', 'Type': 'Resistor'}

# %%
RL = plecs.get(model+'/RL', 'R')

# %%
plecs.get(model+'/ESR')
# Out:
# {'CommentStatus': 'Active',
#  'Name': 'ESR',
#  'R': '0.0015585858958593482',
#  'Type': 'Resistor'}

# %%
plecs.get(model+'/ESL')
# Out:
# {'CommentStatus': 'Active',
#  'L': '5.418518518518518e-07',
#  'Name': 'ESL',
#  'Type': 'Inductor',
#  'i_init': '0'}

# %%
plecs.get(model+'/Deadtime')
# Out:
# {'CommentStatus': 'Active',
#  'Configuration': 'on',
#  'Name': 'Deadtime',
#  'Type': 'ConfigurableSubsystem',
#  'td': '9.66e-07'}

# %%
V_in = 48
V_out = 12
R_on = 5.6
t_rise = 110e-9
t_fall = 78e-9
diode_voltage = 0.5

L_range = (30e-6, 2000e-6)  # Range for L
C_range = (30e-6, 200e-6)   # Range for C
t_dt_range = (0.178e-6, 1e-6) # Range for dead time
fsw_range = (20e3, 200e3)    # Range for fsw
num_values = 15           # Number of values for each parameter

# Borders for R_L
border_values = [
    (144e-6, 0.079576),
    (509e-6, 0.179228),
    (1003e-6, 0.253239),
    (2519e-6, 0.443394)
]

# Constants for ESL calculation
K_esl = 4.389e-11  # Adjust as needed
tan_delta = 0.14

# Create arrays of discrete L and C values within the specified ranges with increments of 1e-6
L_values = np.linspace(L_range[0], L_range[1], num=num_values)
C_values = np.linspace(C_range[0], C_range[1], num=num_values)
t_dt_values = np.linspace(t_dt_range[0], t_dt_range[1], num=num_values)


# Round the values to the desired number of decimal places
L_values = np.around(L_values, decimals=6)
C_values = np.around(C_values, decimals=6)
t_dt_values = np.around(t_dt_values, decimals=9)

fsw_values = np.linspace(fsw_range[0], fsw_range[1], num=num_values, dtype=int)

# Initialize arrays to store results
average_currents = []
delta_currents = []
delta_currents_percentage = []

# Open a CSV file for writing
csv_file_path = 'simulation_results_new_15_15_15_15.csv'

# Define the header for the CSV file
csv_header = ['No','L', 'C','fsw', 't_dt', 'delta_current', 'delta_voltage', 'Pl_s1', 'Pl_s2' ,'Pl_C', 'Pl_L_Cu', 'P_D']

# Initialize a list to store the data for each simulation
csv_data = []

# Print the chosen values
print("Chosen L values:", L_values)
print("Chosen C values:", C_values)
print("Chosen dead time values:", t_dt_values)
print("Chosen fsw values:", fsw_values)

# Generate all combinations of L, C, and fsw
combinations = list(itertools.product(L_values, C_values, fsw_values, t_dt_values))
print(combinations)
# Display the chosen values and simulate
print("\nChosen values and simulation results:")
# Out:
# Chosen L values: [3.000e-05 1.710e-04 3.110e-04 4.520e-04 5.930e-04 7.340e-04 8.740e-04
#  1.015e-03 1.156e-03 1.296e-03 1.437e-03 1.578e-03 1.719e-03 1.859e-03
#  2.000e-03]
# Chosen C values: [3.00e-05 4.20e-05 5.40e-05 6.60e-05 7.90e-05 9.10e-05 1.03e-04 1.15e-04
#  1.27e-04 1.39e-04 1.51e-04 1.64e-04 1.76e-04 1.88e-04 2.00e-04]
# Chosen dead time values: [1.78e-07 2.37e-07 2.95e-07 3.54e-07 4.13e-07 4.72e-07 5.30e-07 5.89e-07
#  6.48e-07 7.06e-07 7.65e-07 8.24e-07 8.83e-07 9.41e-07 1.00e-06]
# Chosen fsw values: [ 20000  32857  45714  58571  71428  84285  97142 110000 122857 135714
#  148571 161428 174285 187142 200000]
# [(3e-05, 3e-05, 20000, 1.78e-07), (3e-05, 3e-05, 20000, 2.37e-07), (3e-05, 3e-05, 20000, 2.95e-07), (3e-05, 3e-05, 20000, 3.54e-07), (3e-05, 3e-05, 20000, 4.13e-07), (3e-05, 3e-05, 20000, 4.72e-07), (3e-05, 3e-05, 20000, 5.3e-07), (3e-05, 3e-05, 20000, 5.89e-07), (3e-05, 3e-05, 20000, 6.48e-07), (3e-05, 3e-05, 20000, 7.06e-07), (3e-05, 3e-05, 20000, 7.65e-07), (3e-05, 3e-05, 20000, 8.24e-07), (3e-05, 3e-05, 20000, 8.83e-07), (3e-05, 3e-05, 20000, 9.41e-07), (3e-05, 3e-05, 20000, 1e-06), (3e-05, 3e-05, 32857, 1.78e-07), (3e-05, 3e-05, 32857, 2.37e-07), (3e-05, 3e-05, 32857, 2.95e-07), (3e-05, 3e-05, 32857, 3.54e-07), (3e-05, 3e-05, 32857, 4.13e-07), (3e-05, 3e-05, 32857, 4.72e-07), (3e-05, 3e-05, 32857, 5.3e-07), (3e-05, 3e-05, 32857, 5.89e-07), (3e-05, 3e-05, 32857, 6.48e-07), (3e-05, 3e-05, 32857, 7.06e-07), (3e-05, 3e-05, 32857, 7.65e-07), (3e-05, 3e-05, 32857, 8.24e-07), (3e-05, 3e-05, 32857, 8.83e-07), (3e-05, 3e-05, 32857, 9.41e-07), (3e-05, 3e-05, 32857, 1e-06), (3e-05, 3e-05, 45714, 1.78e-07), (3e-05, 3e-05, 45714, 2.37e-07), (3e-05, 3e-05, 45714, 2.95e-07), (3e-05, 3e-05, 45714, 3.54e-07), (3e-05, 3e-05, 45714, 4.13e-07), (3e-05, 3e-05, 45714, 4.72e-07), (3e-05, 3e-05, 45714, 5.3e-07), (3e-05, 3e-05, 45714, 5.89e-07), (3e-05, 3e-05, 45714, 6.48e-07), (3e-05, 3e-05, 45714, 7.06e-07), (3e-05, 3e-05, 45714, 7.65e-07), (3e-05, 3e-05, 45714, 8.24e-07), (3e-05, 3e-05, 45714, 8.83e-07), (3e-05, 3e-05, 45714, 9.41e-07), (3e-05, 3e-05, 45714, 1e-06), (3e-05, 3e-05, 58571, 1.78e-07), (3e-05, 3e-05, 58571, 2.37e-07), (3e-05, 3e-05, 58571, 2.95e-07), (3e-05, 3e-05, 58571, 3.54e-07), (3e-05, 3e-05, 58571, 4.13e-07), (3e-05, 3e-05, 58571, 4.72e-07), (3e-05, 3e-05, 58571, 5.3e-07), (3e-05, 3e-05, 58571, 5.89e-07), (3e-05, 3e-05, 58571, 6.48e-07), (3e-05, 3e-05, 58571, 7.06e-07), (3e-05, 3e-05, 58571, 7.65e-07), (3e-05, 3e-05, 58571, 8.24e-07), (3e-05, 3e-05, 58571, 8.83e-07), (3e-05, 3e-05, 58571, 9.41e-07), (3e-05, 3e-05, 58571, 1e-06), (3e-05, 3e-05, 71428, 1.78e-07), (3e-05, 3e-05, 71428, 2.37e-07), (3e-05, 3e-05, 71428, 2.95e-07), (3e-05, 3e-05, 71428, 3.54e-07), (3e-05, 3e-05, 71428, 4.13e-07), (3e-05, 3e-05, 71428, 4.72e-07), (3e-05, 3e-05, 71428, 5.3e-07), (3e-05, 3e-05, 71428, 5.89e-07), (3e-05, 3e-05, 71428, 6.48e-07), (3e-05, 3e-05, 71428, 7.06e-07), (3e-05, 3e-05, 71428, 7.65e-07), (3e-05, 3e-05, 71428, 8.24e-07), (3e-05, 3e-05, 71428, 8.83e-07), (3e-05, 3e-05, 71428, 9.41e-07), (3e-05, 3e-05, 71428, 1e-06), (3e-05, 3e-05, 84285, 1.78e-07), (3e-05, 3e-05, 84285, 2.37e-07), (3e-05, 3e-05, 84285, 2.95e-07), (3e-05, 3e-05, 84285, 3.54e-07), (3e-05, 3e-05, 84285, 4.13e-07), (3e-05, 3e-05, 84285, 4.72e-07), (3e-05, 3e-05, 84285, 5.3e-07), (3e-05, 3e-05, 84285, 5.89e-07), (3e-05, 3e-05, 84285, 6.48e-07), (3e-05, 3e-05, 84285, 7.06e-07), (3e-05, 3e-05, 84285, 7.65e-07), (3e-05, 3e-05, 84285, 8.24e-07), (3e-05, 3e-05, 84285, 8.83e-07), (3e-05, 3e-05, 84285, 9.41e-07), (3e-05, 3e-05, 84285, 1e-06), (3e-05, 3e-05, 97142, 1.78e-07), (3e-05, 3e-05, 97142, 2.37e-07), (3e-05, 3e-05, 97142, 2.95e-07), (3e-05, 3e-05, 97142, 3.54e-07), (3e-05, 3e-05, 97142, 4.13e-07), (3e-05, 3e-05, 97142, 4.72e-07), (3e-05, 3e-05, 97142, 5.3e-07), (3e-05, 3e-05, 97142, 5.89e-07), (3e-05, 3e-05, 97142, 6.48e-07), (3e-05, 3e-05, 97142, 7.06e-07), (3e-05, 3e-05, 97142, 7.65e-07), (3e-05, 3e-05, 97142, 8.24e-07), (3e-05, 3e-05, 97142, 8.83e-07), (3e-05, 3e-05, 97142, 9.41e-07), (3e-05, 3e-05, 97142, 1e-06), (3e-05, 3e-05, 110000, 1.78e-07), (3e-05, 3e-05, 110000, 2.37e-07), (3e-05, 3e-05, 110000, 2.95e-07), (3e-05, 3e-05, 110000, 3.54e-07), (3e-05, 3e-05, 110000, 4.13e-07), (3e-05, 3e-05, 110000, 4.72e-07), (3e-05, 3e-05, 110000, 5.3e-07), (3e-05, 3e-05, 110000, 5.89e-07), (3e-05, 3e-05, 110000, 6.48e-07), (3e-05, 3e-05, 110000, 7.06e-07), (3e-05, 3e-05, 110000, 7.65e-07), (3e-05, 3e-05, 110000, 8.24e-07), (3e-05, 3e-05, 110000, 8.83e-07), (3e-05, 3e-05, 110000, 9.41e-07), (3e-05, 3e-05, 110000, 1e-06), (3e-05, 3e-05, 122857, 1.78e-07), (3e-05, 3e-05, 122857, ...
#
# Chosen values and simulation results:

# %% [markdown]
# # Functions

# %% [markdown]
# ## Write to CSV

# %%
def write_to_csv(file_path, header, data):
    with open(file_path, 'w', newline='') as csv_file:
        csv_writer = csv.writer(csv_file)
        csv_writer.writerow(header)
        csv_writer.writerows(data)

# %% [markdown]
# ## Ripples

# %% [markdown]
# ### Current
# - Average
# - &Delta;I<sub>L</sub>%

# %%
def calculate_current(times, current, start_time, end_time):
    # Convert 'times' to a NumPy array
    times = np.array(times)

    # Find the indices corresponding to the time range
    start_index = np.argmax(times >= start_time)
    end_index = np.argmax(times >= end_time)

    # Extract the current values in the specified time range
    current_range = current[start_index:end_index]

    # Calculate the average current value
    average_current = np.mean(current_range)

    # Calculate the difference between the highest and lowest current values
    delta_current = np.max(current_range) - np.min(current_range)

    # print(np.max(current_range))
    # print(np.min(current_range))
    delta_current_percentage = delta_current/average_current *100

    return average_current, delta_current, delta_current_percentage

# %% [markdown]
# ### &Delta;V<sub>O</sub>%

# %%
def calculate_voltage(times, voltage, start_time, end_time):
    # Convert 'times' to a NumPy array
    times = np.array(times)

    # Find the indices corresponding to the time range
    start_index = np.argmax(times >= start_time)
    end_index = np.argmax(times >= end_time)

    # Extract the voltage values in the specified time range
    voltage_range = voltage[start_index:end_index]

    # Calculate the average voltage value
    average_voltage = np.mean(voltage_range)

    # Calculate the difference between the highest and lowest voltage values
    delta_voltage = np.max(voltage_range) - np.min(voltage_range)

    # print('Voltage:')
    # print("\nmax:", np.max(voltage_range))
    # print("\nmin:", np.min(voltage_range))
    # print("\ndelta:",delta_voltage)
    # print("\naverage:",average_voltage)

    delta_voltage_percentage = delta_voltage/average_voltage * 100

    return average_voltage, delta_voltage, delta_voltage_percentage

# %% [markdown]
# ## Switching Losses
# - Conduction Loss
#     - R<sub>DS(on)</sub> = R<sub>ON-H</sub> = R<sub>ON-L</sub> = 5.6k&Omega;
#     - High Side
#         - P<sub>ON-H</sub> = I<sub>OUT</sub> / 2 &times; R<sub>ON-H</sub> &times; V<sub>OUT</sub> / V<sub>IN</sub> [W]
#     - Low Side
#         - P<sub>ON-L</sub> = I<sub>OUT</sub> / 2 &times; R<sub>ON-L</sub> &times; (1 - V<sub>OUT</sub> / V<sub>IN</sub>) [W]
# - Switching Losses
#     - t<sub>rise</sub> = 110 ns
#     - t<sub>fall</sub> = 78 ns
#     - High Side
#         - P<sub>SW-H</sub> = 1/2 &times; V<sub>IN</sub> &times; I<sub>OUT</sub> &times; (t<sub>rise-H</sub> + t<sub>fall-H</sub>) &times; f<sub>SW</sub>
#     - Low Side
#         - P<sub>SW-L</sub> = 1/2 &times; V<sub>D</sub> &times; I<sub>OUT</sub> &times; (t<sub>rise-L</sub> + t<sub>fall-L</sub>) &times; f<sub>SW</sub>
#
#
#
# <strong>Switching Losses<strong> = P<sub>ON-H</sub> + P<sub>ON-L</sub> + P<sub>SW-H</sub> + P<sub>SW-L</sub>

# %%
def calculate_switching_losses(average_current, V_out, V_in, R_on, t_rise, t_fall, f_sw):
    # Calculate power losses during ON state (High and Low)
    P_ON_H = average_current / 2 * R_on * V_out / V_in
    P_ON_L = average_current / 2 * R_on * V_out / V_in

    # Calculate power losses during switching (High and Low)
    P_SW_H = 0.5 * V_in * average_current * (t_rise + t_fall) * f_sw
    P_SW_L = 0.5 * V_in * average_current * (t_rise + t_fall) * f_sw

    # High Side
    Pl_s1 = P_ON_H + P_SW_H

    #Low Side
    Pl_s2 = P_ON_L + P_SW_L

    return Pl_s1, Pl_s2

# %% [markdown]
# ## Capacitor Loss
# - P<sub>CAP(ESR)</sub> = I<sub>CAP(RMS)</sub><sup>2</sup>  &#x00D7; ESR [W]
# - ESR = tan(&#x03B4;) / 2&pi;f<sub>SW</sub>C)
#     - Dengan 25 V Nippon KZE series: tan &#x03B4; = 0.14
# - ESL = 1 / (4π² SRF² C)
#     - Assume SRF = 100kHz
# - Input Capacitor
#     - I<sub>CIN(RMS)</sub> = I<sub>OUT</sub> &times; &radic;(V<sub>IN</sub> - V<sub>OUT</sub>) &times; V<sub>OUT</sub> / V<sub>IN</sub> [A]
# - Output Capacitor
#     - I<sub>COUT(RMS)</sub> = &Delta;I<sub>L</sub> / (2&radic;3) [A]
#     - &Delta;I<sub>L</sub> = (V<sub>IN</sub> - V<sub>OUT</sub>) / (f<sub>SW</sub> &times; L) &times; V<sub>OUT</sub> / V<sub>IN</sub> [A]
#
# <strong>Capacitor Losses<strong> = P<sub>cap_in</sub> + P<sub>cap_out</sub>

# %%
def calculate_capacitor_losses(average_current, V_in, V_out, f_sw, L, ESR):
    I_cin = average_current * np.sqrt(V_in - V_out) * V_out / V_in
    I_L = ((V_in - V_out) / (f_sw * L)) * (V_out / V_in)

    I_cout = I_L / (2 * np.sqrt(3))
    P_cap_in = I_cin**2 * ESR
    P_cap_out = I_cout**2 * ESR

    Pl_C = P_cap_in + P_cap_out

    return Pl_C

# %% [markdown]
# ## Inductor Loss
# - Inductor Copper Loss
#     - P<sub>Copper, L</sub> = I<sub>RMS</sub><sup>2</sup> &middot; R<sub>L</sub>
# <br>
#     - I<sub>RMS</sub> = &radic;(I<sub>AVG</sub><sup>2</sup> + <sup>1</sup>&frasl;<sub>12</sub> &Delta;I<sub>L</sub><sup>2</sup>)

# %%
def calculate_inductor_copper_loss(average_current, delta_current, R_L):
    I_rms = np.sqrt(average_current**2 + 1/12 * delta_current**2)
    Pl_L_Cu = I_rms**2 * R_L

    return Pl_L_Cu

# %% [markdown]
# ## Dead time losses

# %% [markdown]
# - t<sub>d(on)</sub> = 26 nS
# - t<sub>d(off)</sub> = 68 nS
# - t<sub>r</sub> = 110 nS
# - t<sub>f</sub> = 78 nS
# - Safety factor = 20%
# - V<sub>D</sub> = 0.5V
#
# <strong>t<sub>dt</sub><strong> = (t<sub>r</sub> + t<sub>d(off)</sub>) = 178 nS
#
# <strong>t<sub>dt</sub><strong> = t<sub>Dr</sub> = t<sub>Df</sub>
#
# <strong>P<sub>D</sub></strong> = V<sub>D</sub> × I<sub>out</sub> × (t<sub>Dr</sub> + t<sub>Df</sub>) × f<sub>sw</sub>

# %%
def calculate_dead_time_loss(average_current, f_sw, t_dt):
    P_D = diode_voltage * average_current * 2 * t_dt * f_sw

    return P_D

# %% [markdown]
# # Single

# %%
val_test =  [7.54000e-04 ,6.70000e-05, 1.20247e+05 ,1.00000e-06]


L = val_test[0]
C = val_test[1]
fsw = val_test[2]
t_dt = val_test[3]

R_L = next((rl for border, rl in border_values if L <= border), 0.0)

# Calculate ESR and ESL based on the updated C
ESR = tan_delta / (2 * np.pi * fsw * C)
ESL = K_esl / C

# Set Plecs parameters and simulate
plecs.set(model+'/L1', 'L', str(L))
plecs.set(model+'/C', 'C', str(C))
plecs.set(model+'/Symmetrical PWM1', 'fc', str(fsw))
plecs.set(model+'/RL', 'R', str(R_L))
plecs.set(model+'/ESR', 'R', str(ESR))
plecs.set(model+'/ESL', 'L', str(ESL))
plecs.set(model+'/Deadtime', 'td', str(t_dt))

times = plecs.simulate(model)['Time']
current = plecs.simulate(model)['Values'][0]
voltage = plecs.simulate(model)['Values'][1]

# Calculate average and delta current using the function
average_current, delta_current, delta_current_percentage = calculate_current(times, current, start_time=0.004, end_time=0.005)
average_voltage, delta_voltage, delta_voltage_percentage = calculate_voltage(times, voltage, start_time=0.004, end_time=0.005)
Pl_s1, Pl_s2 = calculate_switching_losses(average_current, V_out, V_in, R_on, t_rise, t_fall, fsw)
Pl_C = calculate_capacitor_losses(average_current, V_in, V_out, fsw, L, ESR)
Pl_L_Cu = calculate_inductor_copper_loss(average_current, delta_current, R_L)
P_D = calculate_dead_time_loss(average_current, fsw, t_dt)

print("Delta Vo:", delta_voltage_percentage)
print("Delta IL:", delta_current_percentage)
print("P_l_s1: ", Pl_s1)
print("P_l_s2: ", Pl_s2)
print("P_l_C: ", Pl_C)
print("P_l_L_Cu: ", Pl_L_Cu)
print("P_D: ", P_D)
print("Losses Total:", Pl_s1 + Pl_s2 + Pl_C + Pl_L_Cu + P_D)
# print(f"Average Current between 0.004 and 0.005 seconds: {average_current} A")
# print(f"Difference between highest and lowest current values between 0.004 and 0.005 seconds: {delta_current} A")
# print(f"Difference between highest and lowest current values between 0.004 and 0.005 seconds: {delta_current_percentage} %")
# print(f"Difference between highest and lowest voltage values between 0.004 and 0.005 seconds: {delta_voltage} V")
# print(f"Difference between highest and lowest voltage values between 0.004 and 0.005 seconds: {delta_voltage_percentage} %")
# print(f"High Side Switching Losses: {Pl_s1} W")
# print(f"Low Side Switching  Losses: {Pl_s2} W")
# print(f"Capacitor Losses: {Pl_C} W")
# print(f"Inductor Copper Losses: {Pl_L_Cu} W")
# print(f"Dead time Losses: {P_D} W")
# print(f"Total Losses: {Pl_s1 + Pl_s2 + Pl_C + Pl_L_Cu + P_D} W")
# print(f"[{delta_current_percentage}, {delta_voltage_percentage}, {Pl_s1}, {Pl_s2}, {Pl_C}, {Pl_L_Cu}, {P_D}]")
# Out:
# Delta Vo: 0.8475774271611582
# Delta IL: 5.241051461189539
# P_l_s1:  1.472356422054826
# P_l_s2:  1.472356422054826
# P_l_C:  0.008739559442926563
# P_l_L_Cu:  0.3556518178257827
# P_D:  0.14248586103250815
# Losses Total: 3.451590082410869

# %% [markdown]
# # Loop

# %%
# Loop through the combinations and simulate
csv_data = []
for simulation_num, (L, C, fsw, t_dt) in enumerate(combinations, start=1):
    # Rules for picking R_L based on L
    R_L = next((rl for border, rl in border_values if L <= border), 0.0)

    # Calculate ESR and ESL based on the updated C
    ESR = tan_delta / (2 * np.pi * fsw * C)
    ESL = K_esl / C

    # Set Plecs parameters and simulate
    plecs.set(model+'/L1', 'L', str(L))
    plecs.set(model+'/C', 'C', str(C))
    plecs.set(model+'/Symmetrical PWM1', 'fc', str(fsw))
    plecs.set(model+'/RL', 'R', str(R_L))
    plecs.set(model+'/ESR', 'R', str(ESR))
    plecs.set(model+'/ESL', 'L', str(ESL))
    plecs.set(model+'/Deadtime', 'td', str(t_dt))

    times = plecs.simulate(model)['Time']
    current = plecs.simulate(model)['Values'][0]
    voltage = plecs.simulate(model)['Values'][1]

    # Calculate average and delta current using the function
    average_current, delta_current, delta_current_percentage = calculate_current(times, current, start_time=0.004, end_time=0.005)
    average_voltage, delta_voltage, delta_voltage_percentage = calculate_voltage(times, voltage, start_time=0.004, end_time=0.005)
    Pl_s1, Pl_s2 = calculate_switching_losses(average_current, V_out, V_in, R_on, t_rise, t_fall, fsw)
    Pl_C = calculate_capacitor_losses(average_current, V_in, V_out, fsw, L, ESR)
    Pl_L_Cu = calculate_inductor_copper_loss(average_current, delta_current, R_L)
    P_D = calculate_dead_time_loss(average_current, fsw, t_dt)

    # Append the data for this simulation to the list
    csv_data.append([simulation_num,L, C, fsw, t_dt, delta_current_percentage, delta_voltage_percentage, Pl_s1, Pl_s2, Pl_C, Pl_L_Cu, P_D])

    print(f'\nSimulation {simulation_num}')
    # print(f'\nSimulation {simulation_num} for L={L:.6f}, C={C:.6f}, fsw={fsw:.2f}, RL={R_L:.6f}, ESR={ESR:.6f}, ESL={ESL:.6e}')
    # print(f"\nSimulation {simulation_num} results:")
    # print(f"Average Current between 0.004 and 0.005 seconds: {average_current} A")
    # print(f"Difference between highest and lowest current values between 0.004 and 0.005 seconds: {delta_current} A")
    # print(f"Difference between highest and lowest current values between 0.004 and 0.005 seconds: {delta_current_percentage} %")
    # print(f"Difference between highest and lowest voltage values between 0.004 and 0.005 seconds: {delta_voltage} A")
    # print(f"Difference between highest and lowest voltage values between 0.004 and 0.005 seconds: {delta_voltage_percentage} %")
    # print(f"High Side Switching Losses: {Pl_s1} W")
    # print(f"Low Side Switching  Losses: {Pl_s2} W")
    # print(f"Capacitor Losses: {Pl_C} W")
    # print(f"Inductor Copper Losses: {Pl_L_Cu} W")
    # print(f"Dead time Losses: {P_D} W")
    # print(f"Total Losses: {Pl_s1 + Pl_s2 + Pl_C + Pl_L_Cu + P_D} W")
# Out:
# Simulation 1
#
# Simulation 2
#
# Simulation 3
#
# Simulation 4
#
# Simulation 5
#
# Simulation 6
#
# Simulation 7
#
# Simulation 8
#
# Simulation 9
#
# Simulation 10
#
# Simulation 11
#
# Simulation 12
#
# Simulation 13
#
# Simulation 14
#
# Simulation 15
#
# Simulation 16
#
# Simulation 17
#
# Simulation 18
#
# Simulation 19
#
# Simulation 20
#
# Simulation 21
#
# Simulation 22
#
# Simulation 23
#
# Simulation 24
#
# Simulation 25
#
# Simulation 26
#
# Simulation 27
#
# Simulation 28
#
# Simulation 29
#
# Simulation 30
#
# Simulation 31
#
# Simulation 32
#
# Simulation 33
#
# Simulation 34
#
# Simulation 35
#
# Simulation 36
#
# Simulation 37
#
# Simulation 38
#
# Simulation 39
#
# Simulation 40
#
# Simulation 41
#
# Simulation 42
#
# Simulation 43
#
# Simulation 44
#
# Simulation 45
#
# Simulation 46
#
# Simulation 47
#
# Simulation 48
#
# Simulation 49
#
# Simulation 50
#
# Simulation 51
#
# Simulation 52
#
# Simulation 53
#
# Simulation 54
#
# Simulation 55
#
# Simulation 56
#
# Simulation 57
#
# Simulation 58
#
# Simulation 59
#
# Simulation 60
#
# Simulation 61
#
# Simulation 62
#
# Simulation 63
#
# Simulation 64
#
# Simulation 65
#
# Simulation 66
#
# Simulation 67
#
# Simulation 68
#
# Simulation 69
#
# Simulation 70
#
# Simulation 71
#
# Simulation 72
#
# Simulation 73
#
# Simulation 74
#
# Simulation 75
#
# Simulation 76
#
# Simulation 77
#
# Simulation 78
#
# Simulation 79
#
# Simulation 80
#
# Simulation 81
#
# Simulation 82
#
# Simulation 83
#
# Simulation 84
#
# Simulation 85
#
# Simulation 86
#
# Simulation 87
#
# Simulation 88
#
# Simulation 89
#
# Simulation 90
#
# Simulation 91
#
# Simulation 92
#
# Simulation 93
#
# Simulation 94
#
# Simulation 95
#
# Simulation 96
#
# Simulation 97
#
# Simulation 98
#
# Simulation 99
#
# Simulation 100
#
# Simulation 101
#
# Simulation 102
#
# Simulation 103
#
# Simulation 104
#
# Simulation 105
#
# Simulation 106
#
# Simulation 107
#
# Simulation 108
#
# Simulation 109
#
# Simulation 110
#
# Simulation 111
#
# Simulation 112
#
# Simulation 113
#
# Simulation 114
#
# Simulation 115
#
# Simulation 116
#
# Simulation 117
#
# Simulation 118
#
# Simulation 119
#
# Simulation 120
#
# Simulation 121
#
# Simulation 122
#
# Simulation 123
#
# Simulation 124
#
# Simulation 125
#
# Simulation 126
#
# Simulation 127
#
# Simulation 128
#
# Simulation 129
#
# Simulation 130
#
# Simulation 131
#
# Simulation 132
#
# Simulation 133
#
# Simulation 134
#
# Simulation 135
#
# Simulation 136
#
# Simulation 137
#
# Simulation 138
#
# Simulation 139
#
# Simulation 140
#
# Simulation 141
#
# Simulation 142
#
# Simulation 143
#
# Simulation 144
#
# Simulation 145
#
# Simulation 146
#
# Simulation 147
#
# Simulation 148
#
# Simulation 149
#
# Simulation 150
#
# Simulation 151
#
# Simulation 152
#
# Simulation 153
#
# Simulation 154
#
# Simulation 155
#
# Simulation 156
#
# Simulation 157
#
# Simulation 158
#
# Simulation 159
#
# Simulation 160
#
# Simulation 161
#
# Simulation 162
#
# Simulation 163
#
# Simulation 164
#
# Simulation 165
#
# Simulation 166
#
# Simulation 167
#
# Simulation 168
#
# Simulation 169
#
# Simulation 170
#
# Simulation 171
#
# Simulation 172
#
# Simulation 173
#
# Simulation 174
#
# Simulation 175
#
# Simulation 176
#
# Simulation 177
#
# Simulation 178
#
# Simulation 179
#
# Simulation 180
#
# Simulation 181
#
# Simulation 182
#
# Simulation 183
#
# Simulation 184
#
# Simulation 185
#
# Simulation 186
#
# Simulation 187
#
# Simulation 188
#
# Simulation 189
#
# Simulation 190
#
# Simulation 191
#
# Simulation 192
#
# Simulation 193
#
# Simulation 194
#
# Simulation 195
#
# Simulation 196
#
# Simulation 197
#
# Simulation 198
#
# Simulation 199
#
# Simulation 200
#
# Simulation 201
#
# Simulation 202
#
# Simulation 203
#
# Simulation 204
#
# Simulation 205
#
# Simulation 206
#
# Simulation 207
#
# Simulation 208
#
# Simulation 209
#
# Simulation 210
#
# Simulation 211
#
# Simulation 212
#
# Simulation 213
#
# Simulation 214
#
# Simulation 215
#
# Simulation 216
#
# Simulation 217
#
# Simulation 218
#
# Simulation 219
#
# Simulation 220
#
# Simulation 221
#
# Simulation 222
#
# Simulation 223
#
# Simulation 224
#
# Simulation 225
#
# Simulation 226
#
# Simulation 227
#
# Simulation 228
#
# Simulation 229
#
# Simulation 230
#
# Simulation 231
#
# Simulation 232
#
# Simulation 233
#
# Simulation 234
#
# Simulation 235
#
# Simulation 236
#
# Simulation 237
#
# Simulation 238
#
# Simulation 239
#
# Simulation 240
#
# Simulation 241
#
# Simulation 242
#
# Simulation 243
#
# Simulation 244
#
# Simulation 245
#
# Simulation 246
#
# Simulation 247
#
# Simulation 248
#
# Simulation 249
#
# Simulation 250
#
# Simulation 251
#
# Simulation 252
#
# Simulation 253
#
# Simulation 254
#
# Simulation 255
#
# Simulation 256
#
# Simulation 257
#
# Simulation 258
#
# Simulation 259
#
# Simulation 260
#
# Simulation 261
#
# Simulation 262
#
# Simulation 263
#
# Simulation 264
#
# Simulation 265
#
# Simulation 266
#
# Simulation 267
#
# Simulation 268
#
# Simulation 269
#
# Simulation 270
#
# Simulation 271
#
# Simulation 272
#
# Simulation 273
#
# Simulation 274
#
# Simulation 275
#
# Simulation 276
#
# Simulation 277
#
# Simulation 278
#
# Simulation 279
#
# Simulation 280
#
# Simulation 281
#
# Simulation 282
#
# Simulation 283
#
# Simulation 284
#
# Simulation 285
#
# Simulation 286
#
# Simulation 287
#
# Simulation 288
#
# Simulation 289
#
# Simulation 290
#
# Simulation 291
#
# Simulation 292
#
# Simulation 293
#
# Simulation 294
#
# Simulation 295
#
# Simulation 296
#
# Simulation 297
#
# Simulation 298
#
# Simulation 299
#
# Simulation 300
#
# Simulation 301
#
# Simulation 302
#
# Simulation 303
#
# Simulation 304
#
# Simulation 305
#
# Simulation 306
#
# Simulation 307
#
# Simulation 308
#
# Simulation 309
#
# Simulation 310
#
# Simulation 311
#
# Simulation 312
#
# Simulation 313
#
# Simulation 314
#
# Simulation 315
#
# Simulation 316
#
# Simulation 317
#
# Simulation 318
#
# Simulation 319
#
# Simulation 320
#
# Simulation 321
#
# Simulation 322
#
# Simulation 323
#
# Simulation 324
#
# Simulation 325
#
# Simulation 326
#
# Simulation 327
#
# Simulation 328
#
# Simulation 329
#
# Simulation 330
#
# Simulation 331
#
# Simulation 332
#
# Simulation 333
#
# Simulation 334
#
# Simulation 335
#
# Simulation 336
#
# Simulation 337
#
# Simulation 338
#
# Simulation 339
#
# Simulation 340
#
# Simulation 341
#
# Simulation 342
#
# Simulation 343
#
# Simulation 344
#
# Simulation 345
#
# Simulation 346
#
# Simulation 347
#
# Simulation 348
#
# Simulation 349
#
# Simulation 350
#
# Simulation 351
#
# Simulation 352
#
# Simulation 353
#
# Simulation 354
#
# Simulation 355
#
# Simulation 356
#
# Simulation 357
#
# Simulation 358
#
# Simulation 359
#
# Simulation 360
#
# Simulation 361
#
# Simulation 362
#
# Simulation 363
#
# Simulation 364
#
# Simulation 365
#
# Simulation 366
#
# Simulation 367
#
# Simulation 368
#
# Simulation 369
#
# Simulation 370
#
# Simulation 371
#
# Simulation 372
#
# Simulation 373
#
# Simulation 374
#
# Simulation 375
#
# Simulation 376
#
# Simulation 377
#
# Simulation 378
#
# Simulation 379
#
# Simulation 380
#
# Simulation 381
#
# Simulation 382
#
# Simulation 383
#
# Simulation 384
#
# Simulation 385
#
# Simulation 386
#
# Simulation 387
#
# Simulation 388
#
# Simulation 389
#
# Simulation 390
#
# Simulation 391
#
# Simulation 392
#
# Simulation 393
#
# Simulation 394
#
# Simulation 395
#
# Simulation 396
#
# Simulation 397
#
# Simulation 398
#
# Simulation 399
#
# Simulation 400
#
# Simulation 401
#
# Simulation 402
#
# Simulation 403
#
# Simulation 404
#
# Simulation 405
#
# Simulation 406
#
# Simulation 407
#
# Simulation 408
#
# Simulation 409
#
# Simulation 410
#
# Simulation 411
#
# Simulation 412
#
# Simulation 413
#
# Simulation 414
#
# Simulation 415
#
# Simulation 416
#
# Simulation 417
#
# Simulation 418
#
# Simulation 419
#
# Simulation 420
#
# Simulation 421
#
# Simulation 422
#
# Simulation 423
#
# Simulation 424
#
# Simulation 425
#
# Simulation 426
#
# Simulation 427
#
# Simulation 428
#
# Simulation 429
#
# Simulation 430
#
# Simulation 431
#
# Simulation 432
#
# Simulation 433
#
# Simulation 434
#
# Simulation 435
#
# Simulation 436
#
# Simulation 437
#
# Simulation 438
#
# Simulation 439
#
# Simulation 440
#
# Simulation 441
#
# Simulation 442
#
# Simulation 443
#
# Simulation 444
#
# Simulation 445
#
# Simulation 446
#
# Simulation 447
#
# Simulation 448
#
# Simulation 449
#
# Simulation 450
#
# Simulation 451
#
# Simulation 452
#
# Simulation 453
#
# Simulation 454
#
# Simulation 455
#
# Simulation 456
#
# Simulation 457
#
# Simulation 458
#
# Simulation 459
#
# Simulation 460
#
# Simulation 461
#
# Simulation 462
#
# Simulation 463
#
# Simulation 464
#
# Simulation 465
#
# Simulation 466
#
# Simulation 467
#
# Simulation 468
#
# Simulation 469
#
# Simulation 470
#
# Simulation 471
#
# Simulation 472
#
# Simulation 473
#
# Simulation 474
#
# Simulation 475
#
# Simulation 476
#
# Simulation 477
#
# Simulation 478
#
# Simulation 479
#
# Simulation 480
#
# Simulation 481
#
# Simulation 482
#
# Simulation 483
#
# Simulation 484
#
# Simulation 485
#
# Simulation 486
#
# Simulation 487
#
# Simulation 488
#
# Simulation 489
#
# Simulation 490
#
# Simulation 491
#
# Simulation 492
#
# Simulation 493
#
# Simulation 494
#
# Simulation 495
#
# Simulation 496
#
# Simulation 497
#
# Simulation 498
#
# Simulation 499
#
# Simulation 500
#
# Simulation 501
#
# Simulation 502
#
# Simulation 503
#
# Simulation 504
#
# Simulation 505
#
# Simulation 506
#
# Simulation 507
#
# Simulation 508
#
# Simulation 509
#
# Simulation 510
#
# Simulation 511
#
# Simulation 512
#
# Simulation 513
#
# Simulation 514
#
# Simulation 515
#
# Simulation 516
#
# Simulation 517
#
# Simulation 518
#
# Simulation 519
#
# Simulation 520
#
# Simulation 521
#
# Simulation 522
#
# Simulation 523
#
# Simulation 524
#
# Simulation 525
#
# Simulation 526
#
# Simulation 527
#
# Simulation 528
#
# Simulation 529
#
# Simulation 530
#
# Simulation 531
#
# Simulation 532
#
# Simulation 533
#
# Simulation 534
#
# Simulation 535
#
# Simulation 536
#
# Simulation 537
#
# Simulation 538
#
# Simulation 539
#
# Simulation 540
#
# Simulation 541
#
# Simulation 542
#
# Simulation 543
#
# Simulation 544
#
# Simulation 545
#
# Simulation 546
#
# Simulation 547
#
# Simulation 548
#
# Simulation 549
#
# Simulation 550
#
# Simulation 551
#
# Simulation 552
#
# Simulation 553
#
# Simulation 554
#
# Simulation 555
#
# Simulation 556
#
# Simulation 557
#
# Simulation 558
#
# Simulation 559
#
# Simulation 560
#
# Simulation 561
#
# Simulation 562
#
# Simulation 563
#
# Simulation 564
#
# Simulation 565
#
# Simulation 566
#
# Simulation 567
#
# Simulation 568
#
# Simulation 569
#
# Simulation 570
#
# Simulation 571
#
# Simulation 572
#
# Simulation 573
#
# Simulation 574
#
# Simulation 575
#
# Simulation 576
#
# Simulation 577
#
# Simulation 578
#
# Simulation 579
#
# Simulation 580
#
# Simulation 581
#
# Simulation 582
#
# Simulation 583
#
# Simulation 584
#
# Simulation 585
#
# Simulation 586
#
# Simulation 587
#
# Simulation 588
#
# Simulation 589
#
# Simulation 590
#
# Simulation 591
#
# Simulation 592
#
# Simulation 593
#
# Simulation 594
#
# Simulation 595
#
# Simulation 596
#
# Simulation 597
#
# Simulation 598
#
# Simulation 599
#
# Simulation 600
#
# Simulation 601
#
# Simulation 602
#
# Simulation 603
#
# Simulation 604
#
# Simulation 605
#
# Simulation 606
#
# Simulation 607
#
# Simulation 608
#
# Simulation 609
#
# Simulation 610
#
# Simulation 611
#
# Simulation 612
#
# Simulation 613
#
# Simulation 614
#
# Simulation 615
#
# Simulation 616
#
# Simulation 617
#
# Simulation 618
#
# Simulation 619
#
# Simulation 620
#
# Simulation 621
#
# Simulation 622
#
# Simulation 623
#
# Simulation 624
#
# Simulation 625
#
# Simulation 626
#
# Simulation 627
#
# Simulation 628
#
# Simulation 629
#
# Simulation 630
#
# Simulation 631
#
# Simulation 632
#
# Simulation 633
#
# Simulation 634
#
# Simulation 635
#
# Simulation 636
#
# Simulation 637
#
# Simulation 638
#
# Simulation 639
#
# Simulation 640
#
# Simulation 641
#
# Simulation 642
#
# Simulation 643
#
# Simulation 644
#
# Simulation 645
#
# Simulation 646
#
# Simulation 647
#
# Simulation 648
#
# Simulation 649
#
# Simulation 650
#
# Simulation 651
#
# Simulation 652
#
# Simulation 653
#
# Simulation 654
#
# Simulation 655
#
# Simulation 656
#
# Simulation 657
#
# Simulation 658
#
# Simulation 659
#
# Simulation 660
#
# Simulation 661
#
# Simulation 662
#
# Simulation 663
#
# Simulation 664
#
# Simulation 665
#
# Simulation 666
#
# Simulation 667
#
# Simulation 668
#
# Simulation 669
#
# Simulation 670
#
# Simulation 671
#
# Simulation 672
#
# Simulation 673
#
# Simulation 674
#
# Simulation 675
#
# Simulation 676
#
# Simulation 677
#
# Simulation 678
#
# Simulation 679
#
# Simulation 680
#
# Simulation 681
#
# Simulation 682
#
# Simulation 683
#
# Simulation 684
#
# Simulation 685
#
# Simulation 686
#
# Simulation 687
#
# Simulation 688
#
# Simulation 689
#
# Simulation 690
#
# Simulation 691
#
# Simulation 692
#
# Simulation 693
#
# Simulation 694
#
# Simulation 695
#
# Simulation 696
#
# Simulation 697
#
# Simulation 698
#
# Simulation 699
#
# Simulation 700
#
# Simulation 701
#
# Simulation 702
#
# Simulation 703
#
# Simulation 704
#
# Simulation 705
#
# Simulation 706
#
# Simulation 707
#
# Simulation 708
#
# Simulation 709
#
# Simulation 710
#
# Simulation 711
#
# Simulation 712
#
# Simulation 713
#
# Simulation 714
#
# Simulation 715
#
# Simulation 716
#
# Simulation 717
#
# Simulation 718
#
# Simulation 719
#
# Simulation 720
#
# Simulation 721
#
# Simulation 722
#
# Simulation 723
#
# Simulation 724
#
# Simulation 725
#
# Simulation 726
#
# Simulation 727
#
# Simulation 728
#
# Simulation 729
#
# Simulation 730
#
# Simulation 731
#
# Simulation 732
#
# Simulation 733
#
# Simulation 734
#
# Simulation 735
#
# Simulation 736
#
# Simulation 737
#
# Simulation 738
#
# Simulation 739
#
# Simulation 740
#
# Simulation 741
#
# Simulation 742
#
# Simulation 743
#
# Simulation 744
#
# Simulation 745
#
# Simulation 746
#
# Simulation 747
#
# Simulation 748
#
# Simulation 749
#
# Simulation 750
#
# Simulation 751
#
# Simulation 752
#
# Simulation 753
#
# Simulation 754
#
# Simulation 755
#
# Simulation 756
#
# Simulation 757
#
# Simulation 758
#
# Simulation 759
#
# Simulation 760
#
# Simulation 761
#
# Simulation 762
#
# Simulation 763
#
# Simulation 764
#
# Simulation 765
#
# Simulation 766
#
# Simulation 767
#
# Simulation 768
#
# Simulation 769
#
# Simulation 770
#
# Simulation 771
#
# Simulation 772
#
# Simulation 773
#
# Simulation 774
#
# Simulation 775
#
# Simulation 776
#
# Simulation 777
#
# Simulation 778
#
# Simulation 779
#
# Simulation 780
#
# Simulation 781
#
# Simulation 782
#
# Simulation 783
#
# Simulation 784
#
# Simulation 785
#
# Simulation 786
#
# Simulation 787
#
# Simulation 788
#
# Simulation 789
#
# Simulation 790
#
# Simulation 791
#
# Simulation 792
#
# Simulation 793
#
# Simulation 794
#
# Simulation 795
#
# Simulation 796
#
# Simulation 797
#
# Simulation 798
#
# Simulation 799
#
# Simulation 800
#
# Simulation 801
#
# Simulation 802
#
# Simulation 803
#
# Simulation 804
#
# Simulation 805
#
# Simulation 806
#
# Simulation 807
#
# Simulation 808
#
# Simulation 809
#
# Simulation 810
#
# Simulation 811
#
# Simulation 812
#
# Simulation 813
#
# Simulation 814
#
# Simulation 815
#
# Simulation 816
#
# Simulation 817
#
# Simulation 818
#
# Simulation 819
#
# Simulation 820
#
# Simulation 821
#
# Simulation 822
#
# Simulation 823
#
# Simulation 824
#
# Simulation 825
#
# Simulation 826
#
# Simulation 827
#
# Simulation 828
#
# Simulation 829
#
# Simulation 830
#
# Simulation 831
#
# Simulation 832
#
# Simulation 833
#
# Simulation 834
#
# Simulation 835
#
# Simulation 836
#
# Simulation 837
#
# Simulation 838
#
# Simulation 839
#
# Simulation 840
#
# Simulation 841
#
# Simulation 842
#
# Simulation 843
#
# Simulation 844
#
# Simulation 845
#
# Simulation 846
#
# Simulation 847
#
# Simulation 848
#
# Simulation 849
#
# Simulation 850
#
# Simulation 851
#
# Simulation 852
#
# Simulation 853
#
# Simulation 854
#
# Simulation 855
#
# Simulation 856
#
# Simulation 857
#
# Simulation 858
#
# Simulation 859
#
# Simulation 860
#
# Simulation 861
#
# Simulation 862
#
# Simulation 863
#
# Simulation 864
#
# Simulation 865
#
# Simulation 866
#
# Simulation 867
#
# Simulation 868
#
# Simulation 869
#
# Simulation 870
#
# Simulation 871
#
# Simulation 872
#
# Simulation 873
#
# Simulation 874
#
# Simulation 875
#
# Simulation 876
#
# Simulation 877
#
# Simulation 878
#
# Simulation 879
#
# Simulation 880
#
# Simulation 881
#
# Simulation 882
#
# Simulation 883
#
# Simulation 884
#
# Simulation 885
#
# Simulation 886
#
# Simulation 887
#
# Simulation 888
#
# Simulation 889
#
# Simulation 890
#
# Simulation 891
#
# Simulation 892
#
# Simulation 893
#
# Simulation 894
#
# Simulation 895
#
# Simulation 896
#
# Simulation 897
#
# Simulation 898
#
# Simulation 899
#
# Simulation 900
#
# Simulation 901
#
# Simulation 902
#
# Simulation 903
#
# Simulation 904
#
# Simulation 905
#
# Simulation 906
#
# Simulation 907
#
# Simulation 908
#
# Simulation 909
#
# Simulation 910
#
# Simulation 911
#
# Simulation 912
#
# Simulation 913
#
# Simulation 914
#
# Simulation 915
#
# Simulation 916
#
# Simulation 917
#
# Simulation 918
#
# Simulation 919
#
# Simulation 920
#
# Simulation 921
#
# Simulation 922
#
# Simulation 923
#
# Simulation 924
#
# Simulation 925
#
# Simulation 926
#
# Simulation 927
#
# Simulation 928
#
# Simulation 929
#
# Simulation 930
#
# Simulation 931
#
# Simulation 932
#
# Simulation 933
#
# Simulation 934
#
# Simulation 935
#
# Simulation 936
#
# Simulation 937
#
# Simulation 938
#
# Simulation 939
#
# Simulation 940
#
# Simulation 941
#
# Simulation 942
#
# Simulation 943
#
# Simulation 944
#
# Simulation 945
#
# Simulation 946
#
# Simulation 947
#
# Simulation 948
#
# Simulation 949
#
# Simulation 950
#
# Simulation 951
#
# Simulation 952
#
# Simulation 953
#
# Simulation 954
#
# Simulation 955
#
# Simulation 956
#
# Simulation 957
#
# Simulation 958
#
# Simulation 959
#
# Simulation 960
#
# Simulation 961
#
# Simulation 962
#
# Simulation 963
#
# Simulation 964
#
# Simulation 965
#
# Simulation 966
#
# Simulation 967
#
# Simulation 968
#
# Simulation 969
#
# Simulation 970
#
# Simulation 971
#
# Simulation 972
#
# Simulation 973
#
# Simulation 974
#
# Simulation 975
#
# Simulation 976
#
# Simulation 977
#
# Simulation 978
#
# Simulation 979
#
# Simulation 980
#
# Simulation 981
#
# Simulation 982
#
# Simulation 983
#
# Simulation 984
#
# Simulation 985
#
# Simulation 986
#
# Simulation 987
#
# Simulation 988
#
# Simulation 989
#
# Simulation 990
#
# Simulation 991
#
# Simulation 992
#
# Simulation 993
#
# Simulation 994
#
# Simulation 995
#
# Simulation 996
#
# Simulation 997
#
# Simulation 998
#
# Simulation 999
#
# Simulation 1000
#
# Simulation 1001
#
# Simulation 1002
#
# Simulation 1003
#
# Simulation 1004
#
# Simulation 1005
#
# Simulation 1006
#
# Simulation 1007
#
# Simulation 1008
#
# Simulation 1009
#
# Simulation 1010
#
# Simulation 1011
#
# Simulation 1012
#
# Simulation 1013
#
# Simulation 1014
#
# Simulation 1015
#
# Simulation 1016
#
# Simulation 1017
#
# Simulation 1018
#
# Simulation 1019
#
# Simulation 1020
#
# Simulation 1021
#
# Simulation 1022
#
# Simulation 1023
#
# Simulation 1024
#
# Simulation 1025
#
# Simulation 1026
#
# Simulation 1027
#
# Simulation 1028
#
# Simulation 1029
#
# Simulation 1030
#
# Simulation 1031
#
# Simulation 1032
#
# Simulation 1033
#
# Simulation 1034
#
# Simulation 1035
#
# Simulation 1036
#
# Simulation 1037
#
# Simulation 1038
#
# Simulation 1039
#
# Simulation 1040
#
# Simulation 1041
#
# Simulation 1042
#
# Simulation 1043
#
# Simulation 1044
#
# Simulation 1045
#
# Simulation 1046
#
# Simulation 1047
#
# Simulation 1048
#
# Simulation 1049
#
# Simulation 1050
#
# Simulation 1051
#
# Simulation 1052
#
# Simulation 1053
#
# Simulation 1054
#
# Simulation 1055
#
# Simulation 1056
#
# Simulation 1057
#
# Simulation 1058
#
# Simulation 1059
#
# Simulation 1060
#
# Simulation 1061
#
# Simulation 1062
#
# Simulation 1063
#
# Simulation 1064
#
# Simulation 1065
#
# Simulation 1066
#
# Simulation 1067
#
# Simulation 1068
#
# Simulation 1069
#
# Simulation 1070
#
# Simulation 1071
#
# Simulation 1072
#
# Simulation 1073
#
# Simulation 1074
#
# Simulation 1075
#
# Simulation 1076
#
# Simulation 1077
#
# Simulation 1078
#
# Simulation 1079
#
# Simulation 1080
#
# Simulation 1081
#
# Simulation 1082
#
# Simulation 1083
#
# Simulation 1084
#
# Simulation 1085
#
# Simulation 1086
#
# Simulation 1087
#
# Simulation 1088
#
# Simulation 1089
#
# Simulation 1090
#
# Simulation 1091
#
# Simulation 1092
#
# Simulation 1093
#
# Simulation 1094
#
# Simulation 1095
#
# Simulation 1096
#
# Simulation 1097
#
# Simulation 1098
#
# Simulation 1099
#
# Simulation 1100
#
# Simulation 1101
#
# Simulation 1102
#
# Simulation 1103
#
# Simulation 1104
#
# Simulation 1105
#
# Simulation 1106
#
# Simulation 1107
#
# Simulation 1108
#
# Simulation 1109
#
# Simulation 1110
#
# Simulation 1111
#
# Simulation 1112
#
# Simulation 1113
#
# Simulation 1114
#
# Simulation 1115
#
# Simulation 1116
#
# Simulation 1117
#
# Simulation 1118
#
# Simulation 1119
#
# Simulation 1120
#
# Simulation 1121
#
# Simulation 1122
#
# Simulation 1123
#
# Simulation 1124
#
# Simulation 1125
#
# Simulation 1126
#
# Simulation 1127
#
# Simulation 1128
#
# Simulation 1129
#
# Simulation 1130
#
# Simulation 1131
#
# Simulation 1132
#
# Simulation 1133
#
# Simulation 1134
#
# Simulation 1135
#
# Simulation 1136
#
# Simulation 1137
#
# Simulation 1138
#
# Simulation 1139
#
# Simulation 1140
#
# Simulation 1141
#
# Simulation 1142
#
# Simulation 1143
#
# Simulation 1144
#
# Simulation 1145
#
# Simulation 1146
#
# Simulation 1147
#
# Simulation 1148
#
# Simulation 1149
#
# Simulation 1150
#
# Simulation 1151
#
# Simulation 1152
#
# Simulation 1153
#
# Simulation 1154
#
# Simulation 1155
#
# Simulation 1156
#
# Simulation 1157
#
# Simulation 1158
#
# Simulation 1159
#
# Simulation 1160
#
# Simulation 1161
#
# Simulation 1162
#
# Simulation 1163
#
# Simulation 1164
#
# Simulation 1165
#
# Simulation 1166
#
# Simulation 1167
#
# Simulation 1168
#
# Simulation 1169
#
# Simulation 1170
#
# Simulation 1171
#
# Simulation 1172
#
# Simulation 1173
#
# Simulation 1174
#
# Simulation 1175
#
# Simulation 1176
#
# Simulation 1177
#
# Simulation 1178
#
# Simulation 1179
#
# Simulation 1180
#
# Simulation 1181
#
# Simulation 1182
#
# Simulation 1183
#
# Simulation 1184
#
# Simulation 1185
#
# Simulation 1186
#
# Simulation 1187
#
# Simulation 1188
#
# Simulation 1189
#
# Simulation 1190
#
# Simulation 1191
#
# Simulation 1192
#
# Simulation 1193
#
# Simulation 1194
#
# Simulation 1195
#
# Simulation 1196
#
# Simulation 1197
#
# Simulation 1198
#
# Simulation 1199
#
# Simulation 1200
#
# Simulation 1201
#
# Simulation 1202
#
# Simulation 1203
#
# Simulation 1204
#
# Simulation 1205
#
# Simulation 1206
#
# Simulation 1207
#
# Simulation 1208
#
# Simulation 1209
#
# Simulation 1210
#
# Simulation 1211
#
# Simulation 1212
#
# Simulation 1213
#
# Simulation 1214
#
# Simulation 1215
#
# Simulation 1216
#
# Simulation 1217
#
# Simulation 1218
#
# Simulation 1219
#
# Simulation 1220
#
# Simulation 1221
#
# Simulation 1222
#
# Simulation 1223
#
# Simulation 1224
#
# Simulation 1225
#
# Simulation 1226
#
# Simulation 1227
#
# Simulation 1228
#
# Simulation 1229
#
# Simulation 1230
#
# Simulation 1231
#
# Simulation 1232
#
# Simulation 1233
#
# Simulation 1234
#
# Simulation 1235
#
# Simulation 1236
#
# Simulation 1237
#
# Simulation 1238
#
# Simulation 1239
#
# Simulation 1240
#
# Simulation 1241
#
# Simulation 1242
#
# Simulation 1243
#
# Simulation 1244
#
# Simulation 1245
#
# Simulation 1246
#
# Simulation 1247
#
# Simulation 1248
#
# Simulation 1249
#
# Simulation 1250
#
# Simulation 1251
#
# Simulation 1252
#
# Simulation 1253
#
# Simulation 1254
#
# Simulation 1255
#
# Simulation 1256
#
# Simulation 1257
#
# Simulation 1258
#
# Simulation 1259
#
# Simulation 1260
#
# Simulation 1261
#
# Simulation 1262
#
# Simulation 1263
#
# Simulation 1264
#
# Simulation 1265
#
# Simulation 1266
#
# Simulation 1267
#
# Simulation 1268
#
# Simulation 1269
#
# Simulation 1270
#
# Simulation 1271
#
# Simulation 1272
#
# Simulation 1273
#
# Simulation 1274
#
# Simulation 1275
#
# Simulation 1276
#
# Simulation 1277
#
# Simulation 1278
#
# Simulation 1279
#
# Simulation 1280
#
# Simulation 1281
#
# Simulation 1282
#
# Simulation 1283
#
# Simulation 1284
#
# Simulation 1285
#
# Simulation 1286
#
# Simulation 1287
#
# Simulation 1288
#
# Simulation 1289
#
# Simulation 1290
#
# Simulation 1291
#
# Simulation 1292
#
# Simulation 1293
#
# Simulation 1294
#
# Simulation 1295
#
# Simulation 1296
#
# Simulation 1297
#
# Simulation 1298
#
# Simulation 1299
#
# Simulation 1300
#
# Simulation 1301
#
# Simulation 1302
#
# Simulation 1303
#
# Simulation 1304
#
# Simulation 1305
#
# Simulation 1306
#
# Simulation 1307
#
# Simulation 1308
#
# Simulation 1309
#
# Simulation 1310
#
# Simulation 1311
#
# Simulation 1312
#
# Simulation 1313
#
# Simulation 1314
#
# Simulation 1315
#
# Simulation 1316
#
# Simulation 1317
#
# Simulation 1318
#
# Simulation 1319
#
# Simulation 1320
#
# Simulation 1321
#
# Simulation 1322
#
# Simulation 1323
#
# Simulation 1324
#
# Simulation 1325
#
# Simulation 1326
#
# Simulation 1327
#
# Simulation 1328
#
# Simulation 1329
#
# Simulation 1330
#
# Simulation 1331
#
# Simulation 1332
#
# Simulation 1333
#
# Simulation 1334
#
# Simulation 1335
#
# Simulation 1336
#
# Simulation 1337
#
# Simulation 1338
#
# Simulation 1339
#
# Simulation 1340
#
# Simulation 1341
#
# Simulation 1342
#
# Simulation 1343
#
# Simulation 1344
#
# Simulation 1345
#
# Simulation 1346
#
# Simulation 1347
#
# Simulation 1348
#
# Simulation 1349
#
# Simulation 1350
#
# Simulation 1351
#
# Simulation 1352
#
# Simulation 1353
#
# Simulation 1354
#
# Simulation 1355
#
# Simulation 1356
#
# Simulation 1357
#
# Simulation 1358
#
# Simulation 1359
#
# Simulation 1360
#
# Simulation 1361
#
# Simulation 1362
#
# Simulation 1363
#
# Simulation 1364
#
# Simulation 1365
#
# Simulation 1366
#
# Simulation 1367
#
# Simulation 1368
#
# Simulation 1369
#
# Simulation 1370
#
# Simulation 1371
#
# Simulation 1372
#
# Simulation 1373
#
# Simulation 1374
#
# Simulation 1375
#
# Simulation 1376
#
# Simulation 1377
#
# Simulation 1378
#
# Simulation 1379
#
# Simulation 1380
#
# Simulation 1381
#
# Simulation 1382
#
# Simulation 1383
#
# Simulation 1384
#
# Simulation 1385
#
# Simulation 1386
#
# Simulation 1387
#
# Simulation 1388
#
# Simulation 1389
#
# Simulation 1390
#
# Simulation 1391
#
# Simulation 1392
#
# Simulation 1393
#
# Simulation 1394
#
# Simulation 1395
#
# Simulation 1396
#
# Simulation 1397
#
# Simulation 1398
#
# Simulation 1399
#
# Simulation 1400
#
# Simulation 1401
#
# Simulation 1402
#
# Simulation 1403
#
# Simulation 1404
#
# Simulation 1405
#
# Simulation 1406
#
# Simulation 1407
#
# Simulation 1408
#
# Simulation 1409
#
# Simulation 1410
#
# Simulation 1411
#
# Simulation 1412
#
# Simulation 1413
#
# Simulation 1414
#
# Simulation 1415
#
# Simulation 1416
#
# Simulation 1417
#
# Simulation 1418
#
# Simulation 1419
#
# Simulation 1420
#
# Simulation 1421
#
# Simulation 1422
#
# Simulation 1423
#
# Simulation 1424
#
# Simulation 1425
#
# Simulation 1426
#
# Simulation 1427
#
# Simulation 1428
#
# Simulation 1429
#
# Simulation 1430
#
# Simulation 1431
#
# Simulation 1432
#
# Simulation 1433
#
# Simulation 1434
#
# Simulation 1435
#
# Simulation 1436
#
# Simulation 1437
#
# Simulation 1438
#
# Simulation 1439
#
# Simulation 1440
#
# Simulation 1441
#
# Simulation 1442
#
# Simulation 1443
#
# Simulation 1444
#
# Simulation 1445
#
# Simulation 1446
#
# Simulation 1447
#
# Simulation 1448
#
# Simulation 1449
#
# Simulation 1450
#
# Simulation 1451
#
# Simulation 1452
#
# Simulation 1453
#
# Simulation 1454
#
# Simulation 1455
#
# Simulation 1456
#
# Simulation 1457
#
# Simulation 1458
#
# Simulation 1459
#
# Simulation 1460
#
# Simulation 1461
#
# Simulation 1462
#
# Simulation 1463
#
# Simulation 1464
#
# Simulation 1465
#
# Simulation 1466
#
# Simulation 1467
#
# Simulation 1468
#
# Simulation 1469
#
# Simulation 1470
#
# Simulation 1471
#
# Simulation 1472
#
# Simulation 1473
#
# Simulation 1474
#
# Simulation 1475
#
# Simulation 1476
#
# Simulation 1477
#
# Simulation 1478
#
# Simulation 1479
#
# Simulation 1480
#
# Simulation 1481
#
# Simulation 1482
#
# Simulation 1483
#
# Simulation 1484
#
# Simulation 1485
#
# Simulation 1486
#
# Simulation 1487
#
# Simulation 1488
#
# Simulation 1489
#
# Simulation 1490
#
# Simulation 1491
#
# Simulation 1492
#
# Simulation 1493
#
# Simulation 1494
#
# Simulation 1495
#
# Simulation 1496
#
# Simulation 1497
#
# Simulation 1498
#
# Simulation 1499
#
# Simulation 1500
#
# Simulation 1501
#
# Simulation 1502
#
# Simulation 1503
#
# Simulation 1504
#
# Simulation 1505
#
# Simulation 1506
#
# Simulation 1507
#
# Simulation 1508
#
# Simulation 1509
#
# Simulation 1510
#
# Simulation 1511
#
# Simulation 1512
#
# Simulation 1513
#
# Simulation 1514
#
# Simulation 1515
#
# Simulation 1516
#
# Simulation 1517
#
# Simulation 1518
#
# Simulation 1519
#
# Simulation 1520
#
# Simulation 1521
#
# Simulation 1522
#
# Simulation 1523
#
# Simulation 1524
#
# Simulation 1525
#
# Simulation 1526
#
# Simulation 1527
#
# Simulation 1528
#
# Simulation 1529
#
# Simulation 1530
#
# Simulation 1531
#
# Simulation 1532
#
# Simulation 1533
#
# Simulation 1534
#
# Simulation 1535
#
# Simulation 1536
#
# Simulation 1537
#
# Simulation 1538
#
# Simulation 1539
#
# Simulation 1540
#
# Simulation 1541
#
# Simulation 1542
#
# Simulation 1543
#
# Simulation 1544
#
# Simulation 1545
#
# Simulation 1546
#
# Simulation 1547
#
# Simulation 1548
#
# Simulation 1549
#
# Simulation 1550
#
# Simulation 1551
#
# Simulation 1552
#
# Simulation 1553
#
# Simulation 1554
#
# Simulation 1555
#
# Simulation 1556
#
# Simulation 1557
#
# Simulation 1558
#
# Simulation 1559
#
# Simulation 1560
#
# Simulation 1561
#
# Simulation 1562
#
# Simulation 1563
#
# Simulation 1564
#
# Simulation 1565
#
# Simulation 1566
#
# Simulation 1567
#
# Simulation 1568
#
# Simulation 1569
#
# Simulation 1570
#
# Simulation 1571
#
# Simulation 1572
#
# Simulation 1573
#
# Simulation 1574
#
# Simulation 1575
#
# Simulation 1576
#
# Simulation 1577
#
# Simulation 1578
#
# Simulation 1579
#
# Simulation 1580
#
# Simulation 1581
#
# Simulation 1582
#
# Simulation 1583
#
# Simulation 1584
#
# Simulation 1585
#
# Simulation 1586
#
# Simulation 1587
#
# Simulation 1588
#
# Simulation 1589
#
# Simulation 1590
#
# Simulation 1591
#
# Simulation 1592
#
# Simulation 1593
#
# Simulation 1594
#
# Simulation 1595
#
# Simulation 1596
#
# Simulation 1597
#
# Simulation 1598
#
# Simulation 1599
#
# Simulation 1600
#
# Simulation 1601
#
# Simulation 1602
#
# Simulation 1603
#
# Simulation 1604
#
# Simulation 1605
#
# Simulation 1606
#
# Simulation 1607
#
# Simulation 1608
#
# Simulation 1609
#
# Simulation 1610
#
# Simulation 1611
#
# Simulation 1612
#
# Simulation 1613
#
# Simulation 1614
#
# Simulation 1615
#
# Simulation 1616
#
# Simulation 1617
#
# Simulation 1618
#
# Simulation 1619
#
# Simulation 1620
#
# Simulation 1621
#
# Simulation 1622
#
# Simulation 1623
#
# Simulation 1624
#
# Simulation 1625
#
# Simulation 1626
#
# Simulation 1627
#
# Simulation 1628
#
# Simulation 1629
#
# Simulation 1630
#
# Simulation 1631
#
# Simulation 1632
#
# Simulation 1633
#
# Simulation 1634
#
# Simulation 1635
#
# Simulation 1636
#
# Simulation 1637
#
# Simulation 1638
#
# Simulation 1639
#
# Simulation 1640
#
# Simulation 1641
#
# Simulation 1642
#
# Simulation 1643
#
# Simulation 1644
#
# Simulation 1645
#
# Simulation 1646
#
# Simulation 1647
#
# Simulation 1648
#
# Simulation 1649
#
# Simulation 1650
#
# Simulation 1651
#
# Simulation 1652
#
# Simulation 1653
#
# Simulation 1654
#
# Simulation 1655
#
# Simulation 1656
#
# Simulation 1657
#
# Simulation 1658
#
# Simulation 1659
#
# Simulation 1660
#
# Simulation 1661
#
# Simulation 1662
#
# Simulation 1663
#
# Simulation 1664
#
# Simulation 1665
#
# Simulation 1666
#
# Simulation 1667
#
# Simulation 1668
#
# Simulation 1669
#
# Simulation 1670
#
# Simulation 1671
#
# Simulation 1672
#
# Simulation 1673
#
# Simulation 1674
#
# Simulation 1675
#
# Simulation 1676
#
# Simulation 1677
#
# Simulation 1678
#
# Simulation 1679
#
# Simulation 1680
#
# Simulation 1681
#
# Simulation 1682
#
# Simulation 1683
#
# Simulation 1684
#
# Simulation 1685
#
# Simulation 1686
#
# Simulation 1687
#
# Simulation 1688
#
# Simulation 1689
#
# Simulation 1690
#
# Simulation 1691
#
# Simulation 1692
#
# Simulation 1693
#
# Simulation 1694
#
# Simulation 1695
#
# Simulation 1696
#
# Simulation 1697
#
# Simulation 1698
#
# Simulation 1699
#
# Simulation 1700
#
# Simulation 1701
#
# Simulation 1702
#
# Simulation 1703
#
# Simulation 1704
#
# Simulation 1705
#
# Simulation 1706
#
# Simulation 1707
#
# Simulation 1708
#
# Simulation 1709
#
# Simulation 1710
#
# Simulation 1711
#
# Simulation 1712
#
# Simulation 1713
#
# Simulation 1714
#
# Simulation 1715
#
# Simulation 1716
#
# Simulation 1717
#
# Simulation 1718
#
# Simulation 1719
#
# Simulation 1720
#
# Simulation 1721
#
# Simulation 1722
#
# Simulation 1723
#
# Simulation 1724
#
# Simulation 1725
#
# Simulation 1726
#
# Simulation 1727
#
# Simulation 1728
#
# Simulation 1729
#
# Simulation 1730
#
# Simulation 1731
#
# Simulation 1732
#
# Simulation 1733
#
# Simulation 1734
#
# Simulation 1735
#
# Simulation 1736
#
# Simulation 1737
#
# Simulation 1738
#
# Simulation 1739
#
# Simulation 1740
#
# Simulation 1741
#
# Simulation 1742
#
# Simulation 1743
#
# Simulation 1744
#
# Simulation 1745
#
# Simulation 1746
#
# Simulation 1747
#
# Simulation 1748
#
# Simulation 1749
#
# Simulation 1750
#
# Simulation 1751
#
# Simulation 1752
#
# Simulation 1753
#
# Simulation 1754
#
# Simulation 1755
#
# Simulation 1756
#
# Simulation 1757
#
# Simulation 1758
#
# Simulation 1759
#
# Simulation 1760
#
# Simulation 1761
#
# Simulation 1762
#
# Simulation 1763
#
# Simulation 1764
#
# Simulation 1765
#
# Simulation 1766
#
# Simulation 1767
#
# Simulation 1768
#
# Simulation 1769
#
# Simulation 1770
#
# Simulation 1771
#
# Simulation 1772
#
# Simulation 1773
#
# Simulation 1774
#
# Simulation 1775
#
# Simulation 1776
#
# Simulation 1777
#
# Simulation 1778
#
# Simulation 1779
#
# Simulation 1780
#
# Simulation 1781
#
# Simulation 1782
#
# Simulation 1783
#
# Simulation 1784
#
# Simulation 1785
#
# Simulation 1786
#
# Simulation 1787
#
# Simulation 1788
#
# Simulation 1789
#
# Simulation 1790
#
# Simulation 1791
#
# Simulation 1792
#
# Simulation 1793
#
# Simulation 1794
#
# Simulation 1795
#
# Simulation 1796
#
# Simulation 1797
#
# Simulation 1798
#
# Simulation 1799
#
# Simulation 1800
#
# Simulation 1801
#
# Simulation 1802
#
# Simulation 1803
#
# Simulation 1804
#
# Simulation 1805
#
# Simulation 1806
#
# Simulation 1807
#
# Simulation 1808
#
# Simulation 1809
#
# Simulation 1810
#
# Simulation 1811
#
# Simulation 1812
#
# Simulation 1813
#
# Simulation 1814
#
# Simulation 1815
#
# Simulation 1816
#
# Simulation 1817
#
# Simulation 1818
#
# Simulation 1819
#
# Simulation 1820
#
# Simulation 1821
#
# Simulation 1822
#
# Simulation 1823
#
# Simulation 1824
#
# Simulation 1825
#
# Simulation 1826
#
# Simulation 1827
#
# Simulation 1828
#
# Simulation 1829
#
# Simulation 1830
#
# Simulation 1831
#
# Simulation 1832
#
# Simulation 1833
#
# Simulation 1834
#
# Simulation 1835
#
# Simulation 1836
#
# Simulation 1837
#
# Simulation 1838
#
# Simulation 1839
#
# Simulation 1840
#
# Simulation 1841
#
# Simulation 1842
#
# Simulation 1843
#
# Simulation 1844
#
# Simulation 1845
#
# Simulation 1846
#
# Simulation 1847
#
# Simulation 1848
#
# Simulation 1849
#
# Simulation 1850
#
# Simulation 1851
#
# Simulation 1852
#
# Simulation 1853
#
# Simulation 1854
#
# Simulation 1855
#
# Simulation 1856
#
# Simulation 1857
#
# Simulation 1858
#
# Simulation 1859
#
# Simulation 1860
#
# Simulation 1861
#
# Simulation 1862
#
# Simulation 1863
#
# Simulation 1864
#
# Simulation 1865
#
# Simulation 1866
#
# Simulation 1867
#
# Simulation 1868
#
# Simulation 1869
#
# Simulation 1870
#
# Simulation 1871
#
# Simulation 1872
#
# Simulation 1873
#
# Simulation 1874
#
# Simulation 1875
#
# Simulation 1876
#
# Simulation 1877
#
# Simulation 1878
#
# Simulation 1879
#
# Simulation 1880
#
# Simulation 1881
#
# Simulation 1882
#
# Simulation 1883
#
# Simulation 1884
#
# Simulation 1885
#
# Simulation 1886
#
# Simulation 1887
#
# Simulation 1888
#
# Simulation 1889
#
# Simulation 1890
#
# Simulation 1891
#
# Simulation 1892
#
# Simulation 1893
#
# Simulation 1894
#
# Simulation 1895
#
# Simulation 1896
#
# Simulation 1897
#
# Simulation 1898
#
# Simulation 1899
#
# Simulation 1900
#
# Simulation 1901
#
# Simulation 1902
#
# Simulation 1903
#
# Simulation 1904
#
# Simulation 1905
#
# Simulation 1906
#
# Simulation 1907
#
# Simulation 1908
#
# Simulation 1909
#
# Simulation 1910
#
# Simulation 1911
#
# Simulation 1912
#
# Simulation 1913
#
# Simulation 1914
#
# Simulation 1915
#
# Simulation 1916
#
# Simulation 1917
#
# Simulation 1918
#
# Simulation 1919
#
# Simulation 1920
#
# Simulation 1921
#
# Simulation 1922
#
# Simulation 1923
#
# Simulation 1924
#
# Simulation 1925
#
# Simulation 1926
#
# Simulation 1927
#
# Simulation 1928
#
# Simulation 1929
#
# Simulation 1930
#
# Simulation 1931
#
# Simulation 1932
#
# Simulation 1933
#
# Simulation 1934
#
# Simulation 1935
#
# Simulation 1936
#
# Simulation 1937
#
# Simulation 1938
#
# Simulation 1939
#
# Simulation 1940
#
# Simulation 1941
#
# Simulation 1942
#
# Simulation 1943
#
# Simulation 1944
#
# Simulation 1945
#
# Simulation 1946
#
# Simulation 1947
#
# Simulation 1948
#
# Simulation 1949
#
# Simulation 1950
#
# Simulation 1951
#
# Simulation 1952
#
# Simulation 1953
#
# Simulation 1954
#
# Simulation 1955
#
# Simulation 1956
#
# Simulation 1957
#
# Simulation 1958
#
# Simulation 1959
#
# Simulation 1960
#
# Simulation 1961
#
# Simulation 1962
#
# Simulation 1963
#
# Simulation 1964
#
# Simulation 1965
#
# Simulation 1966
#
# Simulation 1967
#
# Simulation 1968
#
# Simulation 1969
#
# Simulation 1970
#
# Simulation 1971
#
# Simulation 1972
#
# Simulation 1973
#
# Simulation 1974
#
# Simulation 1975
#
# Simulation 1976
#
# Simulation 1977
#
# Simulation 1978
#
# Simulation 1979
#
# Simulation 1980
#
# Simulation 1981
#
# Simulation 1982
#
# Simulation 1983
#
# Simulation 1984
#
# Simulation 1985
#
# Simulation 1986
#
# Simulation 1987
#
# Simulation 1988
#
# Simulation 1989
#
# Simulation 1990
#
# Simulation 1991
#
# Simulation 1992
#
# Simulation 1993
#
# Simulation 1994
#
# Simulation 1995
#
# Simulation 1996
#
# Simulation 1997
#
# Simulation 1998
#
# Simulation 1999
#
# Simulation 2000
#
# Simulation 2001
#
# Simulation 2002
#
# Simulation 2003
#
# Simulation 2004
#
# Simulation 2005
#
# Simulation 2006
#
# Simulation 2007
#
# Simulation 2008
#
# Simulation 2009
#
# Simulation 2010
#
# Simulation 2011
#
# Simulation 2012
#
# Simulation 2013
#
# Simulation 2014
#
# Simulation 2015
#
# Simulation 2016
#
# Simulation 2017
#
# Simulation 2018
#
# Simulation 2019
#
# Simulation 2020
#
# Simulation 2021
#
# Simulation 2022
#
# Simulation 2023
#
# Simulation 2024
#
# Simulation 2025
#
# Simulation 2026
#
# Simulation 2027
#
# Simulation 2028
#
# Simulation 2029
#
# Simulation 2030
#
# Simulation 2031
#
# Simulation 2032
#
# Simulation 2033
#
# Simulation 2034
#
# Simulation 2035
#
# Simulation 2036
#
# Simulation 2037
#
# Simulation 2038
#
# Simulation 2039
#
# Simulation 2040
#
# Simulation 2041
#
# Simulation 2042
#
# Simulation 2043
#
# Simulation 2044
#
# Simulation 2045
#
# Simulation 2046
#
# Simulation 2047
#
# Simulation 2048
#
# Simulation 2049
#
# Simulation 2050
#
# Simulation 2051
#
# Simulation 2052
#
# Simulation 2053
#
# Simulation 2054
#
# Simulation 2055
#
# Simulation 2056
#
# Simulation 2057
#
# Simulation 2058
#
# Simulation 2059
#
# Simulation 2060
#
# Simulation 2061
#
# Simulation 2062
#
# Simulation 2063
#
# Simulation 2064
#
# Simulation 2065
#
# Simulation 2066
#
# Simulation 2067
#
# Simulation 2068
#
# Simulation 2069
#
# Simulation 2070
#
# Simulation 2071
#
# Simulation 2072
#
# Simulation 2073
#
# Simulation 2074
#
# Simulation 2075
#
# Simulation 2076
#
# Simulation 2077
#
# Simulation 2078
#
# Simulation 2079
#
# Simulation 2080
#
# Simulation 2081
#
# Simulation 2082
#
# Simulation 2083
#
# Simulation 2084
#
# Simulation 2085
#
# Simulation 2086
#
# Simulation 2087
#
# Simulation 2088
#
# Simulation 2089
#
# Simulation 2090
#
# Simulation 2091
#
# Simulation 2092
#
# Simulation 2093
#
# Simulation 2094
#
# Simulation 2095
#
# Simulation 2096
#
# Simulation 2097
#
# Simulation 2098
#
# Simulation 2099
#
# Simulation 2100
#
# Simulation 2101
#
# Simulation 2102
#
# Simulation 2103
#
# Simulation 2104
#
# Simulation 2105
#
# Simulation 2106
#
# Simulation 2107
#
# Simulation 2108
#
# Simulation 2109
#
# Simulation 2110
#
# Simulation 2111
#
# Simulation 2112
#
# Simulation 2113
#
# Simulation 2114
#
# Simulation 2115
#
# Simulation 2116
#
# Simulation 2117
#
# Simulation 2118
#
# Simulation 2119
#
# Simulation 2120
#
# Simulation 2121
#
# Simulation 2122
#
# Simulation 2123
#
# Simulation 2124
#
# Simulation 2125
#
# Simulation 2126
#
# Simulation 2127
#
# Simulation 2128
#
# Simulation 2129
#
# Simulation 2130
#
# Simulation 2131
#
# Simulation 2132
#
# Simulation 2133
#
# Simulation 2134
#
# Simulation 2135
#
# Simulation 2136
#
# Simulation 2137
#
# Simulation 2138
#
# Simulation 2139
#
# Simulation 2140
#
# Simulation 2141
#
# Simulation 2142
#
# Simulation 2143
#
# Simulation 2144
#
# Simulation 2145
#
# Simulation 2146
#
# Simulation 2147
#
# Simulation 2148
#
# Simulation 2149
#
# Simulation 2150
#
# Simulation 2151
#
# Simulation 2152
#
# Simulation 2153
#
# Simulation 2154
#
# Simulation 2155
#
# Simulation 2156
#
# Simulation 2157
#
# Simulation 2158
#
# Simulation 2159
#
# Simulation 2160
#
# Simulation 2161
#
# Simulation 2162
#
# Simulation 2163
#
# Simulation 2164
#
# Simulation 2165
#
# Simulation 2166
#
# Simulation 2167
#
# Simulation 2168
#
# Simulation 2169
#
# Simulation 2170
#
# Simulation 2171
#
# Simulation 2172
#
# Simulation 2173
#
# Simulation 2174
#
# Simulation 2175
#
# Simulation 2176
#
# Simulation 2177
#
# Simulation 2178
#
# Simulation 2179
#
# Simulation 2180
#
# Simulation 2181
#
# Simulation 2182
#
# Simulation 2183
#
# Simulation 2184
#
# Simulation 2185
#
# Simulation 2186
#
# Simulation 2187
#
# Simulation 2188
#
# Simulation 2189
#
# Simulation 2190
#
# Simulation 2191
#
# Simulation 2192
#
# Simulation 2193
#
# Simulation 2194
#
# Simulation 2195
#
# Simulation 2196
#
# Simulation 2197
#
# Simulation 2198
#
# Simulation 2199
#
# Simulation 2200
#
# Simulation 2201
#
# Simulation 2202
#
# Simulation 2203
#
# Simulation 2204
#
# Simulation 2205
#
# Simulation 2206
#
# Simulation 2207
#
# Simulation 2208
#
# Simulation 2209
#
# Simulation 2210
#
# Simulation 2211
#
# Simulation 2212
#
# Simulation 2213
#
# Simulation 2214
#
# Simulation 2215
#
# Simulation 2216
#
# Simulation 2217
#
# Simulation 2218
#
# Simulation 2219
#
# Simulation 2220
#
# Simulation 2221
#
# Simulation 2222
#
# Simulation 2223
#
# Simulation 2224
#
# Simulation 2225
#
# Simulation 2226
#
# Simulation 2227
#
# Simulation 2228
#
# Simulation 2229
#
# Simulation 2230
#
# Simulation 2231
#
# Simulation 2232
#
# Simulation 2233
#
# Simulation 2234
#
# Simulation 2235
#
# Simulation 2236
#
# Simulation 2237
#
# Simulation 2238
#
# Simulation 2239
#
# Simulation 2240
#
# Simulation 2241
#
# Simulation 2242
#
# Simulation 2243
#
# Simulation 2244
#
# Simulation 2245
#
# Simulation 2246
#
# Simulation 2247
#
# Simulation 2248
#
# Simulation 2249
#
# Simulation 2250
#
# Simulation 2251
#
# Simulation 2252
#
# Simulation 2253
#
# Simulation 2254
#
# Simulation 2255
#
# Simulation 2256
#
# Simulation 2257
#
# Simulation 2258
#
# Simulation 2259
#
# Simulation 2260
#
# Simulation 2261
#
# Simulation 2262
#
# Simulation 2263
#
# Simulation 2264
#
# Simulation 2265
#
# Simulation 2266
#
# Simulation 2267
#
# Simulation 2268
#
# Simulation 2269
#
# Simulation 2270
#
# Simulation 2271
#
# Simulation 2272
#
# Simulation 2273
#
# Simulation 2274
#
# Simulation 2275
#
# Simulation 2276
#
# Simulation 2277
#
# Simulation 2278
#
# Simulation 2279
#
# Simulation 2280
#
# Simulation 2281
#
# Simulation 2282
#
# Simulation 2283
#
# Simulation 2284
#
# Simulation 2285
#
# Simulation 2286
#
# Simulation 2287
#
# Simulation 2288
#
# Simulation 2289
#
# Simulation 2290
#
# Simulation 2291
#
# Simulation 2292
#
# Simulation 2293
#
# Simulation 2294
#
# Simulation 2295
#
# Simulation 2296
#
# Simulation 2297
#
# Simulation 2298
#
# Simulation 2299
#
# Simulation 2300
#
# Simulation 2301
#
# Simulation 2302
#
# Simulation 2303
#
# Simulation 2304
#
# Simulation 2305
#
# Simulation 2306
#
# Simulation 2307
#
# Simulation 2308
#
# Simulation 2309
#
# Simulation 2310
#
# Simulation 2311
#
# Simulation 2312
#
# Simulation 2313
#
# Simulation 2314
#
# Simulation 2315
#
# Simulation 2316
#
# Simulation 2317
#
# Simulation 2318
#
# Simulation 2319
#
# Simulation 2320
#
# Simulation 2321
#
# Simulation 2322
#
# Simulation 2323
#
# Simulation 2324
#
# Simulation 2325
#
# Simulation 2326
#
# Simulation 2327
#
# Simulation 2328
#
# Simulation 2329
#
# Simulation 2330
#
# Simulation 2331
#
# Simulation 2332
#
# Simulation 2333
#
# Simulation 2334
#
# Simulation 2335
#
# Simulation 2336
#
# Simulation 2337
#
# Simulation 2338
#
# Simulation 2339
#
# Simulation 2340
#
# Simulation 2341
#
# Simulation 2342
#
# Simulation 2343
#
# Simulation 2344
#
# Simulation 2345
#
# Simulation 2346
#
# Simulation 2347
#
# Simulation 2348
#
# Simulation 2349
#
# Simulation 2350
#
# Simulation 2351
#
# Simulation 2352
#
# Simulation 2353
#
# Simulation 2354
#
# Simulation 2355
#
# Simulation 2356
#
# Simulation 2357
#
# Simulation 2358
#
# Simulation 2359
#
# Simulation 2360
#
# Simulation 2361
#
# Simulation 2362
#
# Simulation 2363
#
# Simulation 2364
#
# Simulation 2365
#
# Simulation 2366
#
# Simulation 2367
#
# Simulation 2368
#
# Simulation 2369
#
# Simulation 2370
#
# Simulation 2371
#
# Simulation 2372
#
# Simulation 2373
#
# Simulation 2374
#
# Simulation 2375
#
# Simulation 2376
#
# Simulation 2377
#
# Simulation 2378
#
# Simulation 2379
#
# Simulation 2380
#
# Simulation 2381
#
# Simulation 2382
#
# Simulation 2383
#
# Simulation 2384
#
# Simulation 2385
#
# Simulation 2386
#
# Simulation 2387
#
# Simulation 2388
#
# Simulation 2389
#
# Simulation 2390
#
# Simulation 2391
#
# Simulation 2392
#
# Simulation 2393
#
# Simulation 2394
#
# Simulation 2395
#
# Simulation 2396
#
# Simulation 2397
#
# Simulation 2398
#
# Simulation 2399
#
# Simulation 2400
#
# Simulation 2401
#
# Simulation 2402
#
# Simulation 2403
#
# Simulation 2404
#
# Simulation 2405
#
# Simulation 2406
#
# Simulation 2407
#
# Simulation 2408
#
# Simulation 2409
#
# Simulation 2410
#
# Simulation 2411
#
# Simulation 2412
#
# Simulation 2413
#
# Simulation 2414
#
# Simulation 2415
#
# Simulation 2416
#
# Simulation 2417
#
# Simulation 2418
#
# Simulation 2419
#
# Simulation 2420
#
# Simulation 2421
#
# Simulation 2422
#
# Simulation 2423
#
# Simulation 2424
#
# Simulation 2425
#
# Simulation 2426
#
# Simulation 2427
#
# Simulation 2428
#
# Simulation 2429
#
# Simulation 2430
#
# Simulation 2431
#
# Simulation 2432
#
# Simulation 2433
#
# Simulation 2434
#
# Simulation 2435
#
# Simulation 2436
#
# Simulation 2437
#
# Simulation 2438
#
# Simulation 2439
#
# Simulation 2440
#
# Simulation 2441
#
# Simulation 2442
#
# Simulation 2443
#
# Simulation 2444
#
# Simulation 2445
#
# Simulation 2446
#
# Simulation 2447
#
# Simulation 2448
#
# Simulation 2449
#
# Simulation 2450
#
# Simulation 2451
#
# Simulation 2452
#
# Simulation 2453
#
# Simulation 2454
#
# Simulation 2455
#
# Simulation 2456
#
# Simulation 2457
#
# Simulation 2458
#
# Simulation 2459
#
# Simulation 2460
#
# Simulation 2461
#
# Simulation 2462
#
# Simulation 2463
#
# Simulation 2464
#
# Simulation 2465
#
# Simulation 2466
#
# Simulation 2467
#
# Simulation 2468
#
# Simulation 2469
#
# Simulation 2470
#
# Simulation 2471
#
# Simulation 2472
#
# Simulation 2473
#
# Simulation 2474
#
# Simulation 2475
#
# Simulation 2476
#
# Simulation 2477
#
# Simulation 2478
#
# Simulation 2479
#
# Simulation 2480
#
# Simulation 2481
#
# Simulation 2482
#
# Simulation 2483
#
# Simulation 2484
#
# Simulation 2485
#
# Simulation 2486
#
# Simulation 2487
#
# Simulation 2488
#
# Simulation 2489
#
# Simulation 2490
#
# Simulation 2491
#
# Simulation 2492
#
# Simulation 2493
#
# Simulation 2494
#
# Simulation 2495
#
# Simulation 2496
#
# Simulation 2497
#
# Simulation 2498
#
# Simulation 2499
#
# Simulation 2500
#
# Simulation 2501
#
# Simulation 2502
#
# Simulation 2503
#
# Simulation 2504
#
# Simulation 2505
#
# Simulation 2506
#
# Simulation 2507
#
# Simulation 2508
#
# Simulation 2509
#
# Simulation 2510
#
# Simulation 2511
#
# Simulation 2512
#
# Simulation 2513
#
# Simulation 2514
#
# Simulation 2515
#
# Simulation 2516
#
# Simulation 2517
#
# Simulation 2518
#
# Simulation 2519
#
# Simulation 2520
#
# Simulation 2521
#
# Simulation 2522
#
# Simulation 2523
#
# Simulation 2524
#
# Simulation 2525
#
# Simulation 2526
#
# Simulation 2527
#
# Simulation 2528
#
# Simulation 2529
#
# Simulation 2530
#
# Simulation 2531
#
# Simulation 2532
#
# Simulation 2533
#
# Simulation 2534
#
# Simulation 2535
#
# Simulation 2536
#
# Simulation 2537
#
# Simulation 2538
#
# Simulation 2539
#
# Simulation 2540
#
# Simulation 2541
#
# Simulation 2542
#
# Simulation 2543
#
# Simulation 2544
#
# Simulation 2545
#
# Simulation 2546
#
# Simulation 2547
#
# Simulation 2548
#
# Simulation 2549
#
# Simulation 2550
#
# Simulation 2551
#
# Simulation 2552
#
# Simulation 2553
#
# Simulation 2554
#
# Simulation 2555
#
# Simulation 2556
#
# Simulation 2557
#
# Simulation 2558
#
# Simulation 2559
#
# Simulation 2560
#
# Simulation 2561
#
# Simulation 2562
#
# Simulation 2563
#
# Simulation 2564
#
# Simulation 2565
#
# Simulation 2566
#
# Simulation 2567
#
# Simulation 2568
#
# Simulation 2569
#
# Simulation 2570
#
# Simulation 2571
#
# Simulation 2572
#
# Simulation 2573
#
# Simulation 2574
#
# Simulation 2575
#
# Simulation 2576
#
# Simulation 2577
#
# Simulation 2578
#
# Simulation 2579
#
# Simulation 2580
#
# Simulation 2581
#
# Simulation 2582
#
# Simulation 2583
#
# Simulation 2584
#
# Simulation 2585
#
# Simulation 2586
#
# Simulation 2587
#
# Simulation 2588
#
# Simulation 2589
#
# Simulation 2590
#
# Simulation 2591
#
# Simulation 2592
#
# Simulation 2593
#
# Simulation 2594
#
# Simulation 2595
#
# Simulation 2596
#
# Simulation 2597
#
# Simulation 2598
#
# Simulation 2599
#
# Simulation 2600
#
# Simulation 2601
#
# Simulation 2602
#
# Simulation 2603
#
# Simulation 2604
#
# Simulation 2605
#
# Simulation 2606
#
# Simulation 2607
#
# Simulation 2608
#
# Simulation 2609
#
# Simulation 2610
#
# Simulation 2611
#
# Simulation 2612
#
# Simulation 2613
#
# Simulation 2614
#
# Simulation 2615
#
# Simulation 2616
#
# Simulation 2617
#
# Simulation 2618
#
# Simulation 2619
#
# Simulation 2620
#
# Simulation 2621
#
# Simulation 2622
#
# Simulation 2623
#
# Simulation 2624
#
# Simulation 2625
#
# Simulation 2626
#
# Simulation 2627
#
# Simulation 2628
#
# Simulation 2629
#
# Simulation 2630
#
# Simulation 2631
#
# Simulation 2632
#
# Simulation 2633
#
# Simulation 2634
#
# Simulation 2635
#
# Simulation 2636
#
# Simulation 2637
#
# Simulation 2638
#
# Simulation 2639
#
# Simulation 2640
#
# Simulation 2641
#
# Simulation 2642
#
# Simulation 2643
#
# Simulation 2644
#
# Simulation 2645
#
# Simulation 2646
#
# Simulation 2647
#
# Simulation 2648
#
# Simulation 2649
#
# Simulation 2650
#
# Simulation 2651
#
# Simulation 2652
#
# Simulation 2653
#
# Simulation 2654
#
# Simulation 2655
#
# Simulation 2656
#
# Simulation 2657
#
# Simulation 2658
#
# Simulation 2659
#
# Simulation 2660
#
# Simulation 2661
#
# Simulation 2662
#
# Simulation 2663
#
# Simulation 2664
#
# Simulation 2665
#
# Simulation 2666
#
# Simulation 2667
#
# Simulation 2668
#
# Simulation 2669
#
# Simulation 2670
#
# Simulation 2671
#
# Simulation 2672
#
# Simulation 2673
#
# Simulation 2674
#
# Simulation 2675
#
# Simulation 2676
#
# Simulation 2677
#
# Simulation 2678
#
# Simulation 2679
#
# Simulation 2680
#
# Simulation 2681
#
# Simulation 2682
#
# Simulation 2683
#
# Simulation 2684
#
# Simulation 2685
#
# Simulation 2686
#
# Simulation 2687
#
# Simulation 2688
#
# Simulation 2689
#
# Simulation 2690
#
# Simulation 2691
#
# Simulation 2692
#
# Simulation 2693
#
# Simulation 2694
#
# Simulation 2695
#
# Simulation 2696
#
# Simulation 2697
#
# Simulation 2698
#
# Simulation 2699
#
# Simulation 2700
#
# Simulation 2701
#
# Simulation 2702
#
# Simulation 2703
#
# Simulation 2704
#
# Simulation 2705
#
# Simulation 2706
#
# Simulation 2707
#
# Simulation 2708
#
# Simulation 2709
#
# Simulation 2710
#
# Simulation 2711
#
# Simulation 2712
#
# Simulation 2713
#
# Simulation 2714
#
# Simulation 2715
#
# Simulation 2716
#
# Simulation 2717
#
# Simulation 2718
#
# Simulation 2719
#
# Simulation 2720
#
# Simulation 2721
#
# Simulation 2722
#
# Simulation 2723
#
# Simulation 2724
#
# Simulation 2725
#
# Simulation 2726
#
# Simulation 2727
#
# Simulation 2728
#
# Simulation 2729
#
# Simulation 2730
#
# Simulation 2731
#
# Simulation 2732
#
# Simulation 2733
#
# Simulation 2734
#
# Simulation 2735
#
# Simulation 2736
#
# Simulation 2737
#
# Simulation 2738
#
# Simulation 2739
#
# Simulation 2740
#
# Simulation 2741
#
# Simulation 2742
#
# Simulation 2743
#
# Simulation 2744
#
# Simulation 2745
#
# Simulation 2746
#
# Simulation 2747
#
# Simulation 2748
#
# Simulation 2749
#
# Simulation 2750
#
# Simulation 2751
#
# Simulation 2752
#
# Simulation 2753
#
# Simulation 2754
#
# Simulation 2755
#
# Simulation 2756
#
# Simulation 2757
#
# Simulation 2758
#
# Simulation 2759
#
# Simulation 2760
#
# Simulation 2761
#
# Simulation 2762
#
# Simulation 2763
#
# Simulation 2764
#
# Simulation 2765
#
# Simulation 2766
#
# Simulation 2767
#
# Simulation 2768
#
# Simulation 2769
#
# Simulation 2770
#
# Simulation 2771
#
# Simulation 2772
#
# Simulation 2773
#
# Simulation 2774
#
# Simulation 2775
#
# Simulation 2776
#
# Simulation 2777
#
# Simulation 2778
#
# Simulation 2779
#
# Simulation 2780
#
# Simulation 2781
#
# Simulation 2782
#
# Simulation 2783
#
# Simulation 2784
#
# Simulation 2785
#
# Simulation 2786
#
# Simulation 2787
#
# Simulation 2788
#
# Simulation 2789
#
# Simulation 2790
#
# Simulation 2791
#
# Simulation 2792
#
# Simulation 2793
#
# Simulation 2794
#
# Simulation 2795
#
# Simulation 2796
#
# Simulation 2797
#
# Simulation 2798
#
# Simulation 2799
#
# Simulation 2800
#
# Simulation 2801
#
# Simulation 2802
#
# Simulation 2803
#
# Simulation 2804
#
# Simulation 2805
#
# Simulation 2806
#
# Simulation 2807
#
# Simulation 2808
#
# Simulation 2809
#
# Simulation 2810
#
# Simulation 2811
#
# Simulation 2812
#
# Simulation 2813
#
# Simulation 2814
#
# Simulation 2815
#
# Simulation 2816
#
# Simulation 2817
#
# Simulation 2818
#
# Simulation 2819
#
# Simulation 2820
#
# Simulation 2821
#
# Simulation 2822
#
# Simulation 2823
#
# Simulation 2824
#
# Simulation 2825
#
# Simulation 2826
#
# Simulation 2827
#
# Simulation 2828
#
# Simulation 2829
#
# Simulation 2830
#
# Simulation 2831
#
# Simulation 2832
#
# Simulation 2833
#
# Simulation 2834
#
# Simulation 2835
#
# Simulation 2836
#
# Simulation 2837
#
# Simulation 2838
#
# Simulation 2839
#
# Simulation 2840
#
# Simulation 2841
#
# Simulation 2842
#
# Simulation 2843
#
# Simulation 2844
#
# Simulation 2845
#
# Simulation 2846
#
# Simulation 2847
#
# Simulation 2848
#
# Simulation 2849
#
# Simulation 2850
#
# Simulation 2851
#
# Simulation 2852
#
# Simulation 2853
#
# Simulation 2854
#
# Simulation 2855
#
# Simulation 2856
#
# Simulation 2857
#
# Simulation 2858
#
# Simulation 2859
#
# Simulation 2860
#
# Simulation 2861
#
# Simulation 2862
#
# Simulation 2863
#
# Simulation 2864
#
# Simulation 2865
#
# Simulation 2866
#
# Simulation 2867
#
# Simulation 2868
#
# Simulation 2869
#
# Simulation 2870
#
# Simulation 2871
#
# Simulation 2872
#
# Simulation 2873
#
# Simulation 2874
#
# Simulation 2875
#
# Simulation 2876
#
# Simulation 2877
#
# Simulation 2878
#
# Simulation 2879
#
# Simulation 2880
#
# Simulation 2881
#
# Simulation 2882
#
# Simulation 2883
#
# Simulation 2884
#
# Simulation 2885
#
# Simulation 2886
#
# Simulation 2887
#
# Simulation 2888
#
# ...
#
# Simulation 49738
#
# Simulation 49739
#
# Simulation 49740
#
# Simulation 49741
#
# Simulation 49742
#
# Simulation 49743
#
# Simulation 49744
#
# Simulation 49745
#
# Simulation 49746
#
# Simulation 49747
#
# Simulation 49748
#
# Simulation 49749
#
# Simulation 49750
#
# Simulation 49751
#
# Simulation 49752
#
# Simulation 49753
#
# Simulation 49754
#
# Simulation 49755
#
# Simulation 49756
#
# Simulation 49757
#
# Simulation 49758
#
# Simulation 49759
#
# Simulation 49760
#
# Simulation 49761
#
# Simulation 49762
#
# Simulation 49763
#
# Simulation 49764
#
# Simulation 49765
#
# Simulation 49766
#
# Simulation 49767
#
# Simulation 49768
#
# Simulation 49769
#
# Simulation 49770
#
# Simulation 49771
#
# Simulation 49772
#
# Simulation 49773
#
# Simulation 49774
#
# Simulation 49775
#
# Simulation 49776
#
# Simulation 49777
#
# Simulation 49778
#
# Simulation 49779
#
# Simulation 49780
#
# Simulation 49781
#
# Simulation 49782
#
# Simulation 49783
#
# Simulation 49784
#
# Simulation 49785
#
# Simulation 49786
#
# Simulation 49787
#
# Simulation 49788
#
# Simulation 49789
#
# Simulation 49790
#
# Simulation 49791
#
# Simulation 49792
#
# Simulation 49793
#
# Simulation 49794
#
# Simulation 49795
#
# Simulation 49796
#
# Simulation 49797
#
# Simulation 49798
#
# Simulation 49799
#
# Simulation 49800
#
# Simulation 49801
#
# Simulation 49802
#
# Simulation 49803
#
# Simulation 49804
#
# Simulation 49805
#
# Simulation 49806
#
# Simulation 49807
#
# Simulation 49808
#
# Simulation 49809
#
# Simulation 49810
#
# Simulation 49811
#
# Simulation 49812
#
# Simulation 49813
#
# Simulation 49814
#
# Simulation 49815
#
# Simulation 49816
#
# Simulation 49817
#
# Simulation 49818
#
# Simulation 49819
#
# Simulation 49820
#
# Simulation 49821
#
# Simulation 49822
#
# Simulation 49823
#
# Simulation 49824
#
# Simulation 49825
#
# Simulation 49826
#
# Simulation 49827
#
# Simulation 49828
#
# Simulation 49829
#
# Simulation 49830
#
# Simulation 49831
#
# Simulation 49832
#
# Simulation 49833
#
# Simulation 49834
#
# Simulation 49835
#
# Simulation 49836
#
# Simulation 49837
#
# Simulation 49838
#
# Simulation 49839
#
# Simulation 49840
#
# Simulation 49841
#
# Simulation 49842
#
# Simulation 49843
#
# Simulation 49844
#
# Simulation 49845
#
# Simulation 49846
#
# Simulation 49847
#
# Simulation 49848
#
# Simulation 49849
#
# Simulation 49850
#
# Simulation 49851
#
# Simulation 49852
#
# Simulation 49853
#
# Simulation 49854
#
# Simulation 49855
#
# Simulation 49856
#
# Simulation 49857
#
# Simulation 49858
#
# Simulation 49859
#
# Simulation 49860
#
# Simulation 49861
#
# Simulation 49862
#
# Simulation 49863
#
# Simulation 49864
#
# Simulation 49865
#
# Simulation 49866
#
# Simulation 49867
#
# Simulation 49868
#
# Simulation 49869
#
# Simulation 49870
#
# Simulation 49871
#
# Simulation 49872
#
# Simulation 49873
#
# Simulation 49874
#
# Simulation 49875
#
# Simulation 49876
#
# Simulation 49877
#
# Simulation 49878
#
# Simulation 49879
#
# Simulation 49880
#
# Simulation 49881
#
# Simulation 49882
#
# Simulation 49883
#
# Simulation 49884
#
# Simulation 49885
#
# Simulation 49886
#
# Simulation 49887
#
# Simulation 49888
#
# Simulation 49889
#
# Simulation 49890
#
# Simulation 49891
#
# Simulation 49892
#
# Simulation 49893
#
# Simulation 49894
#
# Simulation 49895
#
# Simulation 49896
#
# Simulation 49897
#
# Simulation 49898
#
# Simulation 49899
#
# Simulation 49900
#
# Simulation 49901
#
# Simulation 49902
#
# Simulation 49903
#
# Simulation 49904
#
# Simulation 49905
#
# Simulation 49906
#
# Simulation 49907
#
# Simulation 49908
#
# Simulation 49909
#
# Simulation 49910
#
# Simulation 49911
#
# Simulation 49912
#
# Simulation 49913
#
# Simulation 49914
#
# Simulation 49915
#
# Simulation 49916
#
# Simulation 49917
#
# Simulation 49918
#
# Simulation 49919
#
# Simulation 49920
#
# Simulation 49921
#
# Simulation 49922
#
# Simulation 49923
#
# Simulation 49924
#
# Simulation 49925
#
# Simulation 49926
#
# Simulation 49927
#
# Simulation 49928
#
# Simulation 49929
#
# Simulation 49930
#
# Simulation 49931
#
# Simulation 49932
#
# Simulation 49933
#
# Simulation 49934
#
# Simulation 49935
#
# Simulation 49936
#
# Simulation 49937
#
# Simulation 49938
#
# Simulation 49939
#
# Simulation 49940
#
# Simulation 49941
#
# Simulation 49942
#
# Simulation 49943
#
# Simulation 49944
#
# Simulation 49945
#
# Simulation 49946
#
# Simulation 49947
#
# Simulation 49948
#
# Simulation 49949
#
# Simulation 49950
#
# Simulation 49951
#
# Simulation 49952
#
# Simulation 49953
#
# Simulation 49954
#
# Simulation 49955
#
# Simulation 49956
#
# Simulation 49957
#
# Simulation 49958
#
# Simulation 49959
#
# Simulation 49960
#
# Simulation 49961
#
# Simulation 49962
#
# Simulation 49963
#
# Simulation 49964
#
# Simulation 49965
#
# Simulation 49966
#
# Simulation 49967
#
# Simulation 49968
#
# Simulation 49969
#
# Simulation 49970
#
# Simulation 49971
#
# Simulation 49972
#
# Simulation 49973
#
# Simulation 49974
#
# Simulation 49975
#
# Simulation 49976
#
# Simulation 49977
#
# Simulation 49978
#
# Simulation 49979
#
# Simulation 49980
#
# Simulation 49981
#
# Simulation 49982
#
# Simulation 49983
#
# Simulation 49984
#
# Simulation 49985
#
# Simulation 49986
#
# Simulation 49987
#
# Simulation 49988
#
# Simulation 49989
#
# Simulation 49990
#
# Simulation 49991
#
# Simulation 49992
#
# Simulation 49993
#
# Simulation 49994
#
# Simulation 49995
#
# Simulation 49996
#
# Simulation 49997
#
# Simulation 49998
#
# Simulation 49999
#
# Simulation 50000
#
# Simulation 50001
#
# Simulation 50002
#
# Simulation 50003
#
# Simulation 50004
#
# Simulation 50005
#
# Simulation 50006
#
# Simulation 50007
#
# Simulation 50008
#
# Simulation 50009
#
# Simulation 50010
#
# Simulation 50011
#
# Simulation 50012
#
# Simulation 50013
#
# Simulation 50014
#
# Simulation 50015
#
# Simulation 50016
#
# Simulation 50017
#
# Simulation 50018
#
# Simulation 50019
#
# Simulation 50020
#
# Simulation 50021
#
# Simulation 50022
#
# Simulation 50023
#
# Simulation 50024
#
# Simulation 50025
#
# Simulation 50026
#
# Simulation 50027
#
# Simulation 50028
#
# Simulation 50029
#
# Simulation 50030
#
# Simulation 50031
#
# Simulation 50032
#
# Simulation 50033
#
# Simulation 50034
#
# Simulation 50035
#
# Simulation 50036
#
# Simulation 50037
#
# Simulation 50038
#
# Simulation 50039
#
# Simulation 50040
#
# Simulation 50041
#
# Simulation 50042
#
# Simulation 50043
#
# Simulation 50044
#
# Simulation 50045
#
# Simulation 50046
#
# Simulation 50047
#
# Simulation 50048
#
# Simulation 50049
#
# Simulation 50050
#
# Simulation 50051
#
# Simulation 50052
#
# Simulation 50053
#
# Simulation 50054
#
# Simulation 50055
#
# Simulation 50056
#
# Simulation 50057
#
# Simulation 50058
#
# Simulation 50059
#
# Simulation 50060
#
# Simulation 50061
#
# Simulation 50062
#
# Simulation 50063
#
# Simulation 50064
#
# Simulation 50065
#
# Simulation 50066
#
# Simulation 50067
#
# Simulation 50068
#
# Simulation 50069
#
# Simulation 50070
#
# Simulation 50071
#
# Simulation 50072
#
# Simulation 50073
#
# Simulation 50074
#
# Simulation 50075
#
# Simulation 50076
#
# Simulation 50077
#
# Simulation 50078
#
# Simulation 50079
#
# Simulation 50080
#
# Simulation 50081
#
# Simulation 50082
#
# Simulation 50083
#
# Simulation 50084
#
# Simulation 50085
#
# Simulation 50086
#
# Simulation 50087
#
# Simulation 50088
#
# Simulation 50089
#
# Simulation 50090
#
# Simulation 50091
#
# Simulation 50092
#
# Simulation 50093
#
# Simulation 50094
#
# Simulation 50095
#
# Simulation 50096
#
# Simulation 50097
#
# Simulation 50098
#
# Simulation 50099
#
# Simulation 50100
#
# Simulation 50101
#
# Simulation 50102
#
# Simulation 50103
#
# Simulation 50104
#
# Simulation 50105
#
# Simulation 50106
#
# Simulation 50107
#
# Simulation 50108
#
# Simulation 50109
#
# Simulation 50110
#
# Simulation 50111
#
# Simulation 50112
#
# Simulation 50113
#
# Simulation 50114
#
# Simulation 50115
#
# Simulation 50116
#
# Simulation 50117
#
# Simulation 50118
#
# Simulation 50119
#
# Simulation 50120
#
# Simulation 50121
#
# Simulation 50122
#
# Simulation 50123
#
# Simulation 50124
#
# Simulation 50125
#
# Simulation 50126
#
# Simulation 50127
#
# Simulation 50128
#
# Simulation 50129
#
# Simulation 50130
#
# Simulation 50131
#
# Simulation 50132
#
# Simulation 50133
#
# Simulation 50134
#
# Simulation 50135
#
# Simulation 50136
#
# Simulation 50137
#
# Simulation 50138
#
# Simulation 50139
#
# Simulation 50140
#
# Simulation 50141
#
# Simulation 50142
#
# Simulation 50143
#
# Simulation 50144
#
# Simulation 50145
#
# Simulation 50146
#
# Simulation 50147
#
# Simulation 50148
#
# Simulation 50149
#
# Simulation 50150
#
# Simulation 50151
#
# Simulation 50152
#
# Simulation 50153
#
# Simulation 50154
#
# Simulation 50155
#
# Simulation 50156
#
# Simulation 50157
#
# Simulation 50158
#
# Simulation 50159
#
# Simulation 50160
#
# Simulation 50161
#
# Simulation 50162
#
# Simulation 50163
#
# Simulation 50164
#
# Simulation 50165
#
# Simulation 50166
#
# Simulation 50167
#
# Simulation 50168
#
# Simulation 50169
#
# Simulation 50170
#
# Simulation 50171
#
# Simulation 50172
#
# Simulation 50173
#
# Simulation 50174
#
# Simulation 50175
#
# Simulation 50176
#
# Simulation 50177
#
# Simulation 50178
#
# Simulation 50179
#
# Simulation 50180
#
# Simulation 50181
#
# Simulation 50182
#
# Simulation 50183
#
# Simulation 50184
#
# Simulation 50185
#
# Simulation 50186
#
# Simulation 50187
#
# Simulation 50188
#
# Simulation 50189
#
# Simulation 50190
#
# Simulation 50191
#
# Simulation 50192
#
# Simulation 50193
#
# Simulation 50194
#
# Simulation 50195
#
# Simulation 50196
#
# Simulation 50197
#
# Simulation 50198
#
# Simulation 50199
#
# Simulation 50200
#
# Simulation 50201
#
# Simulation 50202
#
# Simulation 50203
#
# Simulation 50204
#
# Simulation 50205
#
# Simulation 50206
#
# Simulation 50207
#
# Simulation 50208
#
# Simulation 50209
#
# Simulation 50210
#
# Simulation 50211
#
# Simulation 50212
#
# Simulation 50213
#
# Simulation 50214
#
# Simulation 50215
#
# Simulation 50216
#
# Simulation 50217
#
# Simulation 50218
#
# Simulation 50219
#
# Simulation 50220
#
# Simulation 50221
#
# Simulation 50222
#
# Simulation 50223
#
# Simulation 50224
#
# Simulation 50225
#
# Simulation 50226
#
# Simulation 50227
#
# Simulation 50228
#
# Simulation 50229
#
# Simulation 50230
#
# Simulation 50231
#
# Simulation 50232
#
# Simulation 50233
#
# Simulation 50234
#
# Simulation 50235
#
# Simulation 50236
#
# Simulation 50237
#
# Simulation 50238
#
# Simulation 50239
#
# Simulation 50240
#
# Simulation 50241
#
# Simulation 50242
#
# Simulation 50243
#
# Simulation 50244
#
# Simulation 50245
#
# Simulation 50246
#
# Simulation 50247
#
# Simulation 50248
#
# Simulation 50249
#
# Simulation 50250
#
# Simulation 50251
#
# Simulation 50252
#
# Simulation 50253
#
# Simulation 50254
#
# Simulation 50255
#
# Simulation 50256
#
# Simulation 50257
#
# Simulation 50258
#
# Simulation 50259
#
# Simulation 50260
#
# Simulation 50261
#
# Simulation 50262
#
# Simulation 50263
#
# Simulation 50264
#
# Simulation 50265
#
# Simulation 50266
#
# Simulation 50267
#
# Simulation 50268
#
# Simulation 50269
#
# Simulation 50270
#
# Simulation 50271
#
# Simulation 50272
#
# Simulation 50273
#
# Simulation 50274
#
# Simulation 50275
#
# Simulation 50276
#
# Simulation 50277
#
# Simulation 50278
#
# Simulation 50279
#
# Simulation 50280
#
# Simulation 50281
#
# Simulation 50282
#
# Simulation 50283
#
# Simulation 50284
#
# Simulation 50285
#
# Simulation 50286
#
# Simulation 50287
#
# Simulation 50288
#
# Simulation 50289
#
# Simulation 50290
#
# Simulation 50291
#
# Simulation 50292
#
# Simulation 50293
#
# Simulation 50294
#
# Simulation 50295
#
# Simulation 50296
#
# Simulation 50297
#
# Simulation 50298
#
# Simulation 50299
#
# Simulation 50300
#
# Simulation 50301
#
# Simulation 50302
#
# Simulation 50303
#
# Simulation 50304
#
# Simulation 50305
#
# Simulation 50306
#
# Simulation 50307
#
# Simulation 50308
#
# Simulation 50309
#
# Simulation 50310
#
# Simulation 50311
#
# Simulation 50312
#
# Simulation 50313
#
# Simulation 50314
#
# Simulation 50315
#
# Simulation 50316
#
# Simulation 50317
#
# Simulation 50318
#
# Simulation 50319
#
# Simulation 50320
#
# Simulation 50321
#
# Simulation 50322
#
# Simulation 50323
#
# Simulation 50324
#
# Simulation 50325
#
# Simulation 50326
#
# Simulation 50327
#
# Simulation 50328
#
# Simulation 50329
#
# Simulation 50330
#
# Simulation 50331
#
# Simulation 50332
#
# Simulation 50333
#
# Simulation 50334
#
# Simulation 50335
#
# Simulation 50336
#
# Simulation 50337
#
# Simulation 50338
#
# Simulation 50339
#
# Simulation 50340
#
# Simulation 50341
#
# Simulation 50342
#
# Simulation 50343
#
# Simulation 50344
#
# Simulation 50345
#
# Simulation 50346
#
# Simulation 50347
#
# Simulation 50348
#
# Simulation 50349
#
# Simulation 50350
#
# Simulation 50351
#
# Simulation 50352
#
# Simulation 50353
#
# Simulation 50354
#
# Simulation 50355
#
# Simulation 50356
#
# Simulation 50357
#
# Simulation 50358
#
# Simulation 50359
#
# Simulation 50360
#
# Simulation 50361
#
# Simulation 50362
#
# Simulation 50363
#
# Simulation 50364
#
# Simulation 50365
#
# Simulation 50366
#
# Simulation 50367
#
# Simulation 50368
#
# Simulation 50369
#
# Simulation 50370
#
# Simulation 50371
#
# Simulation 50372
#
# Simulation 50373
#
# Simulation 50374
#
# Simulation 50375
#
# Simulation 50376
#
# Simulation 50377
#
# Simulation 50378
#
# Simulation 50379
#
# Simulation 50380
#
# Simulation 50381
#
# Simulation 50382
#
# Simulation 50383
#
# Simulation 50384
#
# Simulation 50385
#
# Simulation 50386
#
# Simulation 50387
#
# Simulation 50388
#
# Simulation 50389
#
# Simulation 50390
#
# Simulation 50391
#
# Simulation 50392
#
# Simulation 50393
#
# Simulation 50394
#
# Simulation 50395
#
# Simulation 50396
#
# Simulation 50397
#
# Simulation 50398
#
# Simulation 50399
#
# Simulation 50400
#
# Simulation 50401
#
# Simulation 50402
#
# Simulation 50403
#
# Simulation 50404
#
# Simulation 50405
#
# Simulation 50406
#
# Simulation 50407
#
# Simulation 50408
#
# Simulation 50409
#
# Simulation 50410
#
# Simulation 50411
#
# Simulation 50412
#
# Simulation 50413
#
# Simulation 50414
#
# Simulation 50415
#
# Simulation 50416
#
# Simulation 50417
#
# Simulation 50418
#
# Simulation 50419
#
# Simulation 50420
#
# Simulation 50421
#
# Simulation 50422
#
# Simulation 50423
#
# Simulation 50424
#
# Simulation 50425
#
# Simulation 50426
#
# Simulation 50427
#
# Simulation 50428
#
# Simulation 50429
#
# Simulation 50430
#
# Simulation 50431
#
# Simulation 50432
#
# Simulation 50433
#
# Simulation 50434
#
# Simulation 50435
#
# Simulation 50436
#
# Simulation 50437
#
# Simulation 50438
#
# Simulation 50439
#
# Simulation 50440
#
# Simulation 50441
#
# Simulation 50442
#
# Simulation 50443
#
# Simulation 50444
#
# Simulation 50445
#
# Simulation 50446
#
# Simulation 50447
#
# Simulation 50448
#
# Simulation 50449
#
# Simulation 50450
#
# Simulation 50451
#
# Simulation 50452
#
# Simulation 50453
#
# Simulation 50454
#
# Simulation 50455
#
# Simulation 50456
#
# Simulation 50457
#
# Simulation 50458
#
# Simulation 50459
#
# Simulation 50460
#
# Simulation 50461
#
# Simulation 50462
#
# Simulation 50463
#
# Simulation 50464
#
# Simulation 50465
#
# Simulation 50466
#
# Simulation 50467
#
# Simulation 50468
#
# Simulation 50469
#
# Simulation 50470
#
# Simulation 50471
#
# Simulation 50472
#
# Simulation 50473
#
# Simulation 50474
#
# Simulation 50475
#
# Simulation 50476
#
# Simulation 50477
#
# Simulation 50478
#
# Simulation 50479
#
# Simulation 50480
#
# Simulation 50481
#
# Simulation 50482
#
# Simulation 50483
#
# Simulation 50484
#
# Simulation 50485
#
# Simulation 50486
#
# Simulation 50487
#
# Simulation 50488
#
# Simulation 50489
#
# Simulation 50490
#
# Simulation 50491
#
# Simulation 50492
#
# Simulation 50493
#
# Simulation 50494
#
# Simulation 50495
#
# Simulation 50496
#
# Simulation 50497
#
# Simulation 50498
#
# Simulation 50499
#
# Simulation 50500
#
# Simulation 50501
#
# Simulation 50502
#
# Simulation 50503
#
# Simulation 50504
#
# Simulation 50505
#
# Simulation 50506
#
# Simulation 50507
#
# Simulation 50508
#
# Simulation 50509
#
# Simulation 50510
#
# Simulation 50511
#
# Simulation 50512
#
# Simulation 50513
#
# Simulation 50514
#
# Simulation 50515
#
# Simulation 50516
#
# Simulation 50517
#
# Simulation 50518
#
# Simulation 50519
#
# Simulation 50520
#
# Simulation 50521
#
# Simulation 50522
#
# Simulation 50523
#
# Simulation 50524
#
# Simulation 50525
#
# Simulation 50526
#
# Simulation 50527
#
# Simulation 50528
#
# Simulation 50529
#
# Simulation 50530
#
# Simulation 50531
#
# Simulation 50532
#
# Simulation 50533
#
# Simulation 50534
#
# Simulation 50535
#
# Simulation 50536
#
# Simulation 50537
#
# Simulation 50538
#
# Simulation 50539
#
# Simulation 50540
#
# Simulation 50541
#
# Simulation 50542
#
# Simulation 50543
#
# Simulation 50544
#
# Simulation 50545
#
# Simulation 50546
#
# Simulation 50547
#
# Simulation 50548
#
# Simulation 50549
#
# Simulation 50550
#
# Simulation 50551
#
# Simulation 50552
#
# Simulation 50553
#
# Simulation 50554
#
# Simulation 50555
#
# Simulation 50556
#
# Simulation 50557
#
# Simulation 50558
#
# Simulation 50559
#
# Simulation 50560
#
# Simulation 50561
#
# Simulation 50562
#
# Simulation 50563
#
# Simulation 50564
#
# Simulation 50565
#
# Simulation 50566
#
# Simulation 50567
#
# Simulation 50568
#
# Simulation 50569
#
# Simulation 50570
#
# Simulation 50571
#
# Simulation 50572
#
# Simulation 50573
#
# Simulation 50574
#
# Simulation 50575
#
# Simulation 50576
#
# Simulation 50577
#
# Simulation 50578
#
# Simulation 50579
#
# Simulation 50580
#
# Simulation 50581
#
# Simulation 50582
#
# Simulation 50583
#
# Simulation 50584
#
# Simulation 50585
#
# Simulation 50586
#
# Simulation 50587
#
# Simulation 50588
#
# Simulation 50589
#
# Simulation 50590
#
# Simulation 50591
#
# Simulation 50592
#
# Simulation 50593
#
# Simulation 50594
#
# Simulation 50595
#
# Simulation 50596
#
# Simulation 50597
#
# Simulation 50598
#
# Simulation 50599
#
# Simulation 50600
#
# Simulation 50601
#
# Simulation 50602
#
# Simulation 50603
#
# Simulation 50604
#
# Simulation 50605
#
# Simulation 50606
#
# Simulation 50607
#
# Simulation 50608
#
# Simulation 50609
#
# Simulation 50610
#
# Simulation 50611
#
# Simulation 50612
#
# Simulation 50613
#
# Simulation 50614
#
# Simulation 50615
#
# Simulation 50616
#
# Simulation 50617
#
# Simulation 50618
#
# Simulation 50619
#
# Simulation 50620
#
# Simulation 50621
#
# Simulation 50622
#
# Simulation 50623
#
# Simulation 50624
#
# Simulation 50625

# %%
# Use the function to write data to the CSV file
write_to_csv(csv_file_path, csv_header, csv_data)

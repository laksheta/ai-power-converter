# %% [markdown]
# # Optimization

# %%
import numpy as np
import ga
import pickle
import tensorflow as tf
import csv
import matplotlib.pyplot as plt
# Out:
# WARNING:tensorflow:From d:\Krishna\Python_3_92\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
# Load the machine learning model and scaler
model = tf.keras.models.load_model(r'E:\ai-power-converter\machine-learning\model_3_512_new_from_selected_model.h5')
csv_file_capacitance = r'E:\ai-power-converter\dataset\capacitor_lookup_table.csv'  # Replace 'your_csv_file.csv' with the path to your CSV file
csv_file_inductance = r'E:\ai-power-converter\dataset\inductor_lookup_table.csv'
# Define constraint values
Vol_lim = 7e-6
Delta_Vo_percent_lim = 1
Delta_IL_percent_lim = 0.1

# Genetic algorithm parameters
sol_per_pop = 8
num_parents_mating = 4
pop_size = (sol_per_pop, 3)  # We have 3 variables: fs, L, C
num_generations = 100

# Generate initial population
L_range = (30e-6, 2000e-6)  # Range for L
C_range = (30e-6, 200e-6)   # Range for C
fsw_range = (20e3, 200e3)    # Range for fsw
t_dt_range = (0.178e-6, 1e-6) # Range for dead time

num_values = sol_per_pop

# Define custom scaling ranges for each input feature
L_min, L_max = 30e-6, 2000e-6
C_min, C_max = 20e-6, 1000e-6
fsw_min, fsw_max = 20e3, 200e3
t_dt_min, t_dt_max = 0.178e-6, 1e-6

# Define mutation ranges for each parameter
mutation_ranges = [(30e-6, 100e-6), (20e-6, 100e-6), (10, 1000), (0.001e-6, 0.1e-6)]

# # Create arrays of discrete L, C, and fsw values within the specified ranges
L_values = np.linspace(L_range[0], L_range[1], num=num_values)
C_values = np.linspace(C_range[0], C_range[1], num=num_values)
t_dt_values = np.linspace(t_dt_range[0], t_dt_range[1], num=num_values)

# Round the values to the desired number of decimal places
L_values = np.around(L_values, decimals=6)
C_values = np.around(C_values, decimals=6)
t_dt_values = np.around(t_dt_values, decimals=9)

fsw_values = np.linspace(fsw_range[0], fsw_range[1], num=num_values, dtype=int)

initial_population = np.column_stack((L_values, C_values, fsw_values, t_dt_values))
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[2], line 2
#       1 # Load the machine learning model and scaler
# ----> 2 model = tf.keras.models.load_model(r'E:\ai-power-converter\machine-learning\model_3_512_new_from_selected_model.h5')
#       3 csv_file_capacitance = r'E:\ai-power-converter\dataset\capacitor_lookup_table.csv'  # Replace 'your_csv_file.csv' with the path to your CSV file
#       4 csv_file_inductance = r'E:\ai-power-converter\dataset\inductor_lookup_table.csv'
#
# File d:\Krishna\Python_3_92\lib\site-packages\keras\src\saving\saving_api.py:262, in load_model(filepath, custom_objects, compile, safe_mode, **kwargs)
#     254     return saving_lib.load_model(
#     255         filepath,
#     256         custom_objects=custom_objects,
#     257         compile=compile,
#     258         safe_mode=safe_mode,
#     259     )
#     261 # Legacy case.
# --> 262 return legacy_sm_saving_lib.load_model(
#     263     filepath, custom_objects=custom_objects, compile=compile, **kwargs
#     264 )
#
# File d:\Krishna\Python_3_92\lib\site-packages\keras\src\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File d:\Krishna\Python_3_92\lib\site-packages\keras\src\saving\legacy\save.py:234, in load_model(filepath, custom_objects, compile, options)
#     232 if isinstance(filepath_str, str):
#     233     if not tf.io.gfile.exists(filepath_str):
# --> 234         raise IOError(
#     235             f"No file or directory found at {filepath_str}"
#     236         )
#     238     if tf.io.gfile.isdir(filepath_str):
#     239         return saved_model_load.load(
#     240             filepath_str, compile, options
#     241         )
#
# OSError: No file or directory found at E:\ai-power-converter\machine-learning\model_3_512_new_from_selected_model.h5

# %% [markdown]
# # Function

# %% [markdown]
# ## Scaling

# %%
def scale_input_values(input_values):

    input_values_scaled = np.zeros_like(input_values, dtype=float)  # Initialize scaled data array

    # Scale L
    input_values_scaled[0] = (input_values[0] - L_min) / (L_max - L_min)

    # Scale C
    input_values_scaled[1] = (input_values[1] - C_min) / (C_max - C_min)

    # Scale fsw
    input_values_scaled[2] = (input_values[2] - fsw_min) / (fsw_max - fsw_min)
    # Make predictions using the model

    # Reshape the input data to match the expected shape of the model
    input_values_reshaped = input_values_scaled.reshape((1, -1))

    return input_values_reshaped

# %% [markdown]
# ## Calculate Fitness

# %%
def calculate_fitness(individual):

    input_values_scaled = scale_input_values(individual)

    prediction = model.predict(input_values_scaled, verbose=0)
    
    # Extract predictions from the model output
    P_l_s1 = prediction[0][2]
    P_l_s2 = prediction[0][3]
    P_l_C = prediction[0][4]
    P_l_L_Cu = prediction[0][5]
    
    # Calculate the objective function value based on the given equation
    objective_value = P_l_s1 + P_l_s2 + P_l_L_Cu + P_l_C
    
    return objective_value

# %% [markdown]
# ## Search Volume

# %% [markdown]
# ### Capacitance

# %%
def search_volume_capacitance(capacitance, csv_file):
    with open(csv_file, mode='r') as file:
        reader = csv.DictReader(file)
        capacitance_values = []
        volume_values = []
        for row in reader:
            capacitance_values.append(float(row['Capacitance']))
            volume_values.append(float(row['Total Volume']))
        
        # Find the index of the nearest capacitance value
        nearest_idx = np.abs(np.array(capacitance_values) - capacitance).argmin()
        nearest_capacitance = capacitance_values[nearest_idx]
        nearest_volume = volume_values[nearest_idx]
        
        return nearest_capacitance, nearest_volume

# %% [markdown]
# ### Inductance

# %%
def search_volume_inductance(inductance, csv_file):
    with open(csv_file, mode='r') as file:
        reader = csv.DictReader(file)
        inductance_values = []
        volume_values = []
        for row in reader:
            inductance_values.append(float(row['Inductance']))
            volume_values.append(float(row['Volume']))
        
        # Find the index of the nearest inductance value
        nearest_idx = np.abs(np.array(inductance_values) - inductance).argmin()
        nearest_inductance = inductance_values[nearest_idx]
        nearest_volume = volume_values[nearest_idx]
        
        return nearest_inductance, nearest_volume

# %% [markdown]
# ## Check Constraints

# %%
# Define the constraints function
def check_constraints(individual):
    L = individual[0]
    C = individual[1]
    fs = individual[2]
    
    # Define the constraint values
    nearest_C, Vol_C  = search_volume_capacitance(C, csv_file_capacitance) # Define Vol_L based on your problem-specific requirements
    nearest_L, Vol_L  = search_volume_inductance(L, csv_file_inductance)

    # Prepare input values for prediction
    input_values = np.array([L, C, fs])
    # Apply Min-Max normalization separately for each input feature
    input_values_scaled = scale_input_values(input_values)

    prediction = model.predict(input_values_scaled, verbose = 0)
    # Extract predictions from the model output
    Delta_IL_percent = prediction[0][0]
    Delta_Vo_percent = prediction[0][1]

    # Check if constraints are satisfied
    constraint1 = Vol_C + Vol_L  <= Vol_lim
    constraint2 = Delta_Vo_percent <= Delta_Vo_percent_lim
    constraint3 = Delta_IL_percent <= Delta_IL_percent_lim
    
    # return constraint1 and constraint2 and constraint3
    return constraint1 and constraint2 and constraint3

# %% [markdown]
# # Genetic Algorithm

# %%
# Genetic Algorithm optimization
best_outputs = []
best_solutions = []  # Store the best solution for each generation
best_fitnesses = []  # Store the best fitness for each generation
new_population = initial_population

for generation in range(num_generations):
    print("Generation : ", generation)
    
    # Measuring the fitness of each chromosome in the population.
    fitness_values = []
    delta_IL_percent_values = []
    delta_Vo_percent_values = []
    for individual in new_population:
        fitness_value = calculate_fitness(individual)
        fitness_values.append(fitness_value)

    fitness = np.array(fitness_values)

    print("Population", new_population)
    best_outputs.append(np.min(fitness))
    print("Best result:", np.min(fitness))

    # Find the index of the best solution in this generation
    best_solution_idx = np.argmin(fitness)
    print("Best solution index:", best_solution_idx)

    # Retrieve the best solution from the population
    best_solution = new_population[best_solution_idx].copy()  # Copy the best solution
    print("Best solution:", best_solution)

    # Append the current best solution to the list of best solutions
    best_solutions.append(best_solution.copy())  # Append a copy of the best solution
    print("Best solutions array:", best_solutions)

    # Append the corresponding fitness value to the list of best fitnesses
    best_fitness = fitness[best_solution_idx]
    best_fitnesses.append(best_fitness)
    print("Best fitness:", best_fitness)



    # Check and enforce constraints
    for i in range(sol_per_pop):
        if not check_constraints(new_population[i]):
            # Regenerate individual until it satisfies the constraints
            while not check_constraints(new_population[i]):
                # Generate all possible values within the specified range with the desired increment
                L_values_all = np.arange(L_range[0], L_range[1] + 1e-6, 1e-6)
                C_values_all = np.arange(C_range[0], C_range[1] + 1e-6, 1e-6)
                # Generate new random values for fsw, L, and C
                new_L = np.random.choice(L_values_all, 1, replace=False)
                new_C = np.random.choice(C_values_all, 1, replace=False)
                new_fsw = np.random.randint(fsw_range[0], fsw_range[1] + 1, size=1)

                new_population[i] = [new_L[0], new_C[0], new_fsw[0]]
                # new_population[i] = generate_feasible_solution(L_range, C_range, fsw_range)


    # Selecting the best parents in the population for mating.
    parents = ga.select_mating_pool(new_population, fitness, num_parents_mating)
    print("Parents")
    print(parents)

    # Generating next generation using crossover.
    offspring_crossover = ga.crossover(parents, offspring_size=(pop_size[0]-parents.shape[0], 3))
    print("Crossover")
    print(offspring_crossover)

    # Adding some variations to the offspring using mutation.
    # offspring_mutation = ga.mutation(offspring_crossover, 2)
    # offspring_mutation = ga.mutation(offspring_crossover, mutation_ranges, 1)
    offspring_mutation = ga.mutation(offspring_crossover, mutation_ranges, L_range, C_range, fsw_range, 2)
    print("Mutation")
    print(offspring_mutation)

    # Creating the new population based on the parents and offspring.
    new_population[0:parents.shape[0], :] = parents
    new_population[parents.shape[0]:, :] = offspring_mutation

# Getting the best solution after iterating finishing all generations.
# At first, the fitness is calculated for each solution in the final generation.
fitness_values = []

for individual in new_population:
    fitness_value= calculate_fitness(individual)
    fitness_values.append(fitness_value)

fitness = np.array(fitness_values)


# Then return the index of that solution corresponding to the best fitness.
best_match_idx = np.where(fitness == np.min(fitness))

print("Best solution : ", new_population[best_match_idx, :])
print("Best solution fitness : ", fitness[best_match_idx])


plt.plot(best_outputs)
plt.xlabel("Generation")
plt.ylabel("Fitness")
plt.show()
# Out:
# Generation :  0
# Population [[3.00000e-05 3.00000e-05 2.00000e+04]
#  [3.11000e-04 5.40000e-05 4.57140e+04]
#  [5.93000e-04 7.90000e-05 7.14280e+04]
#  [8.74000e-04 1.03000e-04 9.71420e+04]
#  [1.15600e-03 1.27000e-04 1.22857e+05]
#  [1.43700e-03 1.51000e-04 1.48571e+05]
#  [1.71900e-03 1.76000e-04 1.74285e+05]
#  [2.00000e-03 2.00000e-04 2.00000e+05]]
# Best result: 5.3158712
# Best solution index: 1
# Best solution: [3.1100e-04 5.4000e-05 4.5714e+04]
# Best solutions array: [array([3.1100e-04, 5.4000e-05, 4.5714e+04])]
# Best fitness: 5.3158712
# Parents
# [[1.28000e-03 8.10000e-05 5.20370e+04]
#  [1.18100e-03 8.10000e-05 1.85267e+05]
#  [1.35100e-03 3.80000e-05 1.72734e+05]
#  [1.11100e-03 4.20000e-05 1.27872e+05]]
# Crossover
# [[1.28000e-03 8.10000e-05 1.85267e+05]
#  [1.18100e-03 3.80000e-05 1.72734e+05]
#  [1.35100e-03 4.20000e-05 1.27872e+05]
#  [1.11100e-03 8.10000e-05 5.20370e+04]]
# Mutation
# [[1.31100e-03 7.90000e-05 1.83978e+05]
#  [1.07200e-03 4.90000e-05 1.73713e+05]
#  [1.20900e-03 3.00000e-05 1.27410e+05]
#  [1.16800e-03 6.20000e-05 5.29240e+04]]
# Generation :  1
# Population [[1.28000e-03 8.10000e-05 5.20370e+04]
#  [1.18100e-03 8.10000e-05 1.85267e+05]
#  [1.35100e-03 3.80000e-05 1.72734e+05]
#  [1.11100e-03 4.20000e-05 1.27872e+05]
#  [1.31100e-03 7.90000e-05 1.83978e+05]
#  [1.07200e-03 4.90000e-05 1.73713e+05]
#  [1.20900e-03 3.00000e-05 1.27410e+05]
#  [1.16800e-03 6.20000e-05 5.29240e+04]]
# Best result: 6.3217363
# Best solution index: 0
# Best solution: [1.2800e-03 8.1000e-05 5.2037e+04]
# Best solutions array: [array([3.1100e-04, 5.4000e-05, 4.5714e+04]), array([1.2800e-03, 8.1000e-05, 5.2037e+04])]
# Best fitness: 6.3217363
# Parents
# [[1.28000e-03 8.10000e-05 5.20370e+04]
#  [1.16800e-03 6.20000e-05 5.29240e+04]
#  [1.11100e-03 4.20000e-05 1.27872e+05]
#  [1.20900e-03 3.00000e-05 1.27410e+05]]
# Crossover
# [[1.28000e-03 6.20000e-05 5.29240e+04]
#  [1.16800e-03 4.20000e-05 1.27872e+05]
#  [1.11100e-03 3.00000e-05 1.27410e+05]
#  [1.20900e-03 8.10000e-05 5.20370e+04]]
# Mutation
# [[1.20300e-03 1.29000e-04 5.15510e+04]
#  [1.06400e-03 6.30000e-05 1.29661e+05]
#  [9.92000e-04 1.16000e-04 1.26282e+05]
#  [1.14400e-03 3.00000e-05 5.27770e+04]]
# Generation :  2
# Population [[1.28000e-03 8.10000e-05 5.20370e+04]
#  [1.16800e-03 6.20000e-05 5.29240e+04]
#  [1.11100e-03 4.20000e-05 1.27872e+05]
#  [1.20900e-03 3.00000e-05 1.27410e+05]
#  [1.20300e-03 1.29000e-04 5.15510e+04]
#  [1.06400e-03 6.30000e-05 1.29661e+05]
#  [9.92000e-04 1.16000e-04 1.26282e+05]
#  [1.14400e-03 3.00000e-05 5.27770e+04]]
# Best result: 6.172456
# Best solution index: 4
# Best solution: [1.2030e-03 1.2900e-04 5.1551e+04]
# Best solutions array: [array([3.1100e-04, 5.4000e-05, 4.5714e+04]), array([1.2800e-03, 8.1000e-05, 5.2037e+04]), array([1.2030e-03, 1.2900e-04, 5.1551e+
#  [1.68400e-03 6.90000e-05 3.74660e+04]
#  [8.35000e-04 6.40000e-05 1.59841e+05]
#  [8.93000e-04 1.16000e-04 3.68700e+04]
#  [1.52100e-03 3.00000e-05 3.75150e+04]
#  [1.59100e-03 2.00000e-04 1.60027e+05]
#  [9.07000e-04 3.00000e-05 1.50157e+05]]
# Best result: 5.3397255
# Best solution index: 4
# Best solution: [8.930e-04 1.160e-04 3.687e+04]
# Best solutions array: [array([3.1100e-04, 5.4000e-05, 4.5714e+04]), array([1.2800e-03, 8.1000e-05, 5.2037e+04]), array([1.2030e-03, 1.2900e-04, 5.1551e+04]), array([1.2800e-03, 8.1000e-05, 5.2037e+04]), array([1.1650e-03, 1.1100e-04, 5.3044e+04]), array([1.244e-03, 1.170e-04, 5.199e+04]), array([9.4300e-04, 1.7700e-04, 5.3683e+04]), array([1.637e-03, 8.000e-05, 3.787e+04]), array([1.637e-03, 8.000e-05, 3.787e+04]), array([6.0600e-04, 9.5000e-05, 3.6972e+04]), array([1.5300e-03, 1.1500e-04, 3.6294e+04]), array([3.8900e-04, 8.1000e-05, 3.7544e+04]), array([1.6840e-03, 6.9000e-05, 3.7466e+04]), array([1.3430e-03, 1.0900e-04, 3.8182e+04]), array([1.5620e-03, 6.9000e-05, 3.5771e+04]), array([1.5620e-03, 6.9000e-05, 3.5771e+04]), array([1.5620e-03, 6.9000e-05, 3.5771e+04]), array([1.0380e-03, 1.1100e-04, 3.5963e+04]), array([1.3900e-03, 1.2200e-04, 3.5959e+04]), array([8.930e-04, 1.160e-04, 3.687e+04])]
# Best fitness: 5.3397255
# Parents
# [[1.2500e-03 7.9000e-05 6.7969e+04]
#  [1.5620e-03 6.9000e-05 3.5771e+04]
#  [1.6840e-03 6.9000e-05 3.7466e+04]
#  [1.5210e-03 3.0000e-05 3.7515e+04]]
# Crossover
# [[1.2500e-03 6.9000e-05 3.5771e+04]
#  [1.5620e-03 6.9000e-05 3.7466e+04]
#  [1.6840e-03 3.0000e-05 3.7515e+04]
#  [1.5210e-03 7.9000e-05 6.7969e+04]]
# Mutation
# [[1.0570e-03 1.1100e-04 3.7256e+04]
#  [1.5790e-03 3.0000e-05 3.8099e+04]
#  [1.8070e-03 3.2000e-05 3.5990e+04]
#  [1.5200e-03 9.2000e-05 6.6146e+04]]
# Generation :  20
# Population [[1.2500e-03 7.9000e-05 6.7969e+04]
#  [1.5620e-03 6.9000e-05 3.5771e+04]
#  [1.6840e-03 6.9000e-05 3.7466e+04]
#  [1.5210e-03 3.0000e-05 3.7515e+04]
#  [1.0570e-03 1.1100e-04 3.7256e+04]
#  [1.5790e-03 3.0000e-05 3.8099e+04]
#  [1.8070e-03 3.2000e-05 3.5990e+04]
#  [1.5200e-03 9.2000e-05 6.6146e+04]]
# Best result: 6.01932
# Best solution index: 4
# Best solution: [1.0570e-03 1.1100e-04 3.7256e+04]
# Best solutions array: [array([3.1100e-04, 5.4000e-05, 4.5714e+04]), array([1.2800e-03, 8.1000e-05, 5.2037e+04]), array([1.2030e-03, 1.2900e-04, 5.1551e+04]), array([1.2800e-03, 8.1000e-05, 5.2037e+04]), array([1.1650e-03, 1.1100e-04, 5.3044e+04]), array([1.244e-03, 1.170e-04, 5.199e+04]), array([9.4300e-04, 1.7700e-04, 5.3683e+04]), array([1.637e-03, 8.000e-05, 3.787e+04]), array([1.637e-03, 8.000e-05, 3.787e+04]), array([6.0600e-04, 9.5000e-05, 3.6972e+04]), array([1.5300e-03, 1.1500e-04, 3.6294e+04]), array([3.8900e-04, 8.1000e-05, 3.7544e+04]), array([1.6840e-03, 6.9000e-05, 3.7466e+04]), array([1.3430e-03, 1.0900e-04, 3.8182e+04]), array([1.5620e-03, 6.9000e-05, 3.5771e+04]), array([1.5620e-03, 6.9000e-05, 3.5771e+04]), array([1.5620e-03, 6.9000e-05, 3.5771e+04]), array([1.0380e-03, 1.1100e-04, 3.5963e+04]), array([1.3900e-03, 1.2200e-04, 3.5959e+04]), array([8.930e-04, 1.160e-04, 3.687e+04]), array([1.0570e-03, 1.1100e-04, 3.7256e+04])]
# Best fitness: 6.01932
# Parents
# [[1.98600e-03 4.10000e-05 1.57086e+05]
#  [1.56200e-03 6.90000e-05 3.57710e+04]
#  [1.68400e-03 6.90000e-05 3.74660e+04]
#  [1.52100e-03 3.00000e-05 3.75150e+04]]
# Crossover
# [[1.98600e-03 6.90000e-05 3.57710e+04]
#  [1.56200e-03 6.90000e-05 3.74660e+04]
#  [1.85700e-03 6.90000e-05 3.57710e+04]]
# Mutation
# [[1.71500e-03 3.00000e-05 3.88600e+04]
#  [1.67500e-03 3.00000e-05 1.45692e+05]
#  [1.20200e-03 3.00000e-05 4.36060e+04]
#  [1.76500e-03 1.50000e-04 3.61400e+04]]
# Generation :  26
# Population [[1.56200e-03 6.90000e-05 3.57710e+04]
#  [1.68400e-03 6.90000e-05 3.74660e+04]
#  [1.12200e-03 3.10000e-05 1.46106e+05]
#  [1.85700e-03 6.70000e-05 4.41370e+04]
#  [1.71500e-03 3.00000e-05 3.88600e+04]
#  [1.67500e-03 3.00000e-05 1.45692e+05]
#  [1.20200e-03 3.00000e-05 4.36060e+04]
#  [1.76500e-03 1.50000e-04 3.61400e+04]]
# Best result: 6.0442886
# Best solution index: 0
# Best solution: [1.5620e-03 6.9000e-05 3.5771e+04]
# Best solutions array: [array([3.1100e-04, 5.4000e-05, 4.5714e+04]), array([1.2800e-03, 8.1000e-05, 5.2037e+04]), array([1.2030e-03, 1.2900e-04, 5.1551e+04]), array([1.2800e-03, 8.1000e-05, 5.2037e+04]), array([1.1650e-03, 1.1100e-04, 5.3044e+04]), array([1.244e-03, 1.170e-04, 5.199e+04]), array([9.4300e-04, 1.7700e-04, 5.3683e+04]), array([1.637e-03, 8.000e-05, 3.787e+04]), array([1.637e-03, 8.000e-05, 3.787e+04]), array([6.0600e-04, 9.5000e-05, 3.6972e+04]), array([1.5300e-03, 1.1500e-04, 3.6294e+04]), array([3.8900e-04, 8.1000e-05, 3.7544e+04]), array([1.6840e-03, 6.9000e-05, 3.7466e+04]), array([1.3430e-03, 1.0900e-04, 3.8182e+04]), array([1.5620e-03, 6.9000e-05, 3.5771e+04]), array([1.5620e-03, 6.9000e-05, 3.5771e+04]), array([1.5620e-03, 6.9000e-05, 3.5771e+04]), array([1.0380e-03, 1.1100e-04, 3.5963e+04]), array([1.3900e-03, 1.2200e-04, 3.5959e+04]), array([8.930e-04, 1.160e-04, 3.687e+04]), array([1.0570e-03, 1.1100e-04, 3.7256e+04]), array([1.5620e-03, 6.9000e-05, 3.5771e+04]), array([1.5620e-03, 6.9000e-05, 3.5771e+04]), array([1.5620e-03, 6.9000e-05, 3.5771e+04]), array([1.4660e-03, 1.1200e-04, 3.6557e+04]), array([1.5620e-03, 6.9000e-05, 3.5771e+04]), array([1.5620e-03, 6.9000e-05, 3.5771e+04])]
# Best fitness: 6.0442886
# Parents
# [[1.5620e-03 6.9000e-05 3.5771e+04]
#  [1.6840e-03 6.9000e-05 3.7466e+04]
#  [1.8570e-03 6.7000e-05 4.4137e+04]
#  [1.2020e-03 3.0000e-05 4.3606e+04]]
# Crossover
# [[1.5620e-03 6.9000e-05 3.7466e+04]
#  [1.6840e-03 6.7000e-05 4.4137e+04]
#  [1.8570e-03 3.0000e-05 4.3606e+04]
#  [1.2020e-03 6.9000e-05 3.5771e+04]]
# Mutation
# [[1.6420e-03 1.8000e-04 3.7424e+04]
#  [1.7670e-03 1.5300e-04 4.3242e+04]
#  [1.7530e-03 3.0000e-05 4.4938e+04]
#  [1.2810e-03 3.0000e-05 3.5816e+04]]
# Generation :  27
# Population [[1.5620e-03 6.9000e-05 3.5771e+04]
#  [1.6840e-03 6.9000e-05 3.7466e+04]
#  [1.8570e-03 6.7000e-05 4.4137e+04]
#  [1.2020e-03 3.0000e-05 4.3606e+04]
#  [1.6420e-03 1.8000e-04 3.7424e+04]
#  [1.7670e-03 1.5300e-04 4.3242e+04]
#  [1.7530e-03 3.0000e-05 4.4938e+04]
#  [1.2810e-03 3.0000e-05 3.5816e+04]]
# Best result: 6.0442886
# Best solution index: 0
# Best solution: [1.5620e-03 6.9000e-05 3.5771e+04]
# Best solutions array: [array([3.1100e-04, 5.4000e-05, 4.5714e+04]), array([1.2800e-03, 8.1000e-05, 5.2037e+04]), array([1.2030e-03, 1.2900e-04, 5.1551e+04]), array([1.2800e-03, 8.1000e-05, 5.2037e+04]), array([1.1650e-03, 1.1100e-04, 5.3044e+04]), array([1.244e-03, 1.170e-04, 5.199e+04]), array([9.4300e-04, 1.7700e-04, 5.3683e+04]), array([1.637e-03, 8.000e-05, 3.787e+04]), array([1.637e-03, 8.000e-05, 3.787e+04]), array([6.0600e-04, 9.5000e-05, 3.6972e+04]), array([1.5300e-03, 1.1500e-04, 3.6294e+04]), array([3.8900e-04, 8.1000e-05, 3.7544e+04]), array([1.6840e-03, 6.9000e-05, 3.7466e+04]), array([1.3430e-03, 1.0900e-04, 3.8182e+04]), array([1.5620e-03, 6.9000e-05, 3.5771e+04]), array([1.5620e-03, 6.9000e-05, 3.5771e+04]), array([1.5620e-03, 6.9000e-05, 3.5771e+04]), array([1
#  [1.59000e-03 9.00000e-05 3.62470e+04]
#  [1.62900e-03 3.00000e-05 1.90047e+05]
#  [1.82900e-03 9.80000e-05 4.41070e+04]
#  [1.27800e-03 7.10000e-05 3.76760e+04]]
# Best result: 5.9804664
# Best solution index: 4
# Best solution: [1.5900e-03 9.0000e-05 3.6247e+04]
# ...
# Best fitness: 5.4791207
# Parents
# [[9.7300e-04 4.8000e-05 4.0075e+04]
#  [9.6800e-04 5.5000e-05 4.2221e+04]
#  [1.0630e-03 5.4000e-05 4.1164e+04]
#  [9.0400e-04 6.2000e-05 4.3493e+04]]
# Crossover
# [[9.7300e-04 5.5000e-05 4.2221e+04]
#  [9.6800e-04 5.4000e-05 4.1164e+04]
#  [1.0630e-03 6.2000e-05 4.3493e+04]
#  [9.0400e-04 4.8000e-05 4.0075e+04]]
# Mutation
# [[9.3900e-04 3.0000e-05 4.0715e+04]
#  [9.0900e-04 1.8900e-04 4.1462e+04]
#  [1.1190e-03 1.4000e-04 4.2714e+04]
#  [8.9800e-04 1.2300e-04 3.8848e+04]]
# Generation :  97
# Population [[9.7300e-04 4.8000e-05 4.0075e+04]
#  [9.6800e-04 5.5000e-05 4.2221e+04]
#  [1.0630e-03 5.4000e-05 4.1164e+04]
#  [9.0400e-04 6.2000e-05 4.3493e+04]
#  [9.3900e-04 3.0000e-05 4.0715e+04]
#  [9.0900e-04 1.8900e-04 4.1462e+04]
#  [1.1190e-03 1.4000e-04 4.2714e+04]
#  [8.9800e-04 1.2300e-04 3.8848e+04]]
# Best result: 5.0041237
# Best solution index: 5
# Best solution: [9.0900e-04 1.8900e-04 4.1462e+04]
# Best solutions array: [array([3.1100e-04, 5.4000e-05, 4.5714e+04]), array([1.2800e-03, 8.1000e-05, 5.2037e+04]), array([1.2030e-03, 1.2900e-04, 5.1551e+04]), array([1.2800e-03, 8.1000e-05, 5.2037e+04]), array([1.1650e-03, 1.1100e-04, 5.3044e+04]), array([1.244e-03, 1.170e-04, 5.199e+04]), array([9.4300e-04, 1.7700e-04, 5.3683e+04]), array([1.637e-03, 8.000e-05, 3.787e+04]), array([1.637e-03, 8.000e-05, 3.787e+04]), array([6.0600e-04, 9.5000e-05, 3.6972e+04]), array([1.5300e-03, 1.1500e-04, 3.6294e+04]), array([3.8900e-04, 8.1000e-05, 3.7544e+04]), array([1.6840e-03, 6.9000e-05, 3.7466e+04]), array([1.3430e-03, 1.0900e-04, 3.8182e+04]), array([1.5620e-03, 6.9000e-05, 3.5771e+04]), array([1.5620e-03, 6.9000e-05, 3.5771e+04]), array([1.5620e-03, 6.9000e-05, 3.5771e+04]), array([1.0380e-03, 1.1100e-04, 3.5963e+04]), array([1.3900e-03, 1.2200e-04, 3.5959e+04]), array([8.930e-04, 1.160e-04, 3.687e+04]), array([1.0570e-03, 1.1100e-04, 3.7256e+04]), array([1.5620e-03, 6.9000e-05, 3.5771e+04]), array([1.5620e-03, 6.9000e-05, 3.5771e+04]), array([1.5620e-03, 6.9000e-05, 3.5771e+04]), array([1.4660e-03, 1.1200e-04, 3.6557e+04]), array([1.5620e-03, 6.9000e-05, 3.5771e+04]), array([1.5620e-03, 6.9000e-05, 3.5771e+04]), array([1.5620e-03, 6.9000e-05, 3.5771e+04]), array([1.5620e-03, 6.9000e-05, 3.5771e+04]), array([1.5900e-03, 9.0000e-05, 3.6247e+04]), array([1.5900e-03, 9.0000e-05, 3.6247e+04]), array([7.4700e-04, 1.2300e-04, 3.4554e+04]), array([7.7000e-04, 3.0000e-05, 3.4523e+04]), array([7.3100e-04, 8.3000e-05, 3.5782e+04]), array([9.4600e-04, 1.5700e-04, 3.6123e+04]), array([9.3800e-04, 1.5600e-04, 3.9974e+04]), array([1.0120e-03, 3.0000e-05, 3.6472e+04]), array([1.0140e-03, 1.2700e-04, 3.6083e+04]), array([1.0630e-03, 1.5000e-04, 3.5955e+04]), array([9.5700e-04, 2.0000e-04, 3.6581e+04]), array([8.1300e-04, 3.0000e-05, 4.0664e+04]), array([1.0200e-03, 5.7000e-05, 4.0086e+04]), array([7.9700e-04, 5.6000e-05, 4.0324e+04]), array([8.2300e-04, 1.0100e-04, 3.6785e+04]), array([9.5700e-04, 4.2000e-05,
#  [9.7300e-04 5.5000e-05 4.2221e+04]
#  [9.6800e-04 3.0000e-05 4.3397e+04]
#  [1.8210e-03 3.3000e-05 9.0798e+04]]
# Mutation
# [[8.7500e-04 3.0000e-05 3.9956e+04]
#  [1.1130e-03 3.0000e-05 4.2997e+04]
#  [1.1320e-03 6.9000e-05 4.4019e+04]
#  [1.9860e-03 3.0000e-05 9.1022e+04]]
# Best solution :  [[[9.7300e-04 4.8000e-05 4.0075e+04]]]
# Best solution fitness :  [5.4791207]

# %%
# Print the best solutions for each generation
print("Best solutions for each generation:")
for i, (solution, fitness) in enumerate(zip(best_solutions, best_fitnesses)):
    print("Generation", i, ":", "Fitness:", fitness)
    print("Solution (L, C, fsw):", solution)
    
    # Calculate additional information for the current solution
    L = solution[0]
    C = solution[1]
    fs = solution[2]
    nearest_C, Vol_C = search_volume_capacitance(C, csv_file_capacitance)
    nearest_L, Vol_L = search_volume_inductance(L, csv_file_inductance)
    
    # Prepare input values for prediction
    input_values = np.array([L, C, fs])
    input_values_scaled = np.zeros_like(input_values, dtype=float)
    input_values_scaled[0] = (input_values[0] - L_min) / (L_max - L_min)
    input_values_scaled[1] = (input_values[1] - C_min) / (C_max - C_min)
    input_values_scaled[2] = (input_values[2] - fsw_min) / (fsw_max - fsw_min)
    input_values_reshaped = input_values_scaled.reshape((1, -1))
    
    # Make predictions using the model
    prediction = model.predict(input_values_reshaped, verbose=0)
    Delta_IL_percent = prediction[0][0]
    Delta_Vo_percent = prediction[0][1]
    
    print("Volume L:", Vol_L)
    print("Volume C:", Vol_C)
    print("Delta Vo percent:", Delta_Vo_percent)
    print("Delta Il percent:", Delta_IL_percent)
    print()  # Add a blank line for readability
# Out:
# Best solutions for each generation:
# Generation 0 : Fitness: 5.3158712
# Solution (L, C, fsw): [3.1100e-04 5.4000e-05 4.5714e+04]
# Volume L: 2.0828406321502e-06
# Volume C: 4.129e-06
# Delta Vo percent: 1.1949697
# Delta Il percent: 0.2940497
#
# Generation 1 : Fitness: 6.3217363
# Solution (L, C, fsw): [1.2800e-03 8.1000e-05 5.2037e+04]
# Volume L: 2.0828406321502e-06
# Volume C: 3.586e-06
# Delta Vo percent: 0.48027283
# Delta Il percent: 0.061867215
#
# Generation 2 : Fitness: 6.172456
# Solution (L, C, fsw): [1.2030e-03 1.2900e-04 5.1551e+04]
# Volume L: 2.0828406321502e-06
# Volume C: 4.362e-06
# Delta Vo percent: 3.1335778
# Delta Il percent: 0.09059007
#
# Generation 3 : Fitness: 6.3217363
# Solution (L, C, fsw): [1.2800e-03 8.1000e-05 5.2037e+04]
# Volume L: 2.0828406321502e-06
# Volume C: 3.586e-06
# Delta Vo percent: 0.48027283
# Delta Il percent: 0.061867215
#
# Generation 4 : Fitness: 6.248548
# Solution (L, C, fsw): [1.1650e-03 1.1100e-04 5.3044e+04]
# Volume L: 2.0828406321502e-06
# Volume C: 3.591e-06
# Delta Vo percent: 1.6304953
# Delta Il percent: 0.089307316
#
# Generation 5 : Fitness: 6.2239203
# Solution (L, C, fsw): [1.244e-03 1.170e-04 5.199e+04]
# Volume L: 2.0828406321502e-06
# Volume C: 3.276e-06
# Delta Vo percent: 2.4139612
# Delta Il percent: 0.08083561
#
# Generation 6 : Fitness: 5.2593694
# Solution (L, C, fsw): [9.4300e-04 1.7700e-04 5.3683e+04]
# Volume L: 2.0828406321502e-06
# Volume C: 2.123e-06
# Delta Vo percent: 8.453189
# Delta Il percent: 0.19860141
#
# Generation 7 : Fitness: 6.0800014
# Solution (L, C, fsw): [1.637e-03 8.000e-05 3.787e+04]
# Volume L: 2.0828406321502e-06
# Volume C: 3.335e-06
# Delta Vo percent: 0.6436588
# Delta Il percent: 0.055463776
#
# Generation 8 : Fitness: 6.0800014
# Solution (L, C, fsw): [1.637e-03 8.000e-05 3.787e+04]
# Volume L: 2.0828406321502e-06
# Volume C: 3.335e-06
# Delta Vo percent: 0.6436588
# Delta Il percent: 0.055463776
#
# Generation 9 : Fitness: 5.3036613
# Solution (L, C, fsw): [6.0600e-04 9.5000e-05 3.6972e+04]
# Volume L: 2.0828406321502e-06
# Volume C: 4.86e-06
# Delta Vo percent: 1.2353818
# Delta Il percent: 0.19477148
#
# Generation 10 : Fitness: 6.028861
# Solution (L, C, fsw): [1.5300e-03 1.1500e-04 3.6294e+04]
# Volume L: 2.0828406321502e-06
# Volume C: 5.589e-06
# Delta Vo percent: 1.6842486
# Delta Il percent: 0.0956395
#
# Generation 11 : Fitness: 5.081087
# Solution (L, C, fsw): [3.8900e-04 8.1000e-05 3.7544e+04]
# Volume L: 2.0828406321502e-06
# Volume C: 3.586e-06
# Delta Vo percent: 1.0789897
# Delta Il percent: 0.27081934
#
# Generation 12 : Fitness: 6.045745
# Solution (L, C, fsw): [1.6840e-03 6.9000e-05 3.7466e+04]
# Volume L: 2.0828406321502e-06
# Volume C: 2.668e-06
# Delta Vo percent: 0.076430455
# Delta Il percent: 0.04182062
#
# Generation 13 : Fitness: 5.989225
# Solution (L, C, fsw): [1.3430e-03 1.0900e-04 3.8182e+04]
# Volume L: 2.0828406321502e-06
# Volume C: 4.773e-06
# Delta Vo percent: 1.9781339
# Delta Il percent: 0.0867677
#
# Generation 14 : Fitness: 6.0442886
# Solution (L, C, fsw): [1.5620e-03 6.9000e-05 3.5771e+04]
# Volume L: 2.0828406321502e-06
# Volume C: 2.668e-06
# Delta Vo percent: 0.14753829
# Delta Il percent: 0.048708376
#
# Generation 15 : Fitness: 6.0442886
# Solution (L, C, fsw): [1.5620e-03 6.9000e-05 3.5771e+04]
# Volume L: 2.0828406321502e-06
# Volume C: 2.668e-06
# Delta Vo percent: 0.14753829
# Delta Il percent: 0.048708376
#
# Generation 16 : Fitness: 6.0442886
# Solution (L, C, fsw): [1.5620e-03 6.9000e-05 3.5771e+04]
# Volume L: 2.0828406321502e-06
# Volume C: 2.668e-06
# Delta Vo percent: 0.14753829
# Delta Il percent: 0.048708376
#
# Generation 17 : Fitness: 5.9820676
# Solution (L, C, fsw): [1.0380e-03 1.1100e-04 3.5963e+04]
# Volume L: 2.0828406321502e-06
# Volume C: 3.591e-06
# Delta Vo percent: 1.2248573
# Delta Il percent: 0.12947218
#
# Generation 18 : Fitness: 5.974728
# Solution (L, C, fsw): [1.3900e-03 1.2200e-04 3.5959e+04]
# Volume L: 2.0828406321502e-06
# Volume C: 3.528e-06
# Delta Vo percent: 2.3374805
# Delta Il percent: 0.10053692
#
# Generation 19 : Fitness: 5.3397255
# Solution (L, C, fsw): [8.930e-04 1.160e-04 3.687e+04]
# Volume L: 2.0828406321502e-06
# Volume C: 2.884e-06
# Delta Vo percent: 2.3268354
# Delta Il percent: 0.1594133
#
# Generation 20 : Fitness: 6.01932
# Solution (L, C, fsw): [1.0570e-03 1.1100e-04 3.7256e+04]
# Volume L: 2.0828406321502e-06
# Volume C: 3.591e-06
# Delta Vo percent: 1.1727123
# Delta Il percent: 0.12461882
#
# Generation 21 : Fitness: 6.0442886
# Solution (L, C, fsw): [1.5620e-03 6.9000e-05 3.5771e+04]
# Volume L: 2.0828406321502e-06
# Volume C: 2.668e-06
# Delta Vo percent: 0.14753829
# Delta Il percent: 0.048708376
#
# Generation 22 : Fitness: 6.0442886
# Solution (L, C, fsw): [1.5620e-03 6.9000e-05 3.5771e+04]
# Volume L: 2.0828406321502e-06
# Volume C: 2.668e-06
# Delta Vo percent: 0.14753829
# Delta Il percent: 0.048708376
#
# Generation 23 : Fitness: 6.0442886
# Solution (L, C, fsw): [1.5620e-03 6.9000e-05 3.5771e+04]
# Volume L: 2.0828406321502e-06
# Volume C: 2.668e-06
# Delta Vo percent: 0.14753829
# Delta Il percent: 0.048708376
#
# Generation 24 : Fitness: 6.007637
# Solution (L, C, fsw): [1.4660e-03 1.1200e-04 3.6557e+04]
# Volume L: 2.0828406321502e-06
# Volume C: 6.001e-06
# Delta Vo percent: 1.9416755
# Delta Il percent: 0.091152176
#
# Generation 25 : Fitness: 6.0442886
# Solution (L, C, fsw): [1.5620e-03 6.9000e-05 3.5771e+04]
# Volume L: 2.0828406321502e-06
# Volume C: 2.668e-06
# Delta Vo percent: 0.14753829
# Delta Il percent: 0.048708376
#
# Generation 26 : Fitness: 6.0442886
# Solution (L, C, fsw): [1.5620e-03 6.9000e-05 3.5771e+04]
# Volume L: 2.0828406321502e-06
# Volume C: 2.668e-06
# Delta Vo percent: 0.14753829
# Delta Il percent: 0.048708376
#
# Generation 27 : Fitness: 6.0442886
# Solution (L, C, fsw): [1.5620e-03 6.9000e-05 3.5771e+04]
# Volume L: 2.0828406321502e-06
# Volume C: 2.668e-06
# Delta Vo percent: 0.14753829
# Delta Il percent: 0.048708376
#
# Generation 28 : Fitness: 6.0442886
# Solution (L, C, fsw): [1.5620e-03 6.9000e-05 3.5771e+04]
# Volume L: 2.0828406321502e-06
# Volume C: 2.668e-06
# Delta Vo percent: 0.14753829
# Delta Il percent: 0.048708376
#
# Generation 29 : Fitness: 5.9804664
# Solution (L, C, fsw): [1.5900e-03 9.0000e-05 3.6247e+04]
# Volume L: 2.0828406321502e-06
# Volume C: 1.437e-06
# Delta Vo percent: 0.97435945
# Delta Il percent: 0.070416816
#
# Generation 30 : Fitness: 5.9804664
# Solution (L, C, fsw): [1.5900e-03 9.0000e-05 3.6247e+04]
# Volume L: 2.0828406321502e-06
# Volume C: 1.437e-06
# Delta Vo percent: 0.97435945
# Delta Il percent: 0.070416816
#
# Generation 31 : Fitness: 5.341609
# Solution (L, C, fsw): [7.4700e-04 1.2300e-04 3.4554e+04]
# Volume L: 2.0828406321502e-06
# Volume C: 4.019e-06
# Delta Vo percent: 2.8554525
# Delta Il percent: 0.19303444
#
# Generation 32 : Fitness: 5.4588814
# Solution (L, C, fsw): [7.7000e-04 3.0000e-05 3.4523e+04]
# Volume L: 2.0828406321502e-06
# Volume C: 1.564e-06
# Delta Vo percent: 0.81861234
# Delta Il percent: 0.16677162
#
# Generation 33 : Fitness: 5.304209
# Solution (L, C, fsw): [7.3100e-04 8.3000e-05 3.5782e+04]
# Volume L: 2.0828406321502e-06
# Volume C: 4.155e-06
# Delta Vo percent: 0.8613119
# Delta Il percent: 0.16816463
#
# Generation 34 : Fitness: 4.975721
# Solution (L, C, fsw): [9.4600e-04 1.5700e-04 3.6123e+04]
# Volume L: 2.0828406321502e-06
# Volume C: 2.018e-06
# Delta Vo percent: 6.4093814
# Delta Il percent: 0.20025864
#
# Generation 35 : Fitness: 5.049563
# Solution (L, C, fsw): [9.3800e-04 1.5600e-04 3.9974e+04]
# Volume L: 2.0828406321502e-06
# Volume C: 5.979e-06
# Delta Vo percent: 6.179359
# Delta Il percent: 0.19146675
#
# Generation 36 : Fitness: 5.767745
# Solution (L, C, fsw): [1.0120e-03 3.0000e-05 3.6472e+04]
# Volume L: 2.0828406321502e-06
# Volume C: 1.564e-06
# Delta Vo percent: 0.49482158
# Delta Il percent: 0.10203553
#
# Generation 37 : Fitness: 5.7433467
# Solution (L, C, fsw): [1.0140e-03 1.2700e-04 3.6083e+04]
# Volume L: 2.0828406321502e-06
# Volume C: 3.443e-06
# Delta Vo percent: 2.2198803
# Delta Il percent: 0.13905889
#
# Generation 38 : Fitness: 5.7991567
# Solution (L, C, fsw): [1.0630e-03 1.5000e-04 3.5955e+04]
# Volume L: 2.0828406321502e-06
# Volume C: 2.553e-06
# Delta Vo percent: 4.34347
# Delta Il percent: 0.14635174
#
# Generation 39 : Fitness: 5.191128
# Solution (L, C, fsw): [9.5700e-04 2.0000e-04 3.6581e+04]
# Volume L: 2.0828406321502e-06
# Volume C: 6.86e-07
# Delta Vo percent: 7.0629997
# Delta Il percent: 0.3628493
#
# Generation 40 : Fitness: 5.52818
# Solution (L, C, fsw): [8.1300e-04 3.0000e-05 4.0664e+04]
# Volume L: 2.0828406321502e-06
# Volume C: 1.564e-06
# Delta Vo percent: 0.76378924
# Delta Il percent: 0.12957777
#
# Generation 41 : Fitness: 5.9488277
# Solution (L, C, fsw): [1.0200e-03 5.7000e-05 4.0086e+04]
# Volume L: 2.0828406321502e-06
# Volume C: 1.675e-06
# Delta Vo percent: 0.32293555
# Delta Il percent: 0.09008938
#
# Generation 42 : Fitness: 5.460192
# Solution (L, C, fsw): [7.9700e-04 5.6000e-05 4.0324e+04]
# Volume L: 2.0828406321502e-06
# Volume C: 5.636e-06
# Delta Vo percent: 0.5617104
# Delta Il percent: 0.12317109
#
# Generation 43 : Fitness: 5.3555927
# Solution (L, C, fsw): [8.2300e-04 1.0100e-04 3.6785e+04]
# Volume L: 2.0828406321502e-06
# Volume C: 4.345e-06
# Delta Vo percent: 1.6725019
# Delta Il percent: 0.15142001
#
# Generation 44 : Fitness: 5.425673
# Solution (L, C, fsw): [9.5700e-04 4.2000e-05 3.6181e+04]
# Volume L: 2.0828406321502e-06
# Volume C: 4.241e-06
# Delta Vo percent: 0.44190916
# Delta Il percent: 0.111079134
#
# Generation 45 : Fitness: 5.357788
# Solution (L, C, fsw): [9.9400e-04 1.1000e-04 3.3119e+04]
# Volume L: 2.0828406321502e-06
# Volume C: 7.553e-06
# Delta Vo percent: 1.645138
# Delta Il percent: 0.15456061
#
# Generation 46 : Fitness: 5.6363997
# Solution (L, C, fsw): [1.0010e-03 5.5000e-05 4.0128e+04]
# Volume L: 2.0828406321502e-06
# Volume C: 3.497e-06
# Delta Vo percent: 0.35257545
# Delta Il percent: 0.09508582
#
# Generation 47 : Fitness: 5.103725
# Solution (L, C, fsw): [9.0200e-04 1.3600e-04 3.1957e+04]
# Volume L: 2.0828406321502e-06
# Volume C: 2.522e-06
# Delta Vo percent: 2.3838625
# Delta Il percent: 0.23446237
#
# Generation 48 : Fitness: 5.6363997
# Solution (L, C, fsw): [1.0010e-03 5.5000e-05 4.0128e+04]
# Volume L: 2.0828406321502e-06
# Volume C: 3.497e-06
# Delta Vo percent: 0.35257545
# Delta Il percent: 0.09508582
#
# Generation 49 : Fitness: 5.2770405
# Solution (L, C, fsw): [9.6700e-04 8.1000e-05 3.2677e+04]
# Volume L: 2.0828406321502e-06
# Volume C: 3.586e-06
# Delta Vo percent: 0.97169775
# Delta Il percent: 0.13898225
#
# Generation 50 : Fitness: 5.6363997
# Solution (L, C, fsw): [1.0010e-03 5.5000e-05 4.0128e+04]
# Volume L: 2.0828406321502e-06
# Volume C: 3.497e-06
# Delta Vo percent: 0.35257545
# Delta Il percent: 0.09508582
#
# Generation 51 : Fitness: 5.591354
# Solution (L, C, fsw): [9.980e-04 3.900e-05 4.123e+04]
# Volume L: 2.0828406321502e-06
# Volume C: 5.639e-06
# Delta Vo percent: 0.37226376
# Delta Il percent: 0.09515865
#
# Generation 52 : Fitness: 5.6363997
# Solution (L, C, fsw): [1.0010e-03 5.5000e-05 4.0128e+04]
# Volume L: 2.0828406321502e-06
# Volume C: 3.497e-06
# Delta Vo percent: 0.35257545
# Delta Il percent: 0.09508582
#
# Generation 53 : Fitness: 5.6363997
# Solution (L, C, fsw): [1.0010e-03 5.5000e-05 4.0128e+04]
# Volume L: 2.0828406321502e-06
# Volume C: 3.497e-06
# Delta Vo percent: 0.35257545
# Delta Il percent: 0.09508582
#
# Generation 54 : Fitness: 5.5504193
# Solution (L, C, fsw): [9.3300e-04 3.0000e-05 4.0853e+04]
# Volume L: 2.0828406321502e-06
# Volume C: 1.564e-06
# Delta Vo percent: 0.67934245
# Delta Il percent: 0.10418456
#
# Generation 55 : Fitness: 5.427573
# Solution (L, C, fsw): [8.9700e-04 6.9000e-05 3.9994e+04]
# Volume L: 2.0828406321502e-06
# Volume C: 2.668e-06
# Delta Vo percent: 0.5770031
# Delta Il percent: 0.11163836
#
# Generation 56 : Fitness: 5.2646856
# Solution (L, C, fsw): [9.9300e-04 8.9000e-05 2.8356e+04]
# Volume L: 2.0828406321502e-06
# Volume C: 4.457e-06
# Delta Vo percent: 1.2240199
# Delta Il percent: 0.16745977
#
# Generation 57 : Fitness: 5.6363997
# Solution (L, C, fsw): [1.0010e-03 5.5000e-05 4.0128e+04]
# Volume L: 2.0828406321502e-06
# Volume C: 3.497e-06
# Delta Vo percent: 0.35257545
# Delta Il percent: 0.09508582
#
# Generation 58 : Fitness: 5.2306714
# Solution (L, C, fsw): [8.7500e-04 2.0000e-04 5.2315e+04]
# Volume L: 2.0828406321502e-06
# Volume C: 6.86e-07
# Delta Vo percent: 9.015007
# Delta Il percent: 0.28641695
#
# Generation 59 : Fitness: 5.5323896
# Solution (L, C, fsw): [9.080e-04 3.000e-05 4.129e+04]
# Volume L: 2.0828406321502e-06
# Volume C: 1.564e-06
# Delta Vo percent: 0.70773
# Delta Il percent: 0.10847775
#
# Generation 60 : Fitness: 5.581681
# Solution (L, C, fsw): [9.7500e-04 3.0000e-05 4.0931e+04]
# Volume L: 2.0828406321502e-06
# Volume C: 1.564e-06
# Delta Vo percent: 0.6199644
# Delta Il percent: 0.09558877
#
# Generation 61 : Fitness: 4.949023
# Solution (L, C, fsw): [8.8400e-04 1.9100e-04 4.1283e+04]
# Volume L: 2.0828406321502e-06
# Volume C: 2.346e-06
# Delta Vo percent: 9.318707
# Delta Il percent: 0.2727683
#
# Generation 62 : Fitness: 5.581681
# Solution (L, C, fsw): [9.7500e-04 3.0000e-05 4.0931e+04]
# Volume L: 2.0828406321502e-06
# Volume C: 1.564e-06
# Delta Vo percent: 0.6199644
# Delta Il percent: 0.09558877
#
# Generation 63 : Fitness: 5.5295973
# Solution (L, C, fsw): [8.9900e-04 3.0000e-05 4.1277e+04]
# Volume L: 2.0828406321502e-06
# Volume C: 1.564e-06
# Delta Vo percent: 0.71815926
# Delta Il percent: 0.11026901
#
# Generation 64 : Fitness: 5.027905
# Solution (L, C, fsw): [9.480e-04 1.810e-04 3.967e+04]
# Volume L: 2.0828406321502e-06
# Volume C: 3.929e-06
# Delta Vo percent: 8.334741
# Delta Il percent: 0.25547642
#
# Generation 65 : Fitness: 5.4004045
# Solution (L, C, fsw): [9.8500e-04 1.1600e-04 4.0147e+04]
# Volume L: 2.0828406321502e-06
# Volume C: 2.884e-06
# Delta Vo percent: 1.8197734
# Delta Il percent: 0.14537638
#
# Generation 66 : Fitness: 5.4791207
# Solution (L, C, fsw): [9.7300e-04 4.8000e-05 4.0075e+04]
# Volume L: 2.0828406321502e-06
# Volume C: 4.644e-06
# Delta Vo percent: 0.38669467
# Delta Il percent: 0.09368467
#
# Generation 67 : Fitness: 5.4791207
# Solution (L, C, fsw): [9.7300e-04 4.8000e-05 4.0075e+04]
# Volume L: 2.0828406321502e-06
# Volume C: 4.644e-06
# Delta Vo percent: 0.38669467
# Delta Il percent: 0.09368467
#
# Generation 68 : Fitness: 5.4594975
# Solution (L, C, fsw): [8.5800e-04 4.7000e-05 3.8715e+04]
# Volume L: 2.0828406321502e-06
# Volume C: 2.16e-07
# Delta Vo percent: 0.58709
# Delta Il percent: 0.11644778
#
# Generation 69 : Fitness: 5.468322
# Solution (L, C, fsw): [8.2800e-04 5.1000e-05 3.9798e+04]
# Volume L: 2.0828406321502e-06
# Volume C: 2.68e-06
# Delta Vo percent: 0.5892925
# Delta Il percent: 0.11924581
#
# Generation 70 : Fitness: 5.4791207
# Solution (L, C, fsw): [9.7300e-04 4.8000e-05 4.0075e+04]
# Volume L: 2.0828406321502e-06
# Volume C: 4.644e-06
# Delta Vo percent: 0.38669467
# Delta Il percent: 0.09368467
#
# Generation 71 : Fitness: 5.445796
# Solution (L, C, fsw): [8.9400e-04 6.9000e-05 4.1011e+04]
# Volume L: 2.0828406321502e-06
# Volume C: 2.668e-06
# Delta Vo percent: 0.5749864
# Delta Il percent: 0.10986024
#
# Generation 72 : Fitness: 5.4791207
# Solution (L, C, fsw): [9.7300e-04 4.8000e-05 4.0075e+04]
# Volume L: 2.0828406321502e-06
# Volume C: 4.644e-06
# Delta Vo percent: 0.38669467
# Delta Il percent: 0.09368467
#
# Generation 73 : Fitness: 5.4732995
# Solution (L, C, fsw): [8.2900e-04 5.8000e-05 4.1486e+04]
# Volume L: 2.0828406321502e-06
# Volume C: 4.455e-06
# Delta Vo percent: 0.52353436
# Delta Il percent: 0.11431121
#
# Generation 74 : Fitness: 5.4791207
# Solution (L, C, fsw): [9.7300e-04 4.8000e-05 4.0075e+04]
# Volume L: 2.0828406321502e-06
# Volume C: 4.644e-06
# Delta Vo percent: 0.38669467
# Delta Il percent: 0.09368467
#
# Generation 75 : Fitness: 5.4791207
# Solution (L, C, fsw): [9.7300e-04 4.8000e-05 4.0075e+04]
# Volume L: 2.0828406321502e-06
# Volume C: 4.644e-06
# Delta Vo percent: 0.38669467
# Delta Il percent: 0.09368467
#
# Generation 76 : Fitness: 5.4791207
# Solution (L, C, fsw): [9.7300e-04 4.8000e-05 4.0075e+04]
# Volume L: 2.0828406321502e-06
# Volume C: 4.644e-06
# Delta Vo percent: 0.38669467
# Delta Il percent: 0.09368467
#
# Generation 77 : Fitness: 5.305675
# Solution (L, C, fsw): [9.4700e-04 1.3000e-04 4.0612e+04]
# Volume L: 2.0828406321502e-06
# Volume C: 1.907e-06
# Delta Vo percent: 2.3378177
# Delta Il percent: 0.17955752
#
# Generation 78 : Fitness: 5.195017
# Solution (L, C, fsw): [9.4000e-04 1.3800e-04 3.9227e+04]
# Volume L: 2.0828406321502e-06
# Volume C: 3.013e-06
# Delta Vo percent: 3.3519404
# Delta Il percent: 0.18500368
#
# Generation 79 : Fitness: 5.4137
# Solution (L, C, fsw): [8.1300e-04 8.4000e-05 4.0819e+04]
# Volume L: 2.0828406321502e-06
# Volume C: 2.974e-06
# Delta Vo percent: 0.88254875
# Delta Il percent: 0.13596612
#
# Generation 80 : Fitness: 5.4161124
# Solution (L, C, fsw): [9.4600e-04 9.7000e-05 4.1192e+04]
# Volume L: 2.0828406321502e-06
# Volume C: 5.916e-06
# Delta Vo percent: 1.6130254
# Delta Il percent: 0.1255366
#
# Generation 81 : Fitness: 5.4791207
# Solution (L, C, fsw): [9.7300e-04 4.8000e-05 4.0075e+04]
# Volume L: 2.0828406321502e-06
# Volume C: 4.644e-06
# Delta Vo percent: 0.38669467
# Delta Il percent: 0.09368467
#
# Generation 82 : Fitness: 5.4791207
# Solution (L, C, fsw): [9.7300e-04 4.8000e-05 4.0075e+04]
# Volume L: 2.0828406321502e-06
# Volume C: 4.644e-06
# Delta Vo percent: 0.38669467
# Delta Il percent: 0.09368467
#
# Generation 83 : Fitness: 5.3684006
# Solution (L, C, fsw): [9.1400e-04 1.1600e-04 3.9247e+04]
# Volume L: 2.0828406321502e-06
# Volume C: 2.884e-06
# Delta Vo percent: 2.1812348
# Delta Il percent: 0.15327515
#
# Generation 84 : Fitness: 5.437549
# Solution (L, C, fsw): [9.6600e-04 6.5000e-05 4.0412e+04]
# Volume L: 2.0828406321502e-06
# Volume C: 5.122e-06
# Delta Vo percent: 0.47545567
# Delta Il percent: 0.09591956
#
# Generation 85 : Fitness: 5.45709
# Solution (L, C, fsw): [7.5900e-04 2.0000e-04 7.6981e+04]
# Volume L: 2.0828406321502e-06
# Volume C: 6.86e-07
# Delta Vo percent: 9.773376
# Delta Il percent: 0.21519767
#
# Generation 86 : Fitness: 5.1540074
# Solution (L, C, fsw): [8.1100e-04 1.6100e-04 4.2988e+04]
# Volume L: 2.0828406321502e-06
# Volume C: 4.409e-06
# Delta Vo percent: 4.370691
# Delta Il percent: 0.25209022
#
# Generation 87 : Fitness: 5.413851
# Solution (L, C, fsw): [9.8600e-04 1.0800e-04 4.0446e+04]
# Volume L: 2.0828406321502e-06
# Volume C: 4.282e-06
# Delta Vo percent: 1.732399
# Delta Il percent: 0.13470118
#
# Generation 88 : Fitness: 5.451444
# Solution (L, C, fsw): [7.8800e-04 9.7000e-05 4.2459e+04]
# Volume L: 2.0828406321502e-06
# Volume C: 5.916e-06
# Delta Vo percent: 1.340453
# Delta Il percent: 0.14746413
#
# Generation 89 : Fitness: 5.4791207
# Solution (L, C, fsw): [9.7300e-04 4.8000e-05 4.0075e+04]
# Volume L: 2.0828406321502e-06
# Volume C: 4.644e-06
# Delta Vo percent: 0.38669467
# Delta Il percent: 0.09368467
#
# Generation 90 : Fitness: 5.301155
# Solution (L, C, fsw): [9.3700e-04 1.2900e-04 4.0007e+04]
# Volume L: 2.0828406321502e-06
# Volume C: 4.362e-06
# Delta Vo percent: 2.1767235
# Delta Il percent: 0.18333218
#
# Generation 91 : Fitness: 5.4791207
# Solution (L, C, fsw): [9.7300e-04 4.8000e-05 4.0075e+04]
# Volume L: 2.0828406321502e-06
# Volume C: 4.644e-06
# Delta Vo percent: 0.38669467
# Delta Il percent: 0.09368467
#
# Generation 92 : Fitness: 5.4011607
# Solution (L, C, fsw): [9.510e-04 1.120e-04 4.129e+04]
# Volume L: 2.0828406321502e-06
# Volume C: 6.001e-06
# Delta Vo percent: 1.9465522
# Delta Il percent: 0.14125071
#
# Generation 93 : Fitness: 5.4563317
# Solution (L, C, fsw): [7.8700e-04 3.0000e-05 3.4762e+04]
# Volume L: 2.0828406321502e-06
# Volume C: 1.564e-06
# Delta Vo percent: 0.80306935
# Delta Il percent: 0.16262202
#
# Generation 94 : Fitness: 5.4791207
# Solution (L, C, fsw): [9.7300e-04 4.8000e-05 4.0075e+04]
# Volume L: 2.0828406321502e-06
# Volume C: 4.644e-06
# Delta Vo percent: 0.38669467
# Delta Il percent: 0.09368467
#
# Generation 95 : Fitness: 5.4791207
# Solution (L, C, fsw): [9.7300e-04 4.8000e-05 4.0075e+04]
# Volume L: 2.0828406321502e-06
# Volume C: 4.644e-06
# Delta Vo percent: 0.38669467
# Delta Il percent: 0.09368467
#
# Generation 96 : Fitness: 5.4791207
# Solution (L, C, fsw): [9.7300e-04 4.8000e-05 4.0075e+04]
# Volume L: 2.0828406321502e-06
# Volume C: 4.644e-06
# Delta Vo percent: 0.38669467
# Delta Il percent: 0.09368467
#
# Generation 97 : Fitness: 5.0041237
# Solution (L, C, fsw): [9.0900e-04 1.8900e-04 4.1462e+04]
# Volume L: 2.0828406321502e-06
# Volume C: 4.8e-06
# Delta Vo percent: 8.885523
# Delta Il percent: 0.27487433
#
# Generation 98 : Fitness: 5.4791207
# Solution (L, C, fsw): [9.7300e-04 4.8000e-05 4.0075e+04]
# Volume L: 2.0828406321502e-06
# Volume C: 4.644e-06
# Delta Vo percent: 0.38669467
# Delta Il percent: 0.09368467
#
# Generation 99 : Fitness: 5.4334545
# Solution (L, C, fsw): [8.6100e-04 9.7000e-05 4.1408e+04]
# Volume L: 2.0828406321502e-06
# Volume C: 5.916e-06
# Delta Vo percent: 1.5534799
# Delta Il percent: 0.13310578

# %% [markdown]
# ## Ranking

# %%
# Your additional code snippet for printing and sorting the results
# Define lists to store the results
volume_L_values = []
volume_C_values = []
delta_Vo_values = []
delta_IL_values = []
P_l_s1_values = []
P_l_s2_values = []
P_l_C_values = []
P_l_L_Cu_values = []
solutions = []

# Iterate over different generations
for i, (solution, fitness) in enumerate(zip(best_solutions, best_fitnesses)):
    # Calculate volume values and delta Vo for the current solution
    L = solution[0]
    C = solution[1]
    fs = solution[2]
    nearest_C, Vol_C = search_volume_capacitance(C, csv_file_capacitance)
    nearest_L, Vol_L = search_volume_inductance(L, csv_file_inductance)

    input_values = np.array([L, C, fs])
    input_values_scaled = np.zeros_like(input_values, dtype=float)
    input_values_scaled[0] = (input_values[0] - L_min) / (L_max - L_min)
    input_values_scaled[1] = (input_values[1] - C_min) / (C_max - C_min)
    input_values_scaled[2] = (input_values[2] - fsw_min) / (fsw_max - fsw_min)
    input_values_reshaped = input_values_scaled.reshape((1, -1))
    
    prediction = model.predict(input_values_reshaped, verbose=0)
    Delta_IL_percent = prediction[0][0]
    Delta_Vo_percent = prediction[0][1]
    P_l_s1 = prediction[0][2]
    P_l_s2 = prediction[0][3]
    P_l_C = prediction[0][4]
    P_l_L_Cu = prediction[0][5]
    
    # Store the volume values, delta Vo, and solution for sorting
    volume_L_values.append(Vol_L)
    volume_C_values.append(Vol_C)
    delta_Vo_values.append(Delta_Vo_percent)
    delta_IL_values.append(Delta_IL_percent)
    P_l_s1_values.append(P_l_s1)
    P_l_s2_values.append(P_l_s2)
    P_l_C_values.append(P_l_C)
    P_l_L_Cu_values.append(P_l_L_Cu)

    solutions.append((solution, fitness, Vol_L, Vol_C, Delta_Vo_percent, Delta_IL_percent, P_l_s1, P_l_s2, P_l_C, P_l_L_Cu))

# Sort the solutions based on fitness values in ascending order
sorted_solutions = sorted(solutions, key=lambda x: x[1])

# Print the sorted solutions
print("Sorted Solutions:")
for rank, (solution, fitness, vol_L, vol_C, delta_Vo, delta_IL, P_l_s1, P_l_s2, P_l_C, P_l_L_Cu) in enumerate(sorted_solutions):
    print("Rank:", rank + 1)
    print("Solution (L, C, fsw):", solution)
    print("Fitness:", fitness)
    print("Volume L:", vol_L)
    print("Volume C:", vol_C)
    print("Delta Vo:", delta_Vo)
    print("Delta IL:", delta_IL)
    print("P_l_s1: ", P_l_s1)
    print("P_l_s2: ", P_l_s2)
    print("P_l_C: ", P_l_C)
    print("P_l_L_Cu: ", P_l_L_Cu)
    print("Losses Total:", P_l_s1 + P_l_s2 + P_l_C + P_l_L_Cu)
    print()

# Plot the fitness values for each generation
plt.plot(best_outputs)
plt.xlabel("Generation")
plt.ylabel("Fitness")
plt.title("Fitness Progression")
plt.show()
# Out:
# Sorted Solutions:
# Rank: 1
# Solution (L, C, fsw): [8.8400e-04 1.9100e-04 4.1283e+04]
# Fitness: 4.949023
# Volume L: 2.0828406321502e-06
# Volume C: 2.346e-06
# Delta Vo: 9.318707
# Delta IL: 0.2727683
# P_l_s1:  1.8918213
# P_l_s2:  1.8964293
# P_l_C:  0.02895933
# P_l_L_Cu:  1.1318129
# Losses Total: 4.949023
#
# Rank: 2
# Solution (L, C, fsw): [9.4600e-04 1.5700e-04 3.6123e+04]
# Fitness: 4.975721
# Volume L: 2.0828406321502e-06
# Volume C: 2.018e-06
# Delta Vo: 6.4093814
# Delta IL: 0.20025864
# P_l_s1:  1.8773062
# P_l_s2:  1.8790483
# P_l_C:  0.03949975
# P_l_L_Cu:  1.1798666
# Losses Total: 4.975721
#
# Rank: 3
# Solution (L, C, fsw): [9.0900e-04 1.8900e-04 4.1462e+04]
# Fitness: 5.0041237
# Volume L: 2.0828406321502e-06
# Volume C: 4.8e-06
# Delta Vo: 8.885523
# Delta IL: 0.27487433
# P_l_s1:  1.9054648
# P_l_s2:  1.9119954
# P_l_C:  0.030100795
# P_l_L_Cu:  1.1565629
# Losses Total: 5.0041237
#
# Rank: 4
# Solution (L, C, fsw): [9.480e-04 1.810e-04 3.967e+04]
# Fitness: 5.027905
# Volume L: 2.0828406321502e-06
# Volume C: 3.929e-06
# Delta Vo: 8.334741
# Delta IL: 0.25547642
# P_l_s1:  1.9003948
# P_l_s2:  1.9130375
# P_l_C:  0.03281979
# P_l_L_Cu:  1.1816531
# Losses Total: 5.027905
#
# Rank: 5
# Solution (L, C, fsw): [9.3800e-04 1.5600e-04 3.9974e+04]
# Fitness: 5.049563
# Volume L: 2.0828406321502e-06
# Volume C: 5.979e-06
# Delta Vo: 6.179359
# Delta IL: 0.19146675
# P_l_s1:  1.9153895
# P_l_s2:  1.9169681
# P_l_C:  0.036391526
# P_l_L_Cu:  1.1808137
# Losses Total: 5.049563
#
# Rank: 6
# Solution (L, C, fsw): [3.8900e-04 8.1000e-05 3.7544e+04]
# Fitness: 5.081087
# Volume L: 2.0828406321502e-06
# Volume C: 3.586e-06
# Delta Vo: 1.0789897
# Delta IL: 0.27081934
# P_l_s1:  2.0141137
# P_l_s2:  2.0202184
# P_l_C:  0.08352485
# P_l_L_Cu:  0.96323013
# Losses Total: 5.081087
#
# Rank: 7
# Solution (L, C, fsw): [9.0200e-04 1.3600e-04 3.1957e+04]
# Fitness: 5.103725
# Volume L: 2.0828406321502e-06
# Volume C: 2.522e-06
# Delta Vo: 2.3838625
# Delta IL: 0.23446237
# P_l_s1:  1.8950307
# P_l_s2:  1.8953532
# P_l_C:  0.056828827
# P_l_L_Cu:  1.2565119
# Losses Total: 5.1037245
#
# Rank: 8
# Solution (L, C, fsw): [8.1100e-04 1.6100e-04 4.2988e+04]
# Fitness: 5.1540074
# Volume L: 2.0828406321502e-06
# Volume C: 4.409e-06
# Delta Vo: 4.370691
# Delta IL: 0.25209022
# P_l_s1:  1.9671417
# P_l_s2:  1.9627473
# P_l_C:  0.035218656
# P_l_L_Cu:  1.1888993
# Losses Total: 5.154007
#
# Rank: 9
# Solution (L, C, fsw): [9.5700e-04 2.0000e-04 3.6581e+04]
# Fitness: 5.191128
# Volume L: 2.0828406321502e-06
# Volume C: 6.86e-07
# Delta Vo: 7.0629997
# Delta IL: 0.3628493
# P_l_s1:  1.9372283
# P_l_s2:  1.942061
# P_l_C:  0.030158127
# P_l_L_Cu:  1.2816807
# Losses Total: 5.191128
#
# Rank: 10
# Solution (L, C, fsw): [9.4000e-04 1.3800e-04 3.9227e+04]
# Fitness: 5.195017
# Volume L: 2.0828406321502e-06
# Volume C: 3.013e-06
# Delta Vo: 3.3519404
# Delta IL: 0.18500368
# P_l_s1:  1.951246
# P_l_s2:  1.9552177
# P_l_C:  0.04318642
# P_l_L_Cu:  1.245367
# Losses Total: 5.195017
#
# Rank: 11
# Solution (L, C, fsw): [8.7500e-04 2.0000e-04 5.2315e+04]
# Fitness: 5.2306714
# Volume L: 2.0828406321502e-06
# Volume C: 6.86e-07
# Delta Vo: 9.015007
# Delta IL: 0.28641695
# P_l_s1:  2.0231526
# P_l_s2:  2.024789
# P_l_C:  0.02101567
# P_l_L_Cu:  1.1617141
# Losses Total: 5.2306714
#
# Rank: 12
# Solution (L, C, fsw): [9.4300e-04 1.7700e-04 5.3683e+04]
# Fitness: 5.2593694
# Volume L: 2.0828406321502e-06
# Volume C: 2.123e-06
# Delta Vo: 8.453189
# Delta IL: 0.19860141
# P_l_s1:  2.0262837
# P_l_s2:  2.0386004
# P_l_C:  0.024824122
# P_l_L_Cu:  1.169661
# Losses Total: 5.2593694
#
# Rank: 13
# Solution (L, C, fsw): [9.9300e-04 8.9000e-05 2.8356e+04]
# Fitness: 5.2646856
# Volume L: 2.0828406321502e-06
# Volume C: 4.457e-06
# Delta Vo: 1.2240199
# Delta IL: 0.16745977
# P_l_s1:  1.8762032
# P_l_s2:  1.881912
# P_l_C:  0.101826906
# P_l_L_Cu:  1.4047433
# Losses Total: 5.2646856
#
# Rank: 14
# Solution (L, C, fsw): [9.6700e-04 8.1000e-05 3.2677e+04]
# Fitness: 5.2770405
# Volume L: 2.0828406321502e-06
# Volume C: 3.586e-06
# Delta Vo: 0.97169775
# Delta IL: 0.13898225
# P_l_s1:  1.9278717
# P_l_s2:  1.934666
# P_l_C:  0.09504184
# P_l_L_Cu:  1.3194609
# Losses Total: 5.2770405
#
# Rank: 15
# Solution (L, C, fsw): [9.3700e-04 1.2900e-04 4.0007e+04]
# Fitness: 5.301155
# Volume L: 2.0828406321502e-06
# Volume C: 4.362e-06
# Delta Vo: 2.1767235
# Delta IL: 0.18333218
# P_l_s1:  1.9842694
# P_l_s2:  1.9887711
# P_l_C:  0.047373027
# P_l_L_Cu:  1.2807416
# Losses Total: 5.301155
#
# Rank: 16
# Solution (L, C, fsw): [6.0600e-04 9.5000e-05 3.6972e+04]
# Fitness: 5.3036613
# Volume L: 2.0828406321502e-06
# Volume C: 4.86e-06
# Delta Vo: 1.2353818
# Delta IL: 0.19477148
# P_l_s1:  1.9809729
# P_l_s2:  1.9715669
# P_l_C:  0.0683558
# P_l_L_Cu:  1.2827661
# Losses Total: 5.3036623
#
# Rank: 17
# Solution (L, C, fsw): [7.3100e-04 8.3000e-05 3.5782e+04]
# Fitness: 5.304209
# Volume L: 2.0828406321502e-06
# Volume C: 4.155e-06
# Delta Vo: 0.8613119
# Delta IL: 0.16816463
# P_l_s1:  1.9668158
# P_l_s2:  1.9649003
# P_l_C:  0.08284024
# P_l_L_Cu:  1.2896527
# Losses Total: 5.304209
#
# Rank: 18
# Solution (L, C, fsw): [9.4700e-04 1.3000e-04 4.0612e+04]
# Fitness: 5.305675
# Volume L: 2.0828406321502e-06
# Volume C: 1.907e-06
# Delta Vo: 2.3378177
# Delta IL: 0.17955752
# P_l_s1:  1.9877737
# P_l_s2:  1.9923984
# P_l_C:  0.04571154
# P_l_L_Cu:  1.2797914
# Losses Total: 5.305675
#
# Rank: 19
# Solution (L, C, fsw): [3.1100e-04 5.4000e-05 4.5714e+04]
# Fitness: 5.3158712
# Volume L: 2.0828406321502e-06
# Volume C: 4.129e-06
# Delta Vo: 1.1949697
# Delta IL: 0.2940497
# P_l_s1:  2.126284
# P_l_s2:  2.1196003
# P_l_C:  0.10241246
# P_l_L_Cu:  0.96757495
# Losses Total: 5.3158712
#
# Rank: 20
# Solution (L, C, fsw): [8.930e-04 1.160e-04 3.687e+04]
# Fitness: 5.3397255
# Volume L: 2.0828406321502e-06
# Volume C: 2.884e-06
# Delta Vo: 2.3268354
# Delta IL: 0.1594133
# P_l_s1:  1.988061
# P_l_s2:  1.9899218
# P_l_C:  0.05741361
# P_l_L_Cu:  1.3043292
# Losses Total: 5.3397255
#
# Rank: 21
# Solution (L, C, fsw): [7.4700e-04 1.2300e-04 3.4554e+04]
# Fitness: 5.341609
# Volume L: 2.0828406321502e-06
# Volume C: 4.019e-06
# Delta Vo: 2.8554525
# Delta IL: 0.19303444
# P_l_s1:  1.9852724
# P_l_s2:  1.9735609
# P_l_C:  0.05876648
# P_l_L_Cu:  1.3240094
# Losses Total: 5.341609
#
# Rank: 22
# Solution (L, C, fsw): [8.2300e-04 1.0100e-04 3.6785e+04]
# Fitness: 5.3555927
# Volume L: 2.0828406321502e-06
# Volume C: 4.345e-06
# Delta Vo: 1.6725019
# Delta IL: 0.15142001
# P_l_s1:  1.9929854
# P_l_s2:  1.9856752
# P_l_C:  0.06585704
# P_l_L_Cu:  1.3110751
# Losses Total: 5.3555927
#
# Rank: 23
# Solution (L, C, fsw): [9.9400e-04 1.1000e-04 3.3119e+04]
# Fitness: 5.357788
# Volume L: 2.0828406321502e-06
# Volume C: 7.553e-06
# Delta Vo: 1.645138
# Delta IL: 0.15456061
# P_l_s1:  1.9222512
# P_l_s2:  1.9281211
# P_l_C:  0.067875765
# P_l_L_Cu:  1.43954
# Losses Total: 5.357788
#
# Rank: 24
# Solution (L, C, fsw): [9.1400e-04 1.1600e-04 3.9247e+04]
# Fitness: 5.3684006
# Volume L: 2.0828406321502e-06
# Volume C: 2.884e-06
# Delta Vo: 2.1812348
# Delta IL: 0.15327515
# P_l_s1:  2.0039735
# P_l_s2:  2.008706
# P_l_C:  0.05481766
# P_l_L_Cu:  1.3009034
# Losses Total: 5.3684006
#
# Rank: 25
# Solution (L, C, fsw): [9.8500e-04 1.1600e-04 4.0147e+04]
# Fitness: 5.4004045
# Volume L: 2.0828406321502e-06
# Volume C: 2.884e-06
# Delta Vo: 1.8197734
# Delta IL: 0.14537638
# P_l_s1:  1.9986967
# P_l_s2:  2.0071616
# P_l_C:  0.053008657
# P_l_L_Cu:  1.3415376
# Losses Total: 5.4004045
#
# Rank: 26
# Solution (L, C, fsw): [9.510e-04 1.120e-04 4.129e+04]
# Fitness: 5.4011607
# Volume L: 2.0828406321502e-06
# Volume C: 6.001e-06
# Delta Vo: 1.9465522
# Delta IL: 0.14125071
# P_l_s1:  2.0172951
# P_l_s2:  2.0255888
# P_l_C:  0.054664105
# P_l_L_Cu:  1.3036128
# Losses Total: 5.4011607
#
# Rank: 27
# Solution (L, C, fsw): [8.1300e-04 8.4000e-05 4.0819e+04]
# Fitness: 5.4137
# Volume L: 2.0828406321502e-06
# Volume C: 2.974e-06
# Delta Vo: 0.88254875
# Delta IL: 0.13596612
# P_l_s1:  2.0191722
# P_l_s2:  2.0198867
# P_l_C:  0.07422114
# P_l_L_Cu:  1.3004204
# Losses Total: 5.4137
#
# Rank: 28
# Solution (L, C, fsw): [9.8600e-04 1.0800e-04 4.0446e+04]
# Fitness: 5.413851
# Volume L: 2.0828406321502e-06
# Volume C: 4.282e-06
# Delta Vo: 1.732399
# Delta IL: 0.13470118
# P_l_s1:  2.0022357
# P_l_s2:  2.0119774
# P_l_C:  0.057768997
# P_l_L_Cu:  1.3418689
# Losses Total: 5.413851
#
# Rank: 29
# Solution (L, C, fsw): [9.4600e-04 9.7000e-05 4.1192e+04]
# Fitness: 5.4161124
# Volume L: 2.0828406321502e-06
# Volume C: 5.916e-06
# Delta Vo: 1.6130254
# Delta IL: 0.1255366
# P_l_s1:  2.0171633
# P_l_s2:  2.0235744
# P_l_C:  0.0642563
# P_l_L_Cu:  1.3111187
# Losses Total: 5.4161124
#
# Rank: 30
# Solution (L, C, fsw): [9.5700e-04 4.2000e-05 3.6181e+04]
# Fitness: 5.425673
# Volume L: 2.0828406321502e-06
# Volume C: 4.241e-06
# Delta Vo: 0.44190916
# Delta IL: 0.111079134
# P_l_s1:  1.9588072
# P_l_s2:  1.9744451
# P_l_C:  0.16488585
# P_l_L_Cu:  1.3275344
# Losses Total: 5.4256725
#
# Rank: 31
# Solution (L, C, fsw): [8.9700e-04 6.9000e-05 3.9994e+04]
# Fitness: 5.427573
# Volume L: 2.0828406321502e-06
# Volume C: 2.668e-06
# Delta Vo: 0.5770031
# Delta IL: 0.11163836
# P_l_s1:  2.004854
# P_l_s2:  2.0148785
# P_l_C:  0.08841663
# P_l_L_Cu:  1.3194242
# Losses Total: 5.427573
#
# Rank: 32
# Solution (L, C, fsw): [8.6100e-04 9.7000e-05 4.1408e+04]
# Fitness: 5.4334545
# Volume L: 2.0828406321502e-06
# Volume C: 5.916e-06
# Delta Vo: 1.5534799
# Delta IL: 0.13310578
# P_l_s1:  2.031393
# P_l_s2:  2.02948
# P_l_C:  0.06466621
# P_l_L_Cu:  1.3079151
# Losses Total: 5.4334545
#
# Rank: 33
# Solution (L, C, fsw): [9.6600e-04 6.5000e-05 4.0412e+04]
# Fitness: 5.437549
# Volume L: 2.0828406321502e-06
# Volume C: 5.122e-06
# Delta Vo: 0.47545567
# Delta IL: 0.09591956
# P_l_s1:  2.0051515
# P_l_s2:  2.016149
# P_l_C:  0.09035283
# P_l_L_Cu:  1.3258957
# Losses Total: 5.437549
#
# Rank: 34
# Solution (L, C, fsw): [8.9400e-04 6.9000e-05 4.1011e+04]
# Fitness: 5.445796
# Volume L: 2.0828406321502e-06
# Volume C: 2.668e-06
# Delta Vo: 0.5749864
# Delta IL: 0.10986024
# P_l_s1:  2.0150812
# P_l_s2:  2.0253096
# P_l_C:  0.08682034
# P_l_L_Cu:  1.3185848
# Losses Total: 5.445796
#
# Rank: 35
# Solution (L, C, fsw): [7.8800e-04 9.7000e-05 4.2459e+04]
# Fitness: 5.451444
# Volume L: 2.0828406321502e-06
# Volume C: 5.916e-06
# Delta Vo: 1.340453
# Delta IL: 0.14746413
# P_l_s1:  2.0449777
# P_l_s2:  2.0422957
# P_l_C:  0.06208742
# P_l_L_Cu:  1.3020828
# Losses Total: 5.4514437
#
# Rank: 36
# Solution (L, C, fsw): [7.8700e-04 3.0000e-05 3.4762e+04]
# Fitness: 5.4563317
# Volume L: 2.0828406321502e-06
# Volume C: 1.564e-06
# Delta Vo: 0.80306935
# Delta IL: 0.16262202
# P_l_s1:  1.9533299
# P_l_s2:  1.9544188
# P_l_C:  0.22689658
# P_l_L_Cu:  1.3216861
# Losses Total: 5.4563317
#
# Rank: 37
# Solution (L, C, fsw): [7.5900e-04 2.0000e-04 7.6981e+04]
# Fitness: 5.45709
# Volume L: 2.0828406321502e-06
# Volume C: 6.86e-07
# Delta Vo: 9.773376
# Delta IL: 0.21519767
# P_l_s1:  2.1865437
# P_l_s2:  2.1854975
# P_l_C:  0.01251722
# P_l_L_Cu:  1.0725313
# Losses Total: 5.45709
#
# Rank: 38
# Solution (L, C, fsw): [7.7000e-04 3.0000e-05 3.4523e+04]
# Fitness: 5.4588814
# Volume L: 2.0828406321502e-06
# Volume C: 1.564e-06
# Delta Vo: 0.81861234
# Delta IL: 0.16677162
# P_l_s1:  1.955484
# P_l_s2:  1.9532928
# P_l_C:  0.22848025
# P_l_L_Cu:  1.3216243
# Losses Total: 5.4588814
#
# Rank: 39
# Solution (L, C, fsw): [8.5800e-04 4.7000e-05 3.8715e+04]
# Fitness: 5.4594975
# Volume L: 2.0828406321502e-06
# Volume C: 2.16e-07
# Delta Vo: 0.58709
# Delta IL: 0.11644778
# P_l_s1:  2.0045116
# P_l_s2:  2.0056758
# P_l_C:  0.134955
# P_l_L_Cu:  1.3143555
# Losses Total: 5.4594975
#
# Rank: 40
# Solution (L, C, fsw): [7.9700e-04 5.6000e-05 4.0324e+04]
# Fitness: 5.460192
# Volume L: 2.0828406321502e-06
# Volume C: 5.636e-06
# Delta Vo: 0.5617104
# Delta IL: 0.12317109
# P_l_s1:  2.020947
# P_l_s2:  2.0203936
# P_l_C:  0.10685921
# P_l_L_Cu:  1.311992
# Losses Total: 5.460192
#
# Rank: 41
# Solution (L, C, fsw): [8.2800e-04 5.1000e-05 3.9798e+04]
# Fitness: 5.468322
# Volume L: 2.0828406321502e-06
# Volume C: 2.68e-06
# Delta Vo: 0.5892925
# Delta IL: 0.11924581
# P_l_s1:  2.015766
# P_l_s2:  2.0182989
# P_l_C:  0.12076635
# P_l_L_Cu:  1.3134909
# Losses Total: 5.468322
#
# Rank: 42
# Solution (L, C, fsw): [8.2900e-04 5.8000e-05 4.1486e+04]
# Fitness: 5.4732995
# Volume L: 2.0828406321502e-06
# Volume C: 4.455e-06
# Delta Vo: 0.52353436
# Delta IL: 0.11431121
# P_l_s1:  2.0280614
# P_l_s2:  2.031097
# P_l_C:  0.10096322
# P_l_L_Cu:  1.3131783
# Losses Total: 5.4733
#
# Rank: 43
# Solution (L, C, fsw): [9.7300e-04 4.8000e-05 4.0075e+04]
# Fitness: 5.4791207
# Volume L: 2.0828406321502e-06
# Volume C: 4.644e-06
# Delta Vo: 0.38669467
# Delta IL: 0.09368467
# P_l_s1:  2.004659
# P_l_s2:  2.0155413
# P_l_C:  0.1299921
# P_l_L_Cu:  1.3289285
# Losses Total: 5.4791207
#
# Rank: 44
# Solution (L, C, fsw): [9.7300e-04 4.8000e-05 4.0075e+04]
# Fitness: 5.4791207
# Volume L: 2.0828406321502e-06
# Volume C: 4.644e-06
# Delta Vo: 0.38669467
# Delta IL: 0.09368467
# P_l_s1:  2.004659
# P_l_s2:  2.0155413
# P_l_C:  0.1299921
# P_l_L_Cu:  1.3289285
# Losses Total: 5.4791207
#
# Rank: 45
# Solution (L, C, fsw): [9.7300e-04 4.8000e-05 4.0075e+04]
# Fitness: 5.4791207
# Volume L: 2.0828406321502e-06
# Volume C: 4.644e-06
# Delta Vo: 0.38669467
# Delta IL: 0.09368467
# P_l_s1:  2.004659
# P_l_s2:  2.0155413
# P_l_C:  0.1299921
# P_l_L_Cu:  1.3289285
# Losses Total: 5.4791207
#
# Rank: 46
# Solution (L, C, fsw): [9.7300e-04 4.8000e-05 4.0075e+04]
# Fitness: 5.4791207
# Volume L: 2.0828406321502e-06
# Volume C: 4.644e-06
# Delta Vo: 0.38669467
# Delta IL: 0.09368467
# P_l_s1:  2.004659
# P_l_s2:  2.0155413
# P_l_C:  0.1299921
# P_l_L_Cu:  1.3289285
# Losses Total: 5.4791207
#
# Rank: 47
# Solution (L, C, fsw): [9.7300e-04 4.8000e-05 4.0075e+04]
# Fitness: 5.4791207
# Volume L: 2.0828406321502e-06
# Volume C: 4.644e-06
# Delta Vo: 0.38669467
# Delta IL: 0.09368467
# P_l_s1:  2.004659
# P_l_s2:  2.0155413
# P_l_C:  0.1299921
# P_l_L_Cu:  1.3289285
# Losses Total: 5.4791207
#
# Rank: 48
# Solution (L, C, fsw): [9.7300e-04 4.8000e-05 4.0075e+04]
# Fitness: 5.4791207
# Volume L: 2.0828406321502e-06
# Volume C: 4.644e-06
# Delta Vo: 0.38669467
# Delta IL: 0.09368467
# P_l_s1:  2.004659
# P_l_s2:  2.0155413
# P_l_C:  0.1299921
# P_l_L_Cu:  1.3289285
# Losses Total: 5.4791207
#
# Rank: 49
# Solution (L, C, fsw): [9.7300e-04 4.8000e-05 4.0075e+04]
# Fitness: 5.4791207
# Volume L: 2.0828406321502e-06
# Volume C: 4.644e-06
# Delta Vo: 0.38669467
# Delta IL: 0.09368467
# P_l_s1:  2.004659
# P_l_s2:  2.0155413
# P_l_C:  0.1299921
# P_l_L_Cu:  1.3289285
# Losses Total: 5.4791207
#
# Rank: 50
# Solution (L, C, fsw): [9.7300e-04 4.8000e-05 4.0075e+04]
# Fitness: 5.4791207
# Volume L: 2.0828406321502e-06
# Volume C: 4.644e-06
# Delta Vo: 0.38669467
# Delta IL: 0.09368467
# P_l_s1:  2.004659
# P_l_s2:  2.0155413
# P_l_C:  0.1299921
# P_l_L_Cu:  1.3289285
# Losses Total: 5.4791207
#
# Rank: 51
# Solution (L, C, fsw): [9.7300e-04 4.8000e-05 4.0075e+04]
# Fitness: 5.4791207
# Volume L: 2.0828406321502e-06
# Volume C: 4.644e-06
# Delta Vo: 0.38669467
# Delta IL: 0.09368467
# P_l_s1:  2.004659
# P_l_s2:  2.0155413
# P_l_C:  0.1299921
# P_l_L_Cu:  1.3289285
# Losses Total: 5.4791207
#
# Rank: 52
# Solution (L, C, fsw): [9.7300e-04 4.8000e-05 4.0075e+04]
# Fitness: 5.4791207
# Volume L: 2.0828406321502e-06
# Volume C: 4.644e-06
# Delta Vo: 0.38669467
# Delta IL: 0.09368467
# P_l_s1:  2.004659
# P_l_s2:  2.0155413
# P_l_C:  0.1299921
# P_l_L_Cu:  1.3289285
# Losses Total: 5.4791207
#
# Rank: 53
# Solution (L, C, fsw): [9.7300e-04 4.8000e-05 4.0075e+04]
# Fitness: 5.4791207
# Volume L: 2.0828406321502e-06
# Volume C: 4.644e-06
# Delta Vo: 0.38669467
# Delta IL: 0.09368467
# P_l_s1:  2.004659
# P_l_s2:  2.0155413
# P_l_C:  0.1299921
# P_l_L_Cu:  1.3289285
# Losses Total: 5.4791207
#
# Rank: 54
# Solution (L, C, fsw): [9.7300e-04 4.8000e-05 4.0075e+04]
# Fitness: 5.4791207
# Volume L: 2.0828406321502e-06
# Volume C: 4.644e-06
# Delta Vo: 0.38669467
# Delta IL: 0.09368467
# P_l_s1:  2.004659
# P_l_s2:  2.0155413
# P_l_C:  0.1299921
# P_l_L_Cu:  1.3289285
# Losses Total: 5.4791207
#
# Rank: 55
# Solution (L, C, fsw): [9.7300e-04 4.8000e-05 4.0075e+04]
# Fitness: 5.4791207
# Volume L: 2.0828406321502e-06
# Volume C: 4.644e-06
# Delta Vo: 0.38669467
# Delta IL: 0.09368467
# P_l_s1:  2.004659
# P_l_s2:  2.0155413
# P_l_C:  0.1299921
# P_l_L_Cu:  1.3289285
# Losses Total: 5.4791207
#
# Rank: 56
# Solution (L, C, fsw): [9.7300e-04 4.8000e-05 4.0075e+04]
# Fitness: 5.4791207
# Volume L: 2.0828406321502e-06
# Volume C: 4.644e-06
# Delta Vo: 0.38669467
# Delta IL: 0.09368467
# P_l_s1:  2.004659
# P_l_s2:  2.0155413
# P_l_C:  0.1299921
# P_l_L_Cu:  1.3289285
# Losses Total: 5.4791207
#
# Rank: 57
# Solution (L, C, fsw): [9.7300e-04 4.8000e-05 4.0075e+04]
# Fitness: 5.4791207
# Volume L: 2.0828406321502e-06
# Volume C: 4.644e-06
# Delta Vo: 0.38669467
# Delta IL: 0.09368467
# P_l_s1:  2.004659
# P_l_s2:  2.0155413
# P_l_C:  0.1299921
# P_l_L_Cu:  1.3289285
# Losses Total: 5.4791207
#
# Rank: 58
# Solution (L, C, fsw): [8.1300e-04 3.0000e-05 4.0664e+04]
# Fitness: 5.52818
# Volume L: 2.0828406321502e-06
# Volume C: 1.564e-06
# Delta Vo: 0.76378924
# Delta IL: 0.12957777
# P_l_s1:  2.008214
# P_l_s2:  2.0072947
# P_l_C:  0.19255923
# P_l_L_Cu:  1.320112
# Losses Total: 5.52818
#
# Rank: 59
# Solution (L, C, fsw): [8.9900e-04 3.0000e-05 4.1277e+04]
# Fitness: 5.5295973
# Volume L: 2.0828406321502e-06
# Volume C: 1.564e-06
# Delta Vo: 0.71815926
# Delta IL: 0.11026901
# P_l_s1:  1.9955311
# P_l_s2:  2.0021663
# P_l_C:  0.19947325
# P_l_L_Cu:  1.3324263
# Losses Total: 5.5295973
#
# Rank: 60
# Solution (L, C, fsw): [9.080e-04 3.000e-05 4.129e+04]
# Fitness: 5.5323896
# Volume L: 2.0828406321502e-06
# Volume C: 1.564e-06
# Delta Vo: 0.70773
# Delta IL: 0.10847775
# P_l_s1:  1.9917538
# P_l_s2:  2.0037713
# P_l_C:  0.20183092
# P_l_L_Cu:  1.3350335
# Losses Total: 5.5323896
#
# Rank: 61
# Solution (L, C, fsw): [9.3300e-04 3.0000e-05 4.0853e+04]
# Fitness: 5.5504193
# Volume L: 2.0828406321502e-06
# Volume C: 1.564e-06
# Delta Vo: 0.67934245
# Delta IL: 0.10418456
# P_l_s1:  1.9889641
# P_l_s2:  2.0112696
# P_l_C:  0.20622046
# P_l_L_Cu:  1.3439649
# Losses Total: 5.5504193
#
# Rank: 62
# Solution (L, C, fsw): [9.7500e-04 3.0000e-05 4.0931e+04]
# Fitness: 5.581681
# Volume L: 2.0828406321502e-06
# Volume C: 1.564e-06
# Delta Vo: 0.6199644
# Delta IL: 0.09558877
# P_l_s1:  2.006128
# P_l_s2:  2.0289528
# P_l_C:  0.20050538
# P_l_L_Cu:  1.3460946
# Losses Total: 5.581681
#
# Rank: 63
# Solution (L, C, fsw): [9.7500e-04 3.0000e-05 4.0931e+04]
# Fitness: 5.581681
# Volume L: 2.0828406321502e-06
# Volume C: 1.564e-06
# Delta Vo: 0.6199644
# Delta IL: 0.09558877
# P_l_s1:  2.006128
# P_l_s2:  2.0289528
# P_l_C:  0.20050538
# P_l_L_Cu:  1.3460946
# Losses Total: 5.581681
#
# Rank: 64
# Solution (L, C, fsw): [9.980e-04 3.900e-05 4.123e+04]
# Fitness: 5.591354
# Volume L: 2.0828406321502e-06
# Volume C: 5.639e-06
# Delta Vo: 0.37226376
# Delta IL: 0.09515865
# P_l_s1:  1.9862894
# P_l_s2:  1.9908241
# P_l_C:  0.16544877
# P_l_L_Cu:  1.4487916
# Losses Total: 5.591354
#
# Rank: 65
# Solution (L, C, fsw): [1.0010e-03 5.5000e-05 4.0128e+04]
# Fitness: 5.6363997
# Volume L: 2.0828406321502e-06
# Volume C: 3.497e-06
# Delta Vo: 0.35257545
# Delta IL: 0.09508582
# P_l_s1:  1.985172
# P_l_s2:  1.9890629
# P_l_C:  0.11130696
# P_l_L_Cu:  1.5508575
# Losses Total: 5.6363997
#
# Rank: 66
# Solution (L, C, fsw): [1.0010e-03 5.5000e-05 4.0128e+04]
# Fitness: 5.6363997
# Volume L: 2.0828406321502e-06
# Volume C: 3.497e-06
# Delta Vo: 0.35257545
# Delta IL: 0.09508582
# P_l_s1:  1.985172
# P_l_s2:  1.9890629
# P_l_C:  0.11130696
# P_l_L_Cu:  1.5508575
# Losses Total: 5.6363997
#
# Rank: 67
# Solution (L, C, fsw): [1.0010e-03 5.5000e-05 4.0128e+04]
# Fitness: 5.6363997
# Volume L: 2.0828406321502e-06
# Volume C: 3.497e-06
# Delta Vo: 0.35257545
# Delta IL: 0.09508582
# P_l_s1:  1.985172
# P_l_s2:  1.9890629
# P_l_C:  0.11130696
# P_l_L_Cu:  1.5508575
# Losses Total: 5.6363997
#
# Rank: 68
# Solution (L, C, fsw): [1.0010e-03 5.5000e-05 4.0128e+04]
# Fitness: 5.6363997
# Volume L: 2.0828406321502e-06
# Volume C: 3.497e-06
# Delta Vo: 0.35257545
# Delta IL: 0.09508582
# P_l_s1:  1.985172
# P_l_s2:  1.9890629
# P_l_C:  0.11130696
# P_l_L_Cu:  1.5508575
# Losses Total: 5.6363997
#
# Rank: 69
# Solution (L, C, fsw): [1.0010e-03 5.5000e-05 4.0128e+04]
# Fitness: 5.6363997
# Volume L: 2.0828406321502e-06
# Volume C: 3.497e-06
# Delta Vo: 0.35257545
# Delta IL: 0.09508582
# P_l_s1:  1.985172
# P_l_s2:  1.9890629
# P_l_C:  0.11130696
# P_l_L_Cu:  1.5508575
# Losses Total: 5.6363997
#
# Rank: 70
# Solution (L, C, fsw): [1.0010e-03 5.5000e-05 4.0128e+04]
# Fitness: 5.6363997
# Volume L: 2.0828406321502e-06
# Volume C: 3.497e-06
# Delta Vo: 0.35257545
# Delta IL: 0.09508582
# P_l_s1:  1.985172
# P_l_s2:  1.9890629
# P_l_C:  0.11130696
# P_l_L_Cu:  1.5508575
# Losses Total: 5.6363997
#
# Rank: 71
# Solution (L, C, fsw): [1.0140e-03 1.2700e-04 3.6083e+04]
# Fitness: 5.7433467
# Volume L: 2.0828406321502e-06
# Volume C: 3.443e-06
# Delta Vo: 2.2198803
# Delta IL: 0.13905889
# P_l_s1:  1.9037207
# P_l_s2:  1.9077809
# P_l_C:  0.04742193
# P_l_L_Cu:  1.8844233
# Losses Total: 5.7433467
#
# Rank: 72
# Solution (L, C, fsw): [1.0120e-03 3.0000e-05 3.6472e+04]
# Fitness: 5.767745
# Volume L: 2.0828406321502e-06
# Volume C: 1.564e-06
# Delta Vo: 0.49482158
# Delta IL: 0.10203553
# P_l_s1:  1.949981
# P_l_s2:  1.9471421
# P_l_C:  0.2317228
# P_l_L_Cu:  1.6388988
# Losses Total: 5.7677445
#
# Rank: 73
# Solution (L, C, fsw): [1.0630e-03 1.5000e-04 3.5955e+04]
# Fitness: 5.7991567
# Volume L: 2.0828406321502e-06
# Volume C: 2.553e-06
# Delta Vo: 4.34347
# Delta IL: 0.14635174
# P_l_s1:  1.840388
# P_l_s2:  1.8424984
# P_l_C:  0.03971434
# P_l_L_Cu:  2.076556
# Losses Total: 5.7991567
#
# Rank: 74
# Solution (L, C, fsw): [1.0200e-03 5.7000e-05 4.0086e+04]
# Fitness: 5.9488277
# Volume L: 2.0828406321502e-06
# Volume C: 1.675e-06
# Delta Vo: 0.32293555
# Delta IL: 0.09008938
# P_l_s1:  1.9565884
# P_l_s2:  1.9568204
# P_l_C:  0.10330333
# P_l_L_Cu:  1.9321156
# Losses Total: 5.9488277
#
# Rank: 75
# Solution (L, C, fsw): [1.3900e-03 1.2200e-04 3.5959e+04]
# Fitness: 5.974728
# Volume L: 2.0828406321502e-06
# Volume C: 3.528e-06
# Delta Vo: 2.3374805
# Delta IL: 0.10053692
# P_l_s1:  1.8899469
# P_l_s2:  1.8919504
# P_l_C:  0.05100203
# P_l_L_Cu:  2.1418288
# Losses Total: 5.974728
#
# Rank: 76
# Solution (L, C, fsw): [1.5900e-03 9.0000e-05 3.6247e+04]
# Fitness: 5.9804664
# Volume L: 2.0828406321502e-06
# Volume C: 1.437e-06
# Delta Vo: 0.97435945
# Delta IL: 0.070416816
# P_l_s1:  1.8758516
# P_l_s2:  1.8841119
# P_l_C:  0.06922876
# P_l_L_Cu:  2.1512742
# Losses Total: 5.9804664
#
# Rank: 77
# Solution (L, C, fsw): [1.5900e-03 9.0000e-05 3.6247e+04]
# Fitness: 5.9804664
# Volume L: 2.0828406321502e-06
# Volume C: 1.437e-06
# Delta Vo: 0.97435945
# Delta IL: 0.070416816
# P_l_s1:  1.8758516
# P_l_s2:  1.8841119
# P_l_C:  0.06922876
# P_l_L_Cu:  2.1512742
# Losses Total: 5.9804664
#
# Rank: 78
# Solution (L, C, fsw): [1.0380e-03 1.1100e-04 3.5963e+04]
# Fitness: 5.9820676
# Volume L: 2.0828406321502e-06
# Volume C: 3.591e-06
# Delta Vo: 1.2248573
# Delta IL: 0.12947218
# P_l_s1:  1.9038987
# P_l_s2:  1.9069479
# P_l_C:  0.056888904
# P_l_L_Cu:  2.1143322
# Losses Total: 5.9820676
#
# Rank: 79
# Solution (L, C, fsw): [1.3430e-03 1.0900e-04 3.8182e+04]
# Fitness: 5.989225
# Volume L: 2.0828406321502e-06
# Volume C: 4.773e-06
# Delta Vo: 1.9781339
# Delta IL: 0.0867677
# P_l_s1:  1.9046943
# P_l_s2:  1.9055812
# P_l_C:  0.053158298
# P_l_L_Cu:  2.1257913
# Losses Total: 5.9892254
#
# Rank: 80
# Solution (L, C, fsw): [1.4660e-03 1.1200e-04 3.6557e+04]
# Fitness: 6.007637
# Volume L: 2.0828406321502e-06
# Volume C: 6.001e-06
# Delta Vo: 1.9416755
# Delta IL: 0.091152176
# P_l_s1:  1.8982978
# P_l_s2:  1.9039631
# P_l_C:  0.05477162
# P_l_L_Cu:  2.150605
# Losses Total: 6.0076375
#
# Rank: 81
# Solution (L, C, fsw): [1.0570e-03 1.1100e-04 3.7256e+04]
# Fitness: 6.01932
# Volume L: 2.0828406321502e-06
# Volume C: 3.591e-06
# Delta Vo: 1.1727123
# Delta IL: 0.12461882
# P_l_s1:  1.9040793
# P_l_s2:  1.9093441
# P_l_C:  0.055560797
# P_l_L_Cu:  2.150336
# Losses Total: 6.0193205
#
# Rank: 82
# Solution (L, C, fsw): [1.5300e-03 1.1500e-04 3.6294e+04]
# Fitness: 6.028861
# Volume L: 2.0828406321502e-06
# Volume C: 5.589e-06
# Delta Vo: 1.6842486
# Delta IL: 0.0956395
# P_l_s1:  1.9028218
# P_l_s2:  1.9065713
# P_l_C:  0.05413604
# P_l_L_Cu:  2.1653316
# Losses Total: 6.0288606
#
# Rank: 83
# Solution (L, C, fsw): [1.5620e-03 6.9000e-05 3.5771e+04]
# Fitness: 6.0442886
# Volume L: 2.0828406321502e-06
# Volume C: 2.668e-06
# Delta Vo: 0.14753829
# Delta IL: 0.048708376
# P_l_s1:  1.9045588
# P_l_s2:  1.8943793
# P_l_C:  0.08769508
# P_l_L_Cu:  2.1576555
# Losses Total: 6.0442886
#
# Rank: 84
# Solution (L, C, fsw): [1.5620e-03 6.9000e-05 3.5771e+04]
# Fitness: 6.0442886
# Volume L: 2.0828406321502e-06
# Volume C: 2.668e-06
# Delta Vo: 0.14753829
# Delta IL: 0.048708376
# P_l_s1:  1.9045588
# P_l_s2:  1.8943793
# P_l_C:  0.08769508
# P_l_L_Cu:  2.1576555
# Losses Total: 6.0442886
#
# Rank: 85
# Solution (L, C, fsw): [1.5620e-03 6.9000e-05 3.5771e+04]
# Fitness: 6.0442886
# Volume L: 2.0828406321502e-06
# Volume C: 2.668e-06
# Delta Vo: 0.14753829
# Delta IL: 0.048708376
# P_l_s1:  1.9045588
# P_l_s2:  1.8943793
# P_l_C:  0.08769508
# P_l_L_Cu:  2.1576555
# Losses Total: 6.0442886
#
# Rank: 86
# Solution (L, C, fsw): [1.5620e-03 6.9000e-05 3.5771e+04]
# Fitness: 6.0442886
# Volume L: 2.0828406321502e-06
# Volume C: 2.668e-06
# Delta Vo: 0.14753829
# Delta IL: 0.048708376
# P_l_s1:  1.9045588
# P_l_s2:  1.8943793
# P_l_C:  0.08769508
# P_l_L_Cu:  2.1576555
# Losses Total: 6.0442886
#
# Rank: 87
# Solution (L, C, fsw): [1.5620e-03 6.9000e-05 3.5771e+04]
# Fitness: 6.0442886
# Volume L: 2.0828406321502e-06
# Volume C: 2.668e-06
# Delta Vo: 0.14753829
# Delta IL: 0.048708376
# P_l_s1:  1.9045588
# P_l_s2:  1.8943793
# P_l_C:  0.08769508
# P_l_L_Cu:  2.1576555
# Losses Total: 6.0442886
#
# Rank: 88
# Solution (L, C, fsw): [1.5620e-03 6.9000e-05 3.5771e+04]
# Fitness: 6.0442886
# Volume L: 2.0828406321502e-06
# Volume C: 2.668e-06
# Delta Vo: 0.14753829
# Delta IL: 0.048708376
# P_l_s1:  1.9045588
# P_l_s2:  1.8943793
# P_l_C:  0.08769508
# P_l_L_Cu:  2.1576555
# Losses Total: 6.0442886
#
# Rank: 89
# Solution (L, C, fsw): [1.5620e-03 6.9000e-05 3.5771e+04]
# Fitness: 6.0442886
# Volume L: 2.0828406321502e-06
# Volume C: 2.668e-06
# Delta Vo: 0.14753829
# Delta IL: 0.048708376
# P_l_s1:  1.9045588
# P_l_s2:  1.8943793
# P_l_C:  0.08769508
# P_l_L_Cu:  2.1576555
# Losses Total: 6.0442886
#
# Rank: 90
# Solution (L, C, fsw): [1.5620e-03 6.9000e-05 3.5771e+04]
# Fitness: 6.0442886
# Volume L: 2.0828406321502e-06
# Volume C: 2.668e-06
# Delta Vo: 0.14753829
# Delta IL: 0.048708376
# P_l_s1:  1.9045588
# P_l_s2:  1.8943793
# P_l_C:  0.08769508
# P_l_L_Cu:  2.1576555
# Losses Total: 6.0442886
#
# Rank: 91
# Solution (L, C, fsw): [1.5620e-03 6.9000e-05 3.5771e+04]
# Fitness: 6.0442886
# Volume L: 2.0828406321502e-06
# Volume C: 2.668e-06
# Delta Vo: 0.14753829
# Delta IL: 0.048708376
# P_l_s1:  1.9045588
# P_l_s2:  1.8943793
# P_l_C:  0.08769508
# P_l_L_Cu:  2.1576555
# Losses Total: 6.0442886
#
# Rank: 92
# Solution (L, C, fsw): [1.5620e-03 6.9000e-05 3.5771e+04]
# Fitness: 6.0442886
# Volume L: 2.0828406321502e-06
# Volume C: 2.668e-06
# Delta Vo: 0.14753829
# Delta IL: 0.048708376
# P_l_s1:  1.9045588
# P_l_s2:  1.8943793
# P_l_C:  0.08769508
# P_l_L_Cu:  2.1576555
# Losses Total: 6.0442886
#
# Rank: 93
# Solution (L, C, fsw): [1.6840e-03 6.9000e-05 3.7466e+04]
# Fitness: 6.045745
# Volume L: 2.0828406321502e-06
# Volume C: 2.668e-06
# Delta Vo: 0.076430455
# Delta IL: 0.04182062
# P_l_s1:  1.9103303
# P_l_s2:  1.9176619
# P_l_C:  0.082948126
# P_l_L_Cu:  2.1348045
# Losses Total: 6.045745
#
# Rank: 94
# Solution (L, C, fsw): [1.637e-03 8.000e-05 3.787e+04]
# Fitness: 6.0800014
# Volume L: 2.0828406321502e-06
# Volume C: 3.335e-06
# Delta Vo: 0.6436588
# Delta IL: 0.055463776
# P_l_s1:  1.9283051
# P_l_s2:  1.9196973
# P_l_C:  0.07461229
# P_l_L_Cu:  2.1573868
# Losses Total: 6.080002
#
# Rank: 95
# Solution (L, C, fsw): [1.637e-03 8.000e-05 3.787e+04]
# Fitness: 6.0800014
# Volume L: 2.0828406321502e-06
# Volume C: 3.335e-06
# Delta Vo: 0.6436588
# Delta IL: 0.055463776
# P_l_s1:  1.9283051
# P_l_s2:  1.9196973
# P_l_C:  0.07461229
# P_l_L_Cu:  2.1573868
# Losses Total: 6.080002
#
# Rank: 96
# Solution (L, C, fsw): [1.2030e-03 1.2900e-04 5.1551e+04]
# Fitness: 6.172456
# Volume L: 2.0828406321502e-06
# Volume C: 4.362e-06
# Delta Vo: 3.1335778
# Delta IL: 0.09059007
# P_l_s1:  2.014689
# P_l_s2:  2.0194807
# P_l_C:  0.036511406
# P_l_L_Cu:  2.1017747
# Losses Total: 6.172456
#
# Rank: 97
# Solution (L, C, fsw): [1.244e-03 1.170e-04 5.199e+04]
# Fitness: 6.2239203
# Volume L: 2.0828406321502e-06
# Volume C: 3.276e-06
# Delta Vo: 2.4139612
# Delta IL: 0.08083561
# P_l_s1:  2.0344865
# P_l_s2:  2.0363672
# P_l_C:  0.03949505
# P_l_L_Cu:  2.1135714
# Losses Total: 6.22392
#
# Rank: 98
# Solution (L, C, fsw): [1.1650e-03 1.1100e-04 5.3044e+04]
# Fitness: 6.248548
# Volume L: 2.0828406321502e-06
# Volume C: 3.591e-06
# Delta Vo: 1.6304953
# Delta IL: 0.089307316
# P_l_s1:  2.0474787
# P_l_s2:  2.0419183
# P_l_C:  0.04043073
# P_l_L_Cu:  2.1187208
# Losses Total: 6.2485485
#
# Rank: 99
# Solution (L, C, fsw): [1.2800e-03 8.1000e-05 5.2037e+04]
# Fitness: 6.3217363
# Volume L: 2.0828406321502e-06
# Volume C: 3.586e-06
# Delta Vo: 0.48027283
# Delta IL: 0.061867215
# P_l_s1:  2.0567691
# P_l_s2:  2.054964
# P_l_C:  0.057305187
# P_l_L_Cu:  2.1526973
# Losses Total: 6.3217363
#
# Rank: 100
# Solution (L, C, fsw): [1.2800e-03 8.1000e-05 5.2037e+04]
# Fitness: 6.3217363
# Volume L: 2.0828406321502e-06
# Volume C: 3.586e-06
# Delta Vo: 0.48027283
# Delta IL: 0.061867215
# P_l_s1:  2.0567691
# P_l_s2:  2.054964
# P_l_C:  0.057305187
# P_l_L_Cu:  2.1526973
# Losses Total: 6.3217363

# %% [markdown]
# ## Ranking with constraint

# %%
# Your additional code snippet for printing and sorting the results
# Define lists to store the results
volume_L_values = []
volume_C_values = []
delta_Vo_values = []
delta_IL_values = []
P_l_s1_values = []
P_l_s2_values = []
P_l_C_values = []
P_l_L_Cu_values = []
solutions = []

# Iterate over different generations
for i, (solution, fitness) in enumerate(zip(best_solutions, best_fitnesses)):
    # Calculate volume values and delta Vo for the current solution
    L = solution[0]
    C = solution[1]
    fs = solution[2]
    nearest_C, Vol_C = search_volume_capacitance(C, csv_file_capacitance)
    nearest_L, Vol_L = search_volume_inductance(L, csv_file_inductance)

    input_values = np.array([L, C, fs])
    input_values_scaled = np.zeros_like(input_values, dtype=float)
    input_values_scaled[0] = (input_values[0] - L_min) / (L_max - L_min)
    input_values_scaled[1] = (input_values[1] - C_min) / (C_max - C_min)
    input_values_scaled[2] = (input_values[2] - fsw_min) / (fsw_max - fsw_min)
    input_values_reshaped = input_values_scaled.reshape((1, -1))
    
    prediction = model.predict(input_values_reshaped, verbose=0)
    Delta_IL_percent = prediction[0][0]
    Delta_Vo_percent = prediction[0][1]
    P_l_s1 = prediction[0][2]
    P_l_s2 = prediction[0][3]
    P_l_C = prediction[0][4]
    P_l_L_Cu = prediction[0][5]
    
    # Check constraints for the current solution
    if check_constraints(solution):
        # Store the volume values, delta Vo, and solution for sorting
        volume_L_values.append(Vol_L)
        volume_C_values.append(Vol_C)
        delta_Vo_values.append(Delta_Vo_percent)
        delta_IL_values.append(Delta_IL_percent)
        P_l_s1_values.append(P_l_s1)
        P_l_s2_values.append(P_l_s2)
        P_l_C_values.append(P_l_C)
        P_l_L_Cu_values.append(P_l_L_Cu)

        solutions.append((solution, fitness, Vol_L, Vol_C, Delta_Vo_percent, Delta_IL_percent, P_l_s1, P_l_s2, P_l_C, P_l_L_Cu))

# Sort the solutions based on fitness values in ascending order
sorted_solutions = sorted(solutions, key=lambda x: x[1])

# Print the sorted solutions
print("Sorted Solutions:")
for rank, (solution, fitness, vol_L, vol_C, delta_Vo, delta_IL, P_l_s1, P_l_s2, P_l_C, P_l_L_Cu) in enumerate(sorted_solutions):
    print("Rank:", rank + 1)
    print("Solution (L, C, fsw):", solution)
    print("Fitness:", fitness)
    print("Volume L:", vol_L)
    print("Volume C:", vol_C)
    print("Delta Vo:", delta_Vo)
    print("Delta IL:", delta_IL)
    print("P_l_s1: ", P_l_s1)
    print("P_l_s2: ", P_l_s2)
    print("P_l_C: ", P_l_C)
    print("P_l_L_Cu: ", P_l_L_Cu)
    print("Losses Total:", P_l_s1 + P_l_s2 + P_l_C + P_l_L_Cu)
    print()

# Plot the fitness values for each generation
plt.plot(best_outputs)
plt.xlabel("Generation")
plt.ylabel("Fitness")
plt.title("Fitness Progression")
plt.show()
# Out:
# Sorted Solutions:
# Rank: 1
# Solution (L, C, fsw): [9.7300e-04 4.8000e-05 4.0075e+04]
# Fitness: 5.4791207
# Volume L: 2.0828406321502e-06
# Volume C: 4.644e-06
# Delta Vo: 0.38669467
# Delta IL: 0.09368467
# P_l_s1:  2.004659
# P_l_s2:  2.0155413
# P_l_C:  0.1299921
# P_l_L_Cu:  1.3289285
# Losses Total: 5.4791207
#
# Rank: 2
# Solution (L, C, fsw): [9.7300e-04 4.8000e-05 4.0075e+04]
# Fitness: 5.4791207
# Volume L: 2.0828406321502e-06
# Volume C: 4.644e-06
# Delta Vo: 0.38669467
# Delta IL: 0.09368467
# P_l_s1:  2.004659
# P_l_s2:  2.0155413
# P_l_C:  0.1299921
# P_l_L_Cu:  1.3289285
# Losses Total: 5.4791207
#
# Rank: 3
# Solution (L, C, fsw): [9.7300e-04 4.8000e-05 4.0075e+04]
# Fitness: 5.4791207
# Volume L: 2.0828406321502e-06
# Volume C: 4.644e-06
# Delta Vo: 0.38669467
# Delta IL: 0.09368467
# P_l_s1:  2.004659
# P_l_s2:  2.0155413
# P_l_C:  0.1299921
# P_l_L_Cu:  1.3289285
# Losses Total: 5.4791207
#
# Rank: 4
# Solution (L, C, fsw): [9.7300e-04 4.8000e-05 4.0075e+04]
# Fitness: 5.4791207
# Volume L: 2.0828406321502e-06
# Volume C: 4.644e-06
# Delta Vo: 0.38669467
# Delta IL: 0.09368467
# P_l_s1:  2.004659
# P_l_s2:  2.0155413
# P_l_C:  0.1299921
# P_l_L_Cu:  1.3289285
# Losses Total: 5.4791207
#
# Rank: 5
# Solution (L, C, fsw): [9.7300e-04 4.8000e-05 4.0075e+04]
# Fitness: 5.4791207
# Volume L: 2.0828406321502e-06
# Volume C: 4.644e-06
# Delta Vo: 0.38669467
# Delta IL: 0.09368467
# P_l_s1:  2.004659
# P_l_s2:  2.0155413
# P_l_C:  0.1299921
# P_l_L_Cu:  1.3289285
# Losses Total: 5.4791207
#
# Rank: 6
# Solution (L, C, fsw): [9.7300e-04 4.8000e-05 4.0075e+04]
# Fitness: 5.4791207
# Volume L: 2.0828406321502e-06
# Volume C: 4.644e-06
# Delta Vo: 0.38669467
# Delta IL: 0.09368467
# P_l_s1:  2.004659
# P_l_s2:  2.0155413
# P_l_C:  0.1299921
# P_l_L_Cu:  1.3289285
# Losses Total: 5.4791207
#
# Rank: 7
# Solution (L, C, fsw): [9.7300e-04 4.8000e-05 4.0075e+04]
# Fitness: 5.4791207
# Volume L: 2.0828406321502e-06
# Volume C: 4.644e-06
# Delta Vo: 0.38669467
# Delta IL: 0.09368467
# P_l_s1:  2.004659
# P_l_s2:  2.0155413
# P_l_C:  0.1299921
# P_l_L_Cu:  1.3289285
# Losses Total: 5.4791207
#
# Rank: 8
# Solution (L, C, fsw): [9.7300e-04 4.8000e-05 4.0075e+04]
# Fitness: 5.4791207
# Volume L: 2.0828406321502e-06
# Volume C: 4.644e-06
# Delta Vo: 0.38669467
# Delta IL: 0.09368467
# P_l_s1:  2.004659
# P_l_s2:  2.0155413
# P_l_C:  0.1299921
# P_l_L_Cu:  1.3289285
# Losses Total: 5.4791207
#
# Rank: 9
# Solution (L, C, fsw): [9.7300e-04 4.8000e-05 4.0075e+04]
# Fitness: 5.4791207
# Volume L: 2.0828406321502e-06
# Volume C: 4.644e-06
# Delta Vo: 0.38669467
# Delta IL: 0.09368467
# P_l_s1:  2.004659
# P_l_s2:  2.0155413
# P_l_C:  0.1299921
# P_l_L_Cu:  1.3289285
# Losses Total: 5.4791207
#
# Rank: 10
# Solution (L, C, fsw): [9.7300e-04 4.8000e-05 4.0075e+04]
# Fitness: 5.4791207
# Volume L: 2.0828406321502e-06
# Volume C: 4.644e-06
# Delta Vo: 0.38669467
# Delta IL: 0.09368467
# P_l_s1:  2.004659
# P_l_s2:  2.0155413
# P_l_C:  0.1299921
# P_l_L_Cu:  1.3289285
# Losses Total: 5.4791207
#
# Rank: 11
# Solution (L, C, fsw): [9.7300e-04 4.8000e-05 4.0075e+04]
# Fitness: 5.4791207
# Volume L: 2.0828406321502e-06
# Volume C: 4.644e-06
# Delta Vo: 0.38669467
# Delta IL: 0.09368467
# P_l_s1:  2.004659
# P_l_s2:  2.0155413
# P_l_C:  0.1299921
# P_l_L_Cu:  1.3289285
# Losses Total: 5.4791207
#
# Rank: 12
# Solution (L, C, fsw): [9.7300e-04 4.8000e-05 4.0075e+04]
# Fitness: 5.4791207
# Volume L: 2.0828406321502e-06
# Volume C: 4.644e-06
# Delta Vo: 0.38669467
# Delta IL: 0.09368467
# P_l_s1:  2.004659
# P_l_s2:  2.0155413
# P_l_C:  0.1299921
# P_l_L_Cu:  1.3289285
# Losses Total: 5.4791207
#
# Rank: 13
# Solution (L, C, fsw): [9.7300e-04 4.8000e-05 4.0075e+04]
# Fitness: 5.4791207
# Volume L: 2.0828406321502e-06
# Volume C: 4.644e-06
# Delta Vo: 0.38669467
# Delta IL: 0.09368467
# P_l_s1:  2.004659
# P_l_s2:  2.0155413
# P_l_C:  0.1299921
# P_l_L_Cu:  1.3289285
# Losses Total: 5.4791207
#
# Rank: 14
# Solution (L, C, fsw): [9.7300e-04 4.8000e-05 4.0075e+04]
# Fitness: 5.4791207
# Volume L: 2.0828406321502e-06
# Volume C: 4.644e-06
# Delta Vo: 0.38669467
# Delta IL: 0.09368467
# P_l_s1:  2.004659
# P_l_s2:  2.0155413
# P_l_C:  0.1299921
# P_l_L_Cu:  1.3289285
# Losses Total: 5.4791207
#
# Rank: 15
# Solution (L, C, fsw): [9.7300e-04 4.8000e-05 4.0075e+04]
# Fitness: 5.4791207
# Volume L: 2.0828406321502e-06
# Volume C: 4.644e-06
# Delta Vo: 0.38669467
# Delta IL: 0.09368467
# P_l_s1:  2.004659
# P_l_s2:  2.0155413
# P_l_C:  0.1299921
# P_l_L_Cu:  1.3289285
# Losses Total: 5.4791207
#
# Rank: 16
# Solution (L, C, fsw): [9.7500e-04 3.0000e-05 4.0931e+04]
# Fitness: 5.581681
# Volume L: 2.0828406321502e-06
# Volume C: 1.564e-06
# Delta Vo: 0.6199644
# Delta IL: 0.09558877
# P_l_s1:  2.006128
# P_l_s2:  2.0289528
# P_l_C:  0.20050538
# P_l_L_Cu:  1.3460946
# Losses Total: 5.581681
#
# Rank: 17
# Solution (L, C, fsw): [9.7500e-04 3.0000e-05 4.0931e+04]
# Fitness: 5.581681
# Volume L: 2.0828406321502e-06
# Volume C: 1.564e-06
# Delta Vo: 0.6199644
# Delta IL: 0.09558877
# P_l_s1:  2.006128
# P_l_s2:  2.0289528
# P_l_C:  0.20050538
# P_l_L_Cu:  1.3460946
# Losses Total: 5.581681
#
# Rank: 18
# Solution (L, C, fsw): [1.0010e-03 5.5000e-05 4.0128e+04]
# Fitness: 5.6363997
# Volume L: 2.0828406321502e-06
# Volume C: 3.497e-06
# Delta Vo: 0.35257545
# Delta IL: 0.09508582
# P_l_s1:  1.985172
# P_l_s2:  1.9890629
# P_l_C:  0.11130696
# P_l_L_Cu:  1.5508575
# Losses Total: 5.6363997
#
# Rank: 19
# Solution (L, C, fsw): [1.0010e-03 5.5000e-05 4.0128e+04]
# Fitness: 5.6363997
# Volume L: 2.0828406321502e-06
# Volume C: 3.497e-06
# Delta Vo: 0.35257545
# Delta IL: 0.09508582
# P_l_s1:  1.985172
# P_l_s2:  1.9890629
# P_l_C:  0.11130696
# P_l_L_Cu:  1.5508575
# Losses Total: 5.6363997
#
# Rank: 20
# Solution (L, C, fsw): [1.0010e-03 5.5000e-05 4.0128e+04]
# Fitness: 5.6363997
# Volume L: 2.0828406321502e-06
# Volume C: 3.497e-06
# Delta Vo: 0.35257545
# Delta IL: 0.09508582
# P_l_s1:  1.985172
# P_l_s2:  1.9890629
# P_l_C:  0.11130696
# P_l_L_Cu:  1.5508575
# Losses Total: 5.6363997
#
# Rank: 21
# Solution (L, C, fsw): [1.0010e-03 5.5000e-05 4.0128e+04]
# Fitness: 5.6363997
# Volume L: 2.0828406321502e-06
# Volume C: 3.497e-06
# Delta Vo: 0.35257545
# Delta IL: 0.09508582
# P_l_s1:  1.985172
# P_l_s2:  1.9890629
# P_l_C:  0.11130696
# P_l_L_Cu:  1.5508575
# Losses Total: 5.6363997
#
# Rank: 22
# Solution (L, C, fsw): [1.0010e-03 5.5000e-05 4.0128e+04]
# Fitness: 5.6363997
# Volume L: 2.0828406321502e-06
# Volume C: 3.497e-06
# Delta Vo: 0.35257545
# Delta IL: 0.09508582
# P_l_s1:  1.985172
# P_l_s2:  1.9890629
# P_l_C:  0.11130696
# P_l_L_Cu:  1.5508575
# Losses Total: 5.6363997
#
# Rank: 23
# Solution (L, C, fsw): [1.0010e-03 5.5000e-05 4.0128e+04]
# Fitness: 5.6363997
# Volume L: 2.0828406321502e-06
# Volume C: 3.497e-06
# Delta Vo: 0.35257545
# Delta IL: 0.09508582
# P_l_s1:  1.985172
# P_l_s2:  1.9890629
# P_l_C:  0.11130696
# P_l_L_Cu:  1.5508575
# Losses Total: 5.6363997
#
# Rank: 24
# Solution (L, C, fsw): [1.0200e-03 5.7000e-05 4.0086e+04]
# Fitness: 5.9488277
# Volume L: 2.0828406321502e-06
# Volume C: 1.675e-06
# Delta Vo: 0.32293555
# Delta IL: 0.09008938
# P_l_s1:  1.9565884
# P_l_s2:  1.9568204
# P_l_C:  0.10330333
# P_l_L_Cu:  1.9321156
# Losses Total: 5.9488277
#
# Rank: 25
# Solution (L, C, fsw): [1.5900e-03 9.0000e-05 3.6247e+04]
# Fitness: 5.9804664
# Volume L: 2.0828406321502e-06
# Volume C: 1.437e-06
# Delta Vo: 0.97435945
# Delta IL: 0.070416816
# P_l_s1:  1.8758516
# P_l_s2:  1.8841119
# P_l_C:  0.06922876
# P_l_L_Cu:  2.1512742
# Losses Total: 5.9804664
#
# Rank: 26
# Solution (L, C, fsw): [1.5900e-03 9.0000e-05 3.6247e+04]
# Fitness: 5.9804664
# Volume L: 2.0828406321502e-06
# Volume C: 1.437e-06
# Delta Vo: 0.97435945
# Delta IL: 0.070416816
# P_l_s1:  1.8758516
# P_l_s2:  1.8841119
# P_l_C:  0.06922876
# P_l_L_Cu:  2.1512742
# Losses Total: 5.9804664
#
# Rank: 27
# Solution (L, C, fsw): [1.5620e-03 6.9000e-05 3.5771e+04]
# Fitness: 6.0442886
# Volume L: 2.0828406321502e-06
# Volume C: 2.668e-06
# Delta Vo: 0.14753829
# Delta IL: 0.048708376
# P_l_s1:  1.9045588
# P_l_s2:  1.8943793
# P_l_C:  0.08769508
# P_l_L_Cu:  2.1576555
# Losses Total: 6.0442886
#
# Rank: 28
# Solution (L, C, fsw): [1.5620e-03 6.9000e-05 3.5771e+04]
# Fitness: 6.0442886
# Volume L: 2.0828406321502e-06
# Volume C: 2.668e-06
# Delta Vo: 0.14753829
# Delta IL: 0.048708376
# P_l_s1:  1.9045588
# P_l_s2:  1.8943793
# P_l_C:  0.08769508
# P_l_L_Cu:  2.1576555
# Losses Total: 6.0442886
#
# Rank: 29
# Solution (L, C, fsw): [1.5620e-03 6.9000e-05 3.5771e+04]
# Fitness: 6.0442886
# Volume L: 2.0828406321502e-06
# Volume C: 2.668e-06
# Delta Vo: 0.14753829
# Delta IL: 0.048708376
# P_l_s1:  1.9045588
# P_l_s2:  1.8943793
# P_l_C:  0.08769508
# P_l_L_Cu:  2.1576555
# Losses Total: 6.0442886
#
# Rank: 30
# Solution (L, C, fsw): [1.5620e-03 6.9000e-05 3.5771e+04]
# Fitness: 6.0442886
# Volume L: 2.0828406321502e-06
# Volume C: 2.668e-06
# Delta Vo: 0.14753829
# Delta IL: 0.048708376
# P_l_s1:  1.9045588
# P_l_s2:  1.8943793
# P_l_C:  0.08769508
# P_l_L_Cu:  2.1576555
# Losses Total: 6.0442886
#
# Rank: 31
# Solution (L, C, fsw): [1.5620e-03 6.9000e-05 3.5771e+04]
# Fitness: 6.0442886
# Volume L: 2.0828406321502e-06
# Volume C: 2.668e-06
# Delta Vo: 0.14753829
# Delta IL: 0.048708376
# P_l_s1:  1.9045588
# P_l_s2:  1.8943793
# P_l_C:  0.08769508
# P_l_L_Cu:  2.1576555
# Losses Total: 6.0442886
#
# Rank: 32
# Solution (L, C, fsw): [1.5620e-03 6.9000e-05 3.5771e+04]
# Fitness: 6.0442886
# Volume L: 2.0828406321502e-06
# Volume C: 2.668e-06
# Delta Vo: 0.14753829
# Delta IL: 0.048708376
# P_l_s1:  1.9045588
# P_l_s2:  1.8943793
# P_l_C:  0.08769508
# P_l_L_Cu:  2.1576555
# Losses Total: 6.0442886
#
# Rank: 33
# Solution (L, C, fsw): [1.5620e-03 6.9000e-05 3.5771e+04]
# Fitness: 6.0442886
# Volume L: 2.0828406321502e-06
# Volume C: 2.668e-06
# Delta Vo: 0.14753829
# Delta IL: 0.048708376
# P_l_s1:  1.9045588
# P_l_s2:  1.8943793
# P_l_C:  0.08769508
# P_l_L_Cu:  2.1576555
# Losses Total: 6.0442886
#
# Rank: 34
# Solution (L, C, fsw): [1.5620e-03 6.9000e-05 3.5771e+04]
# Fitness: 6.0442886
# Volume L: 2.0828406321502e-06
# Volume C: 2.668e-06
# Delta Vo: 0.14753829
# Delta IL: 0.048708376
# P_l_s1:  1.9045588
# P_l_s2:  1.8943793
# P_l_C:  0.08769508
# P_l_L_Cu:  2.1576555
# Losses Total: 6.0442886
#
# Rank: 35
# Solution (L, C, fsw): [1.5620e-03 6.9000e-05 3.5771e+04]
# Fitness: 6.0442886
# Volume L: 2.0828406321502e-06
# Volume C: 2.668e-06
# Delta Vo: 0.14753829
# Delta IL: 0.048708376
# P_l_s1:  1.9045588
# P_l_s2:  1.8943793
# P_l_C:  0.08769508
# P_l_L_Cu:  2.1576555
# Losses Total: 6.0442886
#
# Rank: 36
# Solution (L, C, fsw): [1.5620e-03 6.9000e-05 3.5771e+04]
# Fitness: 6.0442886
# Volume L: 2.0828406321502e-06
# Volume C: 2.668e-06
# Delta Vo: 0.14753829
# Delta IL: 0.048708376
# P_l_s1:  1.9045588
# P_l_s2:  1.8943793
# P_l_C:  0.08769508
# P_l_L_Cu:  2.1576555
# Losses Total: 6.0442886
#
# Rank: 37
# Solution (L, C, fsw): [1.6840e-03 6.9000e-05 3.7466e+04]
# Fitness: 6.045745
# Volume L: 2.0828406321502e-06
# Volume C: 2.668e-06
# Delta Vo: 0.076430455
# Delta IL: 0.04182062
# P_l_s1:  1.9103303
# P_l_s2:  1.9176619
# P_l_C:  0.082948126
# P_l_L_Cu:  2.1348045
# Losses Total: 6.045745
#
# Rank: 38
# Solution (L, C, fsw): [1.637e-03 8.000e-05 3.787e+04]
# Fitness: 6.0800014
# Volume L: 2.0828406321502e-06
# Volume C: 3.335e-06
# Delta Vo: 0.6436588
# Delta IL: 0.055463776
# P_l_s1:  1.9283051
# P_l_s2:  1.9196973
# P_l_C:  0.07461229
# P_l_L_Cu:  2.1573868
# Losses Total: 6.080002
#
# Rank: 39
# Solution (L, C, fsw): [1.637e-03 8.000e-05 3.787e+04]
# Fitness: 6.0800014
# Volume L: 2.0828406321502e-06
# Volume C: 3.335e-06
# Delta Vo: 0.6436588
# Delta IL: 0.055463776
# P_l_s1:  1.9283051
# P_l_s2:  1.9196973
# P_l_C:  0.07461229
# P_l_L_Cu:  2.1573868
# Losses Total: 6.080002
#
# Rank: 40
# Solution (L, C, fsw): [1.2800e-03 8.1000e-05 5.2037e+04]
# Fitness: 6.3217363
# Volume L: 2.0828406321502e-06
# Volume C: 3.586e-06
# Delta Vo: 0.48027283
# Delta IL: 0.061867215
# P_l_s1:  2.0567691
# P_l_s2:  2.054964
# P_l_C:  0.057305187
# P_l_L_Cu:  2.1526973
# Losses Total: 6.3217363
#
# Rank: 41
# Solution (L, C, fsw): [1.2800e-03 8.1000e-05 5.2037e+04]
# Fitness: 6.3217363
# Volume L: 2.0828406321502e-06
# Volume C: 3.586e-06
# Delta Vo: 0.48027283
# Delta IL: 0.061867215
# P_l_s1:  2.0567691
# P_l_s2:  2.054964
# P_l_C:  0.057305187
# P_l_L_Cu:  2.1526973
# Losses Total: 6.3217363

# %% [markdown]
# # Optimization

# %%
import numpy as np
import ga_PD as ga
from joblib import load
import tensorflow as tf
import csv
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

# %%
# Load the machine learning model and scaler
# model = tf.keras.models.load_model(r'E:\ai-power-converter\machine-learning\model_4_128_20_20_20_20.h5')
# model_P_D = tf.keras.models.load_model(r'E:\ai-power-converter\machine-learning\split_model\model_1_256_pd.h5')
# model_P_l_C = tf.keras.models.load_model(r'E:\ai-power-converter\machine-learning\split_model\model_2_128_Plc.h5')
# model_P_l_s1 = tf.keras.models.load_model(r'E:\ai-power-converter\machine-learning\split_model\model_2_128_Pls1.h5')

model_P_D = tf.keras.models.load_model(r'D:\Krishna\ai-power-converter-1\machine-learning\split_model\model_1_256_pd.h5')
model_P_l_C = tf.keras.models.load_model(r'D:\Krishna\ai-power-converter-1\machine-learning\split_model\model_2_128_Plc.h5')
model_P_l_s1 = tf.keras.models.load_model(r'D:\Krishna\ai-power-converter-1\machine-learning\split_model\new\model_2_256_Pls1_Pls2_scaler_12_5.h5')
# model_delta_voltage = tf.keras.models.load_model(r'E:\ai-power-converter\machine-learning\split_model\model_3_256_delta_voltage.h5')
# model_delta_current = tf.keras.models.load_model(r'E:\ai-power-converter\machine-learning\split_model\model_4_64_delta_current.h5')
model_P_l_L_Cu = tf.keras.models.load_model(r'D:\Krishna\ai-power-converter-1\machine-learning\split_model\model_4_256_Pllcu.h5')

model_delta_current = tf.keras.models.load_model(r'D:\Krishna\ai-power-converter-1\machine-learning\split_model\new\model_2_256_delta_current_scaler_11_5.h5')
model_delta_voltage = tf.keras.models.load_model(r'D:\Krishna\ai-power-converter-1\machine-learning\split_model\new\model_4_256_delta_voltage_scaler_11_5.h5')

model_current = tf.keras.models.load_model(r'D:\Krishna\ai-power-converter-1\machine-learning\split_model\new\model_2_256_delta_current_scaler_11_5.h5')
model_voltage = tf.keras.models.load_model(r'D:\Krishna\ai-power-converter-1\machine-learning\split_model\new\model_4_256_delta_voltage_scaler_11_5.h5')


# csv_file_capacitance = r'E:\ai-power-converter\dataset\capacitor_lookup_table.csv'  # Replace 'your_csv_file.csv' with the path to your CSV file
# csv_file_inductance = r'E:\ai-power-converter\dataset\inductor_lookup_table.csv'

csv_file_capacitance = r'D:\Krishna\ai-power-converter-1\dataset\capacitor_lookup_table.csv'  # Replace 'your_csv_file.csv' with the path to your CSV file
csv_file_inductance = r'D:\Krishna\ai-power-converter-1\dataset\inductor_lookup_table.csv'

# Define constraint values
Vol_lim = 7e-6
Delta_Vo_percent_lim = 1
Delta_IL_percent_lim = 10
Voltage_percent_lim = 12*0.05

# Genetic algorithm parameters
sol_per_pop = 8
num_parents_mating = 4
pop_size = (sol_per_pop, 3)  # We have 3 variables: fs, L, C
num_generations = 10

# Generate initial population
L_range = (30e-6, 2000e-6)  # Range for L
C_range = (30e-6, 200e-6)   # Range for C
fsw_range = (20e3, 200e3)    # Range for fsw
t_dt_range = (0.178e-6, 1e-6) # Range for dead time

num_values = sol_per_pop

# Define custom scaling ranges for each input feature
L_min, L_max = 30e-6, 2000e-6
C_min, C_max = 20e-6, 1000e-6
fsw_min, fsw_max = 20e3, 200e3
t_dt_min, t_dt_max = 0.178e-6, 1e-6

# Define mutation ranges for each parameter
mutation_ranges = [(30e-6, 100e-6), (20e-6, 100e-6), (10, 1000), (0.001e-6, 0.1e-6)]

# # Create arrays of discrete L, C, and fsw values within the specified ranges
L_values = np.linspace(L_range[0], L_range[1], num=num_values)
C_values = np.linspace(C_range[0], C_range[1], num=num_values)
t_dt_values = np.linspace(t_dt_range[0], t_dt_range[1], num=num_values)

# Round the values to the desired number of decimal places
L_values = np.around(L_values, decimals=6)
C_values = np.around(C_values, decimals=6)
t_dt_values = np.around(t_dt_values, decimals=9)

fsw_values = np.linspace(fsw_range[0], fsw_range[1], num=num_values, dtype=int)

initial_population = np.column_stack((L_values, C_values, fsw_values, t_dt_values))

# %% [markdown]
# # Function

# %% [markdown]
# ## Scaling

# %%
def scale_input_values(input_values):

    input_values_scaled = np.zeros_like(input_values, dtype=float)  # Initialize scaled data array

    # Scale L
    input_values_scaled[0] = (input_values[0] - L_min) / (L_max - L_min)

    # Scale C
    input_values_scaled[1] = (input_values[1] - C_min) / (C_max - C_min)

    # Scale fsw
    input_values_scaled[2] = (input_values[2] - fsw_min) / (fsw_max - fsw_min)

    input_values_scaled[3] = (input_values[3] - t_dt_min) / (t_dt_max - t_dt_min)
    # Make predictions using the model

    # Reshape the input data to match the expected shape of the model
    input_values_reshaped = input_values_scaled.reshape((1, -1))

    return input_values_reshaped


def inverse_scale_input_values(scaled_input_values):
    # Reshape the scaled input values to the original shape
    input_values_scaled = scaled_input_values.reshape(-1)

    # Reverse scaling for L
    input_values_scaled[0] = input_values_scaled[0] * (L_max - L_min) + L_min

    # Reverse scaling for C
    input_values_scaled[1] = input_values_scaled[1] * (C_max - C_min) + C_min

    # Reverse scaling for fsw
    input_values_scaled[2] = input_values_scaled[2] * (fsw_max - fsw_min) + fsw_min

    # Reverse scaling for t_dt
    input_values_scaled[3] = input_values_scaled[3] * (t_dt_max - t_dt_min) + t_dt_min

    # Reshape the input data to match the original shape
    input_values_reshaped = input_values_scaled.reshape((1, -1))

    return input_values_reshaped

# %%
# Generate some sample input data
input_values = [1500e-6, 700e-6, 120e3, 0.6e-6]

# Scale the input data
scaled_input = scale_input_values(input_values)
print("Scaled Input Values:")
print(scaled_input)

# Inverse scale the scaled input data
inverse_scaled_input = inverse_scale_input_values(scaled_input)
print("\nInverse Scaled Input Values:")
print(inverse_scaled_input)

# Compare with original input data
print("\nOriginal Input Values:")
print(input_values)
# Out:
# Scaled Input Values:
# [[0.74619289 0.69387755 0.55555556 0.513382  ]]
#
# Inverse Scaled Input Values:
# [[1.5e-03 7.0e-04 1.2e+05 6.0e-07]]
#
# Original Input Values:
# [0.0015, 0.0007, 120000.0, 6e-07]

# %%
def custom_scaling_minmax(X):
    scaled_features = []  # List to store scaled features
    
    # Define custom minimum and maximum values for each feature
    feature_ranges = {
        'L': (30e-6, 2000e-6),
        'C': (20e-6, 1000e-6),
        'fsw': (20e3, 200e3),
        't_dt': (0.178e-6, 1e-6)
    }

    for i, feature_name in enumerate(['L', 'C', 'fsw', 't_dt']):
        # Extract min and max values for the current feature
        feature_min, feature_max = feature_ranges[feature_name]
        
        # Define MinMaxScaler with custom input range
        scaler = MinMaxScaler(feature_range=(0, 1))
        scaler.fit([[feature_min], [feature_max]])
        
        # Transform the current feature using the scaler
        # scaled_feature = scaler.transform(X[:, i].reshape(-1, 1))
        
        scaled_feature = scaler.transform(X.reshape(-1, 1))
        # Append the scaled feature to the list
        scaled_features.append(scaled_feature)
    
    # Combine the scaled features into a single array
    X_scaled = np.hstack(scaled_features)
    
    return X_scaled

# %%
import pandas as pd
df_data = pd.read_csv(r"D:\Krishna\ai-power-converter-1\simulation_results_new_20_20_20_20.csv")

y_delta_current_1 = df_data[["delta_current"]].values  # Adjust column names as per your dataset
y_delta_voltage_1 = df_data[["delta_voltage"]].values
y_Pl_s1_1 = df_data[["Pl_s1"]].values
y_voltage_1 = df_data[["voltage"]].values  # Adjust column names as per your dataset

scaler_y_delta_current = MinMaxScaler(feature_range=(0, 1))
scaler_y_delta_voltage = MinMaxScaler(feature_range=(0, 1))
scaler_y_Pl_s1 = MinMaxScaler(feature_range=(0, 1))
scaler_voltage = MinMaxScaler(feature_range=(0, 1))

# Fit the scaler to your target variable and transform it
y_scaled_delta_current_1 = scaler_y_delta_current.fit_transform(y_delta_current_1)
y_scaled_delta_voltage_1 = scaler_y_delta_voltage.fit_transform(y_delta_voltage_1)
y_scaled_Pl_s1_1 = scaler_y_Pl_s1.fit_transform(y_Pl_s1_1)
y_scaled_voltage_1 = scaler_voltage.fit_transform(y_voltage_1)

# %% [markdown]
# ## Calculate Fitness

# %%
def calculate_fitness(individual):

    input_values_scaled = scale_input_values(individual)

    # prediction = model.predict(input_values_scaled, verbose=0)
    
    # Extract predictions from the model output
    P_l_s1_ori = model_P_l_s1.predict(input_values_scaled, verbose=0)    
    P_l_s1 = scaler_y_Pl_s1.inverse_transform(P_l_s1_ori)
    
    P_l_s2 = P_l_s1
    P_l_C = model_P_l_C.predict(input_values_scaled, verbose=0)
    P_l_L_Cu = model_P_l_L_Cu.predict(input_values_scaled, verbose=0)
    P_D = model_P_D.predict(input_values_scaled, verbose=0)

    # P_l_s1 = prediction[0][2]
    # P_l_s2 = prediction[0][3]
    # P_l_C = prediction[0][4]
    # P_l_L_Cu = prediction[0][5]
    # P_D = prediction[0][6]
    
    # Calculate the objective function value based on the given equation
    objective_value = P_l_s1 + P_l_s2 + P_l_L_Cu + P_l_C + P_D
    
    return objective_value

# %% [markdown]
# ## Search Volume

# %% [markdown]
# ### Capacitance

# %%
def search_volume_capacitance(capacitance, csv_file):
    with open(csv_file, mode='r') as file:
        reader = csv.DictReader(file)
        capacitance_values = []
        volume_values = []
        for row in reader:
            capacitance_values.append(float(row['Capacitance']))
            volume_values.append(float(row['Total Volume']))
        
        # Find the index of the nearest capacitance value
        nearest_idx = np.abs(np.array(capacitance_values) - capacitance).argmin()
        nearest_capacitance = capacitance_values[nearest_idx]
        nearest_volume = volume_values[nearest_idx]
        
        return nearest_capacitance, nearest_volume

# %% [markdown]
# ### Inductance

# %%
def search_volume_inductance(inductance, csv_file):
    with open(csv_file, mode='r') as file:
        reader = csv.DictReader(file)
        inductance_values = []
        volume_values = []
        for row in reader:
            inductance_values.append(float(row['Inductance']))
            volume_values.append(float(row['Volume']))
        
        # Find the index of the nearest inductance value
        nearest_idx = np.abs(np.array(inductance_values) - inductance).argmin()
        nearest_inductance = inductance_values[nearest_idx]
        nearest_volume = volume_values[nearest_idx]
        
        return nearest_inductance, nearest_volume

# %% [markdown]
# ## Check Constraints

# %%
feature_ranges = {
    'L': (30e-6, 2000e-6),  # Custom range for feature L
    'C': (20e-6, 1000e-6),   # Custom range for feature C
    'fsw': (20e3, 200e3),    # Custom range for feature fsw
    't_dt': (0.178e-6, 1e-6) # Custom range for feature t_dt
}



# Define the constraints function
def check_constraints(individual):
    L = individual[0]
    C = individual[1]
    fs = individual[2]
    t_dt = individual[3]
    
    # Define the constraint values
    nearest_C, Vol_C  = search_volume_capacitance(C, csv_file_capacitance) # Define Vol_L based on your problem-specific requirements
    nearest_L, Vol_L  = search_volume_inductance(L, csv_file_inductance)

    # Prepare input values for prediction

    input_values = np.array([L, C, fs, t_dt])
    # Apply Min-Max normalization separately for each input feature
    
    print("input_values", input_values)
    input_values_scaled = scale_input_values(input_values)
    # input_values_scaled = scaler_y_new_20_20_20_20.transform(input_values)
    print("scaled", input_values_scaled)
    # prediction = model.predict(input_values_scaled, verbose = 0)

    # Extract predictions from the model output
    Delta_IL_percent_ori = model_delta_current.predict(input_values_scaled, verbose = 0)
    Delta_Vo_percent_ori = model_delta_voltage.predict(input_values_scaled, verbose = 0)

    Voltage_ori = model_voltage.predict(input_values_scaled, verbose = 0)
    
    
    # Delta_IL_percent = prediction[0][0]
    # Delta_Vo_percent = prediction[0][1]
    # print("Shape \n")
    # print(Delta_IL_percent_ori.shape)
    # print(Delta_Vo_percent_ori.shape)
    # scaler_y_new_loaded = load(r'E:\ai-power-converter\machine-learning\scaler_y_new_20_20_20_20.joblib')
    
    # # Fit the scaler with the training data
    # scaler_y_new_loaded.fit([[feature_min], [feature_max]])
    # Inverse transform the predictions
    Delta_IL_percent = scaler_y_delta_current.inverse_transform(Delta_IL_percent_ori)
    Delta_Vo_percent = scaler_y_delta_voltage.inverse_transform(Delta_Vo_percent_ori)

    print("delta_IL inverse",Delta_IL_percent)
    print("delta_Vo inverse",Delta_Vo_percent)

    # Delta_IL_percent = inverse_scale_input_values(Delta_IL_percent_ori)
    # Delta_Vo_percent = inverse_scale_input_values(Delta_Vo_percent_ori)

    # Define the acceptable voltage range
    acceptable_voltage_range = (12 - 0.05 * 12, 12 + 0.05 * 12)

    # Check if Voltage_ori is within the acceptable voltage range


    # Check if constraints are satisfied
    constraint1 = Vol_C + Vol_L  <= Vol_lim
    constraint2 = Delta_Vo_percent <= Delta_Vo_percent_lim
    constraint3 = Delta_IL_percent <= Delta_IL_percent_lim
    constraint4 = (Voltage_ori >= acceptable_voltage_range[0]) and (Voltage_ori <= acceptable_voltage_range[1])
 
    
    # return constraint1 and constraint2 and constraint3
    return constraint1 and constraint2 and constraint3 and constraint4

# %% [markdown]
# # Genetic Algorithm

# %%
# Genetic Algorithm optimization
best_outputs = []
best_solutions = []  # Store the best solution for each generation
best_fitnesses = []  # Store the best fitness for each generation
new_population = initial_population

for generation in range(num_generations):
    print("Generation : ", generation)
    
    # Measuring the fitness of each chromosome in the population.
    fitness_values = []
    delta_IL_percent_values = []
    delta_Vo_percent_values = []
    for individual in new_population:
        fitness_value = calculate_fitness(individual)
        print('fitness value', fitness_value)
        fitness_values.append(fitness_value)

    fitness = np.array(fitness_values)
    print('cek fitness', fitness)

    print("Population", new_population)
    best_outputs.append(np.min(fitness))
    print("Best result:", np.min(fitness))

    # Find the index of the best solution in this generation
    best_solution_idx = np.argmin(fitness)
    print("Best solution index:", best_solution_idx)

    # Retrieve the best solution from the population
    best_solution = new_population[best_solution_idx].copy()  # Copy the best solution
    print("Best solution:", best_solution)

    # Append the current best solution to the list of best solutions
    best_solutions.append(best_solution.copy())  # Append a copy of the best solution
    print("Best solutions array:", best_solutions)

    # Append the corresponding fitness value to the list of best fitnesses
    best_fitness = fitness[best_solution_idx][0]
    # best_fitness = fitness[best_solution_idx][0]

    best_fitnesses.append(best_fitness[0])
    print("Best fitness:", best_fitness)
    print("Best fitnesses:", best_fitnesses)



    # Check and enforce constraints
    for i in range(sol_per_pop):
        if not check_constraints(new_population[i]):
            # Regenerate individual until it satisfies the constraints
            while not check_constraints(new_population[i]):
                # Generate all possible values within the specified range with the desired increment
                L_values_all = np.arange(L_range[0], L_range[1] + 1e-6, 1e-6)
                C_values_all = np.arange(C_range[0], C_range[1] + 1e-6, 1e-6)
                t_dt_values_all = np.arange(t_dt_range[0], t_dt_range[1] + 0.001e-6, 0.001e-6)

                    
                # Generate new random values for fsw, L, and C
                new_L = np.random.choice(L_values_all, 1, replace=False)
                new_C = np.random.choice(C_values_all, 1, replace=False)
                new_fsw = np.random.randint(fsw_range[0], fsw_range[1] + 1, size=1)
                new_t_dt = np.random.choice(t_dt_values_all, 1, replace=False)

                new_population[i] = [new_L[0], new_C[0], new_fsw[0], new_t_dt[0]]
                # new_population[i] = generate_feasible_solution(L_range, C_range, fsw_range)


    # Selecting the best parents in the population for mating.
    parents = ga.select_mating_pool(new_population, fitness, num_parents_mating)
    print("Parents")
    print(parents)

    # Generating next generation using crossover.
    offspring_crossover = ga.crossover(parents, offspring_size=(pop_size[0]-parents.shape[0], 4))
    print("Crossover")
    print(offspring_crossover)

    # Adding some variations to the offspring using mutation.
    # offspring_mutation = ga.mutation(offspring_crossover, 2)
    # offspring_mutation = ga.mutation(offspring_crossover, mutation_ranges, 1)
    offspring_mutation = ga.mutation(offspring_crossover, mutation_ranges, L_range, C_range, fsw_range, t_dt_range, 2)
    print("Mutation")
    print(offspring_mutation)

    # Creating the new population based on the parents and offspring.
    new_population[0:parents.shape[0], :] = parents
    new_population[parents.shape[0]:, :] = offspring_mutation

# Getting the best solution after iterating finishing all generations.
# At first, the fitness is calculated for each solution in the final generation.
fitness_values = []

for individual in new_population:
    fitness_value= calculate_fitness(individual)
    fitness_values.append(fitness_value)

fitness = np.array(fitness_values)


# Then return the index of that solution corresponding to the best fitness.
# best_match_idx = np.where(fitness == np.min(fitness))
best_match_idx = np.where(fitness == np.min(fitness))[0]

print("Best solution : ", new_population[best_match_idx, :])
print("cek")
print("Best solution fitness : ", fitness[best_match_idx])
print("ceki")

plt.plot(best_outputs)
plt.xlabel("Generation")
plt.ylabel("Fitness")
plt.show()
# Out:
# Generation :  0
# WARNING:tensorflow:5 out of the last 92767 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000019D65296FC0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# fitness value [[6.438211]]
# fitness value [[4.9396896]]
# fitness value [[5.3276353]]
# fitness value [[5.1282215]]
# fitness value [[4.8870144]]
# fitness value [[4.2312365]]
# fitness value [[3.1995285]]
# fitness value [[1.567535]]
# cek fitness [[[6.438211 ]]
#
#  [[4.9396896]]
#
#  [[5.3276353]]
#
#  [[5.1282215]]
#
#  [[4.8870144]]
#
#  [[4.2312365]]
#
#  [[3.1995285]]
#
#  [[1.567535 ]]]
# Population [[3.00000e-05 3.00000e-05 2.00000e+04 1.78000e-07]
#  [3.11000e-04 5.40000e-05 4.57140e+04 2.95000e-07]
#  [5.93000e-04 7.90000e-05 7.14280e+04 4.13000e-07]
#  [8.74000e-04 1.03000e-04 9.71420e+04 5.30000e-07]
#  [1.15600e-03 1.27000e-04 1.22857e+05 6.48000e-07]
#  [1.43700e-03 1.51000e-04 1.48571e+05 7.65000e-07]
#  [1.71900e-03 1.76000e-04 1.74285e+05 8.83000e-07]
#  [2.00000e-03 2.00000e-04 2.00000e+05 1.00000e-06]]
# Best result: 1.567535
# Best solution index: 7
# Best solution: [2.e-03 2.e-04 2.e+05 1.e-06]
# Best solutions array: [array([2.e-03, 2.e-04, 2.e+05, 1.e-06])]
# Best fitness: [1.567535]
# Best fitnesses: [1.567535]
# input_values [3.00e-05 3.00e-05 2.00e+04 1.78e-07]
# scaled [[0.         0.01020408 0.         0.        ]]
# delta_IL ori [[0.9713404]]
# delta_Vo ori [[0.40921995]]
# delta_IL inverse [[797.6914]]
# delta_Vo inverse [[22.104929]]
# input_values [3.00e-05 3.00e-05 2.00e+04 1.78e-07]
# scaled [[0.         0.01020408 0.         0.        ]]
# delta_IL ori [[0.9713404]]
# delta_Vo ori [[0.40921995]]
# delta_IL inverse [[797.6914]]
# delta_Vo inverse [[22.104929]]
# input_values [1.3690e-03 4.4000e-05 4.7684e+04 4.1400e-07]
# scaled [[0.67969543 0.0244898  0.1538     0.28710462]]
# delta_IL ori [[0.00535811]]
# delta_Vo ori [[0.00022405]]
# delta_IL inverse [[5.462672]]
# delta_Vo inverse [[0.24019846]]
# input_values [3.1100e-04 5.4000e-05 4.5714e+04 2.9500e-07]
# scaled [[0.14263959 0.03469388 0.14285556 0.14233577]]
# delta_IL ori [[0.03530718]]
# delta_Vo ori [[0.01921267]]
# delta_IL inverse [[30.024729]]
# delta_Vo inverse [[1.255321]]
# input_values [3.1100e-04 5.4000e-05 4.5714e+04 2.9500e-07]
# scaled [[0.14263959 0.03469388 0.14285556 0.14233577]]
# delta_IL ori [[0.03530718]]
# delta_Vo ori [[0.01921267]]
# delta_IL inverse [[30.024729]]
# delta_Vo inverse [[1.255321]]
# input_values [8.9100e-04 1.7900e-04 6.8135e+04 5.5800e-07]
# scaled [[0.43705584 0.1622449  0.26741667 0.4622871 ]]
# delta_IL ori [[0.02440951]]
# delta_Vo ori [[0.16838758]]
# delta_IL inverse [[21.087255]]
# delta_Vo inverse [[9.230143]]
# input_values [1.77800e-03 1.27000e-04 1.54204e+05 7.60000e-07]
# scaled [[0.88730964 0.10918367 0.74557778 0.7080292 ]]
# delta_IL ori [[0.00279785]]
# delta_Vo ori [[0.03518505]]
# delta_IL inverse [[3.3629324]]
# delta_Vo inverse [[2.1091974]]
# input_values [1.4310e-03 1.2800e-04 6.4714e+04 2.0200e-07]
# scaled [[0.71116751 0.11020408 0.24841111 0.02919708]]
# delta_IL ori [[0.00804799]]
# delta_Vo ori [[0.03246969]]
# delta_IL inverse [[7.6687207]]
# delta_Vo inverse [[1.9640354]]
# input_values [1.18700e-03 1.79000e-04 1.03089e+05 4.79000e-07]
# scaled [[0.58730964 0.1622449  0.46160556 0.36618005]]
# delta_IL ori [[0.01707243]]
# delta_Vo ori [[0.03828665]]
# delta_IL inverse [[15.069914]]
# delta_Vo inverse [[2.2750072]]
# input_values [1.4450e-03 1.5800e-04 2.2537e+04 6.4700e-07]
# scaled [[0.71827411 0.14081633 0.01409444 0.57055961]]
# delta_IL ori [[0.02075184]]
# delta_Vo ori [[0.04804879]]
# delta_IL inverse [[18.087496]]
# delta_Vo inverse [[2.7968872]]
# input_values [8.87000e-04 1.39000e-04 1.01475e+05 8.41000e-07]
# scaled [[0.43502538 0.12142857 0.45263889 0.80656934]]
# delta_IL ori [[0.01213191]]
# delta_Vo ori [[0.05448038]]
# delta_IL inverse [[11.018054]]
# delta_Vo inverse [[3.1407168]]
# input_values [1.32000e-03 1.34000e-04 1.08014e+05 9.02000e-07]
# scaled [[0.65482234 0.11632653 0.48896667 0.88077859]]
# delta_IL ori [[0.00796326]]
# delta_Vo ori [[0.04618423]]
# delta_IL inverse [[7.599226]]
# delta_Vo inverse [[2.6972082]]
# input_values [1.3200e-04 6.1000e-05 9.1451e+04 7.8000e-07]
# scaled [[0.05177665 0.04183673 0.39695    0.7323601 ]]
# delta_IL ori [[0.04277563]]
# delta_Vo ori [[0.05390153]]
# delta_IL inverse [[36.14981]]
# delta_Vo inverse [[3.1097715]]
# input_values [9.11000e-04 9.20000e-05 1.38003e+05 9.54000e-07]
# scaled [[0.44720812 0.07346939 0.65557222 0.94403893]]
# delta_IL ori [[0.00472936]]
# delta_Vo ori [[0.02539077]]
# delta_IL inverse [[4.9470196]]
# delta_Vo inverse [[1.5855995]]
# input_values [1.8700e-04 1.3000e-04 1.5429e+05 6.7400e-07]
# scaled [[0.07969543 0.1122449  0.74605556 0.60340633]]
# delta_IL ori [[0.02324168]]
# delta_Vo ori [[0.03843172]]
# delta_IL inverse [[20.129486]]
# delta_Vo inverse [[2.2827628]]
# input_values [1.94900e-03 6.50000e-05 1.83867e+05 5.52000e-07]
# scaled [[0.97411168 0.04591837 0.91037222 0.45498783]]
# delta_IL ori [[0.0001933]]
# delta_Vo ori [[0.0037683]]
# delta_IL inverse [[1.2268685]]
# delta_Vo inverse [[0.42967254]]
# input_values [5.8200e-04 9.0000e-05 7.6202e+04 9.8900e-07]
# scaled [[0.28020305 0.07142857 0.31223333 0.986618  ]]
# delta_IL ori [[0.01195648]]
# delta_Vo ori [[0.01996095]]
# delta_IL inverse [[10.874183]]
# delta_Vo inverse [[1.2953237]]
# input_values [1.5420e-03 1.5200e-04 3.3194e+04 5.3100e-07]
# scaled [[0.76751269 0.13469388 0.0733     0.42944039]]
# delta_IL ori [[0.01418142]]
# delta_Vo ori [[0.05393089]]
# delta_IL inverse [[12.698915]]
# delta_Vo inverse [[3.111341]]
# input_values [4.73000e-04 7.40000e-05 1.58552e+05 5.96000e-07]
# scaled [[0.2248731  0.05510204 0.76973333 0.50851582]]
# delta_IL ori [[0.00623868]]
# delta_Vo ori [[0.01522292]]
# delta_IL inverse [[6.1848555]]
# delta_Vo inverse [[1.0420312]]
# input_values [3.16000e-04 9.80000e-05 1.51048e+05 9.61000e-07]
# scaled [[0.14517766 0.07959184 0.72804444 0.95255474]]
# delta_IL ori [[0.01333796]]
# delta_Vo ori [[0.03498231]]
# delta_IL inverse [[12.007169]]
# delta_Vo inverse [[2.0983586]]
# input_values [5.2600e-04 9.7000e-05 5.6861e+04 3.5200e-07]
# scaled [[0.25177665 0.07857143 0.20478333 0.21167883]]
# delta_IL ori [[0.01734078]]
# delta_Vo ori [[0.02085626]]
# delta_IL inverse [[15.289992]]
# delta_Vo inverse [[1.3431871]]
# input_values [3.55000e-04 1.34000e-04 1.63792e+05 5.44000e-07]
# scaled [[0.16497462 0.11632653 0.79884444 0.44525547]]
# delta_IL ori [[0.0162937]]
# delta_Vo ori [[0.04876667]]
# delta_IL inverse [[14.431251]]
# delta_Vo inverse [[2.8352642]]
# input_values [1.87100e-03 3.20000e-05 1.85077e+05 6.24000e-07]
# scaled [[0.93451777 0.0122449  0.91709444 0.54257908]]
# delta_IL ori [[2.3967275e-05]]
# delta_Vo ori [[0.00028041]]
# delta_IL inverse [[1.0879972]]
# delta_Vo inverse [[0.24321161]]
# input_values [5.9300e-04 7.9000e-05 7.1428e+04 4.1300e-07]
# scaled [[0.2857868  0.06020408 0.28571111 0.28588808]]
# delta_IL ori [[0.01176841]]
# delta_Vo ori [[0.01065314]]
# delta_IL inverse [[10.719936]]
# delta_Vo inverse [[0.7977327]]
# input_values [5.9300e-04 7.9000e-05 7.1428e+04 4.1300e-07]
# scaled [[0.2857868  0.06020408 0.28571111 0.28588808]]
# delta_IL ori [[0.01176841]]
# delta_Vo ori [[0.01065314]]
# delta_IL inverse [[10.719936]]
# delta_Vo inverse [[0.7977327]]
# input_values [2.2600e-04 1.2900e-04 8.0998e+04 3.3600e-07]
# scaled [[0.09949239 0.11122449 0.33887778 0.19221411]]
# delta_IL ori [[0.02947395]]
# delta_Vo ori [[0.02810774]]
# delta_IL inverse [[25.240742]]
# delta_Vo inverse [[1.7308478]]
# input_values [7.66000e-04 8.70000e-05 1.35551e+05 3.21000e-07]
# scaled [[0.37360406 0.06836735 0.64195    0.17396594]]
# delta_IL ori [[0.00587653]]
# delta_Vo ori [[0.01210208]]
# delta_IL inverse [[5.8878474]]
# delta_Vo inverse [[0.8751924]]
# input_values [3.17000e-04 1.55000e-04 1.23384e+05 2.98000e-07]
# scaled [[0.14568528 0.1377551  0.57435556 0.1459854 ]]
# delta_IL ori [[0.02285453]]
# delta_Vo ori [[0.04463271]]
# delta_IL inverse [[19.811972]]
# delta_Vo inverse [[2.6142647]]
# input_values [1.69600e-03 6.70000e-05 1.43377e+05 9.17000e-07]
# scaled [[0.84568528 0.04795918 0.68542778 0.89902676]]
# delta_IL ori [[0.00134216]]
# delta_Vo ori [[0.00592578]]
# delta_IL inverse [[2.1690803]]
# delta_Vo inverse [[0.54501027]]
# input_values [8.7400e-04 1.0300e-04 9.7142e+04 5.3000e-07]
# scaled [[0.4284264  0.08469388 0.42856667 0.42822384]]
# delta_IL ori [[0.00720747]]
# delta_Vo ori [[0.03089393]]
# delta_IL inverse [[6.9793863]]
# delta_Vo inverse [[1.8797961]]
# input_values [8.7400e-04 1.0300e-04 9.7142e+04 5.3000e-07]
# scaled [[0.4284264  0.08469388 0.42856667 0.42822384]]
# delta_IL ori [[0.00720747]]
# delta_Vo ori [[0.03089393]]
# delta_IL inverse [[6.9793863]]
# delta_Vo inverse [[1.8797961]]
# input_values [4.48000e-04 1.13000e-04 1.06354e+05 4.57000e-07]
# scaled [[0.21218274 0.09489796 0.47974444 0.33941606]]
# delta_IL ori [[0.01406674]]
# delta_Vo ori [[0.03251033]]
# delta_IL inverse [[12.604859]]
# delta_Vo inverse [[1.9662077]]
# input_values [3.8100e-04 3.6000e-05 6.1193e+04 4.0400e-07]
# scaled [[0.17817259 0.01632653 0.22885    0.27493917]]
# delta_IL ori [[0.01852284]]
# delta_Vo ori [[0.02650966]]
# delta_IL inverse [[16.259434]]
# delta_Vo inverse [[1.6454151]]
# input_values [2.3300e-04 1.9000e-04 1.8212e+05 5.6400e-07]
# scaled [[0.10304569 0.17346939 0.90066667 0.46958637]]
# delta_IL ori [[0.02487251]]
# delta_Vo ori [[0.04836511]]
# delta_IL inverse [[21.466969]]
# delta_Vo inverse [[2.813797]]
# input_values [1.850e-03 1.210e-04 9.255e+04 5.890e-07]
# scaled [[0.92385787 0.10306122 0.40305556 0.5       ]]
# delta_IL ori [[0.00347433]]
# delta_Vo ori [[0.0291355]]
# delta_IL inverse [[3.9177337]]
# delta_Vo inverse [[1.7857909]]
# input_values [9.78000e-04 1.86000e-04 1.43451e+05 2.93000e-07]
# scaled [[0.48121827 0.16938776 0.68583889 0.13990268]]
# delta_IL ori [[0.02131311]]
# delta_Vo ori [[0.12899841]]
# delta_IL inverse [[18.547808]]
# delta_Vo inverse [[7.1244164]]
# input_values [1.2890e-03 9.2000e-05 1.8483e+05 5.4800e-07]
# scaled [[0.63908629 0.07346939 0.91572222 0.45012165]]
# delta_IL ori [[0.00183597]]
# delta_Vo ori [[0.01216977]]
# delta_IL inverse [[2.5740724]]
# delta_Vo inverse [[0.8788113]]
# input_values [1.15600e-03 1.27000e-04 1.22857e+05 6.48000e-07]
# scaled [[0.5715736  0.10918367 0.57142778 0.57177616]]
# delta_IL ori [[0.00705377]]
# delta_Vo ori [[0.05282911]]
# delta_IL inverse [[6.85333]]
# delta_Vo inverse [[3.0524404]]
# input_values [1.15600e-03 1.27000e-04 1.22857e+05 6.48000e-07]
# scaled [[0.5715736  0.10918367 0.57142778 0.57177616]]
# delta_IL ori [[0.00705377]]
# delta_Vo ori [[0.05282911]]
# delta_IL inverse [[6.85333]]
# delta_Vo inverse [[3.0524404]]
# input_values [1.56400e-03 6.50000e-05 1.73542e+05 4.16000e-07]
# scaled [[0.7786802  0.04591837 0.85301111 0.28953771]]
# delta_IL ori [[0.00088071]]
# delta_Vo ori [[0.00445508]]
# delta_IL inverse [[1.7906351]]
# delta_Vo inverse [[0.46638736]]
# input_values [1.3600e-03 7.7000e-05 2.8246e+04 2.2600e-07]
# scaled [[0.6751269  0.05816327 0.04581111 0.05839416]]
# delta_IL ori [[0.01203149]]
# delta_Vo ori [[0.00466419]]
# delta_IL inverse [[10.935699]]
# delta_Vo inverse [[0.4775662]]
# input_values [8.0800e-04 1.1900e-04 3.2363e+04 6.5200e-07]
# scaled [[0.39492386 0.10102041 0.06868333 0.57664234]]
# delta_IL ori [[0.0201887]]
# delta_Vo ori [[0.04555311]]
# delta_IL inverse [[17.625654]]
# delta_Vo inverse [[2.663469]]
# input_values [1.01700e-03 1.58000e-04 1.88753e+05 7.23000e-07]
# scaled [[0.50101523 0.14081633 0.93751667 0.66301703]]
# delta_IL ori [[0.0128183]]
# delta_Vo ori [[0.09622044]]
# delta_IL inverse [[11.580978]]
# delta_Vo inverse [[5.372121]]
# input_values [8.10000e-05 1.58000e-04 1.22848e+05 4.16000e-07]
# scaled [[0.02588832 0.14081633 0.57137778 0.28953771]]
# delta_IL ori [[0.06089972]]
# delta_Vo ori [[0.04249559]]
# delta_IL inverse [[51.01388]]
# delta_Vo inverse [[2.5000155]]
# input_values [5.88000e-04 4.00000e-05 1.08271e+05 5.57000e-07]
# scaled [[0.28324873 0.02040816 0.49039444 0.46107056]]
# delta_IL ori [[0.00701591]]
# delta_Vo ori [[0.01545744]]
# delta_IL inverse [[6.8222837]]
# delta_Vo inverse [[1.0545688]]
# input_values [6.6800e-04 1.2000e-04 3.3115e+04 5.5700e-07]
# scaled [[0.32385787 0.10204082 0.07286111 0.46107056]]
# delta_IL ori [[0.02427654]]
# delta_Vo ori [[0.03820242]]
# delta_IL inverse [[20.9782]]
# delta_Vo inverse [[2.2705045]]
# input_values [1.5460e-03 4.9000e-05 1.3028e+05 2.8100e-07]
# scaled [[0.76954315 0.02959184 0.61266667 0.12530414]]
# delta_IL ori [[0.00114756]]
# delta_Vo ori [[0.00054274]]
# delta_IL inverse [[2.0094883]]
# delta_Vo inverse [[0.2572358]]
# input_values [1.53900e-03 9.70000e-05 1.98619e+05 9.51000e-07]
# scaled [[0.76598985 0.07857143 0.99232778 0.94038929]]
# delta_IL ori [[0.00133694]]
# delta_Vo ori [[0.02648065]]
# delta_IL inverse [[2.1648028]]
# delta_Vo inverse [[1.6438639]]
# input_values [4.78000e-04 1.14000e-04 1.47442e+05 3.93000e-07]
# scaled [[0.22741117 0.09591837 0.70801111 0.26155718]]
# delta_IL ori [[0.0113937]]
# delta_Vo ori [[0.03200862]]
# delta_IL inverse [[10.41263]]
# delta_Vo inverse [[1.9393867]]
# input_values [1.36000e-04 6.30000e-05 1.57853e+05 6.30000e-07]
# scaled [[0.05380711 0.04387755 0.76585    0.54987835]]
# delta_IL ori [[0.02577887]]
# delta_Vo ori [[0.05869178]]
# delta_IL inverse [[22.210299]]
# delta_Vo inverse [[3.3658564]]
# input_values [1.23800e-03 1.51000e-04 1.40306e+05 6.23000e-07]
# scaled [[0.61319797 0.13367347 0.66836667 0.54136253]]
# delta_IL ori [[0.01090194]]
# delta_Vo ori [[0.052305]]
# delta_IL inverse [[10.009322]]
# delta_Vo inverse [[3.024422]]
# input_values [1.9440e-03 5.0000e-05 2.1819e+04 7.0700e-07]
# scaled [[0.9715736  0.03061224 0.01010556 0.64355231]]
# delta_IL ori [[0.00931312]]
# delta_Vo ori [[2.3228537e-05]]
# delta_IL inverse [[8.706284]]
# delta_Vo inverse [[0.22946274]]
# input_values [1.2800e-03 1.3400e-04 4.6028e+04 7.2800e-07]
# scaled [[0.63451777 0.11632653 0.1446     0.66909976]]
# delta_IL ori [[0.01186]]
# delta_Vo ori [[0.05047505]]
# delta_IL inverse [[10.795054]]
# delta_Vo inverse [[2.9265933]]
# input_values [1.25000e-03 9.60000e-05 1.83496e+05 5.34000e-07]
# scaled [[0.61928934 0.07755102 0.90831111 0.43309002]]
# delta_IL ori [[0.00219258]]
# delta_Vo ori [[0.01413741]]
# delta_IL inverse [[2.8665366]]
# delta_Vo inverse [[0.98400015]]
# input_values [1.6280e-03 1.3300e-04 5.1677e+04 7.2900e-07]
# scaled [[0.81116751 0.11530612 0.17598333 0.6703163 ]]
# delta_IL ori [[0.00886205]]
# delta_Vo ori [[0.02727183]]
# delta_IL inverse [[8.336349]]
# delta_Vo inverse [[1.6861604]]
# input_values [1.39500e-03 1.50000e-04 1.78651e+05 7.83000e-07]
# scaled [[0.6928934  0.13265306 0.88139444 0.73600973]]
# delta_IL ori [[0.0083794]]
# delta_Vo ori [[0.0309959]]
# delta_IL inverse [[7.9405184]]
# delta_Vo inverse [[1.8852476]]
# input_values [1.9840e-03 1.6200e-04 4.4857e+04 7.7000e-07]
# scaled [[0.99187817 0.14489796 0.13809444 0.72019465]]
# delta_IL ori [[0.01130261]]
# delta_Vo ori [[0.11863544]]
# delta_IL inverse [[10.337926]]
# delta_Vo inverse [[6.570416]]
# input_values [2.82000e-04 1.44000e-04 1.56048e+05 3.93000e-07]
# scaled [[0.12791878 0.12653061 0.75582222 0.26155718]]
# delta_IL ori [[0.01961313]]
# delta_Vo ori [[0.03637607]]
# delta_IL inverse [[17.153606]]
# delta_Vo inverse [[2.1728687]]
# input_values [1.96000e-04 1.47000e-04 1.53538e+05 9.93000e-07]
# scaled [[0.08426396 0.12959184 0.74187778 0.99148418]]
# delta_IL ori [[0.02465881]]
# delta_Vo ori [[0.05057693]]
# delta_IL inverse [[21.29171]]
# delta_Vo inverse [[2.93204]]
# input_values [4.67000e-04 1.41000e-04 1.98424e+05 2.64000e-07]
# scaled [[0.22182741 0.12346939 0.99124444 0.10462287]]
# delta_IL ori [[0.01513966]]
# delta_Vo ori [[0.06754153]]
# delta_IL inverse [[13.484795]]
# delta_Vo inverse [[3.8389597]]
# input_values [4.0400e-04 1.7200e-04 1.9159e+05 8.6600e-07]
# scaled [[0.18984772 0.15510204 0.95327778 0.83698297]]
# delta_IL ori [[0.02290976]]
# delta_Vo ori [[0.08836058]]
# delta_IL inverse [[19.857264]]
# delta_Vo inverse [[4.9519362]]
# input_values [1.29000e-04 9.90000e-05 1.54101e+05 6.83000e-07]
# scaled [[0.05025381 0.08061224 0.74500556 0.61435523]]
# delta_IL ori [[0.02904627]]
# delta_Vo ori [[0.04710604]]
# delta_IL inverse [[24.889992]]
# delta_Vo inverse [[2.7464876]]
# input_values [6.2500e-04 1.0800e-04 3.8629e+04 8.0600e-07]
# scaled [[0.30203046 0.08979592 0.10349444 0.76399027]]
# delta_IL ori [[0.0227188]]
# delta_Vo ori [[0.02603071]]
# delta_IL inverse [[19.700653]]
# delta_Vo inverse [[1.6198107]]
# input_values [8.87000e-04 4.60000e-05 1.33161e+05 7.93000e-07]
# scaled [[0.43502538 0.02653061 0.62867222 0.74817518]]
# delta_IL ori [[0.00283659]]
# delta_Vo ori [[0.00715215]]
# delta_IL inverse [[3.3947082]]
# delta_Vo inverse [[0.6105717]]
# input_values [1.43700e-03 1.51000e-04 1.48571e+05 7.65000e-07]
# scaled [[0.7142132  0.13367347 0.71428333 0.71411192]]
# delta_IL ori [[0.00903997]]
# delta_Vo ori [[0.03535249]]
# delta_IL inverse [[8.482268]]
# delta_Vo inverse [[2.1181488]]
# input_values [1.43700e-03 1.51000e-04 1.48571e+05 7.65000e-07]
# scaled [[0.7142132  0.13367347 0.71428333 0.71411192]]
# delta_IL ori [[0.00903997]]
# delta_Vo ori [[0.03535249]]
# delta_IL inverse [[8.482268]]
# delta_Vo inverse [[2.1181488]]
# input_values [1.9260e-03 1.9600e-04 8.2367e+04 2.2100e-07]
# scaled [[0.96243655 0.17959184 0.34648333 0.05231144]]
# delta_IL ori [[0.01778149]]
# delta_Vo ori [[0.13874683]]
# delta_IL inverse [[15.651431]]
# delta_Vo inverse [[7.645562]]
# input_values [1.7460e-03 8.0000e-05 9.4444e+04 2.1700e-07]
# scaled [[0.87106599 0.06122449 0.41357778 0.04744526]]
# delta_IL ori [[0.00204875]]
# delta_Vo ori [[0.00776424]]
# delta_IL inverse [[2.7485797]]
# delta_Vo inverse [[0.64329386]]
# input_values [1.71900e-03 1.76000e-04 1.74285e+05 8.83000e-07]
# scaled [[0.85736041 0.15918367 0.85713889 0.85766423]]
# delta_IL ori [[0.00678252]]
# delta_Vo ori [[0.1455113]]
# delta_IL inverse [[6.6308737]]
# delta_Vo inverse [[8.007188]]
# input_values [1.71900e-03 1.76000e-04 1.74285e+05 8.83000e-07]
# scaled [[0.85736041 0.15918367 0.85713889 0.85766423]]
# delta_IL ori [[0.00678252]]
# delta_Vo ori [[0.1455113]]
# delta_IL inverse [[6.6308737]]
# delta_Vo inverse [[8.007188]]
# input_values [1.3410e-03 3.6000e-05 5.1342e+04 7.5200e-07]
# scaled [[0.66548223 0.01632653 0.17412222 0.69829684]]
# delta_IL ori [[0.0052897]]
# delta_Vo ori [[0.00079263]]
# delta_IL inverse [[5.406571]]
# delta_Vo inverse [[0.27059478]]
# input_values [2.e-03 2.e-04 2.e+05 1.e-06]
# scaled [[1.         0.18367347 1.         1.        ]]
# delta_IL ori [[0.01816381]]
# delta_Vo ori [[0.11377188]]
# delta_IL inverse [[15.964979]]
# delta_Vo inverse [[6.3104124]]
# input_values [2.e-03 2.e-04 2.e+05 1.e-06]
# scaled [[1.         0.18367347 1.         1.        ]]
# delta_IL ori [[0.01816381]]
# delta_Vo ori [[0.11377188]]
# delta_IL inverse [[15.964979]]
# delta_Vo inverse [[6.3104124]]
# input_values [9.7600e-04 5.4000e-05 8.0071e+04 2.4500e-07]
# scaled [[0.48020305 0.03469388 0.33372778 0.08150852]]
# delta_IL ori [[0.005163]]
# delta_Vo ori [[0.00240971]]
# delta_IL inverse [[5.3026567]]
# delta_Vo inverse [[0.35704285]]
# Parents
# [[9.76000e-04 5.40000e-05 8.00710e+04 2.45000e-07]
#  [1.34100e-03 3.60000e-05 5.13420e+04 7.52000e-07]
#  [1.74600e-03 8.00000e-05 9.44440e+04 2.17000e-07]
#  [8.87000e-04 4.60000e-05 1.33161e+05 7.93000e-07]]
# Crossover
# [[9.76000e-04 5.40000e-05 5.13420e+04 7.52000e-07]
#  [1.34100e-03 3.60000e-05 9.44440e+04 2.17000e-07]
#  [1.74600e-03 8.00000e-05 1.33161e+05 7.93000e-07]
#  [8.87000e-04 4.60000e-05 8.00710e+04 2.45000e-07]]
# Mutation
# [[8.24000e-04 3.00000e-05 5.25360e+04 1.78000e-07]
#  [1.29600e-03 5.90000e-05 9.53730e+04 2.17000e-07]
#  [1.74500e-03 1.59000e-04 1.33985e+05 1.00000e-06]
#  [9.02000e-04 1.37000e-04 8.11800e+04 1.78000e-07]]
# Generation :  1
# fitness value [[5.694233]]
# fitness value [[5.194378]]
# fitness value [[6.4315286]]
# fitness value [[4.066306]]
# fitness value [[5.5338244]]
# fitness value [[6.471957]]
# fitness value [[3.4494421]]
# fitness value [[5.693407]]
# cek fitness [[[5.694233 ]]
#
#  [[5.194378 ]]
#
#  [[6.4315286]]
#
#  [[4.066306 ]]
#
#  [[5.5338244]]
#
#  [[6.471957 ]]
#
#  [[3.4494421]]
#
#  [[5.693407 ]]]
# Population [[9.76000e-04 5.40000e-05 8.00710e+04 2.45000e-07]
#  [1.34100e-03 3.60000e-05 5.13420e+04 7.52000e-07]
#  [1.74600e-03 8.00000e-05 9.44440e+04 2.17000e-07]
#  [8.87000e-04 4.60000e-05 1.33161e+05 7.93000e-07]
#  [8.24000e-04 3.00000e-05 5.25360e+04 1.78000e-07]
#  [1.29600e-03 5.90000e-05 9.53730e+04 2.17000e-07]
#  [1.74500e-03 1.59000e-04 1.33985e+05 1.00000e-06]
#  [9.02000e-04 1.37000e-04 8.11800e+04 1.78000e-07]]
# Best result: 3.4494421
# Best solution index: 6
# Best solution: [1.74500e-03 1.59000e-04 1.33985e+05 1.00000e-06]
# Best solutions array: [array([2.e-03, 2.e-04, 2.e+05, 1.e-06]), array([1.74500e-03, 1.59000e-04, 1.33985e+05, 1.00000e-06])]
# Best fitness: [3.4494421]
# Best fitnesses: [1.567535, 3.4494421]
# input_values [9.7600e-04 5.4000e-05 8.0071e+04 2.4500e-07]
# scaled [[0.48020305 0.03469388 0.33372778 0.08150852]]
# delta_IL ori [[0.005163]]
# delta_Vo ori [[0.00240971]]
# delta_IL inverse [[5.3026567]]
# delta_Vo inverse [[0.35704285]]
# input_values [1.3410e-03 3.6000e-05 5.1342e+04 7.5200e-07]
# scaled [[0.66548223 0.01632653 0.17412222 0.69829684]]
# delta_IL ori [[0.0052897]]
# delta_Vo ori [[0.00079263]]
# delta_IL inverse [[5.406571]]
# delta_Vo inverse [[0.27059478]]
# input_values [1.7460e-03 8.0000e-05 9.4444e+04 2.1700e-07]
# scaled [[0.87106599 0.06122449 0.41357778 0.04744526]]
# delta_IL ori [[0.00204875]]
# delta_Vo ori [[0.00776424]]
# delta_IL inverse [[2.7485797]]
# delta_Vo inverse [[0.64329386]]
# input_values [8.87000e-04 4.60000e-05 1.33161e+05 7.93000e-07]
# scaled [[0.43502538 0.02653061 0.62867222 0.74817518]]
# delta_IL ori [[0.00283659]]
# delta_Vo ori [[0.00715215]]
# delta_IL inverse [[3.3947082]]
# delta_Vo inverse [[0.6105717]]
# input_values [8.2400e-04 3.0000e-05 5.2536e+04 1.7800e-07]
# scaled [[0.40304569 0.01020408 0.18075556 0.        ]]
# delta_IL ori [[0.00853144]]
# delta_Vo ori [[0.01187947]]
# delta_IL inverse [[8.065207]]
# delta_Vo inverse [[0.8632921]]
# input_values [1.2960e-03 5.9000e-05 9.5373e+04 2.1700e-07]
# scaled [[0.64263959 0.03979592 0.41873889 0.04744526]]
# delta_IL ori [[0.00285977]]
# delta_Vo ori [[0.00084676]]
# delta_IL inverse [[3.4137173]]
# delta_Vo inverse [[0.2734885]]
# input_values [1.2960e-03 5.9000e-05 9.5373e+04 2.1700e-07]
# scaled [[0.64263959 0.03979592 0.41873889 0.04744526]]
# delta_IL ori [[0.00285977]]
# delta_Vo ori [[0.00084676]]
# delta_IL inverse [[3.4137173]]
# delta_Vo inverse [[0.2734885]]
# input_values [1.35300e-03 1.63000e-04 1.50451e+05 7.29000e-07]
# scaled [[0.6715736  0.14591837 0.72472778 0.6703163 ]]
# delta_IL ori [[0.01153216]]
# delta_Vo ori [[0.0410784]]
# delta_IL inverse [[10.526179]]
# delta_Vo inverse [[2.4242532]]
# input_values [1.3630e-03 7.5000e-05 3.8251e+04 6.7300e-07]
# scaled [[0.67664975 0.05612245 0.10139444 0.60218978]]
# delta_IL ori [[0.0096873]]
# delta_Vo ori [[0.00414974]]
# delta_IL inverse [[9.013163]]
# delta_Vo inverse [[0.450064]]
# input_values [1.74500e-03 1.59000e-04 1.33985e+05 1.00000e-06]
# scaled [[0.87055838 0.14183673 0.63325    1.        ]]
# delta_IL ori [[0.00568259]]
# delta_Vo ori [[0.11326836]]
# delta_IL inverse [[5.7287908]]
# delta_Vo inverse [[6.2834945]]
# input_values [1.74500e-03 1.59000e-04 1.33985e+05 1.00000e-06]
# scaled [[0.87055838 0.14183673 0.63325    1.        ]]
# delta_IL ori [[0.00568259]]
# delta_Vo ori [[0.11326836]]
# delta_IL inverse [[5.7287908]]
# delta_Vo inverse [[6.2834945]]
# input_values [1.0610e-03 1.1600e-04 6.6304e+04 3.1900e-07]
# scaled [[0.52335025 0.09795918 0.25724444 0.17153285]]
# delta_IL ori [[0.00957602]]
# delta_Vo ori [[0.02083396]]
# delta_IL inverse [[8.921902]]
# delta_Vo inverse [[1.3419948]]
# input_values [1.69400e-03 3.70000e-05 1.20386e+05 4.84000e-07]
# scaled [[0.84467005 0.01734694 0.5577     0.37226277]]
# delta_IL ori [[0.00086379]]
# delta_Vo ori [[0.00053938]]
# delta_IL inverse [[1.7767595]]
# delta_Vo inverse [[0.25705612]]
# input_values [9.020e-04 1.370e-04 8.118e+04 1.780e-07]
# scaled [[0.44263959 0.11938776 0.33988889 0.        ]]
# delta_IL ori [[0.01263842]]
# delta_Vo ori [[0.04839822]]
# delta_IL inverse [[11.4334545]]
# delta_Vo inverse [[2.815567]]
# input_values [9.020e-04 1.370e-04 8.118e+04 1.780e-07]
# scaled [[0.44263959 0.11938776 0.33988889 0.        ]]
# delta_IL ori [[0.01263842]]
# delta_Vo ori [[0.04839822]]
# delta_IL inverse [[11.4334545]]
# delta_Vo inverse [[2.815567]]
# input_values [5.8700e-04 1.9400e-04 3.4092e+04 3.7000e-07]
# scaled [[0.28274112 0.17755102 0.07828889 0.23357664]]
# delta_IL ori [[0.04342308]]
# delta_Vo ori [[0.09146805]]
# delta_IL inverse [[36.68081]]
# delta_Vo inverse [[5.11806]]
# input_values [5.17000e-04 4.00000e-05 1.24605e+05 6.57000e-07]
# scaled [[0.24720812 0.02040816 0.58113889 0.58272506]]
# delta_IL ori [[0.00732465]]
# delta_Vo ori [[0.02215523]]
# delta_IL inverse [[7.0754876]]
# delta_Vo inverse [[1.4126294]]
# input_values [5.47000e-04 7.60000e-05 1.85439e+05 8.82000e-07]
# scaled [[0.26243655 0.05714286 0.91910556 0.85644769]]
# delta_IL ori [[0.00541812]]
# delta_Vo ori [[0.02492397]]
# delta_IL inverse [[5.5118895]]
# delta_Vo inverse [[1.5606447]]
# input_values [3.17000e-04 1.23000e-04 1.81725e+05 8.02000e-07]
# scaled [[0.14568528 0.10510204 0.89847222 0.75912409]]
# delta_IL ori [[0.01481361]]
# delta_Vo ori [[0.04634661]]
# delta_IL inverse [[13.217392]]
# delta_Vo inverse [[2.705889]]
# input_values [1.890e-04 1.010e-04 8.723e+04 7.140e-07]
# scaled [[0.08071066 0.08265306 0.3735     0.65206813]]
# delta_IL ori [[0.03267956]]
# delta_Vo ori [[0.02825719]]
# delta_IL inverse [[27.869751]]
# delta_Vo inverse [[1.738837]]
# input_values [1.7980e-03 7.9000e-05 5.1997e+04 8.6100e-07]
# scaled [[0.89746193 0.06020408 0.17776111 0.83090024]]
# delta_IL ori [[0.00483541]]
# delta_Vo ori [[0.00685023]]
# delta_IL inverse [[5.0339966]]
# delta_Vo inverse [[0.5944311]]
# Parents
# [[1.69400e-03 3.70000e-05 1.20386e+05 4.84000e-07]
#  [8.87000e-04 4.60000e-05 1.33161e+05 7.93000e-07]
#  [1.34100e-03 3.60000e-05 5.13420e+04 7.52000e-07]
#  [8.24000e-04 3.00000e-05 5.25360e+04 1.78000e-07]]
# Crossover
# [[1.69400e-03 3.70000e-05 1.33161e+05 7.93000e-07]
#  [8.87000e-04 4.60000e-05 5.13420e+04 7.52000e-07]
#  [1.34100e-03 3.60000e-05 5.25360e+04 1.78000e-07]
#  [8.24000e-04 3.00000e-05 1.20386e+05 4.84000e-07]]
# Mutation
# [[1.64700e-03 4.10000e-05 1.32940e+05 1.78000e-07]
#  [9.80000e-04 1.07000e-04 5.25330e+04 7.52000e-07]
#  [1.37500e-03 1.51000e-04 5.26930e+04 1.78000e-07]
#  [9.17000e-04 1.13000e-04 1.20349e+05 4.84000e-07]]
# Generation :  2
# fitness value [[5.613582]]
# fitness value [[4.066306]]
# fitness value [[5.194378]]
# fitness value [[5.5338244]]
# fitness value [[7.026902]]
# fitness value [[4.6912813]]
# fitness value [[6.171747]]
# fitness value [[5.2835894]]
# cek fitness [[[5.613582 ]]
#
#  [[4.066306 ]]
#
#  [[5.194378 ]]
#
#  [[5.5338244]]
#
#  [[7.026902 ]]
#
#  [[4.6912813]]
#
#  [[6.171747 ]]
#
#  [[5.2835894]]]
# Population [[1.69400e-03 3.70000e-05 1.20386e+05 4.84000e-07]
#  [8.87000e-04 4.60000e-05 1.33161e+05 7.93000e-07]
#  [1.34100e-03 3.60000e-05 5.13420e+04 7.52000e-07]
#  [8.24000e-04 3.00000e-05 5.25360e+04 1.78000e-07]
#  [1.64700e-03 4.10000e-05 1.32940e+05 1.78000e-07]
#  [9.80000e-04 1.07000e-04 5.25330e+04 7.52000e-07]
#  [1.37500e-03 1.51000e-04 5.26930e+04 1.78000e-07]
#  [9.17000e-04 1.13000e-04 1.20349e+05 4.84000e-07]]
# Best result: 4.066306
# Best solution index: 1
# Best solution: [8.87000e-04 4.60000e-05 1.33161e+05 7.93000e-07]
# Best solutions array: [array([2.e-03, 2.e-04, 2.e+05, 1.e-06]), array([1.74500e-03, 1.59000e-04, 1.33985e+05, 1.00000e-06]), array([8.87000e-04, 4.60000e-05, 1.33161e+05, 7.93000e-07])]
# Best fitness: [4.066306]
# Best fitnesses: [1.567535, 3.4494421, 4.066306]
# input_values [1.69400e-03 3.70000e-05 1.20386e+05 4.84000e-07]
# scaled [[0.84467005 0.01734694 0.5577     0.37226277]]
# delta_IL ori [[0.00086379]]
# delta_Vo ori [[0.00053938]]
# delta_IL inverse [[1.7767595]]
# delta_Vo inverse [[0.25705612]]
# input_values [8.87000e-04 4.60000e-05 1.33161e+05 7.93000e-07]
# scaled [[0.43502538 0.02653061 0.62867222 0.74817518]]
# delta_IL ori [[0.00283659]]
# delta_Vo ori [[0.00715215]]
# delta_IL inverse [[3.3947082]]
# delta_Vo inverse [[0.6105717]]
# input_values [1.3410e-03 3.6000e-05 5.1342e+04 7.5200e-07]
# scaled [[0.66548223 0.01632653 0.17412222 0.69829684]]
# delta_IL ori [[0.0052897]]
# delta_Vo ori [[0.00079263]]
# delta_IL inverse [[5.406571]]
# delta_Vo inverse [[0.27059478]]
# input_values [8.2400e-04 3.0000e-05 5.2536e+04 1.7800e-07]
# scaled [[0.40304569 0.01020408 0.18075556 0.        ]]
# delta_IL ori [[0.00853144]]
# delta_Vo ori [[0.01187947]]
# delta_IL inverse [[8.065207]]
# delta_Vo inverse [[0.8632921]]
# input_values [1.6470e-03 4.1000e-05 1.3294e+05 1.7800e-07]
# scaled [[0.82081218 0.02142857 0.62744444 0.        ]]
# delta_IL ori [[0.00052806]]
# delta_Vo ori [[0.00034326]]
# delta_IL inverse [[1.5014195]]
# delta_Vo inverse [[0.24657173]]
# input_values [9.8000e-04 1.0700e-04 5.2533e+04 7.5200e-07]
# scaled [[0.4822335  0.08877551 0.18073889 0.69829684]]
# delta_IL ori [[0.01161046]]
# delta_Vo ori [[0.02097947]]
# delta_IL inverse [[10.590401]]
# delta_Vo inverse [[1.3497735]]
# input_values [9.8000e-04 1.0700e-04 5.2533e+04 7.5200e-07]
# scaled [[0.4822335  0.08877551 0.18073889 0.69829684]]
# delta_IL ori [[0.01161046]]
# delta_Vo ori [[0.02097947]]
# delta_IL inverse [[10.590401]]
# delta_Vo inverse [[1.3497735]]
# input_values [1.43200e-03 7.50000e-05 1.18974e+05 5.67000e-07]
# scaled [[0.71167513 0.05612245 0.54985556 0.47323601]]
# delta_IL ori [[0.00212235]]
# delta_Vo ori [[0.00571762]]
# delta_IL inverse [[2.8089387]]
# delta_Vo inverse [[0.5338825]]
# input_values [1.3750e-03 1.5100e-04 5.2693e+04 1.7800e-07]
# scaled [[0.68274112 0.13367347 0.18162778 0.        ]]
# delta_IL ori [[0.01268268]]
# delta_Vo ori [[0.02767474]]
# delta_IL inverse [[11.469758]]
# delta_Vo inverse [[1.7076995]]
# input_values [1.3750e-03 1.5100e-04 5.2693e+04 1.7800e-07]
# scaled [[0.68274112 0.13367347 0.18162778 0.        ]]
# delta_IL ori [[0.01268268]]
# delta_Vo ori [[0.02767474]]
# delta_IL inverse [[11.469758]]
# delta_Vo inverse [[1.7076995]]
# input_values [1.9650e-03 1.9600e-04 1.6434e+05 1.8900e-07]
# scaled [[0.9822335  0.17959184 0.80188889 0.013382  ]]
# delta_IL ori [[0.0148902]]
# delta_Vo ori [[0.12606698]]
# delta_IL inverse [[13.280209]]
# delta_Vo inverse [[6.9677033]]
# input_values [8.13000e-04 1.96000e-04 1.56012e+05 9.81000e-07]
# scaled [[0.39746193 0.17959184 0.75562222 0.97688564]]
# delta_IL ori [[0.02626436]]
# delta_Vo ori [[0.19338663]]
# delta_IL inverse [[22.608469]]
# delta_Vo inverse [[10.566581]]
# input_values [1.4480e-03 1.7200e-04 2.5448e+04 2.4800e-07]
# scaled [[0.71979695 0.15510204 0.03026667 0.08515815]]
# delta_IL ori [[0.02009562]]
# delta_Vo ori [[0.08354799]]
# delta_IL inverse [[17.549314]]
# delta_Vo inverse [[4.694658]]
# input_values [4.90000e-04 1.19000e-04 1.24558e+05 7.21000e-07]
# scaled [[0.23350254 0.10102041 0.58087778 0.66058394]]
# delta_IL ori [[0.01368299]]
# delta_Vo ori [[0.03614972]]
# delta_IL inverse [[12.29014]]
# delta_Vo inverse [[2.1607683]]
# input_values [1.3530e-03 1.7900e-04 3.5239e+04 4.8700e-07]
# scaled [[0.6715736  0.1622449  0.08466111 0.37591241]]
# delta_IL ori [[0.01964236]]
# delta_Vo ori [[0.07766327]]
# delta_IL inverse [[17.17758]]
# delta_Vo inverse [[4.380063]]
# input_values [5.09000e-04 1.57000e-04 1.21095e+05 2.65000e-07]
# scaled [[0.24314721 0.13979592 0.56163889 0.10583942]]
# delta_IL ori [[0.02094406]]
# delta_Vo ori [[0.07537387]]
# delta_IL inverse [[18.245144]]
# delta_Vo inverse [[4.2576733]]
# input_values [5.5800e-04 1.8700e-04 6.2685e+04 7.3400e-07]
# scaled [[0.2680203  0.17040816 0.23713889 0.67639903]]
# delta_IL ori [[0.03389588]]
# delta_Vo ori [[0.11491684]]
# delta_IL inverse [[28.867287]]
# delta_Vo inverse [[6.3716216]]
# input_values [4.41000e-04 1.07000e-04 1.32361e+05 8.27000e-07]
# scaled [[0.20862944 0.08877551 0.62422778 0.78953771]]
# delta_IL ori [[0.01201832]]
# delta_Vo ori [[0.03378114]]
# delta_IL inverse [[10.924896]]
# delta_Vo inverse [[2.0341449]]
# input_values [3.38000e-04 1.98000e-04 1.03769e+05 9.63000e-07]
# scaled [[0.15634518 0.18163265 0.46538333 0.95498783]]
# delta_IL ori [[0.03211429]]
# delta_Vo ori [[0.08596072]]
# delta_IL inverse [[27.406155]]
# delta_Vo inverse [[4.8236413]]
# input_values [7.30000e-04 1.49000e-04 1.50147e+05 8.87000e-07]
# scaled [[0.35532995 0.13163265 0.72303889 0.86253041]]
# delta_IL ori [[0.01497023]]
# delta_Vo ori [[0.07153908]]
# delta_IL inverse [[13.34584]]
# delta_Vo inverse [[4.0526667]]
# input_values [5.8300e-04 1.7600e-04 4.8354e+04 7.3200e-07]
# scaled [[0.28071066 0.15918367 0.15752222 0.67396594]]
# delta_IL ori [[0.03454063]]
# delta_Vo ori [[0.10558517]]
# delta_IL inverse [[29.39606]]
# delta_Vo inverse [[5.8727546]]
# input_values [1.07600e-03 1.49000e-04 1.85771e+05 6.24000e-07]
# scaled [[0.53096447 0.13163265 0.92095    0.54257908]]
# delta_IL ori [[0.01033642]]
# delta_Vo ori [[0.07816447]]
# delta_IL inverse [[9.545522]]
# delta_Vo inverse [[4.406857]]
# input_values [5.4000e-05 8.1000e-05 1.7544e+05 4.3900e-07]
# scaled [[0.01218274 0.0622449  0.86355556 0.31751825]]
# delta_IL ori [[0.0707483]]
# delta_Vo ori [[0.16332659]]
# delta_IL inverse [[59.090973]]
# delta_Vo inverse [[8.959585]]
# input_values [7.80000e-05 1.04000e-04 1.95113e+05 9.72000e-07]
# scaled [[0.02436548 0.08571429 0.97285    0.96593674]]
# delta_IL ori [[0.0383288]]
# delta_Vo ori [[0.26868773]]
# delta_IL inverse [[32.502842]]
# delta_Vo inverse [[14.592141]]
# input_values [1.82600e-03 1.49000e-04 1.32604e+05 8.01000e-07]
# scaled [[0.91167513 0.13163265 0.62557778 0.75790754]]
# delta_IL ori [[0.00450327]]
# delta_Vo ori [[0.09578721]]
# delta_IL inverse [[4.7615967]]
# delta_Vo inverse [[5.348961]]
# input_values [1.2800e-04 1.5700e-04 3.5729e+04 6.7600e-07]
# scaled [[0.04974619 0.13979592 0.08738333 0.60583942]]
# delta_IL ori [[0.09946334]]
# delta_Vo ori [[0.03749822]]
# delta_IL inverse [[82.64097]]
# delta_Vo inverse [[2.2328582]]
# input_values [3.4700e-04 1.3800e-04 2.8639e+04 8.1100e-07]
# scaled [[0.16091371 0.12040816 0.04799444 0.77007299]]
# delta_IL ori [[0.05247911]]
# delta_Vo ori [[0.04099713]]
# delta_IL inverse [[44.107906]]
# delta_Vo inverse [[2.4199085]]
# input_values [1.9260e-03 1.0300e-04 4.9849e+04 7.3000e-07]
# scaled [[0.96243655 0.08469388 0.16582778 0.67153285]]
# delta_IL ori [[0.00474644]]
# delta_Vo ori [[0.01067045]]
# delta_IL inverse [[4.961027]]
# delta_Vo inverse [[0.798658]]
# input_values [1.57400e-03 1.93000e-04 1.48719e+05 2.41000e-07]
# scaled [[0.78375635 0.17653061 0.71510556 0.07664234]]
# delta_IL ori [[0.00931063]]
# delta_Vo ori [[0.16789714]]
# delta_IL inverse [[8.7042465]]
# delta_Vo inverse [[9.203924]]
# input_values [8.3100e-04 1.7400e-04 4.8405e+04 1.9100e-07]
# scaled [[0.40659898 0.15714286 0.15780556 0.01581509]]
# delta_IL ori [[0.02916454]]
# delta_Vo ori [[0.13188949]]
# delta_IL inverse [[24.986982]]
# delta_Vo inverse [[7.278972]]
# input_values [6.67000e-04 4.30000e-05 1.99389e+05 8.76000e-07]
# scaled [[0.32335025 0.02346939 0.99660556 0.84914842]]
# delta_IL ori [[0.00235717]]
# delta_Vo ori [[0.03303996]]
# delta_IL inverse [[3.0015173]]
# delta_Vo inverse [[1.9945219]]
# input_values [1.1020e-03 1.9000e-04 5.8206e+04 4.4600e-07]
# scaled [[0.54416244 0.17346939 0.21225556 0.32603406]]
# delta_IL ori [[0.02391392]]
# delta_Vo ori [[0.04774325]]
# delta_IL inverse [[20.680803]]
# delta_Vo inverse [[2.7805529]]
# input_values [1.0230e-03 1.3800e-04 1.4017e+05 2.6200e-07]
# scaled [[0.50406091 0.12040816 0.66761111 0.10218978]]
# delta_IL ori [[0.00969369]]
# delta_Vo ori [[0.06207719]]
# delta_IL inverse [[9.018401]]
# delta_Vo inverse [[3.5468388]]
# input_values [1.4920e-03 3.7000e-05 7.6576e+04 6.4100e-07]
# scaled [[0.74213198 0.01734694 0.31431111 0.56326034]]
# delta_IL ori [[0.00235495]]
# delta_Vo ori [[0.00056393]]
# delta_IL inverse [[2.9997044]]
# delta_Vo inverse [[0.25836864]]
# input_values [9.17000e-04 1.13000e-04 1.20349e+05 4.84000e-07]
# scaled [[0.45025381 0.09489796 0.55749444 0.37226277]]
# delta_IL ori [[0.00711106]]
# delta_Vo ori [[0.0296684]]
# delta_IL inverse [[6.90032]]
# delta_Vo inverse [[1.8142799]]
# input_values [9.17000e-04 1.13000e-04 1.20349e+05 4.84000e-07]
# scaled [[0.45025381 0.09489796 0.55749444 0.37226277]]
# delta_IL ori [[0.00711106]]
# delta_Vo ori [[0.0296684]]
# delta_IL inverse [[6.90032]]
# delta_Vo inverse [[1.8142799]]
# input_values [9.12000e-04 7.90000e-05 1.43544e+05 7.76000e-07]
# scaled [[0.44771574 0.06020408 0.68635556 0.72749392]]
# delta_IL ori [[0.0036799]]
# delta_Vo ori [[0.01298929]]
# delta_IL inverse [[4.086325]]
# delta_Vo inverse [[0.92262256]]
# Parents
# [[8.87000e-04 4.60000e-05 1.33161e+05 7.93000e-07]
#  [1.43200e-03 7.50000e-05 1.18974e+05 5.67000e-07]
#  [1.34100e-03 3.60000e-05 5.13420e+04 7.52000e-07]
#  [9.12000e-04 7.90000e-05 1.43544e+05 7.76000e-07]]
# Crossover
# [[8.87000e-04 4.60000e-05 1.18974e+05 5.67000e-07]
#  [1.43200e-03 7.50000e-05 5.13420e+04 7.52000e-07]
#  [1.34100e-03 3.60000e-05 1.43544e+05 7.76000e-07]
#  [9.12000e-04 7.90000e-05 1.33161e+05 7.93000e-07]]
# Mutation
# [[7.54000e-04 6.70000e-05 1.20247e+05 1.00000e-06]
#  [1.44100e-03 1.25000e-04 5.17770e+04 1.00000e-06]
#  [1.42200e-03 5.20000e-05 1.42785e+05 7.76000e-07]
#  [1.00200e-03 6.70000e-05 1.33873e+05 1.78000e-07]]
# Generation :  3
# fitness value [[4.066306]]
# fitness value [[5.263479]]
# fitness value [[5.194378]]
# fitness value [[4.014155]]
# fitness value [[3.457279]]
# fitness value [[4.7442455]]
# fitness value [[4.144556]]
# fitness value [[6.9116945]]
# cek fitness [[[4.066306 ]]
#
#  [[5.263479 ]]
#
#  [[5.194378 ]]
#
#  [[4.014155 ]]
#
#  [[3.457279 ]]
#
#  [[4.7442455]]
#
#  [[4.144556 ]]
#
#  [[6.9116945]]]
# Population [[8.87000e-04 4.60000e-05 1.33161e+05 7.93000e-07]
#  [1.43200e-03 7.50000e-05 1.18974e+05 5.67000e-07]
#  [1.34100e-03 3.60000e-05 5.13420e+04 7.52000e-07]
#  [9.12000e-04 7.90000e-05 1.43544e+05 7.76000e-07]
#  [7.54000e-04 6.70000e-05 1.20247e+05 1.00000e-06]
#  [1.44100e-03 1.25000e-04 5.17770e+04 1.00000e-06]
#  [1.42200e-03 5.20000e-05 1.42785e+05 7.76000e-07]
#  [1.00200e-03 6.70000e-05 1.33873e+05 1.78000e-07]]
# Best result: 3.457279
# Best solution index: 4
# Best solution: [7.54000e-04 6.70000e-05 1.20247e+05 1.00000e-06]
# Best solutions array: [array([2.e-03, 2.e-04, 2.e+05, 1.e-06]), array([1.74500e-03, 1.59000e-04, 1.33985e+05, 1.00000e-06]), array([8.87000e-04, 4.60000e-05, 1.33161e+05, 7.93000e-07]), array([7.54000e-04, 6.70000e-05, 1.20247e+05, 1.00000e-06])]
# Best fitness: [3.457279]
# Best fitnesses: [1.567535, 3.4494421, 4.066306, 3.457279]
# input_values [8.87000e-04 4.60000e-05 1.33161e+05 7.93000e-07]
# scaled [[0.43502538 0.02653061 0.62867222 0.74817518]]
# delta_IL ori [[0.00283659]]
# delta_Vo ori [[0.00715215]]
# delta_IL inverse [[3.3947082]]
# delta_Vo inverse [[0.6105717]]
# input_values [1.43200e-03 7.50000e-05 1.18974e+05 5.67000e-07]
# scaled [[0.71167513 0.05612245 0.54985556 0.47323601]]
# delta_IL ori [[0.00212235]]
# delta_Vo ori [[0.00571762]]
# delta_IL inverse [[2.8089387]]
# delta_Vo inverse [[0.5338825]]
# input_values [1.3410e-03 3.6000e-05 5.1342e+04 7.5200e-07]
# scaled [[0.66548223 0.01632653 0.17412222 0.69829684]]
# delta_IL ori [[0.0052897]]
# delta_Vo ori [[0.00079263]]
# delta_IL inverse [[5.406571]]
# delta_Vo inverse [[0.27059478]]
# input_values [9.12000e-04 7.90000e-05 1.43544e+05 7.76000e-07]
# scaled [[0.44771574 0.06020408 0.68635556 0.72749392]]
# delta_IL ori [[0.0036799]]
# delta_Vo ori [[0.01298929]]
# delta_IL inverse [[4.086325]]
# delta_Vo inverse [[0.92262256]]
# input_values [7.54000e-04 6.70000e-05 1.20247e+05 1.00000e-06]
# scaled [[0.36751269 0.04795918 0.55692778 1.        ]]
# delta_IL ori [[0.00556616]]
# delta_Vo ori [[0.0125211]]
# delta_IL inverse [[5.6332984]]
# delta_Vo inverse [[0.8975931]]
# input_values [1.4410e-03 1.2500e-04 5.1777e+04 1.0000e-06]
# scaled [[0.71624365 0.10714286 0.17653889 1.        ]]
# delta_IL ori [[0.00942782]]
# delta_Vo ori [[0.03339581]]
# delta_IL inverse [[8.80036]]
# delta_Vo inverse [[2.0135453]]
# input_values [1.4410e-03 1.2500e-04 5.1777e+04 1.0000e-06]
# scaled [[0.71624365 0.10714286 0.17653889 1.        ]]
# delta_IL ori [[0.00942782]]
# delta_Vo ori [[0.03339581]]
# delta_IL inverse [[8.80036]]
# delta_Vo inverse [[2.0135453]]
# input_values [4.6900e-04 1.6200e-04 3.6196e+04 3.0800e-07]
# scaled [[0.22284264 0.14489796 0.08997778 0.15815085]]
# delta_IL ori [[0.03901259]]
# delta_Vo ori [[0.07370462]]
# delta_IL inverse [[33.063644]]
# delta_Vo inverse [[4.168435]]
# input_values [4.0200e-04 1.6400e-04 2.3899e+04 3.0600e-07]
# scaled [[0.18883249 0.14693878 0.02166111 0.15571776]]
# delta_IL ori [[0.06448874]]
# delta_Vo ori [[0.07434097]]
# delta_IL inverse [[53.957333]]
# delta_Vo inverse [[4.2024546]]
# input_values [9.6500e-04 6.3000e-05 6.1527e+04 3.3600e-07]
# scaled [[0.47461929 0.04387755 0.23070556 0.19221411]]
# delta_IL ori [[0.00723755]]
# delta_Vo ori [[0.00614021]]
# delta_IL inverse [[7.0040536]]
# delta_Vo inverse [[0.5564739]]
# input_values [7.77000e-04 1.69000e-04 1.76773e+05 6.73000e-07]
# scaled [[0.37918782 0.15204082 0.87096111 0.60218978]]
# delta_IL ori [[0.01888028]]
# delta_Vo ori [[0.09808374]]
# delta_IL inverse [[16.55258]]
# delta_Vo inverse [[5.471732]]
# input_values [1.4530e-03 5.4000e-05 6.8251e+04 9.2700e-07]
# scaled [[0.72233503 0.03469388 0.26806111 0.91119221]]
# delta_IL ori [[0.00391814]]
# delta_Vo ori [[0.00125136]]
# delta_IL inverse [[4.281712]]
# delta_Vo inverse [[0.295118]]
# input_values [1.42200e-03 5.20000e-05 1.42785e+05 7.76000e-07]
# scaled [[0.70659898 0.03265306 0.68213889 0.72749392]]
# delta_IL ori [[0.00122111]]
# delta_Vo ori [[0.00233107]]
# delta_IL inverse [[2.0698092]]
# delta_Vo inverse [[0.35283875]]
# input_values [1.42200e-03 5.20000e-05 1.42785e+05 7.76000e-07]
# scaled [[0.70659898 0.03265306 0.68213889 0.72749392]]
# delta_IL ori [[0.00122111]]
# delta_Vo ori [[0.00233107]]
# delta_IL inverse [[2.0698092]]
# delta_Vo inverse [[0.35283875]]
# input_values [5.8600e-04 4.4000e-05 3.4038e+04 7.0800e-07]
# scaled [[0.2822335  0.0244898  0.07798889 0.64476886]]
# delta_IL ori [[0.0243898]]
# delta_Vo ori [[0.01125784]]
# delta_IL inverse [[21.07109]]
# delta_Vo inverse [[0.8300596]]
# input_values [1.7950e-03 1.6500e-04 1.1117e+05 6.3900e-07]
# scaled [[0.89593909 0.14795918 0.5065     0.56082725]]
# delta_IL ori [[0.00815066]]
# delta_Vo ori [[0.12779495]]
# delta_IL inverse [[7.752919]]
# delta_Vo inverse [[7.06008]]
# input_values [3.400e-05 5.100e-05 3.002e+04 9.890e-07]
# scaled [[0.00203046 0.03163265 0.05566667 0.986618  ]]
# delta_IL ori [[0.5076087]]
# delta_Vo ori [[0.20884433]]
# delta_IL inverse [[417.37225]]
# delta_Vo inverse [[11.392942]]
# input_values [3.15000e-04 7.80000e-05 1.34517e+05 4.31000e-07]
# scaled [[0.14467005 0.05918367 0.63620556 0.30778589]]
# delta_IL ori [[0.01256465]]
# delta_Vo ori [[0.01650215]]
# delta_IL inverse [[11.372955]]
# delta_Vo inverse [[1.1104182]]
# input_values [1.21200e-03 8.70000e-05 1.66126e+05 5.10000e-07]
# scaled [[0.6        0.06836735 0.81181111 0.40389294]]
# delta_IL ori [[0.00194608]]
# delta_Vo ori [[0.00785922]]
# delta_IL inverse [[2.6643765]]
# delta_Vo inverse [[0.64837134]]
# input_values [6.36000e-04 4.40000e-05 1.69731e+05 7.16000e-07]
# scaled [[0.30761421 0.0244898  0.83183889 0.65450122]]
# delta_IL ori [[0.00350492]]
# delta_Vo ori [[0.02006695]]
# delta_IL inverse [[3.9428241]]
# delta_Vo inverse [[1.3009909]]
# input_values [1.97600e-03 1.44000e-04 1.38011e+05 9.18000e-07]
# scaled [[0.98781726 0.12653061 0.65561667 0.90024331]]
# delta_IL ori [[0.00444356]]
# delta_Vo ori [[0.09362981]]
# delta_IL inverse [[4.7126307]]
# delta_Vo inverse [[5.2336273]]
# input_values [3.67000e-04 4.80000e-05 1.61608e+05 2.72000e-07]
# scaled [[0.17106599 0.02857143 0.78671111 0.11435523]]
# delta_IL ori [[0.00749282]]
# delta_Vo ori [[0.01950427]]
# delta_IL inverse [[7.213406]]
# delta_Vo inverse [[1.2709101]]
# input_values [1.6730e-03 7.3000e-05 1.8076e+05 5.9500e-07]
# scaled [[0.83401015 0.05408163 0.89311111 0.50729927]]
# delta_IL ori [[0.00085875]]
# delta_Vo ori [[0.00778906]]
# delta_IL inverse [[1.772622]]
# delta_Vo inverse [[0.64462066]]
# input_values [1.00200e-03 6.70000e-05 1.33873e+05 1.78000e-07]
# scaled [[0.49340102 0.04795918 0.63262778 0.        ]]
# delta_IL ori [[0.00267417]]
# delta_Vo ori [[0.00686438]]
# delta_IL inverse [[3.2615013]]
# delta_Vo inverse [[0.59518737]]
# Parents
# [[7.54000e-04 6.70000e-05 1.20247e+05 1.00000e-06]
#  [9.12000e-04 7.90000e-05 1.43544e+05 7.76000e-07]
#  [8.87000e-04 4.60000e-05 1.33161e+05 7.93000e-07]
#  [1.67300e-03 7.30000e-05 1.80760e+05 5.95000e-07]]
# Crossover
# [[7.54000e-04 6.70000e-05 1.43544e+05 7.76000e-07]
#  [9.12000e-04 7.90000e-05 1.33161e+05 7.93000e-07]
#  [8.87000e-04 4.60000e-05 1.80760e+05 5.95000e-07]
#  [1.67300e-03 7.30000e-05 1.20247e+05 1.00000e-06]]
# Mutation
# [[7.39000e-04 1.27000e-04 1.43869e+05 1.00000e-06]
#  [8.87000e-04 1.51000e-04 1.32029e+05 7.93000e-07]
#  [8.58000e-04 1.25000e-04 1.80805e+05 1.78000e-07]
#  [1.77100e-03 1.48000e-04 1.19383e+05 1.00000e-06]]
# Generation :  4
# fitness value [[3.457279]]
# fitness value [[4.014155]]
# fitness value [[4.066306]]
# fitness value [[4.7027345]]
# fitness value [[2.9855154]]
# fitness value [[3.9026306]]
# fitness value [[7.114039]]
# fitness value [[3.7765257]]
# cek fitness [[[3.457279 ]]
#
#  [[4.014155 ]]
#
#  [[4.066306 ]]
#
#  [[4.7027345]]
#
#  [[2.9855154]]
#
#  [[3.9026306]]
#
#  [[7.114039 ]]
#
#  [[3.7765257]]]
# Population [[7.54000e-04 6.70000e-05 1.20247e+05 1.00000e-06]
#  [9.12000e-04 7.90000e-05 1.43544e+05 7.76000e-07]
#  [8.87000e-04 4.60000e-05 1.33161e+05 7.93000e-07]
#  [1.67300e-03 7.30000e-05 1.80760e+05 5.95000e-07]
#  [7.39000e-04 1.27000e-04 1.43869e+05 1.00000e-06]
#  [8.87000e-04 1.51000e-04 1.32029e+05 7.93000e-07]
#  [8.58000e-04 1.25000e-04 1.80805e+05 1.78000e-07]
#  [1.77100e-03 1.48000e-04 1.19383e+05 1.00000e-06]]
# Best result: 2.9855154
# Best solution index: 4
# Best solution: [7.39000e-04 1.27000e-04 1.43869e+05 1.00000e-06]
# Best solutions array: [array([2.e-03, 2.e-04, 2.e+05, 1.e-06]), array([1.74500e-03, 1.59000e-04, 1.33985e+05, 1.00000e-06]), array([8.87000e-04, 4.60000e-05, 1.33161e+05, 7.93000e-07]), array([7.54000e-04, 6.70000e-05, 1.20247e+05, 1.00000e-06]), array([7.39000e-04, 1.27000e-04, 1.43869e+05, 1.00000e-06])]
# Best fitness: [2.9855154]
# Best fitnesses: [1.567535, 3.4494421, 4.066306, 3.457279, 2.9855154]
# input_values [7.54000e-04 6.70000e-05 1.20247e+05 1.00000e-06]
# scaled [[0.36751269 0.04795918 0.55692778 1.        ]]
# delta_IL ori [[0.00556616]]
# delta_Vo ori [[0.0125211]]
# delta_IL inverse [[5.6332984]]
# delta_Vo inverse [[0.8975931]]
# input_values [9.12000e-04 7.90000e-05 1.43544e+05 7.76000e-07]
# scaled [[0.44771574 0.06020408 0.68635556 0.72749392]]
# delta_IL ori [[0.0036799]]
# delta_Vo ori [[0.01298929]]
# delta_IL inverse [[4.086325]]
# delta_Vo inverse [[0.92262256]]
# input_values [8.87000e-04 4.60000e-05 1.33161e+05 7.93000e-07]
# scaled [[0.43502538 0.02653061 0.62867222 0.74817518]]
# delta_IL ori [[0.00283659]]
# delta_Vo ori [[0.00715215]]
# delta_IL inverse [[3.3947082]]
# delta_Vo inverse [[0.6105717]]
# input_values [1.6730e-03 7.3000e-05 1.8076e+05 5.9500e-07]
# scaled [[0.83401015 0.05408163 0.89311111 0.50729927]]
# delta_IL ori [[0.00085875]]
# delta_Vo ori [[0.00778906]]
# delta_IL inverse [[1.772622]]
# delta_Vo inverse [[0.64462066]]
# input_values [7.39000e-04 1.27000e-04 1.43869e+05 1.00000e-06]
# scaled [[0.35989848 0.10918367 0.68816111 1.        ]]
# delta_IL ori [[0.0101895]]
# delta_Vo ori [[0.06905786]]
# delta_IL inverse [[9.425028]]
# delta_Vo inverse [[3.920022]]
# input_values [7.39000e-04 1.27000e-04 1.43869e+05 1.00000e-06]
# scaled [[0.35989848 0.10918367 0.68816111 1.        ]]
# delta_IL ori [[0.0101895]]
# delta_Vo ori [[0.06905786]]
# delta_IL inverse [[9.425028]]
# delta_Vo inverse [[3.920022]]
# input_values [1.9990e-03 1.2400e-04 7.9528e+04 3.8400e-07]
# scaled [[0.99949239 0.10612245 0.33071111 0.25060827]]
# delta_IL ori [[0.00432561]]
# delta_Vo ori [[0.04798656]]
# delta_IL inverse [[4.615896]]
# delta_Vo inverse [[2.7935598]]
# input_values [3.4900e-04 1.8000e-04 1.0106e+05 8.2700e-07]
# scaled [[0.16192893 0.16326531 0.45033333 0.78953771]]
# delta_IL ori [[0.02993912]]
# delta_Vo ori [[0.08411176]]
# delta_IL inverse [[25.622236]]
# delta_Vo inverse [[4.7247963]]
# input_values [1.6500e-03 9.8000e-05 5.7966e+04 5.1400e-07]
# scaled [[0.82233503 0.07959184 0.21092222 0.40875912]]
# delta_IL ori [[0.00560689]]
# delta_Vo ori [[0.01635253]]
# delta_IL inverse [[5.66671]]
# delta_Vo inverse [[1.1024199]]
# input_values [6.83000e-04 1.32000e-04 1.73368e+05 8.60000e-07]
# scaled [[0.33147208 0.11428571 0.85204444 0.8296837 ]]
# delta_IL ori [[0.01060531]]
# delta_Vo ori [[0.07165897]]
# delta_IL inverse [[9.766047]]
# delta_Vo inverse [[4.059076]]
# input_values [1.2580e-03 1.0200e-04 5.2114e+04 2.1200e-07]
# scaled [[0.62335025 0.08367347 0.17841111 0.04136253]]
# delta_IL ori [[0.00786615]]
# delta_Vo ori [[0.01972553]]
# delta_IL inverse [[7.5195904]]
# delta_Vo inverse [[1.2827383]]
# ...
#  [1.98200e-03 4.60000e-05 1.06484e+05 4.40000e-07]
#  [1.29400e-03 3.70000e-05 1.77355e+05 8.27000e-07]]
# Mutation
# [[1.28400e-03 4.40000e-05 1.20781e+05 1.00000e-06]
#  [8.09000e-04 9.10000e-05 1.56627e+05 1.00000e-06]
#  [1.98200e-03 3.00000e-05 1.05085e+05 4.40000e-07]
#  [1.26100e-03 3.00000e-05 1.76568e+05 1.00000e-06]]
# Generation :  8
# fitness value [[3.336921]]
# fitness value [[3.457279]]
# fitness value [[4.3929205]]
# fitness value [[5.795156]]
# fitness value [[3.6089094]]
# fitness value [[2.6930554]]
# fitness value [[5.7779927]]
# fitness value [[2.1659145]]
# cek fitness [[[3.336921 ]]
#
#  [[3.457279 ]]
#
#  [[4.3929205]]
#
#  [[5.795156 ]]
#
#  [[3.6089094]]
#
#  [[2.6930554]]
#
#  [[5.7779927]]
#
#  [[2.1659145]]]
# Population [[1.27800e-03 7.80000e-05 1.77355e+05 8.27000e-07]
#  [7.54000e-04 6.70000e-05 1.20247e+05 1.00000e-06]
#  [1.98200e-03 4.60000e-05 1.56274e+05 6.87000e-07]
#  [1.29400e-03 3.70000e-05 1.06484e+05 4.40000e-07]
#  [1.28400e-03 4.40000e-05 1.20781e+05 1.00000e-06]
#  [8.09000e-04 9.10000e-05 1.56627e+05 1.00000e-06]
#  [1.98200e-03 3.00000e-05 1.05085e+05 4.40000e-07]
#  [1.26100e-03 3.00000e-05 1.76568e+05 1.00000e-06]]
# Best result: 2.1659145
# Best solution index: 7
# Best solution: [1.26100e-03 3.00000e-05 1.76568e+05 1.00000e-06]
# Best solutions array: [array([2.e-03, 2.e-04, 2.e+05, 1.e-06]), array([1.74500e-03, 1.59000e-04, 1.33985e+05, 1.00000e-06]), array([8.87000e-04, 4.60000e-05, 1.33161e+05, 7.93000e-07]), array([7.54000e-04, 6.70000e-05, 1.20247e+05, 1.00000e-06]), array([7.39000e-04, 1.27000e-04, 1.43869e+05, 1.00000e-06]), array([6.40000e-04, 3.00000e-05, 1.56084e+05, 1.00000e-06]), array([7.54000e-04, 6.70000e-05, 1.20247e+05, 1.00000e-06]), array([1.35400e-03, 3.00000e-05, 1.68882e+05, 1.00000e-06]), array([1.26100e-03, 3.00000e-05, 1.76568e+05, 1.00000e-06])]
# Best fitness: [2.1659145]
# Best fitnesses: [1.567535, 3.4494421, 4.066306, 3.457279, 2.9855154, 2.6228385, 3.457279, 2.4865704, 2.1659145]
# input_values [1.27800e-03 7.80000e-05 1.77355e+05 8.27000e-07]
# scaled [[0.63350254 0.05918367 0.87419444 0.78953771]]
# delta_IL ori [[0.00176515]]
# delta_Vo ori [[0.00739884]]
# delta_IL inverse [[2.515989]]
# delta_Vo inverse [[0.62375945]]
# input_values [7.54000e-04 6.70000e-05 1.20247e+05 1.00000e-06]
# scaled [[0.36751269 0.04795918 0.55692778 1.        ]]
# delta_IL ori [[0.00556616]]
# delta_Vo ori [[0.0125211]]
# delta_IL inverse [[5.6332984]]
# delta_Vo inverse [[0.8975931]]
# input_values [1.98200e-03 4.60000e-05 1.56274e+05 6.87000e-07]
# scaled [[0.99086294 0.02653061 0.75707778 0.61922141]]
# delta_IL ori [[0.0001483]]
# delta_Vo ori [[0.00080545]]
# delta_IL inverse [[1.1899642]]
# delta_Vo inverse [[0.27128005]]
# input_values [1.29400e-03 3.70000e-05 1.06484e+05 4.40000e-07]
# scaled [[0.64162437 0.01734694 0.48046667 0.31873479]]
# delta_IL ori [[0.00194315]]
# delta_Vo ori [[0.00192401]]
# delta_IL inverse [[2.661972]]
# delta_Vo inverse [[0.3310776]]
# input_values [1.28400e-03 4.40000e-05 1.20781e+05 1.00000e-06]
# scaled [[0.63654822 0.0244898  0.55989444 1.        ]]
# delta_IL ori [[0.00211468]]
# delta_Vo ori [[0.00383074]]
# delta_IL inverse [[2.8026521]]
# delta_Vo inverse [[0.43301064]]
# input_values [8.09000e-04 9.10000e-05 1.56627e+05 1.00000e-06]
# scaled [[0.39543147 0.07244898 0.75903889 1.        ]]
# delta_IL ori [[0.00487267]]
# delta_Vo ori [[0.02430816]]
# delta_IL inverse [[5.064554]]
# delta_Vo inverse [[1.527724]]
# input_values [8.09000e-04 9.10000e-05 1.56627e+05 1.00000e-06]
# scaled [[0.39543147 0.07244898 0.75903889 1.        ]]
# delta_IL ori [[0.00487267]]
# delta_Vo ori [[0.02430816]]
# delta_IL inverse [[5.064554]]
# delta_Vo inverse [[1.527724]]
# input_values [1.94200e-03 1.04000e-04 1.18496e+05 7.97000e-07]
# scaled [[0.97055838 0.08571429 0.5472     0.75304136]]
# delta_IL ori [[0.00200318]]
# delta_Vo ori [[0.01364078]]
# delta_IL inverse [[2.7112057]]
# delta_Vo inverse [[0.9574507]]
# input_values [1.98200e-03 3.00000e-05 1.05085e+05 4.40000e-07]
# scaled [[0.99086294 0.01020408 0.47269444 0.31873479]]
# delta_IL ori [[0.00051502]]
# delta_Vo ori [[1.4354923e-29]]
# delta_IL inverse [[1.4907225]]
# delta_Vo inverse [[0.22822095]]
# input_values [1.26100e-03 3.00000e-05 1.76568e+05 1.00000e-06]
# scaled [[0.6248731  0.01020408 0.86982222 1.        ]]
# delta_IL ori [[0.00077537]]
# delta_Vo ori [[0.01909634]]
# delta_IL inverse [[1.7042407]]
# delta_Vo inverse [[1.2491022]]
# input_values [1.26100e-03 3.00000e-05 1.76568e+05 1.00000e-06]
# scaled [[0.6248731  0.01020408 0.86982222 1.        ]]
# delta_IL ori [[0.00077537]]
# delta_Vo ori [[0.01909634]]
# delta_IL inverse [[1.7042407]]
# delta_Vo inverse [[1.2491022]]
# input_values [1.0640e-03 3.7000e-05 2.7223e+04 2.3200e-07]
# scaled [[0.5248731  0.01734694 0.04012778 0.06569343]]
# delta_IL ori [[0.01600204]]
# delta_Vo ori [[0.0032693]]
# delta_IL inverse [[14.192059]]
# delta_Vo inverse [[0.4029963]]
# input_values [2.440e-04 2.010e-04 7.913e+04 6.730e-07]
# scaled [[0.10862944 0.18469388 0.3285     0.60218978]]
# delta_IL ori [[0.03617349]]
# delta_Vo ori [[0.04370623]]
# delta_IL inverse [[30.735214]]
# delta_Vo inverse [[2.564736]]
# input_values [8.8600e-04 7.2000e-05 1.6208e+05 1.8600e-07]
# scaled [[0.43451777 0.05306122 0.78933333 0.00973236]]
# delta_IL ori [[0.00235813]]
# delta_Vo ori [[0.00799845]]
# delta_IL inverse [[3.0023096]]
# delta_Vo inverse [[0.65581447]]
# Parents
# [[8.86000e-04 7.20000e-05 1.62080e+05 1.86000e-07]
#  [1.94200e-03 1.04000e-04 1.18496e+05 7.97000e-07]
#  [1.27800e-03 7.80000e-05 1.77355e+05 8.27000e-07]
#  [7.54000e-04 6.70000e-05 1.20247e+05 1.00000e-06]]
# Crossover
# [[8.86000e-04 7.20000e-05 1.18496e+05 7.97000e-07]
#  [1.94200e-03 1.04000e-04 1.77355e+05 8.27000e-07]
#  [1.27800e-03 7.80000e-05 1.20247e+05 1.00000e-06]
#  [7.54000e-04 6.70000e-05 1.62080e+05 1.86000e-07]]
# Mutation
# [[7.40000e-04 9.70000e-05 1.18174e+05 1.00000e-06]
#  [1.89400e-03 1.15000e-04 1.77232e+05 1.00000e-06]
#  [1.20900e-03 3.00000e-05 1.21100e+05 1.00000e-06]
#  [6.67000e-04 9.20000e-05 1.60469e+05 1.00000e-06]]
# Generation :  9
# fitness value [[6.8717694]]
# fitness value [[4.402595]]
# fitness value [[3.336921]]
# fitness value [[3.457279]]
# fitness value [[3.501861]]
# fitness value [[2.0778418]]
# fitness value [[3.6138203]]
# fitness value [[2.550253]]
# cek fitness [[[6.8717694]]
#
#  [[4.402595 ]]
#
#  [[3.336921 ]]
#
#  [[3.457279 ]]
#
#  [[3.501861 ]]
#
#  [[2.0778418]]
#
#  [[3.6138203]]
#
#  [[2.550253 ]]]
# Population [[8.86000e-04 7.20000e-05 1.62080e+05 1.86000e-07]
#  [1.94200e-03 1.04000e-04 1.18496e+05 7.97000e-07]
#  [1.27800e-03 7.80000e-05 1.77355e+05 8.27000e-07]
#  [7.54000e-04 6.70000e-05 1.20247e+05 1.00000e-06]
#  [7.40000e-04 9.70000e-05 1.18174e+05 1.00000e-06]
#  [1.89400e-03 1.15000e-04 1.77232e+05 1.00000e-06]
#  [1.20900e-03 3.00000e-05 1.21100e+05 1.00000e-06]
#  [6.67000e-04 9.20000e-05 1.60469e+05 1.00000e-06]]
# Best result: 2.0778418
# Best solution index: 5
# Best solution: [1.89400e-03 1.15000e-04 1.77232e+05 1.00000e-06]
# Best solutions array: [array([2.e-03, 2.e-04, 2.e+05, 1.e-06]), array([1.74500e-03, 1.59000e-04, 1.33985e+05, 1.00000e-06]), array([8.87000e-04, 4.60000e-05, 1.33161e+05, 7.93000e-07]), array([7.54000e-04, 6.70000e-05, 1.20247e+05, 1.00000e-06]), array([7.39000e-04, 1.27000e-04, 1.43869e+05, 1.00000e-06]), array([6.40000e-04, 3.00000e-05, 1.56084e+05, 1.00000e-06]), array([7.54000e-04, 6.70000e-05, 1.20247e+05, 1.00000e-06]), array([1.35400e-03, 3.00000e-05, 1.68882e+05, 1.00000e-06]), array([1.26100e-03, 3.00000e-05, 1.76568e+05, 1.00000e-06]), array([1.89400e-03, 1.15000e-04, 1.77232e+05, 1.00000e-06])]
# Best fitness: [2.0778418]
# Best fitnesses: [1.567535, 3.4494421, 4.066306, 3.457279, 2.9855154, 2.6228385, 3.457279, 2.4865704, 2.1659145, 2.0778418]
# input_values [8.8600e-04 7.2000e-05 1.6208e+05 1.8600e-07]
# scaled [[0.43451777 0.05306122 0.78933333 0.00973236]]
# delta_IL ori [[0.00235813]]
# delta_Vo ori [[0.00799845]]
# delta_IL inverse [[3.0023096]]
# delta_Vo inverse [[0.65581447]]
# input_values [1.94200e-03 1.04000e-04 1.18496e+05 7.97000e-07]
# scaled [[0.97055838 0.08571429 0.5472     0.75304136]]
# delta_IL ori [[0.00200318]]
# delta_Vo ori [[0.01364078]]
# delta_IL inverse [[2.7112057]]
# delta_Vo inverse [[0.9574507]]
# input_values [1.27800e-03 7.80000e-05 1.77355e+05 8.27000e-07]
# scaled [[0.63350254 0.05918367 0.87419444 0.78953771]]
# delta_IL ori [[0.00176515]]
# delta_Vo ori [[0.00739884]]
# delta_IL inverse [[2.515989]]
# delta_Vo inverse [[0.62375945]]
# input_values [7.54000e-04 6.70000e-05 1.20247e+05 1.00000e-06]
# scaled [[0.36751269 0.04795918 0.55692778 1.        ]]
# delta_IL ori [[0.00556616]]
# delta_Vo ori [[0.0125211]]
# delta_IL inverse [[5.6332984]]
# delta_Vo inverse [[0.8975931]]
# input_values [7.40000e-04 9.70000e-05 1.18174e+05 1.00000e-06]
# scaled [[0.36040609 0.07857143 0.54541111 1.        ]]
# delta_IL ori [[0.00718339]]
# delta_Vo ori [[0.02358742]]
# delta_IL inverse [[6.959633]]
# delta_Vo inverse [[1.4891936]]
# input_values [7.40000e-04 9.70000e-05 1.18174e+05 1.00000e-06]
# scaled [[0.36040609 0.07857143 0.54541111 1.        ]]
# delta_IL ori [[0.00718339]]
# delta_Vo ori [[0.02358742]]
# delta_IL inverse [[6.959633]]
# delta_Vo inverse [[1.4891936]]
# input_values [4.19000e-04 1.57000e-04 1.82232e+05 5.87000e-07]
# scaled [[0.19746193 0.13979592 0.90128889 0.49756691]]
# delta_IL ori [[0.02045419]]
# delta_Vo ori [[0.08307774]]
# delta_IL inverse [[17.843386]]
# delta_Vo inverse [[4.6695185]]
# input_values [1.36600e-03 3.70000e-05 1.58661e+05 8.04000e-07]
# scaled [[0.67817259 0.01734694 0.77033889 0.76155718]]
# delta_IL ori [[0.00082887]]
# delta_Vo ori [[0.00658925]]
# delta_IL inverse [[1.7481195]]
# delta_Vo inverse [[0.58047944]]
# input_values [1.89400e-03 1.15000e-04 1.77232e+05 1.00000e-06]
# scaled [[0.94619289 0.09693878 0.87351111 1.        ]]
# delta_IL ori [[0.00141008]]
# delta_Vo ori [[0.02580532]]
# delta_IL inverse [[2.2247894]]
# delta_Vo inverse [[1.6077613]]
# input_values [1.89400e-03 1.15000e-04 1.77232e+05 1.00000e-06]
# scaled [[0.94619289 0.09693878 0.87351111 1.        ]]
# delta_IL ori [[0.00141008]]
# delta_Vo ori [[0.02580532]]
# delta_IL inverse [[2.2247894]]
# delta_Vo inverse [[1.6077613]]
# input_values [1.1130e-03 4.0000e-05 7.5341e+04 7.7200e-07]
# scaled [[0.54974619 0.02040816 0.30745    0.72262774]]
# delta_IL ori [[0.00488377]]
# delta_Vo ori [[0.00262041]]
# delta_IL inverse [[5.073659]]
# delta_Vo inverse [[0.3683066]]
# input_values [4.2900e-04 1.9700e-04 9.7963e+04 8.7000e-07]
# scaled [[0.20253807 0.18061224 0.43312778 0.84184915]]
# delta_IL ori [[0.03200206]]
# delta_Vo ori [[0.12655918]]
# delta_IL inverse [[27.314112]]
# delta_Vo inverse [[6.994016]]
# input_values [1.5390e-03 1.1300e-04 4.0164e+04 6.2600e-07]
# scaled [[0.76598985 0.09489796 0.11202222 0.54501217]]
# delta_IL ori [[0.00893627]]
# delta_Vo ori [[0.02569865]]
# delta_IL inverse [[8.397221]]
# delta_Vo inverse [[1.6020585]]
# input_values [5.130e-04 4.900e-05 6.414e+04 3.740e-07]
# scaled [[0.24517766 0.02959184 0.24522222 0.23844282]]
# delta_IL ori [[0.01379621]]
# delta_Vo ori [[0.01137036]]
# delta_IL inverse [[12.382993]]
# delta_Vo inverse [[0.83607525]]
# input_values [1.45500e-03 1.52000e-04 1.21561e+05 2.59000e-07]
# scaled [[0.72335025 0.13469388 0.56422778 0.09854015]]
# delta_IL ori [[0.01028997]]
# delta_Vo ori [[0.03748173]]
# delta_IL inverse [[9.507432]]
# delta_Vo inverse [[2.231977]]
# input_values [3.2900e-04 1.5000e-04 2.5309e+04 3.2400e-07]
# scaled [[0.15177665 0.13265306 0.02949444 0.17761557]]
# delta_IL ori [[0.06665342]]
# delta_Vo ori [[0.04369158]]
# delta_IL inverse [[55.732643]]
# delta_Vo inverse [[2.5639527]]
# input_values [5.27000e-04 1.09000e-04 1.48368e+05 7.74000e-07]
# scaled [[0.25228426 0.09081633 0.71315556 0.72506083]]
# delta_IL ori [[0.00996094]]
# delta_Vo ori [[0.03264639]]
# delta_IL inverse [[9.237581]]
# delta_Vo inverse [[1.9734817]]
# input_values [1.14400e-03 1.16000e-04 1.81987e+05 6.44000e-07]
# scaled [[0.56548223 0.09795918 0.89992778 0.56690998]]
# delta_IL ori [[0.00413103]]
# delta_Vo ori [[0.03427422]]
# delta_IL inverse [[4.456316]]
# delta_Vo inverse [[2.0605047]]
# input_values [8.49000e-04 9.70000e-05 1.79318e+05 6.65000e-07]
# scaled [[0.41573604 0.07857143 0.8851     0.59245742]]
# delta_IL ori [[0.00407664]]
# delta_Vo ori [[0.02959219]]
# delta_IL inverse [[4.4117093]]
# delta_Vo inverse [[1.8102055]]
# input_values [4.8100e-04 1.3500e-04 5.4599e+04 7.5600e-07]
# scaled [[0.22893401 0.11734694 0.19221667 0.70316302]]
# delta_IL ori [[0.0270467]]
# delta_Vo ori [[0.05317691]]
# delta_IL inverse [[23.25009]]
# delta_Vo inverse [[3.0710337]]
# input_values [6.4900e-04 1.9600e-04 9.5916e+04 2.1200e-07]
# scaled [[0.3142132  0.17959184 0.42175556 0.04136253]]
# delta_IL ori [[0.03107495]]
# delta_Vo ori [[0.08700318]]
# delta_IL inverse [[26.553766]]
# delta_Vo inverse [[4.87937]]
# input_values [1.84400e-03 1.77000e-04 1.80464e+05 1.80000e-07]
# scaled [[0.92081218 0.16020408 0.89146667 0.00243309]]
# delta_IL ori [[0.00850874]]
# delta_Vo ori [[0.14305952]]
# delta_IL inverse [[8.046594]]
# delta_Vo inverse [[7.8761168]]
# input_values [1.66500e-03 5.90000e-05 1.64828e+05 6.08000e-07]
# scaled [[0.82994924 0.03979592 0.8046     0.52311436]]
# delta_IL ori [[0.00079006]]
# delta_Vo ori [[0.00372563]]
# delta_IL inverse [[1.7162939]]
# delta_Vo inverse [[0.4273912]]
# input_values [1.8560e-03 1.6700e-04 5.4111e+04 8.4700e-07]
# scaled [[0.92690355 0.15       0.18950556 0.81386861]]
# delta_IL ori [[0.0101776]]
# delta_Vo ori [[0.13052855]]
# delta_IL inverse [[9.415272]]
# delta_Vo inverse [[7.206217]]
# input_values [1.9420e-03 1.1600e-04 1.0395e+05 5.2200e-07]
# scaled [[0.97055838 0.09795918 0.46638889 0.41849148]]
# delta_IL ori [[0.00277918]]
# delta_Vo ori [[0.02849178]]
# delta_IL inverse [[3.3476205]]
# delta_Vo inverse [[1.7513782]]
# input_values [4.41000e-04 2.00000e-04 1.82123e+05 9.30000e-07]
# scaled [[0.20862944 0.18367347 0.90068333 0.91484185]]
# delta_IL ori [[0.02861408]]
# delta_Vo ori [[0.14468332]]
# delta_IL inverse [[24.535536]]
# delta_Vo inverse [[7.962924]]
# input_values [1.72100e-03 1.76000e-04 1.86095e+05 6.59000e-07]
# scaled [[0.85837563 0.15918367 0.92275    0.58515815]]
# delta_IL ori [[0.00641016]]
# delta_Vo ori [[0.14482455]]
# delta_IL inverse [[6.32549]]
# delta_Vo inverse [[7.9704742]]
# input_values [8.05000e-04 6.20000e-05 1.01201e+05 5.38000e-07]
# scaled [[0.39340102 0.04285714 0.45111667 0.4379562 ]]
# delta_IL ori [[0.00591942]]
# delta_Vo ori [[0.00694116]]
# delta_IL inverse [[5.9230237]]
# delta_Vo inverse [[0.59929186]]
# input_values [1.209e-03 3.000e-05 1.211e+05 1.000e-06]
# scaled [[0.59847716 0.01020408 0.56166667 1.        ]]
# delta_IL ori [[0.00213156]]
# delta_Vo ori [[0.01133413]]
# delta_IL inverse [[2.8164883]]
# delta_Vo inverse [[0.8341381]]
# input_values [6.67000e-04 9.20000e-05 1.60469e+05 1.00000e-06]
# scaled [[0.32335025 0.07346939 0.78038333 1.        ]]
# delta_IL ori [[0.00623368]]
# delta_Vo ori [[0.02642878]]
# delta_IL inverse [[6.180752]]
# delta_Vo inverse [[1.6410913]]
# input_values [6.67000e-04 9.20000e-05 1.60469e+05 1.00000e-06]
# scaled [[0.32335025 0.07346939 0.78038333 1.        ]]
# delta_IL ori [[0.00623368]]
# delta_Vo ori [[0.02642878]]
# delta_IL inverse [[6.180752]]
# delta_Vo inverse [[1.6410913]]
# input_values [1.2150e-03 8.8000e-05 2.6488e+04 9.2300e-07]
# scaled [[0.60152284 0.06938776 0.03604444 0.90632603]]
# delta_IL ori [[0.01497769]]
# delta_Vo ori [[0.00808683]]
# delta_IL inverse [[13.351955]]
# delta_Vo inverse [[0.66053915]]
# input_values [1.0350e-03 4.3000e-05 9.5509e+04 5.8600e-07]
# scaled [[0.51015228 0.02346939 0.41949444 0.49635036]]
# delta_IL ori [[0.00360219]]
# delta_Vo ori [[0.00300412]]
# delta_IL inverse [[4.022599]]
# delta_Vo inverse [[0.38881972]]
# Parents
# [[8.05000e-04 6.20000e-05 1.01201e+05 5.38000e-07]
#  [1.03500e-03 4.30000e-05 9.55090e+04 5.86000e-07]
#  [1.27800e-03 7.80000e-05 1.77355e+05 8.27000e-07]
#  [7.54000e-04 6.70000e-05 1.20247e+05 1.00000e-06]]
# Crossover
# [[8.05000e-04 6.20000e-05 9.55090e+04 5.86000e-07]
#  [1.03500e-03 4.30000e-05 1.77355e+05 8.27000e-07]
#  [1.27800e-03 7.80000e-05 1.20247e+05 1.00000e-06]
#  [7.54000e-04 6.70000e-05 1.01201e+05 5.38000e-07]]
# Mutation
# [[7.39000e-04 3.00000e-05 9.43000e+04 1.00000e-06]
#  [1.07800e-03 2.00000e-04 1.77395e+05 1.78000e-07]
#  [1.33800e-03 4.40000e-05 1.18849e+05 1.78000e-07]
#  [8.72000e-04 3.00000e-05 1.01696e+05 1.78000e-07]]
# Best solution :  [[1.27800e-03 7.80000e-05 1.77355e+05 8.27000e-07]]
# cek
# Best solution fitness :  [[[3.336921]]]
# ceki

# %%
print(best_fitnesses)
# Out:
# [1.567535, 3.4494421, 4.066306, 3.457279, 2.9855154, 2.6228385, 3.457279, 2.4865704, 2.1659145, 2.0778418]

# %%
# Print the best solutions for each generation
print("Best solutions for each generation:")
for i, (solution, fitness) in enumerate(zip(best_solutions, best_fitnesses)):
    print("Generation", i, ":", "Fitness:", fitness)
    print("Solution (L, C, fsw):", solution)
    
    # Calculate additional information for the current solution
    L = solution[0]
    C = solution[1]
    fs = solution[2]
    t_dt = solution[3]
    nearest_C, Vol_C = search_volume_capacitance(C, csv_file_capacitance)
    nearest_L, Vol_L = search_volume_inductance(L, csv_file_inductance)
    
    # Prepare input values for prediction
    input_values = np.array([L, C, fs, t_dt])
    input_values_scaled = np.zeros_like(input_values, dtype=float)
    input_values_scaled[0] = (input_values[0] - L_min) / (L_max - L_min)
    input_values_scaled[1] = (input_values[1] - C_min) / (C_max - C_min)
    input_values_scaled[2] = (input_values[2] - fsw_min) / (fsw_max - fsw_min)
    input_values_scaled[3] = (input_values[3] - t_dt_min) / (t_dt_max - t_dt_min)
    input_values_reshaped = input_values_scaled.reshape((1, -1))
    
    # Make predictions using the model
    # prediction = model.predict(input_values_reshaped, verbose=0)
    # print("Prediction: ", prediction)
    # print("Shape: ", prediction.shape)
    # Delta_IL_percent = prediction[0][0]
    # Delta_Vo_percent = prediction[0][1]
    Delta_IL_percent = model_delta_current.predict(input_values_reshaped, verbose=0)
    Delta_Vo_percent = model_delta_voltage.predict(input_values_reshaped, verbose=0)

    Delta_IL_percent = scaler_y_delta_current.inverse_transform(Delta_IL_percent)
    Delta_Vo_percent = scaler_y_delta_voltage.inverse_transform(Delta_Vo_percent)


    print("Volume L:", Vol_L)
    print("Volume C:", Vol_C)
    print("Delta Vo percent:", Delta_Vo_percent)
    print("Delta Il percent:", Delta_IL_percent)
    print()  # Add a blank line for readability
# Out:
# Best solutions for each generation:
# Generation 0 : Fitness: 1.567535
# Solution (L, C, fsw): [2.e-03 2.e-04 2.e+05 1.e-06]
# Volume L: 2.0828406321502e-06
# Volume C: 6.86e-07
# Delta Vo percent: [[6.3104124]]
# Delta Il percent: [[15.964979]]
#
# Generation 1 : Fitness: 3.4494421
# Solution (L, C, fsw): [1.74500e-03 1.59000e-04 1.33985e+05 1.00000e-06]
# Volume L: 2.0828406321502e-06
# Volume C: 5.289e-06
# Delta Vo percent: [[6.2834945]]
# Delta Il percent: [[5.7287908]]
#
# Generation 2 : Fitness: 4.066306
# Solution (L, C, fsw): [8.87000e-04 4.60000e-05 1.33161e+05 7.93000e-07]
# Volume L: 2.0828406321502e-06
# Volume C: 2.16e-07
# Delta Vo percent: [[0.6105717]]
# Delta Il percent: [[3.3947082]]
#
# Generation 3 : Fitness: 3.457279
# Solution (L, C, fsw): [7.54000e-04 6.70000e-05 1.20247e+05 1.00000e-06]
# Volume L: 2.0828406321502e-06
# Volume C: 4.882e-06
# Delta Vo percent: [[0.8975931]]
# Delta Il percent: [[5.6332984]]
#
# Generation 4 : Fitness: 2.9855154
# Solution (L, C, fsw): [7.39000e-04 1.27000e-04 1.43869e+05 1.00000e-06]
# Volume L: 2.0828406321502e-06
# Volume C: 3.443e-06
# Delta Vo percent: [[3.920022]]
# Delta Il percent: [[9.425028]]
#
# Generation 5 : Fitness: 2.6228385
# Solution (L, C, fsw): [6.40000e-04 3.00000e-05 1.56084e+05 1.00000e-06]
# Volume L: 2.0828406321502e-06
# Volume C: 1.564e-06
# Delta Vo percent: [[2.448179]]
# Delta Il percent: [[4.0182505]]
#
# Generation 6 : Fitness: 3.457279
# Solution (L, C, fsw): [7.54000e-04 6.70000e-05 1.20247e+05 1.00000e-06]
# Volume L: 2.0828406321502e-06
# Volume C: 4.882e-06
# Delta Vo percent: [[0.8975931]]
# Delta Il percent: [[5.6332984]]
#
# Generation 7 : Fitness: 2.4865704
# Solution (L, C, fsw): [1.35400e-03 3.00000e-05 1.68882e+05 1.00000e-06]
# Volume L: 2.0828406321502e-06
# Volume C: 1.564e-06
# Delta Vo percent: [[1.0402105]]
# Delta Il percent: [[1.6581689]]
#
# Generation 8 : Fitness: 2.1659145
# Solution (L, C, fsw): [1.26100e-03 3.00000e-05 1.76568e+05 1.00000e-06]
# Volume L: 2.0828406321502e-06
# Volume C: 1.564e-06
# Delta Vo percent: [[1.2491022]]
# Delta Il percent: [[1.7042407]]
#
# Generation 9 : Fitness: 2.0778418
# Solution (L, C, fsw): [1.89400e-03 1.15000e-04 1.77232e+05 1.00000e-06]
# Volume L: 2.0828406321502e-06
# Volume C: 5.589e-06
# Delta Vo percent: [[1.6077613]]
# Delta Il percent: [[2.2247894]]

# %% [markdown]
# ## Ranking

# %%
# Your additional code snippet for printing and sorting the results
# Define lists to store the results
volume_L_values = []
volume_C_values = []
delta_Vo_values = []
delta_IL_values = []
P_l_s1_values = []
P_l_s2_values = []
P_l_C_values = []
P_l_L_Cu_values = []
P_D_values = []
solutions = []

# Iterate over different generations
for i, (solution, fitness) in enumerate(zip(best_solutions, best_fitnesses)):
    # Calculate volume values and delta Vo for the current solution
    L = solution[0]
    C = solution[1]
    fs = solution[2]
    t_dt = solution[3]
    nearest_C, Vol_C = search_volume_capacitance(C, csv_file_capacitance)
    nearest_L, Vol_L = search_volume_inductance(L, csv_file_inductance)

    input_values = np.array([L, C, fs, t_dt])
    input_values_scaled = np.zeros_like(input_values, dtype=float)
    input_values_scaled[0] = (input_values[0] - L_min) / (L_max - L_min)
    input_values_scaled[1] = (input_values[1] - C_min) / (C_max - C_min)
    input_values_scaled[2] = (input_values[2] - fsw_min) / (fsw_max - fsw_min)
    input_values_scaled[3] = (input_values[3] - t_dt_min) / (t_dt_max - t_dt_min)
    input_values_reshaped = input_values_scaled.reshape((1, -1))

    P_l_s1_ori = model_P_l_s1.predict(input_values_reshaped, verbose=0)
    P_l_s1 = scaler_y_Pl_s1.inverse_transform(P_l_s1_ori)
    P_l_s2 = P_l_s1
    P_l_C = model_P_l_C.predict(input_values_reshaped, verbose=0)
    P_l_L_Cu = model_P_l_L_Cu.predict(input_values_reshaped, verbose=0)
    P_D = model_P_D.predict(input_values_reshaped, verbose=0)
    
    Delta_IL_percent = model_delta_current.predict(input_values_reshaped, verbose = 0)
    Delta_Vo_percent = model_delta_voltage.predict(input_values_reshaped, verbose = 0)

    Delta_IL_percent = scaler_y_delta_current.inverse_transform(Delta_IL_percent)
    Delta_Vo_percent = scaler_y_delta_voltage.inverse_transform(Delta_Vo_percent)


    # prediction = model.predict(input_values_reshaped, verbose=0)
    # Delta_IL_percent = prediction[0][0]
    # Delta_Vo_percent = prediction[0][1]
    # P_l_s1 = prediction[0][2]
    # P_l_s2 = prediction[0][3]
    # P_l_C = prediction[0][4]
    # P_l_L_Cu = prediction[0][5]
    # P_D = prediction[0][6]
    
    # Store the volume values, delta Vo, and solution for sorting
    volume_L_values.append(Vol_L)
    volume_C_values.append(Vol_C)
    delta_Vo_values.append(Delta_Vo_percent)
    delta_IL_values.append(Delta_IL_percent)
    P_l_s1_values.append(P_l_s1)
    P_l_s2_values.append(P_l_s2)
    P_l_C_values.append(P_l_C)
    P_l_L_Cu_values.append(P_l_L_Cu)
    P_D_values.append(P_D)

    solutions.append((solution, fitness, Vol_L, Vol_C, Delta_Vo_percent, Delta_IL_percent, P_l_s1, P_l_s2, P_l_C, P_l_L_Cu, P_D))

# Sort the solutions based on fitness values in ascending order
sorted_solutions = sorted(solutions, key=lambda x: x[1])

# Print the sorted solutions
print("Sorted Solutions:")
for rank, (solution, fitness, vol_L, vol_C, delta_Vo, delta_IL, P_l_s1, P_l_s2, P_l_C, P_l_L_Cu, P_D) in enumerate(sorted_solutions):
    print("Rank:", rank + 1)
    print("Solution (L, C, fsw, t_dt):", solution)
    print("Fitness:", fitness)
    print("Volume L:", vol_L)
    print("Volume C:", vol_C)
    print("Delta Vo:", delta_Vo)
    print("Delta IL:", delta_IL)
    print("P_l_s1: ", P_l_s1)
    print("P_l_s2: ", P_l_s2)
    print("P_l_C: ", P_l_C)
    print("P_l_L_Cu: ", P_l_L_Cu)
    print("P_D: ", P_D)
    print("Losses Total:", P_l_s1 + P_l_s2 + P_l_C + P_l_L_Cu + P_D)
    print()

# Plot the fitness values for each generation
plt.plot(best_outputs)
plt.xlabel("Generation")
plt.ylabel("Fitness")
plt.title("Fitness Progression")
plt.show()
# Out:
# Sorted Solutions:
# Rank: 1
# Solution (L, C, fsw, t_dt): [2.e-03 2.e-04 2.e+05 1.e-06]
# Fitness: 1.567535
# Volume L: 2.0828406321502e-06
# Volume C: 6.86e-07
# Delta Vo: [[6.3104124]]
# Delta IL: [[15.964979]]
# P_l_s1:  [[0.6848769]]
# P_l_s2:  [[0.6848769]]
# P_l_C:  [[7.404231e-07]]
# P_l_L_Cu:  [[0.10054594]]
# P_D:  [[0.09723458]]
# Losses Total: [[1.567535]]
#
# Rank: 2
# Solution (L, C, fsw, t_dt): [1.89400e-03 1.15000e-04 1.77232e+05 1.00000e-06]
# Fitness: 2.0778418
# Volume L: 2.0828406321502e-06
# Volume C: 5.589e-06
# Delta Vo: [[1.6077613]]
# Delta IL: [[2.2247894]]
# P_l_s1:  [[0.88257104]]
# P_l_s2:  [[0.88257104]]
# P_l_C:  [[0.00013625]]
# P_l_L_Cu:  [[0.20301314]]
# P_D:  [[0.10955026]]
# Losses Total: [[2.0778418]]
#
# Rank: 3
# Solution (L, C, fsw, t_dt): [1.26100e-03 3.00000e-05 1.76568e+05 1.00000e-06]
# Fitness: 2.1659145
# Volume L: 2.0828406321502e-06
# Volume C: 1.564e-06
# Delta Vo: [[1.2491022]]
# Delta IL: [[1.7042407]]
# P_l_s1:  [[0.934327]]
# P_l_s2:  [[0.934327]]
# P_l_C:  [[0.00344726]]
# P_l_L_Cu:  [[0.18640852]]
# P_D:  [[0.10740473]]
# Losses Total: [[2.1659145]]
#
# Rank: 4
# Solution (L, C, fsw, t_dt): [1.35400e-03 3.00000e-05 1.68882e+05 1.00000e-06]
# Fitness: 2.4865704
# Volume L: 2.0828406321502e-06
# Volume C: 1.564e-06
# Delta Vo: [[1.0402105]]
# Delta IL: [[1.6581689]]
# P_l_s1:  [[1.0620619]]
# P_l_s2:  [[1.0620619]]
# P_l_C:  [[0.00409203]]
# P_l_L_Cu:  [[0.24597543]]
# P_D:  [[0.11237902]]
# Losses Total: [[2.4865704]]
#
# Rank: 5
# Solution (L, C, fsw, t_dt): [6.40000e-04 3.00000e-05 1.56084e+05 1.00000e-06]
# Fitness: 2.6228385
# Volume L: 2.0828406321502e-06
# Volume C: 1.564e-06
# Delta Vo: [[2.448179]]
# Delta IL: [[4.0182505]]
# P_l_s1:  [[1.1687119]]
# P_l_s2:  [[1.1687119]]
# P_l_C:  [[0.00702068]]
# P_l_L_Cu:  [[0.14811474]]
# P_D:  [[0.13027918]]
# Losses Total: [[2.6228385]]
#
# Rank: 6
# Solution (L, C, fsw, t_dt): [7.39000e-04 1.27000e-04 1.43869e+05 1.00000e-06]
# Fitness: 2.9855154
# Volume L: 2.0828406321502e-06
# Volume C: 3.443e-06
# Delta Vo: [[3.920022]]
# Delta IL: [[9.425028]]
# P_l_s1:  [[1.2861669]]
# P_l_s2:  [[1.2861669]]
# P_l_C:  [[0.00184725]]
# P_l_L_Cu:  [[0.2750472]]
# P_D:  [[0.13628687]]
# Losses Total: [[2.9855154]]
#
# Rank: 7
# Solution (L, C, fsw, t_dt): [1.74500e-03 1.59000e-04 1.33985e+05 1.00000e-06]
# Fitness: 3.4494421
# Volume L: 2.0828406321502e-06
# Volume C: 5.289e-06
# Delta Vo: [[6.2834945]]
# Delta IL: [[5.7287908]]
# P_l_s1:  [[1.3893249]]
# P_l_s2:  [[1.3893249]]
# P_l_C:  [[0.00320339]]
# P_l_L_Cu:  [[0.53008854]]
# P_D:  [[0.13750061]]
# Losses Total: [[3.4494421]]
#
# Rank: 8
# Solution (L, C, fsw, t_dt): [7.54000e-04 6.70000e-05 1.20247e+05 1.00000e-06]
# Fitness: 3.457279
# Volume L: 2.0828406321502e-06
# Volume C: 4.882e-06
# Delta Vo: [[0.8975931]]
# Delta IL: [[5.6332984]]
# P_l_s1:  [[1.4695678]]
# P_l_s2:  [[1.4695678]]
# P_l_C:  [[0.00598888]]
# P_l_L_Cu:  [[0.37194633]]
# P_D:  [[0.14020833]]
# Losses Total: [[3.457279]]
#
# Rank: 9
# Solution (L, C, fsw, t_dt): [7.54000e-04 6.70000e-05 1.20247e+05 1.00000e-06]
# Fitness: 3.457279
# Volume L: 2.0828406321502e-06
# Volume C: 4.882e-06
# Delta Vo: [[0.8975931]]
# Delta IL: [[5.6332984]]
# P_l_s1:  [[1.4695678]]
# P_l_s2:  [[1.4695678]]
# P_l_C:  [[0.00598888]]
# P_l_L_Cu:  [[0.37194633]]
# P_D:  [[0.14020833]]
# Losses Total: [[3.457279]]
#
# Rank: 10
# Solution (L, C, fsw, t_dt): [8.87000e-04 4.60000e-05 1.33161e+05 7.93000e-07]
# Fitness: 4.066306
# Volume L: 2.0828406321502e-06
# Volume C: 2.16e-07
# Delta Vo: [[0.6105717]]
# Delta IL: [[3.3947082]]
# P_l_s1:  [[1.7312303]]
# P_l_s2:  [[1.7312303]]
# P_l_C:  [[0.01228159]]
# P_l_L_Cu:  [[0.45310357]]
# P_D:  [[0.13846062]]
# Losses Total: [[4.066306]]

# %% [markdown]
# ## Ranking with constraint

# %%
# Your additional code snippet for printing and sorting the results
# Define lists to store the results
volume_L_values = []
volume_C_values = []
delta_Vo_values = []
delta_IL_values = []
P_l_s1_values = []
P_l_s2_values = []
P_l_C_values = []
P_l_L_Cu_values = []
P_D_values = []
solutions = []

# Iterate over different generations
for i, (solution, fitness) in enumerate(zip(best_solutions, best_fitnesses)):
    # Calculate volume values and delta Vo for the current solution
    L = solution[0]
    C = solution[1]
    fs = solution[2]
    t_dt = solution[3]
    nearest_C, Vol_C = search_volume_capacitance(C, csv_file_capacitance)
    nearest_L, Vol_L = search_volume_inductance(L, csv_file_inductance)

    input_values = np.array([L, C, fs, t_dt])
    input_values_scaled = np.zeros_like(input_values, dtype=float)
    input_values_scaled[0] = (input_values[0] - L_min) / (L_max - L_min)
    input_values_scaled[1] = (input_values[1] - C_min) / (C_max - C_min)
    input_values_scaled[2] = (input_values[2] - fsw_min) / (fsw_max - fsw_min)
    input_values_scaled[3] = (input_values[3] - t_dt_min) / (t_dt_max - t_dt_min)
    input_values_reshaped = input_values_scaled.reshape((1, -1))

    P_l_s1_ori = model_P_l_s1.predict(input_values_reshaped, verbose=0)
    P_l_s1 = scaler_y_Pl_s1.inverse_transform(P_l_s1_ori)
    P_l_s2 = P_l_s1
    P_l_C = model_P_l_C.predict(input_values_reshaped, verbose=0)
    P_l_L_Cu = model_P_l_L_Cu.predict(input_values_reshaped, verbose=0)
    P_D = model_P_D.predict(input_values_reshaped, verbose=0)
    Delta_IL_percent = model_delta_current.predict(input_values_reshaped, verbose = 0)
    Delta_Vo_percent = model_delta_voltage.predict(input_values_reshaped, verbose = 0)

    Delta_IL_percent = scaler_y_delta_current.inverse_transform(Delta_IL_percent)
    Delta_Vo_percent = scaler_y_delta_voltage.inverse_transform(Delta_Vo_percent)


    # prediction = model.predict(input_values_reshaped, verbose=0)
    # Delta_IL_percent = prediction[0][0]
    # Delta_Vo_percent = prediction[0][1]
    # P_l_s1 = prediction[0][2]
    # P_l_s2 = prediction[0][3]
    # P_l_C = prediction[0][4]
    # P_l_L_Cu = prediction[0][5]
    # P_D = prediction[0][6]

    # Check constraints for the current solution
    if check_constraints(solution):
        # Store the volume values, delta Vo, and solution for sorting
        volume_L_values.append(Vol_L)
        volume_C_values.append(Vol_C)
        delta_Vo_values.append(Delta_Vo_percent)
        delta_IL_values.append(Delta_IL_percent)
        P_l_s1_values.append(P_l_s1)
        P_l_s2_values.append(P_l_s2)
        P_l_C_values.append(P_l_C)
        P_l_L_Cu_values.append(P_l_L_Cu)
        P_D_values.append(P_D)

        solutions.append((solution, fitness, Vol_L, Vol_C, Delta_Vo_percent, Delta_IL_percent, P_l_s1, P_l_s2, P_l_C, P_l_L_Cu, P_D))

# Sort the solutions based on fitness values in ascending order
sorted_solutions = sorted(solutions, key=lambda x: x[1])

# Print the sorted solutions
print("Sorted Solutions:")
for rank, (solution, fitness, vol_L, vol_C, delta_Vo, delta_IL, P_l_s1, P_l_s2, P_l_C, P_l_L_Cu, P_D) in enumerate(sorted_solutions):
    print("Rank:", rank + 1)
    print("Solution (L, C, fsw, t_dt):", solution)
    print("Fitness:", fitness)
    print("Volume L:", vol_L)
    print("Volume C:", vol_C)
    print("Delta Vo:", delta_Vo)
    print("Delta IL:", delta_IL)
    print("P_l_s1: ", P_l_s1)
    print("P_l_s2: ", P_l_s2)
    print("P_l_C: ", P_l_C)
    print("P_l_L_Cu: ", P_l_L_Cu)
    print("P_D: ", P_D)
    print("Losses Total:", P_l_s1 + P_l_s2 + P_l_C + P_l_L_Cu + P_D)
    print()

# Plot the fitness values for each generation
plt.plot(best_outputs)
plt.xlabel("Generation")
plt.ylabel("Fitness")
plt.title("Fitness Progression")
plt.show()
# Out:
# input_values [2.e-03 2.e-04 2.e+05 1.e-06]
# scaled [[1.         0.18367347 1.         1.        ]]
# delta_IL ori [[0.01816381]]
# delta_Vo ori [[0.11377188]]
# delta_IL inverse [[15.964979]]
# delta_Vo inverse [[6.3104124]]
# input_values [1.74500e-03 1.59000e-04 1.33985e+05 1.00000e-06]
# scaled [[0.87055838 0.14183673 0.63325    1.        ]]
# delta_IL ori [[0.00568259]]
# delta_Vo ori [[0.11326836]]
# delta_IL inverse [[5.7287908]]
# delta_Vo inverse [[6.2834945]]
# input_values [8.87000e-04 4.60000e-05 1.33161e+05 7.93000e-07]
# scaled [[0.43502538 0.02653061 0.62867222 0.74817518]]
# delta_IL ori [[0.00283659]]
# delta_Vo ori [[0.00715215]]
# delta_IL inverse [[3.3947082]]
# delta_Vo inverse [[0.6105717]]
# input_values [7.54000e-04 6.70000e-05 1.20247e+05 1.00000e-06]
# scaled [[0.36751269 0.04795918 0.55692778 1.        ]]
# delta_IL ori [[0.00556616]]
# delta_Vo ori [[0.0125211]]
# delta_IL inverse [[5.6332984]]
# delta_Vo inverse [[0.8975931]]
# input_values [7.39000e-04 1.27000e-04 1.43869e+05 1.00000e-06]
# scaled [[0.35989848 0.10918367 0.68816111 1.        ]]
# delta_IL ori [[0.0101895]]
# delta_Vo ori [[0.06905786]]
# delta_IL inverse [[9.425028]]
# delta_Vo inverse [[3.920022]]
# input_values [6.40000e-04 3.00000e-05 1.56084e+05 1.00000e-06]
# scaled [[0.30964467 0.01020408 0.75602222 1.        ]]
# delta_IL ori [[0.00359689]]
# delta_Vo ori [[0.04152595]]
# delta_IL inverse [[4.0182505]]
# delta_Vo inverse [[2.448179]]
# input_values [7.54000e-04 6.70000e-05 1.20247e+05 1.00000e-06]
# scaled [[0.36751269 0.04795918 0.55692778 1.        ]]
# delta_IL ori [[0.00556616]]
# delta_Vo ori [[0.0125211]]
# delta_IL inverse [[5.6332984]]
# delta_Vo inverse [[0.8975931]]
# input_values [1.35400e-03 3.00000e-05 1.68882e+05 1.00000e-06]
# scaled [[0.67208122 0.01020408 0.82712222 1.        ]]
# delta_IL ori [[0.00071919]]
# delta_Vo ori [[0.01518886]]
# delta_IL inverse [[1.6581689]]
# delta_Vo inverse [[1.0402105]]
# input_values [1.26100e-03 3.00000e-05 1.76568e+05 1.00000e-06]
# scaled [[0.6248731  0.01020408 0.86982222 1.        ]]
# delta_IL ori [[0.00077537]]
# delta_Vo ori [[0.01909634]]
# delta_IL inverse [[1.7042407]]
# delta_Vo inverse [[1.2491022]]
# input_values [1.89400e-03 1.15000e-04 1.77232e+05 1.00000e-06]
# scaled [[0.94619289 0.09693878 0.87351111 1.        ]]
# delta_IL ori [[0.00141008]]
# delta_Vo ori [[0.02580532]]
# delta_IL inverse [[2.2247894]]
# delta_Vo inverse [[1.6077613]]
# Sorted Solutions:
# Rank: 1
# Solution (L, C, fsw, t_dt): [7.54000e-04 6.70000e-05 1.20247e+05 1.00000e-06]
# Fitness: 3.457279
# Volume L: 2.0828406321502e-06
# Volume C: 4.882e-06
# Delta Vo: [[0.8975931]]
# Delta IL: [[5.6332984]]
# P_l_s1:  [[1.4695678]]
# P_l_s2:  [[1.4695678]]
# P_l_C:  [[0.00598888]]
# P_l_L_Cu:  [[0.37194633]]
# P_D:  [[0.14020833]]
# Losses Total: [[3.457279]]
#
# Rank: 2
# Solution (L, C, fsw, t_dt): [7.54000e-04 6.70000e-05 1.20247e+05 1.00000e-06]
# Fitness: 3.457279
# Volume L: 2.0828406321502e-06
# Volume C: 4.882e-06
# Delta Vo: [[0.8975931]]
# Delta IL: [[5.6332984]]
# P_l_s1:  [[1.4695678]]
# P_l_s2:  [[1.4695678]]
# P_l_C:  [[0.00598888]]
# P_l_L_Cu:  [[0.37194633]]
# P_D:  [[0.14020833]]
# Losses Total: [[3.457279]]
#
# Rank: 3
# Solution (L, C, fsw, t_dt): [8.87000e-04 4.60000e-05 1.33161e+05 7.93000e-07]
# Fitness: 4.066306
# Volume L: 2.0828406321502e-06
# Volume C: 2.16e-07
# Delta Vo: [[0.6105717]]
# Delta IL: [[3.3947082]]
# P_l_s1:  [[1.7312303]]
# P_l_s2:  [[1.7312303]]
# P_l_C:  [[0.01228159]]
# P_l_L_Cu:  [[0.45310357]]
# P_D:  [[0.13846062]]
# Losses Total: [[4.066306]]
